# %%
##  load all the dependencies and files needed
# %run loadpackagesandfiles.ipynb

# %%
##  create a graph of the loaded data, 
## gives access to variable FG which is the (directed) graph displayed below 
## (if it is not shown the plot can be activated by uncommenting in buildgraph.ipynb file)

# %run buildgraph.ipynb
# %run EnviromentReport.ipynb

#%run locktest.ipynb
# Out:
# found restriction 8.7
# <__main__.Lock object at 0x000001E62F27C470>
# <__main__.Lock object at 0x000001E62F27C320>
# <__main__.Lock object at 0x000001E62F27C240>
# <__main__.Lock object at 0x000001E62F27C400>
# <__main__.Lock object at 0x000001E62F27C2B0>
# <__main__.Lock object at 0x000001E62F27C390>

# %%
## obtain the paths possible sorted by length 
## (these paths are classes containing node keys and path lengths (in meter?))
# %run get_paths.ipynb
#%run testpaths.ipynb

# %%
print(len(ordered_paths))
#ordered_paths[8].plot(FG, save=True)
# Out:
# 54

# %%
# %run Vessels-FleetScenario-StandardVessels-NS-low.ipynb

# %%
def start(env, vessel):
    while True:
        
        vessel.log_entry("Start sailing", env.now, "", vessel.geometry)
        yield from vessel.move()
        vessel.log_entry("Stop sailing", env.now, "", vessel.geometry)
        vessel.report()
        if vessel.geometry == nx.get_node_attributes(FG, "geometry")[vessel.route[-1]]:
            break

# %%
# Add graph to environment
env.FG = FG

env.paths = {}
env.enviromental_report = EnviromentReport()
# 24hours
SIM_TIME = 60 * 60  * 24 * 31
vessels = []

def pois(t):
    hour = int((t%(24*3600))/3600)
    average_on_hour = [4,4,4,4,4,4,4,4,3,4,4,4,4,4,4,4,4,4,4,4,3,4,4,4]
    number_of_boats_this_hour = np.random.normal(average_on_hour[hour])
    if number_of_boats_this_hour == 0:
        return 0
    return 60 * 60 / number_of_boats_this_hour

def setup(env, distribution):
    # initial vessel
    i = 1
    vessel = init_random_vessel(ordered_paths, "ship-{}".format(i))
    vessel.env = env
    vessel.geometry = nx.get_node_attributes(FG, "geometry")[vessel.route[0]]
    env.process(start(env, vessel))
    vessels.append(vessel)

    while True:
        #break
        # timeout before next ship is released
        i += 1
        yield env.timeout(distribution(env.now))
        vessel = init_random_vessel(ordered_paths, "ship-{}".format(i))
        vessel.env = env
        vessel.geometry = nx.get_node_attributes(FG, "geometry")[vessel.route[0]]
        env.process(start(env, vessel))
        vessels.append(vessel)
         
        

        
env.process(setup(env, pois))

env.crossover_points = {182: ((184, 394,154,155,156,216,217, 218), (164, 134,133, 132,73,72,71,402,401)),
                        2: ((218,217,216,156,155,154,394,184), (401, 402,71,72,73,132,133,134,164)),
                        141: ((140,139,179,178,379), (363, 364, 365, 317, 403)),
                        382: ((379,178,179,139,140), (403,317,365,364,363)),
                        273:((222,221,220,279), (272, 209, 208, 210)),
                        278: ((279,220,221,222), (210,208, 209,272))                        
}

env.epoch = datetime.datetime.now()


env.run(until=SIM_TIME)

# EnviromentReport notebook for plot calculations
env.enviromental_report.plot_energy_usage()
env.enviromental_report.plot_path_usage()
env.enviromental_report.plot_co2_emission()
env.enviromental_report.plot_co2_emission_km_load()
env.enviromental_report.plot_transported_weight_corridor()
# Out:
# Queues:  Kreekraklock 0 0 1.5778447637594606
# Queues:  Kreekraklock 0 0 2.0939954925811537
# Queues:  Kreekraklock 0 0 2.689264170728684
# Queues:  Kreekraklock 0 0 3.3541798000547183
# Queues:  Krammerlock 0 0 3.3629147577422733
# Queues:  Kreekraklock 0 0 3.926412487825417
# Queues:  Kreekraklock 0 0 4.156142612473825
# Queues:  Krammerlock 0 0 4.162378413257746
# Queues:  Kreekraklock 0 0 4.452775940616957
# Queues:  Hansweertlock 0 0 4.695484343411626
# Queues:  Krammerlock 0 0 5.220749750753252
# Queues:  Krammerlock 0 0 5.763585221232815
# Queues:  Krammerlock 0 0 6.283545905314692
# Queues:  Kreekraklock 0 0 6.348637654959437
# Queues:  Kreekraklock 0 0 6.4960917058816925
# Queues:  Hansweertlock 0 0 7.044408721777049
# Queues:  Hansweertlock 0 0 7.058572267649396
# Queues:  Kreekraklock 0 0 7.144663114240635
# Queues:  Kreekraklock 0 0 7.22992264219887
# Queues:  Hansweertlock 0 0 7.266179799253001
# Queues:  Hansweertlock 0 0 7.5173743736902905
# Queues:  Krammerlock 0 0 7.579839034922216
# Queues:  Kreekraklock 0 0 7.58626071386392
# Queues:  Kreekraklock 0 0 7.648784899953867
# Queues:  Kreekraklock 0 0 7.980555054461682
# Queues:  Kreekraklock 0 0 8.337015989517564
# Queues:  Kreekraklock 0 0 8.39723665427963
# Queues:  Hansweertlock 0 0 8.564624735338198
# Queues:  Kreekraklock 0 1 8.574042950000914
# Queues:  Kreekraklock 0 0 9.113264266595408
# Queues:  Kreekraklock 0 0 9.113277251562499
# Queues:  Krammerlock 0 0 9.194215318478939
# Queues:  Hansweertlock 0 0 9.242822111918718
# Queues:  Hansweertlock 0 0 9.482968508766115
# Queues:  Krammerlock 0 0 9.677100381625262
# Queues:  Kreekraklock 0 0 9.763736697454155
# Queues:  Krammerlock 0 0 10.1954300799543
# Queues:  Kreekraklock 0 0 10.433619204841644
# Queues:  Hansweertlock 0 0 11.559138689287371
# Queues:  Kreekraklock 0 0 11.769427314450269
# Queues:  Hansweertlock 0 0 11.823742506203928
# Queues:  Krammerlock 0 0 12.096181174250978
# Queues:  Kreekraklock 0 0 12.12362428622402
# Queues:  Hansweertlock 0 0 12.217954879136194
# Queues:  Kreekraklock 0 0 12.278947669693416
# Queues:  Kreekraklock 0 0 12.380819109700543
# Queues:  Kreekraklock 0 0 12.552379881939816
# Queues:  Kreekraklock 0 0 13.052304014861468
# Queues:  Krammerlock 0 0 13.165972328663834
# Queues:  Kreekraklock 0 0 13.249209314954198
# Queues:  Hansweertlock 0 0 13.41452312694766
# Queues:  Krammerlock 0 0 13.994520757845082
# Queues:  Kreekraklock 0 0 14.048938819360345
# Queues:  Krammerlock 0 0 14.367437339478267
# Queues:  Kreekraklock 0 0 14.540154589186946
# Queues:  Kreekraklock 0 0 14.680184284811741
# Queues:  Kreekraklock 0 0 15.177339025017806
# Queues:  Hansweertlock 0 0 15.239834927036336
# Queues:  Kreekraklock 0 0 15.491142975425143
# Queues:  Kreekraklock 0 0 15.617815647516304
# Queues:  Hansweertlock 0 0 15.999446215761703
# Queues:  Hansweertlock 0 0 16.06216618305549
# Queues:  Krammerlock 0 0 16.197416010370304
# Queues:  Krammerlock 0 0 16.56554448512491
# Queues:  Hansweertlock 0 0 16.637309258717185
# Queues:  Kreekraklock 0 0 16.706475760934175
# Queues:  Kreekraklock 0 0 16.875834643147364
# Queues:  Hansweertlock 0 0 16.982048468094455
# Queues:  Kreekraklock 0 0 17.58630139833152
# Queues:  Hansweertlock 0 0 17.65058507517621
# Queues:  Kreekraklock 0 0 17.688953091881732
# Queues:  Kreekraklock 0 0 17.7441611870359
# Queues:  Krammerlock 0 0 18.005147997575893
# Queues:  Kreekraklock 0 0 18.040858197433913
# Queues:  Kreekraklock 0 0 18.45129643754716
# Queues:  Hansweertlock 0 0 18.53736904765565
# Queues:  Kreekraklock 0 0 18.855886216726347
# Queues:  Hansweertlock 0 0 19.009569950092317
# Queues:  Krammerlock 0 0 19.129002226559653
# Queues:  Krammerlock 0 0 19.135955662590074
# Queues:  Krammerlock 0 0 19.48069487196734
# Queues:  Krammerlock 0 0 19.937731873810048
# Queues:  Kreekraklock 0 0 20.065522390581553
# Queues:  Krammerlock 0 0 20.35263381040057
# Queues:  Krammerlock 0 0 20.551480255294138
# Queues:  Hansweertlock 0 0 20.63302549584741
# Queues:  Kreekraklock 0 0 20.95516708798576
# Queues:  Krammerlock 0 0 21.16929595802727
# Queues:  Hansweertlock 0 0 21.82161176649702
# Queues:  Kreekraklock 0 0 22.03803231029656
# Queues:  Kreekraklock 0 0 22.27553145942023
# Queues:  Kreekraklock 0 0 22.358747720523375
# Queues:  Kreekraklock 0 0 22.550566679317704
# Queues:  Hansweertlock 0 0 22.559062606364602
# Queues:  Krammerlock 0 0 22.580623141546976
# Queues:  Kreekraklock 0 0 22.641814350313318
# Queues:  Hansweertlock 0 0 22.906144321182026
# Queues:  Kreekraklock 0 0 23.03885636316082
# Queues:  Kreekraklock 0 0 23.042309612965802
# Queues:  Kreekraklock 0 0 23.162063370705603
# Queues:  Hansweertlock 0 0 23.290677779825852
# Queues:  Kreekraklock 0 0 23.463720513417414
# Queues:  Kreekraklock 0 0 23.818594820797465
# Queues:  Kreekraklock 0 0 24.103405939002776
# Queues:  Krammerlock 0 0 24.612486627081505
# Queues:  Kreekraklock 0 0 25.37082659733904
# Queues:  Kreekraklock 0 0 25.99759899212402
# Queues:  Krammerlock 0 0 26.041153803168925
# Queues:  Kreekraklock 0 0 26.232961977148236
# Queues:  Kreekraklock 0 0 26.337313425262067
# Queues:  Krammerlock 0 0 26.426118827202547
# Queues:  Hansweertlock 0 0 26.483888183057687
# Queues:  Hansweertlock 0 0 26.814757006964896
# Queues:  Krammerlock 0 0 26.819060019199046
# Queues:  Krammerlock 0 0 27.41887530739521
# Queues:  Kreekraklock 0 0 27.45738487275577
# Queues:  Hansweertlock 0 0 27.566541793394304
# Queues:  Kreekraklock 0 0 27.594867977871257
# Queues:  Kreekraklock 0 0 27.978419106904052
# Queues:  Hansweertlock 0 0 28.403518585677638
# Queues:  Kreekraklock 0 0 28.407571787810884
# Queues:  Kreekraklock 0 0 28.704889962507742
# Queues:  Hansweertlock 0 0 28.73376334310629
# Queues:  Kreekraklock 0 0 28.82568996867567
# Queues:  Kreekraklock 0 0 28.90986045490157
# Queues:  Krammerlock 0 0 29.135283176859467
# Queues:  Kreekraklock 0 0 29.364480302478707
# Queues:  Kreekraklock 0 0 29.57625449638579
# Queues:  Kreekraklock 0 0 29.662830056142933
# Queues:  Hansweertlock 0 0 30.145502114735848
# Queues:  Krammerlock 0 0 30.19558995175098
# Queues:  Hansweertlock 0 0 30.315069161786848
# Queues:  Kreekraklock 0 0 30.507673004824603
# Queues:  Krammerlock 0 0 30.557637706534837
# Queues:  Kreekraklock 0 0 30.580782766563992
# Queues:  Krammerlock 0 0 30.71756315157157
# Queues:  Kreekraklock 0 0 30.71761440220621
# Queues:  Krammerlock 0 0 30.794218138198993
# Queues:  Krammerlock 0 1 30.8899466911448
# Queues:  Kreekraklock 0 0 31.01872297368789
# Queues:  Krammerlock 0 0 31.16883165621721
# Queues:  Krammerlock 0 0 31.82685000372418
# Queues:  Kreekraklock 0 0 32.053338445629905
# Queues:  Krammerlock 0 0 32.09817062513182
# Queues:  Hansweertlock 0 0 32.32978543932948
# Queues:  Krammerlock 0 0 33.07062726111248
# Queues:  Hansweertlock 0 0 33.091783806142615
# Queues:  Hansweertlock 0 0 33.12133313105944
# Queues:  Hansweertlock 0 0 33.24505874599369
# Queues:  Krammerlock 0 0 33.450763243871116
# Queues:  Hansweertlock 0 0 33.96141647619371
# Queues:  Hansweertlock 0 0 34.27702099406814
# Queues:  Krammerlock 0 0 34.29184964864623
# Queues:  Krammerlock 0 0 34.518711789706074
# Queues:  Hansweertlock 0 0 34.51945954366155
# Queues:  Krammerlock 0 0 34.7242638811325
# Queues:  Hansweertlock 0 0 34.727697812856796
# Queues:  Krammerlock 0 0 34.76516750788717
# Queues:  Kreekraklock 0 0 34.870571840169134
# Queues:  Kreekraklock 0 0 35.047515561734805
# Queues:  Kreekraklock 0 0 35.67147132300087
# Queues:  Hansweertlock 0 0 35.86568904482922
# Queues:  Hansweertlock 0 0 36.02990346771651
# Queues:  Krammerlock 0 0 36.121799974345585
# Queues:  Krammerlock 0 0 36.396798544751405
# Queues:  Krammerlock 0 0 36.531312684833615
# Queues:  Kreekraklock 0 0 36.63362445047249
# Queues:  Kreekraklock 0 0 36.830466806748035
# Queues:  Krammerlock 0 0 37.07868032068727
# Queues:  Hansweertlock 0 0 37.17014653140442
# Queues:  Kreekraklock 0 0 37.336034142365186
# Queues:  Hansweertlock 0 0 37.416873421069866
# Queues:  Hansweertlock 0 0 37.86258677429104
# Queues:  Krammerlock 0 0 37.878658986746935
# Queues:  Krammerlock 0 0 37.91919205112952
# Queues:  Kreekraklock 0 0 37.95958853559324
# Queues:  Hansweertlock 0 0 38.247893507066685
# Queues:  Hansweertlock 0 0 38.2778996028462
# Queues:  Krammerlock 0 0 38.30107111338693
# Queues:  Hansweertlock 0 0 38.476464040233466
# Queues:  Kreekraklock 0 0 38.535363939754646
# Queues:  Kreekraklock 0 0 38.898531498713425
# Queues:  Kreekraklock 0 0 38.907242813395904
# Queues:  Kreekraklock 0 0 39.10645119235064
# Queues:  Hansweertlock 0 0 39.16083987255861
# Queues:  Kreekraklock 0 1 39.210447521133354
# Queues:  Kreekraklock 0 1 39.261164384324026
# Queues:  Kreekraklock 0 0 39.3250235398588
# Queues:  Kreekraklock 0 0 40.04573128365719
# Queues:  Hansweertlock 0 0 40.19088750101213
# Queues:  Hansweertlock 0 0 40.273856117017395
# Queues:  Hansweertlock 0 0 40.42255530527224
# Queues:  Krammerlock 0 0 41.013206577606255
# Queues:  Krammerlock 0 0 41.26923985555434
# Queues:  Hansweertlock 0 0 41.598042274280225
# Queues:  Hansweertlock 0 0 41.74619355086537
# Queues:  Kreekraklock 0 0 41.884662377912235
# Queues:  Kreekraklock 0 0 42.124976533485025
# Queues:  Kreekraklock 0 0 42.55665524625631
# Queues:  Krammerlock 0 0 42.587055206401466
# Queues:  Kreekraklock 0 0 42.6721866757063
# Queues:  Kreekraklock 0 0 42.84236497003159
# Queues:  Kreekraklock 0 0 42.91279078933651
# Queues:  Krammerlock 0 0 42.96947043794559
# Queues:  Kreekraklock 0 0 43.27053054392762
# Queues:  Krammerlock 0 0 43.719269740385315
# Queues:  Hansweertlock 0 0 43.961849395491726
# Queues:  Kreekraklock 0 0 44.37968670784582
# Queues:  Krammerlock 0 0 44.51837825106994
# Queues:  Kreekraklock 0 0 44.585063164102706
# Queues:  Krammerlock 0 0 44.630548242375994
# Queues:  Kreekraklock 0 0 44.646255902620304
# Queues:  Krammerlock 0 0 44.662349989628765
# Queues:  Hansweertlock 0 0 45.05872028739724
# Queues:  Kreekraklock 0 0 45.422278038594676
# Queues:  Hansweertlock 0 0 45.598997625670584
# Queues:  Kreekraklock 0 0 45.78652852620687
# Queues:  Krammerlock 0 0 46.1095637302999
# Queues:  Kreekraklock 0 0 46.15631897891312
# Queues:  Hansweertlock 0 0 46.306438493934756
# Queues:  Kreekraklock 0 0 46.42107331545781
# Queues:  Hansweertlock 0 0 46.54685590747961
# Queues:  Krammerlock 0 0 46.58583901952987
# Queues:  Kreekraklock 0 0 46.79733220207218
# Queues:  Kreekraklock 0 0 46.85882558069682
# Queues:  Hansweertlock 0 0 47.01701405551665
# Queues:  Hansweertlock 0 0 47.21098779100733
# Queues:  Krammerlock 0 0 47.943074978907866
# Queues:  Hansweertlock 0 0 48.01690022177465
# Queues:  Kreekraklock 0 0 48.05970873632899
# Queues:  Kreekraklock 0 0 48.47793170865002
# Queues:  Kreekraklock 0 0 48.57797043972389
# Queues:  Hansweertlock 0 0 48.80217327023728
# Queues:  Hansweertlock 0 0 48.8616684123088
# Queues:  Krammerlock 0 0 49.045502311352514
# Queues:  Kreekraklock 0 0 49.23567067062374
# Queues:  Hansweertlock 0 0 49.27844855946726
# Queues:  Kreekraklock 0 0 49.35525462330683
# Queues:  Kreekraklock 0 0 49.467406375136
# Queues:  Hansweertlock 0 0 49.597727039408205
# Queues:  Hansweertlock 0 0 49.70896045415596
# Queues:  Kreekraklock 0 0 49.787139328795305
# Queues:  Kreekraklock 0 0 49.809814081442916
# Queues:  Kreekraklock 0 1 50.02179327090206
# Queues:  Kreekraklock 0 0 50.24950948593427
# Queues:  Kreekraklock 0 0 50.63307214921295
# Queues:  Krammerlock 0 0 51.33665547990825
# Queues:  Krammerlock 0 0 51.372768240829416
# Queues:  Kreekraklock 0 0 51.43112992400534
# Queues:  Krammerlock 0 0 51.545282461147835
# Queues:  Krammerlock 0 0 51.626981482848365
# Queues:  Kreekraklock 0 0 51.76658097315503
# Queues:  Krammerlock 0 1 51.82006203123461
# Queues:  Kreekraklock 0 0 52.313889738106994
# Queues:  Krammerlock 0 0 52.660062852639115
# Queues:  Krammerlock 0 0 52.859981812333245
# Queues:  Kreekraklock 0 0 53.05433403342579
# Queues:  Kreekraklock 0 0 53.11718986692937
# Queues:  Kreekraklock 0 0 53.20336355307825
# Queues:  Kreekraklock 0 0 53.34746440211263
# Queues:  Krammerlock 0 0 53.39277594544806
# Queues:  Hansweertlock 0 0 54.02926501984564
# Queues:  Kreekraklock 0 0 54.225386357155614
# Queues:  Kreekraklock 0 0 54.30898944911119
# Queues:  Hansweertlock 0 0 55.014726918526996
# Queues:  Hansweertlock 0 0 55.092151528362706
# Queues:  Hansweertlock 0 0 55.164569479891824
# Queues:  Kreekraklock 0 0 55.263552063971126
# Queues:  Kreekraklock 0 0 55.72338387064913
# Queues:  Kreekraklock 0 0 56.01018126733535
# Queues:  Kreekraklock 0 0 56.130439384497144
# Queues:  Kreekraklock 0 0 56.181878777357554
# Queues:  Kreekraklock 0 1 56.328192381943175
# Queues:  Kreekraklock 0 0 56.76310374051579
# Queues:  Kreekraklock 0 0 57.01595880707958
# Queues:  Kreekraklock 0 0 57.40036780528406
# Queues:  Kreekraklock 0 0 57.72379541911912
# Queues:  Kreekraklock 0 0 58.16440025847672
# Queues:  Kreekraklock 0 0 58.77832086298429
# Queues:  Kreekraklock 0 0 58.81990743493593
# Queues:  Kreekraklock 0 0 59.1490725092909
# Queues:  Kreekraklock 0 0 59.35259186801256
# Queues:  Hansweertlock 0 0 59.99099885382508
# Queues:  Hansweertlock 0 0 60.74555017609751
# Queues:  Hansweertlock 0 0 60.76301589138106
# Queues:  Krammerlock 0 0 60.77017550553373
# Queues:  Kreekraklock 0 0 60.918819017669804
# Queues:  Kreekraklock 0 0 61.73490169884357
# Queues:  Krammerlock 0 0 61.782591904512735
# Queues:  Kreekraklock 0 0 61.82067436604383
# Queues:  Kreekraklock 0 0 62.746072510466114
# Queues:  Hansweertlock 0 0 62.78237603481312
# Queues:  Krammerlock 0 0 62.875353545335706
# Queues:  Kreekraklock 0 0 63.050828651356326
# Queues:  Krammerlock 0 0 63.18940856598268
# Queues:  Kreekraklock 0 0 63.20908737118237
# Queues:  Krammerlock 0 0 63.30157166855372
# Queues:  Krammerlock 0 0 63.75311782936946
# Queues:  Kreekraklock 0 0 63.7683194341274
# Queues:  Kreekraklock 0 0 63.89599146741489
# Queues:  Kreekraklock 0 0 64.2358551120035
# Queues:  Krammerlock 0 0 64.54059908213736
# Queues:  Hansweertlock 0 0 64.67344054704448
# Queues:  Hansweertlock 0 0 64.75879961525024
# Queues:  Krammerlock 0 0 64.78280602906615
# Queues:  Hansweertlock 0 0 64.89853903225297
# Queues:  Krammerlock 0 0 64.90432314493576
# Queues:  Kreekraklock 0 0 65.03947458528428
# Queues:  Kreekraklock 0 0 65.12575777150879
# Queues:  Krammerlock 0 0 65.20876870941474
# Queues:  Hansweertlock 0 0 65.7686418587127
# Queues:  Hansweertlock 0 0 65.92290240110826
# Queues:  Hansweertlock 0 0 66.42473307230135
# Queues:  Hansweertlock 0 0 66.44572736930684
# Queues:  Kreekraklock 0 0 66.7639235218166
# Queues:  Krammerlock 0 0 66.79628769484962
# Queues:  Hansweertlock 0 0 66.96089527031152
# Queues:  Krammerlock 0 0 67.32493170685458
# Queues:  Kreekraklock 0 0 67.32625364260758
# Queues:  Kreekraklock 0 0 67.43643013098644
# Queues:  Hansweertlock 0 0 67.80051699932743
# Queues:  Kreekraklock 0 0 68.00065961140051
# Queues:  Krammerlock 0 0 68.0416420736891
# Queues:  Krammerlock 0 0 68.41230594036722
# Queues:  Kreekraklock 0 0 68.48548734181584
# Queues:  Kreekraklock 0 0 68.55377093779816
# Queues:  Krammerlock 0 0 68.55384852129009
# Queues:  Krammerlock 0 0 68.5844590802363
# Queues:  Hansweertlock 0 0 68.63398641528617
# Queues:  Hansweertlock 0 0 68.7688559832661
# Queues:  Hansweertlock 0 0 68.99548012776484
# Queues:  Krammerlock 0 0 69.28545638904399
# Queues:  Krammerlock 0 0 69.7262083408511
# Queues:  Hansweertlock 0 0 69.87349601276793
# Queues:  Kreekraklock 0 0 69.9049427066704
# Queues:  Kreekraklock 0 0 70.2797330941713
# Queues:  Kreekraklock 0 0 70.28429146290443
# Queues:  Hansweertlock 0 0 71.00091828029316
# Queues:  Hansweertlock 0 0 71.04183312809222
# Queues:  Kreekraklock 0 0 71.17263276048918
# Queues:  Krammerlock 0 0 71.49412653163773
# Queues:  Kreekraklock 0 0 71.79985995545408
# Queues:  Hansweertlock 0 0 71.90678712159853
# Queues:  Kreekraklock 0 0 72.06591740963944
# Queues:  Kreekraklock 0 0 72.08990856110846
# Queues:  Kreekraklock 0 0 72.11317446989786
# Queues:  Kreekraklock 0 0 72.13376398308505
# Queues:  Krammerlock 0 0 72.16236865465936
# Queues:  Kreekraklock 0 2 72.35074971068785
# Queues:  Krammerlock 0 0 72.42689683468812
# Queues:  Kreekraklock 0 2 72.51465661613946
# Queues:  Kreekraklock 0 0 72.82151262240892
# Queues:  Hansweertlock 0 0 73.51187960435965
# Queues:  Kreekraklock 0 0 73.90664332907507
# Queues:  Kreekraklock 0 0 74.2559027117466
# Queues:  Krammerlock 0 0 74.37109284082153
# Queues:  Kreekraklock 0 0 74.48529409085059
# Queues:  Kreekraklock 0 0 74.6863417309989
# Queues:  Hansweertlock 0 0 74.8644963107802
# Queues:  Hansweertlock 0 0 75.50410515260643
# Queues:  Kreekraklock 0 0 75.67867026068078
# Queues:  Kreekraklock 0 0 75.96979717974425
# Queues:  Krammerlock 0 0 76.03964404774881
# Queues:  Krammerlock 0 0 76.25344693545215
# Queues:  Kreekraklock 0 0 76.59462541446989
# Queues:  Kreekraklock 0 0 76.71056169516646
# Queues:  Kreekraklock 0 0 76.8021545817561
# Queues:  Kreekraklock 0 0 76.85317695271124
# Queues:  Krammerlock 0 0 77.04026184373286
# Queues:  Kreekraklock 0 0 77.166454309183
# Queues:  Hansweertlock 0 0 77.26728669521312
# Queues:  Kreekraklock 0 0 77.48506120608117
# Queues:  Kreekraklock 0 0 77.95693084884068
# Queues:  Krammerlock 0 0 78.29034735719642
# Queues:  Krammerlock 0 0 78.65954521682008
# Queues:  Kreekraklock 0 0 78.75853948904468
# Queues:  Hansweertlock 0 0 79.59732192003713
# Queues:  Krammerlock 0 0 79.69477343990884
# Queues:  Hansweertlock 0 0 79.95302985861125
# Queues:  Kreekraklock 0 0 79.99516107816643
# Queues:  Hansweertlock 0 0 80.02569400194882
# Queues:  Hansweertlock 0 0 80.30718355637771
# Queues:  Kreekraklock 0 0 80.4283342020867
# Queues:  Kreekraklock 0 0 80.75288372755675
# Queues:  Hansweertlock 0 0 81.27975244137006
# Queues:  Kreekraklock 0 0 81.96379612456882
# Queues:  Hansweertlock 0 0 81.99509549966602
# Queues:  Hansweertlock 0 0 82.00973064472977
# Queues:  Hansweertlock 0 0 82.0494375057968
# Queues:  Hansweertlock 0 0 82.05985344117968
# Queues:  Krammerlock 0 0 82.180754132501
# Queues:  Krammerlock 0 0 82.2748526014291
# Queues:  Hansweertlock 0 1 82.3167793655832
# Queues:  Kreekraklock 0 0 82.53880721355694
# Queues:  Kreekraklock 0 0 82.79166808555391
# Queues:  Hansweertlock 0 0 82.98491164623111
# Queues:  Kreekraklock 0 0 83.49689608004137
# Queues:  Kreekraklock 0 0 83.54922591851106
# Queues:  Krammerlock 0 0 83.83556579575092
# Queues:  Krammerlock 0 0 83.93249098984532
# Queues:  Hansweertlock 0 0 83.94693612567892
# Queues:  Kreekraklock 0 0 84.18995049521618
# Queues:  Kreekraklock 0 0 84.5155467444102
# Queues:  Kreekraklock 0 0 84.6900189028469
# Queues:  Krammerlock 0 0 84.9498157141046
# Queues:  Hansweertlock 0 0 85.07694798689258
# Queues:  Krammerlock 0 0 85.25921357260414
# Queues:  Krammerlock 0 0 85.7901444057059
# Queues:  Krammerlock 0 0 85.84499971990087
# Queues:  Hansweertlock 0 0 85.87641136458652
# Queues:  Kreekraklock 0 0 85.96968101058789
# Queues:  Kreekraklock 0 0 86.01865256932012
# Queues:  Krammerlock 0 0 86.13593300440841
# Queues:  Hansweertlock 0 0 86.22466239736913
# Queues:  Kreekraklock 0 0 86.24744511895096
# Queues:  Kreekraklock 0 0 86.39593736781214
# Queues:  Hansweertlock 0 0 86.44478430960646
# Queues:  Krammerlock 0 0 86.7122491962185
# Queues:  Hansweertlock 0 0 86.83022199626714
# Queues:  Hansweertlock 0 0 87.09683762008342
# Queues:  Kreekraklock 0 0 87.17997166772545
# Queues:  Hansweertlock 0 0 87.43841611739094
# Queues:  Kreekraklock 0 0 87.5113860208484
# Queues:  Kreekraklock 0 0 87.9502969786309
# Queues:  Hansweertlock 0 0 88.08619490061115
# Queues:  Krammerlock 0 0 88.37505776845943
# Queues:  Krammerlock 0 0 88.6600444659268
# Queues:  Hansweertlock 0 0 89.05138735188318
# Queues:  Kreekraklock 0 0 89.49009106264458
# Queues:  Krammerlock 0 0 89.53227073149148
# Queues:  Kreekraklock 0 0 89.56860715561929
# Queues:  Krammerlock 0 0 89.69601786530457
# Queues:  Kreekraklock 0 0 89.83268591253707
# Queues:  Krammerlock 0 0 89.98119231159406
# Queues:  Krammerlock 0 0 89.99350300705231
# Queues:  Kreekraklock 0 0 90.31671246113606
# Queues:  Krammerlock 0 1 90.35314330703443
# Queues:  Kreekraklock 0 0 90.39066673951523
# Queues:  Krammerlock 0 0 90.4170573902554
# Queues:  Krammerlock 0 0 90.85150797115072
# Queues:  Krammerlock 0 0 90.96679835676416
# Queues:  Kreekraklock 0 0 90.96859804551191
# Queues:  Kreekraklock 0 0 90.97061584975559
# Queues:  Kreekraklock 0 0 91.08355136288704
# Queues:  Hansweertlock 0 0 91.51432917186038
# Queues:  Krammerlock 0 0 91.65113097145323
# Queues:  Hansweertlock 0 0 91.70231156320472
# Queues:  Krammerlock 0 0 91.75343608710752
# Queues:  Kreekraklock 0 0 92.22026664629992
# Queues:  Hansweertlock 0 0 92.97492202855005
# Queues:  Hansweertlock 0 0 93.31619993339704
# Queues:  Kreekraklock 0 0 93.34299163123383
# Queues:  Hansweertlock 0 0 93.4154011528379
# Queues:  Hansweertlock 0 0 93.4942657081737
# Queues:  Hansweertlock 0 0 94.00579503734117
# Queues:  Hansweertlock 0 0 94.06163559442578
# Queues:  Kreekraklock 0 0 94.1414186365813
# Queues:  Kreekraklock 0 0 94.22593455742066
# Queues:  Krammerlock 0 0 94.27964224239996
# Queues:  Hansweertlock 0 0 94.46160171115629
# Queues:  Krammerlock 0 0 94.4676246337443
# Queues:  Hansweertlock 0 0 94.88599867856338
# Queues:  Kreekraklock 0 0 95.0741245564806
# Queues:  Kreekraklock 0 0 95.70839932631401
# Queues:  Kreekraklock 0 0 95.79995406608113
# Queues:  Kreekraklock 0 0 95.80007023662229
# Queues:  Krammerlock 0 0 96.01824866862138
# Queues:  Kreekraklock 0 0 96.2203526252191
# Queues:  Hansweertlock 0 0 96.56332521055418
# Queues:  Kreekraklock 0 0 96.58160565172217
# Queues:  Hansweertlock 0 0 96.58484857719081
# Queues:  Krammerlock 0 0 96.99904735337371
# Queues:  Kreekraklock 0 0 97.59394818293637
# Queues:  Hansweertlock 0 0 98.08562678621394
# Queues:  Kreekraklock 0 0 98.33048845934334
# Queues:  Hansweertlock 0 0 98.3420813812331
# Queues:  Kreekraklock 0 0 98.52180600747342
# Queues:  Krammerlock 0 0 98.68104758460326
# Queues:  Krammerlock 0 0 99.03197532695309
# Queues:  Krammerlock 0 0 99.28689731241515
# Queues:  Hansweertlock 0 0 99.29247075553681
# Queues:  Kreekraklock 0 0 99.35452736718484
# Queues:  Kreekraklock 0 0 99.57613823089255
# Queues:  Hansweertlock 0 0 100.03185566130418
# Queues:  Krammerlock 0 0 100.31580558629099
# Queues:  Kreekraklock 0 0 100.37038464017633
# Queues:  Krammerlock 0 0 100.54278634178826
# Queues:  Kreekraklock 0 0 100.54580043199128
# Queues:  Hansweertlock 0 0 100.56941084168979
# Queues:  Kreekraklock 0 0 100.86588203539937
# Queues:  Kreekraklock 0 0 100.93977447571082
# Queues:  Hansweertlock 0 0 100.99507662441783
# Queues:  Hansweertlock 0 0 101.65330605950771
# Queues:  Kreekraklock 0 0 101.86100241048761
# Queues:  Krammerlock 0 0 101.88067569225382
# Queues:  Krammerlock 0 0 102.13713028727298
# Queues:  Kreekraklock 0 0 102.6285419609776
# Queues:  Kreekraklock 0 0 102.66783648594838
# Queues:  Krammerlock 0 0 102.72913684962482
# Queues:  Kreekraklock 0 0 102.80131095249321
# Queues:  Hansweertlock 0 0 102.8088602833325
# Queues:  Krammerlock 0 0 103.08751966157669
# Queues:  Krammerlock 0 0 103.18287701948148
# Queues:  Kreekraklock 0 0 103.33170094101524
# Queues:  Kreekraklock 0 0 103.42412372474827
# Queues:  Kreekraklock 0 0 103.58029413527275
# Queues:  Kreekraklock 0 0 103.61129979462132
# Queues:  Krammerlock 0 0 103.6571653950797
# Queues:  Krammerlock 0 0 103.69712535964217
# Queues:  Hansweertlock 0 0 104.17726484119594
# Queues:  Krammerlock 0 0 104.27835981127515
# Queues:  Krammerlock 0 0 104.33208376439961
# Queues:  Hansweertlock 0 0 104.48573729446834
# Queues:  Hansweertlock 0 0 104.51443552251519
# Queues:  Krammerlock 0 0 104.90480387233858
# Queues:  Krammerlock 0 0 105.24424235189016
# Queues:  Kreekraklock 0 0 105.40106917587897
# Queues:  Kreekraklock 0 0 105.40982661471939
# Queues:  Kreekraklock 0 0 105.85191864991923
# Queues:  Hansweertlock 0 0 105.96404009768769
# Queues:  Kreekraklock 0 0 106.43545668956196
# Queues:  Kreekraklock 0 0 106.65914583505979
# Queues:  Kreekraklock 0 0 106.65920164945607
# Queues:  Hansweertlock 0 0 106.734373712998
# Queues:  Hansweertlock 0 0 106.89969054382976
# Queues:  Krammerlock 0 0 106.94981759107286
# Queues:  Krammerlock 0 0 107.2402468264284
# Queues:  Krammerlock 0 0 107.32828619937324
# Queues:  Hansweertlock 0 0 107.59741341227596
# Queues:  Kreekraklock 0 0 107.83400336032823
# Queues:  Kreekraklock 0 0 107.97227311722493
# Queues:  Krammerlock 0 0 108.12376610562272
# Queues:  Kreekraklock 0 0 108.45804361195448
# Queues:  Hansweertlock 0 0 108.50201547257696
# Queues:  Hansweertlock 0 0 108.95289299851204
# Queues:  Krammerlock 0 0 109.0238643337154
# Queues:  Kreekraklock 0 0 109.20628546960694
# Queues:  Kreekraklock 0 0 109.73205131830531
# Queues:  Hansweertlock 0 0 109.86157755898302
# Queues:  Krammerlock 0 0 109.9619608964594
# Queues:  Kreekraklock 0 0 109.99096266344516
# Queues:  Kreekraklock 0 0 110.19501400602232
# Queues:  Krammerlock 0 0 110.75868798766807
# Queues:  Hansweertlock 0 0 111.17487354905023
# Queues:  Kreekraklock 0 0 111.34108222329601
# Queues:  Hansweertlock 0 0 111.37852839960335
# Queues:  Krammerlock 0 0 111.48787320034326
# Queues:  Kreekraklock 0 0 111.64291067056556
# Queues:  Krammerlock 0 0 111.71820606905162
# Queues:  Hansweertlock 0 0 111.76570957594534
# Queues:  Kreekraklock 0 0 111.89911454173117
# Queues:  Krammerlock 0 0 112.33761658412088
# Queues:  Kreekraklock 0 0 112.45729548337883
# Queues:  Hansweertlock 0 0 112.98611479132515
# Queues:  Kreekraklock 0 0 113.0517664620693
# Queues:  Hansweertlock 0 0 113.10644072234112
# Queues:  Krammerlock 0 0 113.33459955698525
# Queues:  Hansweertlock 0 0 113.83589630558639
# Queues:  Hansweertlock 0 0 113.9480108506594
# Queues:  Krammerlock 0 0 114.53102264648491
# Queues:  Kreekraklock 0 0 114.5557851154276
# Queues:  Hansweertlock 0 0 114.83174818492824
# Queues:  Kreekraklock 0 0 114.84727789453265
# Queues:  Hansweertlock 0 0 114.96862536900285
# Queues:  Kreekraklock 0 0 115.18809848647149
# Queues:  Kreekraklock 0 0 115.34271083397795
# Queues:  Krammerlock 0 0 115.41250746592685
# Queues:  Kreekraklock 0 0 115.5156663975911
# Queues:  Kreekraklock 0 1 115.57524266475873
# Queues:  Kreekraklock 0 0 115.70265398273972
# Queues:  Kreekraklock 0 0 115.76559761880254
# Queues:  Hansweertlock 0 0 116.05699987165421
# Queues:  Kreekraklock 0 0 116.1575035156953
# Queues:  Hansweertlock 0 0 116.16560741215231
# Queues:  Krammerlock 0 0 116.25746208051842
# Queues:  Kreekraklock 0 0 116.68077229368845
# Queues:  Krammerlock 0 0 116.97338263806894
# Queues:  Kreekraklock 0 0 117.22197603240434
# Queues:  Krammerlock 0 0 117.31824254601966
# Queues:  Kreekraklock 0 0 117.79210840841223
# Queues:  Krammerlock 0 0 117.85298006051349
# Queues:  Kreekraklock 0 0 118.33349643137404
# Queues:  Hansweertlock 0 0 118.4073507421024
# Queues:  Kreekraklock 0 0 119.36363843456532
# Queues:  Krammerlock 0 0 119.72120289433082
# Queues:  Kreekraklock 0 0 119.83953616309216
# Queues:  Kreekraklock 0 0 119.84358715230735
# Queues:  Krammerlock 0 0 119.87840187671972
# Queues:  Hansweertlock 0 0 120.04583339270162
# Queues:  Kreekraklock 0 0 120.19035758289871
# Queues:  Krammerlock 0 0 120.56040850452375
# Queues:  Krammerlock 0 0 120.71717086518103
# Queues:  Hansweertlock 0 0 120.87664767957962
# Queues:  Hansweertlock 0 0 120.91592316946314
# Queues:  Hansweertlock 0 0 121.037625833553
# Queues:  Kreekraklock 0 0 121.04468949039402
# Queues:  Krammerlock 0 0 121.29170543361303
# Queues:  Hansweertlock 0 0 121.87467397350386
# Queues:  Hansweertlock 0 0 122.18752897459316
# Queues:  Krammerlock 0 0 122.39019970260577
# Queues:  Kreekraklock 0 0 122.605172114437

# %%
env.enviromental_report.get_transported_weight_corridor()

# %%
vessel_log = pd.DataFrame.from_dict(vessels[0].log)
#
print(vessel_log.to_string())
print(len(vessels))

# %%
# running  saves a plot for all vessels
'''
for vessel in vessels[:10]:
    print(vessel.path_complete.name)
    vessel.path_complete.plot(FG, True, vessel.name)
''' 
print(vessels[3].path_complete.name)
vessels[3].path_complete.plot(FG, False, vessels[3].name)

# %%
# this way I can see activity at lock
for edge in FG.edges(data=True):
    if (edge[2]["Object"] == "Lock"):
        lock_log = pd.DataFrame.from_dict(edge[2]["attribute"].log)
        print(lock_log, edge[2]["attribute"].lock_name)

# %%
print(vessels[0].path_complete.length)
print(vessels[0].loaded_capacity)
print(vessels[0].distance)
print(vessels[1].distance)
print(vessels[9116].loaded_capacity)

# %%
# this way I can see activity at lock in graph
for edge in FG.edges(data=True):
    if (edge[2]["Object"] == "Lock"):
        edge[2]["attribute"].plot_arrivales()
        lock_log = pd.DataFrame.from_dict(edge[2]["attribute"].log)
        #print(lock_log, edge[2]["attribute"].lock_name)
        print(edge[2]["attribute"].lock_name)
