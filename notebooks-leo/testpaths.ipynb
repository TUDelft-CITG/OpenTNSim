# %%
paths = []
for path in nx.all_simple_paths(FG, "Node 1", "Node 6"):
    paths.append(path)
print(paths)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b08e97212432> in <module>()
#       1 paths = []
# ----> 2 for path in nx.all_simple_paths(FG, "Node 1", "Node 6"):
#       3     paths.append(path)
#       4 print(paths)
#
# NameError: name 'nx' is not defined
