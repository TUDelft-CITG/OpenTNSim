# %%
M8 = {
    'width': 11.4,
    'length':110,
    'height': 4,
    'height_loaded': 9.1,
    'emissionfactor': 0.7,
    'power': 318,
    'own_weight': 100,
    'loaded_capacity':2711*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.7777,
    'speed_unloaded': 5.3333,
    'loaded_resistance': 106453,
    'resistance_unloaded':61526,
    # variable values depend on random variables
    'is_loaded': False,
}

M8_loaded = {
    'width': 11.4,
    'length':110,
    'height': 4,
    'height_loaded': 9.1,
    'emissionfactor': 0.7,
    'power': 318,
    'own_weight': 100,
    'loaded_capacity':2711*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.7777,
    'speed_unloaded': 5.3333,
    'loaded_resistance': 106453,
    'resistance_unloaded':61526,
    # variable values depend on random variables
    'is_loaded': True,
}
"""

M8_high = {
    'width': 11.4,
    'length':110,
    'height': 9.1,
    'height_loaded': 4,
    'emissionfactor': 0.7,
    'power': 318,
    'own_weight': 100,
    'loaded_capacity':2711,
    'capacity_unloaded':0,
    'loaded_speed': 3.7777,
    'speed_unloaded': 5.3333,
    'loaded_resistance': 106453,
    'resistance_unloaded':61526,
     #variable values depend on random variables
    'is_loaded': False,
}

M8_loaded_low = {
    'width': 11.4,
    'length':110,
    'height': 9.1,
    'height_loaded': 4,
    'emissionfactor': 0.7,
    'power': 318,
    'own_weight': 100,
    'loaded_capacity':2711,
    'capacity_unloaded':0,
    'loaded_speed': 3.7777,
    'speed_unloaded': 5.3333,
    'loaded_resistance': 106453,
    'resistance_unloaded':61526,
    # variable values depend on random variables
    'is_loaded': True,
}


"""

M1 = {
    'width': 5.05,
    'length':38.5,
    'height': 2,
    'height_loaded': 5.25,
    'emissionfactor': 0.73,
    'power': 36,
    'own_weight': 80,
    'loaded_capacity':400*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.083,
    'speed_unloaded': 4.47,
    'loaded_resistance': 16919,
    'resistance_unloaded':9188,
    # variable values depend on random variables
    'is_loaded': False,
}

M1_loaded = {
    'width': 5.05,
    'length':38.5,
    'height': 2,
    'height_loaded': 5.25,
    'emissionfactor': 0.73,
    'power': 36,
    'own_weight': 80,
    'loaded_capacity':400*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.083,
    'speed_unloaded': 4.47,
    'loaded_resistance': 16919,
    'resistance_unloaded':9188,
    # variable values depend on random variables
    'is_loaded': True,
}



M2 = {
    'width': 6.06,
    'length':55,
    'height': 2,
    'height_loaded': 6.1,
    'emissionfactor': 0.72,
    'power': 118,
    'own_weight': 90,
    'loaded_capacity':650*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.361,
    'speed_unloaded': 4.638,
    'loaded_resistance': 28770,
    'resistance_unloaded':17524,
    # variable values depend on random variables
    'is_loaded': False,
}

M2_loaded = {
    'width': 6.06,
    'length':55,
    'height': 2,
    'height_loaded': 6.1,
    'emissionfactor': 0.72,
    'power': 118,
    'own_weight': 90,
    'loaded_capacity':650*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.361,
    'speed_unloaded': 4.638,
    'loaded_resistance': 28770,
    'resistance_unloaded':17524,
    # variable values depend on random variables
    'is_loaded': True,
}

"""

M2_2 = {
    'width': 6.06,
    'length':55,
    'height': 2,
    'height_loaded': 6.1,
    'emissionfactor': 0.72,
    'power': 118,
    'own_weight': 90,
    'loaded_capacity':650*0.7,
    'capacity_unloaded':0,
    'loaded_speed': 3.361,
    'speed_unloaded': 4.638,
    'loaded_resistance': 28770,
    'resistance_unloaded':17524,
    # variable values depend on random variables
    'is_loaded': True,
}

M2_loaded_2 = {
    'width': 6.06,
    'length':55,
    'height': 2,
    'height_loaded': 6.1,
    'emissionfactor': 0.72,
    'power': 118,
    'own_weight': 90,
    'loaded_capacity':650*0.7,
    'capacity_unloaded':0,
    'loaded_speed': 3.361,
    'speed_unloaded': 4.638,
    'loaded_resistance': 28770,
    'resistance_unloaded':17524,
    # variable values depend on random variables
    'is_loaded': True,
}

"""

M3 = {
    'width': 7.2,
    'length':70,
    'height': 2,
    'height_loaded': 6.4,
    'emissionfactor': 0.72,
    'power': 120,
    'own_weight': 100,
    'loaded_capacity':800*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.861,
    'speed_unloaded': 4.638,
    'loaded_resistance': 43935,
    'resistance_unloaded':22746,
    # variable values depend on random variables
    'is_loaded': False,
}

M3_loaded = {
    'width': 7.2,
    'length':70,
    'height': 2,
    'height_loaded': 6.4,
    'emissionfactor': 0.72,
    'power': 120,
    'own_weight': 100,
    'loaded_capacity':800 * 0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.861,
    'speed_unloaded': 4.638,
    'loaded_resistance': 43935,
    'resistance_unloaded':22746,
    # variable values depend on random variables
    'is_loaded': True,
}




M4 = {
    'width': 8.2,
    'length':73,
    'height': 2,
    'height_loaded': 6.6,
    'emissionfactor': 0.72,
    'power': 160,
    'own_weight': 110,
    'loaded_capacity':1050*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 4.000,
    'speed_unloaded': 4.889,
    'loaded_resistance': 50582,
    'resistance_unloaded':28777,
    # variable values depend on random variables
    'is_loaded': False,
}

M4_loaded = {
    'width': 8.2,
    'length':73,
    'height': 2,
    'height_loaded': 6.6,
    'emissionfactor': 0.72,
    'power': 160,
    'own_weight': 110,
    'loaded_capacity':1050*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 4.000,
    'speed_unloaded': 4.889,
    'loaded_resistance': 50582,
    'resistance_unloaded':28777,
    # variable values depend on random variables
    'is_loaded': True,
}


M5 = {
    'width': 8.2,
    'length':85,
    'height': 2,
    'height_loaded': 6.4,
    'emissionfactor': 0.72,
    'power': 323,
    'own_weight': 140,
    'loaded_capacity':1250*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.916,
    'speed_unloaded': 5.027,
    'loaded_resistance': 54096,
    'resistance_unloaded':31794,
    # variable values depend on random variables
    'is_loaded': False,
}

M5_loaded = {
    'width': 8.2,
    'length':85,
    'height': 2,
    'height_loaded': 6.4,
    'emissionfactor': 0.72,
    'power': 323,
    'own_weight': 140,
    'loaded_capacity':1250*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.916,
    'speed_unloaded': 5.027,
    'loaded_resistance': 54096,
    'resistance_unloaded':31794,
    # variable values depend on random variables
    'is_loaded': True,
}





M6 = {
    'width': 9.5,
    'length':85,
    'height': 2,
    'height_loaded': 7,
    'emissionfactor': 0.71,
    'power': 263,
    'own_weight': 120,
    'loaded_capacity':1750*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.916,
    'speed_unloaded': 5.194,
    'loaded_resistance': 70802,
    'resistance_unloaded':44676,
    # variable values depend on random variables
    'is_loaded': False,
}

M6_loaded = {
    'width': 9.5,
    'length':85,
    'height': 2,
    'height_loaded': 7,
    'emissionfactor': 0.71,
    'power': 263,
    'own_weight': 120,
    'loaded_capacity':1750*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.916,
    'speed_unloaded': 5.194,
    'loaded_resistance': 70802,
    'resistance_unloaded':44676,
    # variable values depend on random variables
    'is_loaded': True,
}



M7 = {
    'width': 9.5,
    'length':105,
    'height': 2,
    'height_loaded': 7,
    'emissionfactor': 0.70,
    'power': 258,
    'own_weight': 110,
    'loaded_capacity':2050*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.778,
    'speed_unloaded': 5.361,
    'loaded_resistance': 74294,
    'resistance_unloaded':53220,
    # variable values depend on random variables
    'is_loaded': False,
}

M7_loaded = {
    'width': 9.5,
    'length':105,
    'height': 2,
    'height_loaded': 7,
    'emissionfactor': 0.70,
    'power': 258,
    'own_weight': 110,
    'loaded_capacity':2050*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.778,
    'speed_unloaded': 5.361,
    'loaded_resistance': 74294,
    'resistance_unloaded':53220,
    # variable values depend on random variables
    'is_loaded': True,
}

M9 = {
    'width': 11.4,
    'length':135,
    'height': 3,
    'height_loaded': 9.1,
    'emissionfactor': 0.70,
    'power': 350,
    'own_weight': 120,
    'loaded_capacity':4000*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.805,
    'speed_unloaded': 5.416,
    'loaded_resistance': 116161,
    'resistance_unloaded':69833,
    # variable values depend on random variables
    'is_loaded': False,
}

M9_loaded = {
    'width': 11.4,
    'length':135,
    'height': 3,
    'height_loaded': 9.1,
    'emissionfactor': 0.70,
    'power': 350,
    'own_weight': 120,
    'loaded_capacity':4000*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.805,
    'speed_unloaded': 5.416,
    'loaded_resistance': 116161,
    'resistance_unloaded':69833,
    # variable values depend on random variables
    'is_loaded': True,
}


M10 = {
    'width': 13.5,
    'length':135,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.70,
    'power': 350,
    'own_weight': 120,
    'loaded_capacity':4300*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.583,
    'speed_unloaded': 5.388,
    'loaded_resistance': 124101,
    'resistance_unloaded':72153,
    # variable values depend on random variables
    'is_loaded': False,
}

M10_loaded = {
    'width': 13.5,
    'length':135,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.70,
    'power': 350,
    'own_weight': 120,
    'loaded_capacity':4300*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.583,
    'speed_unloaded': 5.388,
    'loaded_resistance': 124101,
    'resistance_unloaded':72153,
    # variable values depend on random variables
    'is_loaded': True,
}


M11 = {
    'width': 14.2,
    'length':135,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.70,
    'power': 380,
    'own_weight': 150,
    'loaded_capacity':5600*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 4.027,
    'speed_unloaded': 5.277,
    'loaded_resistance': 141593,
    'resistance_unloaded':85947,
    # variable values depend on random variables
    'is_loaded': False,
}

M11_loaded = {
    'width': 14.2,
    'length':135,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.70,
    'power': 380,
    'own_weight': 140,
    'loaded_capacity':5600*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 4.027,
    'speed_unloaded': 5.277,
    'loaded_resistance': 141593,
    'resistance_unloaded':85947,
    # variable values depend on random variables
    'is_loaded': True,
}



M12 = {
    'width': 17,
    'length':135,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.70,
    'power': 380,
    'own_weight': 145,
    'loaded_capacity':5600*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.888,
    'speed_unloaded': 5.138,
    'loaded_resistance': 167863,
    'resistance_unloaded':102290,
    # variable values depend on random variables
    'is_loaded': False,
}

M12_loaded = {
    'width': 17,
    'length':135,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.70,
    'power': 380,
    'own_weight': 145,
    'loaded_capacity':5600*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.888,
    'speed_unloaded': 5.138,
    'loaded_resistance': 167863,
    'resistance_unloaded':102290,
    # variable values depend on random variables
    'is_loaded': True,
}



BI = {
    'width': 9.5,
    'length':90,
    'height': 3,
    'height_loaded': 7,
    'emissionfactor': 0.71,
    'power': 263,
    'own_weight': 130,
    'loaded_capacity':1800*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.666,
    'speed_unloaded': 4.444,
    'loaded_resistance': 63671,
    'resistance_unloaded':27159,
    # variable values depend on random variables
    'is_loaded': False,
}


BI_loaded = {
    'width': 9.5,
    'length':90,
    'height': 3,
    'height_loaded': 7,
    'emissionfactor': 0.71,
    'power': 263,
    'own_weight': 130,
    'loaded_capacity':1800*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.666,
    'speed_unloaded': 4.444,
    'loaded_resistance': 63671,
    'resistance_unloaded':27159,
    # variable values depend on random variables
    'is_loaded': True,
}




BII_1 = {
    'width': 11.4,
    'length':110,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 318,
    'own_weight': 135,
    'loaded_capacity':3950*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.555,
    'speed_unloaded': 4.778,
    'loaded_resistance': 85750,
    'resistance_unloaded':37792,
    # variable values depend on random variables
    'is_loaded': False,
}

BII_1_loaded = {
    'width': 11.4,
    'length':110,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 318,
    'own_weight': 135,
    'loaded_capacity':3950*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.555,
    'speed_unloaded': 4.778,
    'loaded_resistance': 85750,
    'resistance_unloaded':37792,
    # variable values depend on random variables
    'is_loaded': True,
}



BII_2b = {
    'width': 22.8,
    'length':145,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 350,
    'own_weight': 150,
    'loaded_capacity':7050*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.055,
    'speed_unloaded':4.722,
    'loaded_resistance': 140637,
    'resistance_unloaded':77029,
    # variable values depend on random variables
    'is_loaded': False,
}

BII_2b_loaded = {
    'width': 22.8,
    'length':145,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 350,
    'own_weight': 150,
    'loaded_capacity':7050*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.055,
    'speed_unloaded':4.722,
    'loaded_resistance': 140637,
    'resistance_unloaded':77029,
    # variable values depend on random variables
    'is_loaded': True,
}


BII_2L = {
    'width': 11.4,
    'length':190,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 350,
    'own_weight': 140,
    'loaded_capacity':7050*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.638,
    'speed_unloaded':4.972,
    'loaded_resistance': 129810,
    'resistance_unloaded':55974,
    # variable values depend on random variables
    'is_loaded': False,
}

BII_2L_loaded = {
    'width': 11.4,
    'length':190,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 350,
    'own_weight': 140,
    'loaded_capacity':7050*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.638,
    'speed_unloaded':4.972,
    'loaded_resistance': 129810,
    'resistance_unloaded':55974,
    # variable values depend on random variables
    'is_loaded': True,
}



BII_4 = {
    'width': 22.8,
    'length':195,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 400,
    'own_weight': 160,
    'loaded_capacity':12000*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 2.833,
    'speed_unloaded':4.611,
    'loaded_resistance': 861913,
    'resistance_unloaded':114953,
    # variable values depend on random variables
    'is_loaded': False,
}

BII_4_loaded = {
    'width': 22.8,
    'length':195,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 400,
    'own_weight': 160,
    'loaded_capacity':12000*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 2.833,
    'speed_unloaded':4.611,
    'loaded_resistance': 861913,
    'resistance_unloaded':114953,
    # variable values depend on random variables
    'is_loaded': True,
}


BII_6L = {
    'width': 22.8,
    'length':270,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 400,
    'own_weight': 165,
    'loaded_capacity':18000*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 2.667,
    'speed_unloaded':4.472,
    'loaded_resistance': 213665,
    'resistance_unloaded':151739,
    # variable values depend on random variables
    'is_loaded': False,
}

BII_6L_loaded = {
    'width': 22.8,
    'length':270,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 400,
    'own_weight': 165,
    'loaded_capacity':18000*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 2.667,
    'speed_unloaded':4.472,
    'loaded_resistance': 213665,
    'resistance_unloaded':151739,
    # variable values depend on random variables
    'is_loaded': True,
}

"""
BII_6L_2 = {
    'width': 22.8,
    'length':270,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 400,
    'own_weight': 165,
    'loaded_capacity':18000,
    'capacity_unloaded':0,
    'loaded_speed': 2.667,
    'speed_unloaded':4.472,
    'loaded_resistance': 213665,
    'resistance_unloaded':151739,
    # variable values depend on random variables
    'is_loaded': True,
}

BII_6L_loaded_2 = {
    'width': 22.8,
    'length':270,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 400,
    'own_weight': 165,
    'loaded_capacity':18000,
    'capacity_unloaded':0,
    'loaded_speed': 2.667,
    'speed_unloaded':4.472,
    'loaded_resistance': 213665,
    'resistance_unloaded':151739,
    # variable values depend on random variables
    'is_loaded': True,
}

"""


B01 = {
    'width': 5.2,
    'length':55,
    'height': 3,
    'height_loaded': 5.25,
    'emissionfactor': 0.71,
    'power': 36,
    'own_weight': 80,
    'loaded_capacity':400*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.889,
    'speed_unloaded':4.167,
    'loaded_resistance': 27281,
    'resistance_unloaded':10473,
    # variable values depend on random variables
    'is_loaded': False,
}


B01_loaded = {
    'width': 5.2,
    'length':55,
    'height': 3,
    'height_loaded': 5.25,
    'emissionfactor': 0.71,
    'power': 36,
    'own_weight': 80,
    'loaded_capacity':400*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.889,
    'speed_unloaded':4.167,
    'loaded_resistance': 27281,
    'resistance_unloaded':10473,
    # variable values depend on random variables
    'is_loaded': True,
}



B02 = {
    'width': 6.6,
    'length':70,
    'height': 3,
    'height_loaded': 6.1,
    'emissionfactor': 0.71,
    'power': 118,
    'own_weight': 90,
    'loaded_capacity':600*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.333,
    'speed_unloaded':4.305,
    'loaded_resistance': 36338,
    'resistance_unloaded':15187,
    # variable values depend on random variables
    'is_loaded': False,
}


B02_loaded = {
    'width': 6.6,
    'length':70,
    'height': 3,
    'height_loaded': 6.1,
    'emissionfactor': 0.71,
    'power': 118,
    'own_weight': 90,
    'loaded_capacity':600*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.333,
    'speed_unloaded':4.305,
    'loaded_resistance': 36338,
    'resistance_unloaded':15187,
    # variable values depend on random variables
    'is_loaded': True,
}



B03 = {
    'width': 7.5,
    'length':80,
    'height': 3,
    'height_loaded': 6.4,
    'emissionfactor': 0.71,
    'power': 120,
    'own_weight': 95,
    'loaded_capacity':800*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.667,
    'speed_unloaded':4.278,
    'loaded_resistance': 42647,
    'resistance_unloaded':18677,
    # variable values depend on random variables
    'is_loaded': False,
}


B03_loaded = {
    'width': 7.5,
    'length':80,
    'height': 3,
    'height_loaded': 6.4,
    'emissionfactor': 0.71,
    'power': 120,
    'own_weight': 95,
    'loaded_capacity':800*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.667,
    'speed_unloaded':4.278,
    'loaded_resistance': 42647,
    'resistance_unloaded':18677,
    # variable values depend on random variables
    'is_loaded': True,
}



B04 = {
    'width': 8.2,
    'length':85,
    'height': 3,
    'height_loaded': 6.6,
    'emissionfactor': 0.71,
    'power': 160,
    'own_weight': 95,
    'loaded_capacity':1250*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.778,
    'speed_unloaded':4.361,
    'loaded_resistance': 47147,
    'resistance_unloaded':21147,
    # variable values depend on random variables
    'is_loaded': False,
}


B04_loaded = {
    'width': 8.2,
    'length':85,
    'height': 3,
    'height_loaded': 6.6,
    'emissionfactor': 0.71,
    'power': 160,
    'own_weight': 95,
    'loaded_capacity':1250*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 3.778,
    'speed_unloaded':4.361,
    'loaded_resistance': 47147,
    'resistance_unloaded':21147,
    # variable values depend on random variables
    'is_loaded': True,
}


C1b = {
    'width': 10.1,
    'length':38.5,
    'height': 3,
    'height_loaded': 5.25,
    'emissionfactor': 0.71,
    'power': 36,
    'own_weight': 80,
    'loaded_capacity':900*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.00,
    'speed_unloaded':4.222,
    'loaded_resistance': 28204,
    'resistance_unloaded':15387,
    # variable values depend on random variables
    'is_loaded': False,
}

C1b_loaded = {
    'width': 10.1,
    'length':38.5,
    'height': 3,
    'height_loaded': 5.25,
    'emissionfactor': 0.71,
    'power': 36,
    'own_weight': 80,
    'loaded_capacity':900*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.00,
    'speed_unloaded':4.222,
    'loaded_resistance': 28204,
    'resistance_unloaded':15387,
    # variable values depend on random variables
    'is_loaded': True,
}



C1L = {
    'width': 5.05,
    'length':80,
    'height': 3,
    'height_loaded': 5.25,
    'emissionfactor': 0.71,
    'power': 36,
    'own_weight': 80,
    'loaded_capacity':900*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.278,
    'speed_unloaded':4.389,
    'loaded_resistance': 20357,
    'resistance_unloaded':15211,
    # variable values depend on random variables
    'is_loaded': False,
}

C1L_loaded = {
    'width': 5.05,
    'length':80,
    'height': 3,
    'height_loaded': 5.25,
    'emissionfactor': 0.71,
    'power': 36,
    'own_weight': 80,
    'loaded_capacity':900*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.278,
    'speed_unloaded':4.389,
    'loaded_resistance': 20357,
    'resistance_unloaded':15211,
    # variable values depend on random variables
    'is_loaded': True,
}


C2b = {
    'width': 19,
    'length':105,
    'height': 3,
    'height_loaded': 9.1,
    'emissionfactor': 0.71,
    'power': 350,
    'own_weight':140,
    'loaded_capacity':3350*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 2.583,
    'speed_unloaded':4.167,
    'loaded_resistance': 93843,
    'resistance_unloaded':70473,
    # variable values depend on random variables
    'is_loaded': False,
}

C2b_loaded = {
    'width': 19,
    'length':105,
    'height': 3,
    'height_loaded': 9.1,
    'emissionfactor': 0.71,
    'power': 350,
    'own_weight':140,
    'loaded_capacity':3350*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 2.583,
    'speed_unloaded':4.167,
    'loaded_resistance': 93843,
    'resistance_unloaded':70473,
    # variable values depend on random variables
    'is_loaded': True,
}



C2L = {
    'width': 9.5,
    'length':185,
    'height': 3,
    'height_loaded': 7,
    'emissionfactor': 0.71,
    'power': 258,
    'own_weight':140,
    'loaded_capacity':3350*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.583,
    'speed_unloaded':4.722,
    'loaded_resistance': 111004,
    'resistance_unloaded':68736,
    # variable values depend on random variables
    'is_loaded': False,
}

C2L_loaded = {
    'width': 9.5,
    'length':185,
    'height': 3,
    'height_loaded': 7,
    'emissionfactor': 0.71,
    'power': 258,
    'own_weight':140,
    'loaded_capacity':3350*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.583,
    'speed_unloaded':4.722,
    'loaded_resistance': 111004,
    'resistance_unloaded':68736,
    # variable values depend on random variables
    'is_loaded': True,
}

"""
C2L_2 = {
    'width': 9.5,
    'length':185,
    'height': 3,
    'height_loaded': 7,
    'emissionfactor': 0.71,
    'power': 258,
    'own_weight':140,
    'loaded_capacity':3350*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.583,
    'speed_unloaded':4.722,
    'loaded_resistance': 111004,
    'resistance_unloaded':68736,
    # variable values depend on random variables
    'is_loaded': False,
}

C2L_loaded_2 = {
    'width': 9.5,
    'length':185,
    'height': 3,
    'height_loaded': 7,
    'emissionfactor': 0.71,
    'power': 258,
    'own_weight':140,
    'loaded_capacity':3350*0.65,
    'capacity_unloaded':0,
    'loaded_speed': 3.583,
    'speed_unloaded':4.722,
    'loaded_resistance': 111004,
    'resistance_unloaded':68736,
    # variable values depend on random variables
    'is_loaded': True,
}

"""

C3b = {
    'width': 22.8,
    'length':110,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 350,
    'own_weight':140,
    'loaded_capacity':7250*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 2.333,
    'speed_unloaded':4.278,
    'loaded_resistance': 93843,
    'resistance_unloaded':70473,
    # variable values depend on random variables
    'is_loaded': False,
}

C3b_loaded = {
    'width': 22.8,
    'length':110,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 350,
    'own_weight':140,
    'loaded_capacity':7250*0.5,
    'capacity_unloaded':0,
    'loaded_speed': 2.333,
    'speed_unloaded':4.278,
    'loaded_resistance': 93843,
    'resistance_unloaded':70473,
    # variable values depend on random variables
    'is_loaded': True,
}

C3L = {
    'width': 11.4,
    'length':190,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 350,
    'own_weight':140,
    'loaded_capacity':7250*0.55,
    'capacity_unloaded':0,
    'loaded_speed': 3.250,
    'speed_unloaded':5.056,
    'loaded_resistance': 111004,
    'resistance_unloaded':68736,
    # variable values depend on random variables
    'is_loaded': False,
}

C3L_loaded = {
    'width': 11.4,
    'length':190,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 350,
    'own_weight':140,
    'loaded_capacity':7250*0.55,
    'capacity_unloaded':0,
    'loaded_speed': 3.250,
    'speed_unloaded':5.056,
    'loaded_resistance': 111004,
    'resistance_unloaded':68736,
    # variable values depend on random variables
    'is_loaded': True,
}


C4 = {
    'width': 22.8,
    'length':185,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 400,
    'own_weight':150,
    'loaded_capacity':7250*0.60,
    'capacity_unloaded':0,
    'loaded_speed': 3.00,
    'speed_unloaded':4.472,
    'loaded_resistance': 111004,
    'resistance_unloaded':68736,
    # variable values depend on random variables
    'is_loaded': False,
}


C4_loaded = {
    'width': 22.8,
    'length':185,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 400,
    'own_weight':150,
    'loaded_capacity':7250*0.60,
    'capacity_unloaded':0,
    'loaded_speed': 3.00,
    'speed_unloaded':4.472,
    'loaded_resistance': 111004,
    'resistance_unloaded':68736,
    # variable values depend on random variables
    'is_loaded': True,
}

"""
C4_2 = {
    'width': 22.8,
    'length':185,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 400,
    'own_weight':150,
    'loaded_capacity':7250*0.6,
    'capacity_unloaded':0,
    'loaded_speed': 3.00,
    'speed_unloaded':4.472,
    'loaded_resistance': 111004,
    'resistance_unloaded':68736,
    # variable values depend on random variables
    'is_loaded': True,
}


C4_loaded_2 = {
    'width': 22.8,
    'length':185,
    'height': 3,
    'height_loaded': 8,
    'emissionfactor': 0.71,
    'power': 400,
    'own_weight':150,
    'loaded_capacity':7250*0.60,
    'capacity_unloaded':0,
    'loaded_speed': 3.00,
    'speed_unloaded':4.472,
    'loaded_resistance': 111004,
    'resistance_unloaded':68736,
    # variable values depend on random variables
    'is_loaded': True,
}
"""
ships = [M8_loaded, M8,M1, M1_loaded, M2, M2_loaded, M5, M5_loaded, M4, M4_loaded, M3, M3_loaded, M6, M6_loaded, M7, M7_loaded, M9, M9_loaded, M10, M10_loaded, M11, M11_loaded, M12, M12_loaded, BI, BI_loaded, BII_1, BII_1_loaded, BII_2b ,BII_2b_loaded ,BII_2L, BII_2L_loaded, BII_4, BII_4_loaded, B01, B01_loaded, B02, B02_loaded, B03, B03_loaded, B04, B04_loaded,C1b, C1b_loaded, C1L, C1L_loaded, C2b, C2b_loaded, C2L, C2L_loaded, C3b, C3b_loaded, C3L, C3L_loaded, C4, C4_loaded,BII_6L, BII_6L_loaded]

# For testing purposes we only want v to be 1
def compute_v_provider(v_empty, v_full):
    return lambda x: (v_empty + v_full) / 2

TransportResource = type('TransportResource', 
                         (core.Identifiable, core.Log, core.ContainerDependentMovable, 
                          core.HasResource, core.Routeable), {})
                
const_data_vessel = {"env": None,
               "name": "Vessel",
               "route": None,
               "geometry": shapely.geometry.Point(0, 0),  # lon, lat
               "capacity": 1_000,
               "compute_v": compute_v_provider(v_empty=0.05, v_full=0.05)}

# %%
def init_random_vessel(routes, vessel_name):
    vessel_dict = random.choice(ships)
    # init_vessels gives list but need just one
    vessel = init_vessels([vessel_dict], routes)[0]
    vessel.name = vessel_name
    vessel.shipType = 'None'
    return vessel



     #Normal situation
def init_vessels(list_vessel_dict, routes):    
    correction = 0
    if random.random() < 0.35:
        correction = 10
    vessels = []
    height = 0
    for i in range(len(list_vessel_dict)):
        for path in routes:
            if path.closed:
                continue
            if list_vessel_dict[i]["is_loaded"]:
                height = list_vessel_dict[i]["height_loaded"]
                if list_vessel_dict[i]["height_loaded"] >= path.max_height or correction >= path.max_height:
                    continue
            else:
                height = list_vessel_dict[i]["height"]
                if list_vessel_dict[i]["height"] >= path.max_height or correction >= path.max_height:
                    continue
            break
        vessel = TransportResource(**const_data_vessel)
        vessel.height = height
        vessel.length = list_vessel_dict[i]["length"]
        vessel.route = path.nodes
        vessel.loaded = list_vessel_dict[i]["is_loaded"]
        if vessel.loaded:
            speed = list_vessel_dict[i]["loaded_speed"]
            vessel.compute_v = compute_v_provider(speed, speed)
            vessel.resistance = list_vessel_dict[i]["loaded_resistance"]
        else:
            speed = list_vessel_dict[i]["speed_unloaded"]
            vessel.compute_v = compute_v_provider(speed, speed)
            vessel.resistance =list_vessel_dict[i]["resistance_unloaded"]
        vessel.speed = speed
        vessel.emission = list_vessel_dict[i]["emissionfactor"]
        vessel.name = "Vessel " + str(i + 1)
        vessel.path_complete = path
        vessel.loaded_capacity = list_vessel_dict[i]["loaded_capacity"]
        # 50/50 choses different direction
        if random.random() < 0.5:
            vessel.route = vessel.route[::-1]
            vessel.path_complete.nodes = vessel.path_complete.nodes[::-1]
        vessels.append(vessel)
    
    return vessels
