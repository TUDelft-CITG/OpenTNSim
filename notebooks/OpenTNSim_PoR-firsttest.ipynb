# %% [markdown]
# # Port of Rotterdam - OpenTNSim

# %%
import opentnsim

from importlib import reload 
opentnsim = reload(opentnsim)

# %%
# package(s) related to time, space and id
import datetime, time
import platform
import random
import os
import pathlib
import io
import urllib
import tempfile
import functools
import logging
import pickle

# package(s) related to the simulation
import simpy
import networkx as nx  

# spatial libraries 
import shapely.geometry
import shapely.wkt
import pyproj
import shapely.geometry
from osgeo import ogr, osr
from simplekml import Kml, Style
import folium
import yaml

# package(s) for data handling
import requests
import math             
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

# define the coorinate system
geod = pyproj.Geod(ellps="WGS84")

# %%
# Link to the latest version of the 'Vaarweginformatie.nl' network
#url = 'https://zenodo.org/record/3981105/files/network_digital_twin_v0.1.yaml'
url = 'https://zenodo.org/record/4578289/files/network_digital_twin_v0.2.yaml'

# %%
# Link to vessel database
location_vessel_database = "Vessels/Vessel-database-2.csv"

# %% [markdown]
# ## 0. Load useful methods

# %% [markdown]
# ### A) Network functions
# I think Fedor included working with the FIS in another version of OpenTNSim (for the P&W exercise) -- need to check

# %%
@functools.lru_cache
def load_fis_network(url):
    """load the topological fairway information system network (vaarweginformatie.nl)"""

    # get the data from the url
    resp = requests.get(url)
    # convert to file object
    stream = io.StringIO(resp.text)
    
    # This will take a minute or two
    # Here we convert the network to a networkx object
    G = nx.read_yaml(stream)
    
#     with open(url, 'r') as fh:
#         G = yaml.load(fh, Loader=yaml.Loader)

    # some brief info
    n_bytes = len(resp.content)
    msg = '''Loaded network from {url} file size {mb:.2f}MB. Network has {n_nodes} nodes and {n_edges} edges.'''
    summary = msg.format(url=url, mb=n_bytes / 1000**2, n_edges=len(G.edges), n_nodes=len(G.nodes))
    logger.info(summary)

    # The topological network contains information about the original geometry. 
    # Let's convert those into python shapely objects for easier use later
    for n in G.nodes:
        G.nodes[n]['geometry'] = shapely.geometry.Point(G.nodes[n]['X'], G.nodes[n]['Y'])
    for e in G.edges:
        edge = G.edges[e]
        edge['geometry'] = shapely.wkt.loads(edge['Wkt'])
        edge['length'] = edge_length(edge)    
    
    return G

# %%
def find_closest_node(G, point):
    """find the closest node on the graph from a given point"""
    
    distance = np.full((len(G.nodes)), fill_value=np.nan)
    for ii, n in enumerate(G.nodes):
        distance[ii] = point.distance(G.nodes[n]['geometry'])
    name_node = list(G.nodes)[np.argmin(distance)]
    distance_node = np.min(distance)
    
    return name_node, distance_node

# %%
def find_closest_edge(G, point):
    """find the closest edge on the graph from a given point"""
    
    distance = np.full((len(G.edges)), fill_value=np.nan)
    for ii, e in enumerate(G.edges):
        distance[ii] = point.distance(G.edges[e]['geometry'])
    name_edge = list(G.edges)[np.argmin(distance)]
    distance_edge = np.min(distance)
    
    return name_edge, distance_edge

# %%
def edge_length(edge):
    """compute the great circle length of an edge
    The network version 0.1 contains the lat/lon distance in a length property. 
    But we need the "great circle" or projected distance. 
    Let's define a function to recompute it.
    """
    
    # get the geometry
    geom = edge['geometry']
    # get lon, lat
    lats, lons = np.array(geom).T
    # this requires pyproj 2.3.0
    distance = geod.line_length(lons, lats)

    return distance

# %% [markdown]
# ### 1. Load Vaarweginformatie.nl graph (saved with PoR features)

# %%
# create a cached version to speed up loading (remove cached file if a better yaml file is available)
fname = "fis_wdata/FIS_wdata.pkl"
#fname = "fis_cache/FIS.pkl"

if os.path.exists(fname):
    print('I am loading cached network')
    with open(fname, 'rb') as pkl_file:
        FG = pickle.load(pkl_file)
        pkl_file.close()

else:
    print('I am getting new network')
    FG = load_fis_network(url)

    os.makedirs(os.path.dirname(fname), exist_ok=True)
    with open(fname, 'wb') as pkl_file:
        pickle.dump(FG, pkl_file)
        pkl_file.close()
# Out:
# I am loading cached network

# %% [markdown]
# #### 1.3 Plot the entire network

# %%
# Plot the network 
m = folium.Map(location=[51.9, 4.4], zoom_start = 11, tiles="cartodbpositron")

for edge in FG.edges(data = True):
    points_x = list(edge[2]["geometry"].coords.xy[0])
    points_y = list(edge[2]["geometry"].coords.xy[1])
    
    line = []
    for i, _ in enumerate(points_x):
        line.append((points_y[i], points_x[i]))
        
    folium.PolyLine(line, weight = 2, popup = (edge[2]["StartJunctionId"], edge[2]["EndJunctionId"])).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2. Prepare vessel objects

# %%
sim_start_time = datetime.datetime(2019, 1, 1, 0, 0, tzinfo=datetime.timezone.utc)
sim_start_time
# Out:
# datetime.datetime(2019, 1, 1, 0, 0, tzinfo=datetime.timezone.utc)

# %% [markdown]
# #### 2.1 Load vessel database

# %%
# import the route information
df_trips = pd.read_parquet('03_vessels/df_3epet.parquet')
df_trips = df_trips[df_trips['vessellength']>150]

# %%
for i, path in enumerate(df_trips['path']): 
    newpath = []
    for node in path: 
        try: 
            newpath.append(float(node))
        except: 
            newpath.append(node)
    df_trips.at[df_trips.index[i], 'path'] = newpath

# %%
for i, speed in enumerate(df_trips['speed']):
    df_trips.at[df_trips.index[i], 'speed'] = list(speed)

# %%
# Example calculations UKC and FWA over route
iship = df_trips.index[0]
path = df_trips.loc[iship, 'path']
T_s = df_trips.loc[iship, 'draughtMarine']
direction = 'inbound'

for i in range(1,len(path)):
    edge = path[i-1], path[i]
    
    if FG.has_edge(edge[0], edge[1]):
        # FWA
        FWA = T_s * FG.edges[edge]['FWA']
        
        # UKC
        if T_s < 17.4: 
            UKC_a = FG.edges[edge]['UKC_a (T<17.4)']
        else: 
            UKC_a = FG.edges[edge]['UKC_a (T>=17.4)']
            
        if direction == 'outbound':
            UKC_b = FG.edges[edge]['UKC_b (outbound)']
        else: 
            UKC_b = FG.edges[edge]['UKC_b (outbound)']
        UKC = UKC_a + UKC_b*T_s
        
    else: 
        FWA = float('nan')
        UKC = float('nan')
    print('edge {}: UKC = {}, FWA = {}'.format(edge, UKC, FWA))
# Out:
# edge (8864185.0, 8866260.0): UKC = 1.0, FWA = 0.09800000190734863
# edge (8866260.0, 8864288.0): UKC = 1.0, FWA = 0.09800000190734863
# edge (8864288.0, 8861022.0): UKC = 1.0, FWA = 0.09800000190734863
# edge (8861022.0, 8860701.0): UKC = 1.0, FWA = 0.09800000190734863
# edge (8860701.0, 8864748.0): UKC = 1.0, FWA = 0.09800000190734863
# edge (8864748.0, 8865822.0): UKC = 1.0, FWA = 0.09800000190734863
# edge (8865822.0, 8866305.0): UKC = 1.0, FWA = 0.09800000190734863
# edge (8866305.0, 8864266.0): UKC = 0.9800000190734863, FWA = 0.09800000190734863
# edge (8864266.0, 8862925.0): UKC = 0.9800000190734863, FWA = 0.09800000190734863
# edge (8862925.0, 8864465.0): UKC = 0.9800000190734863, FWA = 0.09800000190734863
# edge (8864465.0, 'S14716_B'): UKC = 0.9800000190734863, FWA = 0.09800000190734863
# edge ('S14716_B', 'S14716_A'): UKC = 0.9800000190734863, FWA = 0.09800000190734863
# edge ('S14716_A', 8860845.0): UKC = 0.9800000190734863, FWA = 0.09800000190734863
# edge (8860845.0, 8861674.0): UKC = 0.9800000190734863, FWA = 0.24500000476837158
# edge (8861674.0, 8861158.0): UKC = 0.9800000190734863, FWA = 0.24500000476837158
# edge (8861158.0, 8867547.0): UKC = 1.0, FWA = 0.24500000476837158
# edge (8867547.0, 8867980.0): UKC = 1.0, FWA = 0.24500000476837158
# edge (8867980.0, 8860596.0): UKC = 1.0, FWA = 0.24500000476837158
# edge (8860596.0, 8865217.0): UKC = 1.0, FWA = 0.24500000476837158

# %% [markdown]
# #### 2.2 Create multiple vessel objects with the new mixins, and use this in the vessel generator

# %%
# Make a class out of mix-ins
TransportResource = type('TransportResource', 
                         (opentnsim.core.Identifiable, opentnsim.core.ContainerDependentMovable, 
                          opentnsim.core.HasResource, opentnsim.core.Routeable, 
                          opentnsim.core.VesselProperties, opentnsim.energy_consumption_module.ConsumesEnergy), {})

# %%
# For testing purposes: default v = v_empty
def compute_v_provider(v_empty, v_full):
    return lambda x: v_empty

# %%
df_trips.drop(index=4173, inplace=True)

# %%
# identify which vessel type to extract from the vessel database (change the name to change the vessel used)
vessels = []

for i_vessel in df_trips.index:

    # path and route info
    path = df_trips['path'].loc[i_vessel]
    v_list = df_trips['speed'].loc[i_vessel]

    if len(path) - len(v_list) != 1: 
        print('Path and velocities input length incorrect (difference = {} and should be 1)'.format(len(path) - len(v_list)))

    start_point = path[0]

    # prepare data for the vessel
    data_vessel = {"env": None,
                   "name": df_trips['shipname'].loc[i_vessel],
                   "route": df_trips['path'].loc[i_vessel],
                   "geometry": FG.nodes[start_point]['geometry'],
                   "capacity": 1000,
                   "compute_v": compute_v_provider(v_empty=v_list, v_full=v_list),
                   "type": df_trips['vesseltypeERI'].loc[i_vessel],
                   "B": df_trips['vesselwidth'].loc[i_vessel],
                   "L": df_trips['vessellength'].loc[i_vessel],
                   "T_e": df_trips['draughtMarine'].loc[i_vessel],
                   "T_f": df_trips['draughtMarine'].loc[i_vessel],
                   "H_e": 10,
                   "H_f": 5,
                   "P_installed": 500,
                   "L_w": 1,
                   "C_b": 0.85
                  }
    
    vessel = TransportResource(**data_vessel)
    vessels.append(vessel)
# Out:
# The construction year of the engine is 2004
# The construction year of the engine is 2010
# The construction year of the engine is 1994
# The construction year of the engine is 2002
# The construction year of the engine is 2018
# The construction year of the engine is 1963
# The construction year of the engine is 2020
# The construction year of the engine is 2006
# The construction year of the engine is 2013
# The construction year of the engine is 1974
# The construction year of the engine is 2012
# The construction year of the engine is 2009
# The construction year of the engine is 1999
# The construction year of the engine is 2011
# The construction year of the engine is 1986
# The construction year of the engine is 1997
# The construction year of the engine is 1994
# The construction year of the engine is 1998
# The construction year of the engine is 2004
# The construction year of the engine is 1977
# The construction year of the engine is 2018
# The construction year of the engine is 2011
# The construction year of the engine is 2000
# The construction year of the engine is 2008
# The construction year of the engine is 1997
# The construction year of the engine is 2014
# The construction year of the engine is 2007
# The construction year of the engine is 2018
# The construction year of the engine is 1989
# The construction year of the engine is 1995
# The construction year of the engine is 2013
# The construction year of the engine is 2014
# The construction year of the engine is 2016
# The construction year of the engine is 2017
# The construction year of the engine is 2001
# The construction year of the engine is 2011
# The construction year of the engine is 2010
# The construction year of the engine is 2010
# The construction year of the engine is 2019
# The construction year of the engine is 2005
# The construction year of the engine is 1998
# The construction year of the engine is 2017
# The construction year of the engine is 1977
# The construction year of the engine is 2018
# The construction year of the engine is 2015
# The construction year of the engine is 2002
# The construction year of the engine is 2017
# The construction year of the engine is 1992
# The construction year of the engine is 2014
# The construction year of the engine is 2003
# The construction year of the engine is 2012
# The construction year of the engine is 2001
# The construction year of the engine is 2015
# The construction year of the engine is 1989
# The construction year of the engine is 2006
# The construction year of the engine is 2009
# The construction year of the engine is 2010
# The construction year of the engine is 2015
# The construction year of the engine is 2005
# The construction year of the engine is 1989
# The construction year of the engine is 2000
# The construction year of the engine is 2014
# The construction year of the engine is 2017
# The construction year of the engine is 2000
# The construction year of the engine is 2003
# The construction year of the engine is 2003
# The construction year of the engine is 2016
# The construction year of the engine is 2016
# The construction year of the engine is 2007

# %% [markdown]
# # 3. Create environment

# %%
# sim.add_vessels(origin,destination,[],vessel)

# %%
# # specify start time and duration
# simulation_start = sim_start_time 
# duration = 5*12.5*60*60 #seconds

# # create simulation with environment
# sim = model.Simulation(simulation_start,FG)
# env = sim.environment




# sim.run(duration = duration)

# %%
# Start simpy environment (at a given date and time) (simulation_start = datetime.datetime.now() to just start now)
simulation_start = sim_start_time # <============ start time
env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
env.epoch = time.mktime(simulation_start.timetuple())

# Add graph to environment
env.FG = FG

# %%
env

# %% [markdown]
# # 4. Run simulation

# %%
sim.add_vessels(origin,destination,[],vessel)

# %%
simulation_start = datetime.datetime.now()
sim = model.Simulation(simulation_start,FG)
env = sim.environment
duration = 5*12.5*60*60 #seconds

sim.run(duration = duration)

# %%
def start(env, vessel):
    """The start process moves a vessel over the network 
    (from its 'vessel.geometry' position to the end of 'vessel.route')"""
    vessel.log_entry("Start sailing", env.now, "", vessel.geometry)
    yield from vessel.move()
    vessel.log_entry("Stop sailing", env.now, "", vessel.geometry)

# %%
for i, vessel in enumerate(vessels):
    
    # Add graph to environment
    vessel.env = env
    
    # Add the movements of the vessel to the simulation
    env.process(start(env, vessel))

env.run()
# Out:
# origin = 8868083.0, destination = 8863475.0
# inode = 0, speed = 7.857539643698429, name = testschip-5953
# origin = 8860614.0, destination = B5729_A
# inode = 0, speed = 4.9633746885987735, name = testschip-6735
# origin = 8866859.0, destination = 8866999.0
# inode = 0, speed = 9.848134545748662, name = testschip-6735
# origin = 8864283.0, destination = 8860614.0
# inode = 0, speed = 5.591261482718618, name = testschip-6735
# origin = 8866859.0, destination = 8866999.0
# inode = 0, speed = 9.235068006296736, name = testschip-6735
# origin = 8860614.0, destination = B5729_A
# inode = 0, speed = 9.183999269507456, name = testschip-6735
# origin = 8866859.0, destination = 8866999.0
# inode = 0, speed = 12.6913682245053, name = testschip-6735
# origin = 8867980.0, destination = 8867547.0
# inode = 0, speed = 11.62633898884754, name = testschip-6457
# origin = 8863253.0, destination = 8868083.0
# inode = 0, speed = 7.770368464718986, name = testschip-2923
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 21.015768545712703, name = testschip-5000
# origin = 8860615.0, destination = 8861732.0
# inode = 0, speed = 5.888127512929995, name = testschip-5000
# origin = 8865217.0, destination = 8860596.0
# inode = 0, speed = 5.761854493277964, name = testschip-6394
# origin = 8868083.0, destination = 8863475.0
# inode = 0, speed = 9.39929475779824, name = testschip-5637
# origin = 8866305.0, destination = 8865822.0
# inode = 0, speed = 21.35264444084305, name = testschip-8110
# origin = 8863253.0, destination = 8868083.0
# inode = 0, speed = 5.969897722336634, name = testschip-8110
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 21.93372856724068, name = testschip-7484
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 15.356128207096884, name = testschip-6043
# origin = 8860615.0, destination = 8861732.0
# inode = 0, speed = 9.05885027261233, name = testschip-6043
# origin = 8863275.0, destination = 8864002.0
# inode = 0, speed = 9.368778780182174, name = testschip-8385
# origin = 8864988.0, destination = 8860596.0
# inode = 0, speed = 1.497435684083568, name = testschip-8385
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 13.926211009469668, name = testschip-4951
# origin = 8866999.0, destination = 8867980.0
# inode = 0, speed = 10.934059050040297, name = testschip-4951
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 11.996967470842655, name = testschip-8946
# origin = 8863253.0, destination = 8868083.0
# inode = 0, speed = 6.567204163354408, name = testschip-8946
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 12.8564172722422, name = testschip-9086
# origin = 8868083.0, destination = 8861732.0
# inode = 0, speed = 3.2548795736057907, name = testschip-9086
# origin = 8865217.0, destination = 8860596.0
# inode = 0, speed = 7.153593700162904, name = testschip-8332
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 18.65760880513075, name = testschip-9088
# origin = 8866859.0, destination = 8866999.0
# inode = 0, speed = 9.441931266093992, name = testschip-9088
# origin = 8864069.0, destination = 8865217.0
# inode = 0, speed = 8.271659427543254, name = testschip-6120
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 16.010164898211467, name = testschip-9465
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 16.54957130891621, name = testschip-9735
# origin = 8861732.0, destination = 8868083.0
# inode = 0, speed = 4.321967464254654, name = testschip-9735
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 13.359788481351664, name = testschip-9890
# origin = 8868083.0, destination = 8863475.0
# inode = 0, speed = 7.92788413243133, name = testschip-9890
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 23.072142953653888, name = testschip-9317
# origin = 8866999.0, destination = 8867980.0
# inode = 0, speed = 10.8253744568139, name = testschip-9317
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 21.83531316288611, name = testschip-9317
# origin = 8868178.0, destination = 8866999.0
# inode = 0, speed = 11.030080917011347, name = testschip-9317
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 23.28775614159544, name = testschip-5316
# origin = 8868419.0, destination = 8861732.0
# inode = 0, speed = 5.7422761347386055, name = testschip-5316
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 15.161734161356089, name = testschip-10445
# origin = 8863253.0, destination = 8868083.0
# inode = 0, speed = 6.470939281634372, name = testschip-10445
# origin = 8864002.0, destination = 8861067.0
# inode = 0, speed = 11.467968974999506, name = testschip-10756
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 19.431458404108245, name = testschip-10010
# origin = 8864069.0, destination = 8865217.0
# inode = 0, speed = 7.584679128014443, name = testschip-10010
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 17.90667366599802, name = testschip-11372
# origin = 8865217.0, destination = 8860596.0
# inode = 0, speed = 6.2745056789123606, name = testschip-11372
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 19.57740768723372, name = testschip-7363
# origin = 8868178.0, destination = 8866999.0
# inode = 0, speed = 8.576006602868384, name = testschip-7363
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 18.47644117531216, name = testschip-7363
# origin = 8863090.0, destination = 8863475.0
# inode = 0, speed = 5.086287257036144, name = testschip-7363
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 15.205947257363373, name = testschip-9265
# origin = 8866999.0, destination = 8867980.0
# inode = 0, speed = 10.221945684081144, name = testschip-9265
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 20.01207252432266, name = testschip-8397
# origin = 8866859.0, destination = 8866999.0
# inode = 0, speed = 8.01958311487492, name = testschip-8397
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 24.16962830628217, name = testschip-8961
# origin = 8867980.0, destination = 8866999.0
# inode = 0, speed = 5.297032689448233, name = testschip-8961
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 14.512729657865655, name = testschip-12115
# origin = 8866999.0, destination = 8867980.0
# inode = 0, speed = 12.586684705000286, name = testschip-12115
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 17.11979918362883, name = testschip-12011
# origin = 8863253.0, destination = 8868083.0
# inode = 0, speed = 5.192540363304493, name = testschip-12011
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 16.467876082134918, name = testschip-11583
# origin = 8865217.0, destination = 8860596.0
# inode = 0, speed = 7.3859731982377586, name = testschip-11583
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 16.472284281574385, name = testschip-12927
# origin = 8868178.0, destination = 8866999.0
# inode = 0, speed = 6.547758925628303, name = testschip-12927
# origin = 8866305.0, destination = 8864266.0
# inode = 0, speed = 15.9223687902327, name = testschip-12440
# origin = 8863090.0, destination = 8863475.0
# inode = 0, speed = 4.9496380660952815, name = testschip-12440
# origin = 8867547.0, destination = 8861158.0
# inode = 1, speed = 14.776321395425803, name = testschip-6457
# origin = 8861067.0, destination = 8865127.0
# inode = 1, speed = 15.491785854769356, name = testschip-10756
# origin = 8865127.0, destination = 8868177.0
# inode = 2, speed = 16.86594885253783, name = testschip-10756
# inode = 0, speed = 9.183999269507456, name = testschip-6735
# inode = 0, speed = 21.35264444084305, name = testschip-8110
# origin = 8865822.0, destination = 8866305.0
# inode = 1, speed = 19.87660213418813, name = testschip-8110
# inode = 1, speed = 19.87660213418813, name = testschip-8110
# inode = 0, speed = 4.9633746885987735, name = testschip-6735
# inode = 0, speed = 8.271659427543254, name = testschip-6120
# origin = 8861158.0, destination = 8861674.0
# inode = 2, speed = 21.07407337073666, name = testschip-6457
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 25.830788299596506, name = testschip-8961
# inode = 0, speed = 7.584679128014443, name = testschip-10010
# inode = 0, speed = 5.297032689448233, name = testschip-8961
# inode = 1, speed = 25.830788299596506, name = testschip-8961
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 22.31264617248797, name = testschip-5316
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 24.379477314498573, name = testschip-9317
# inode = 1, speed = 22.31264617248797, name = testschip-5316
# inode = 1, speed = 24.379477314498573, name = testschip-9317
# inode = 0, speed = 9.183999269507456, name = testschip-6735
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 22.6989224168711, name = testschip-7484
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 16.894940991265635, name = testschip-9317
# origin = 8863475.0, destination = 8865217.0
# inode = 1, speed = 9.194534278704143, name = testschip-5637
# inode = 1, speed = 22.6989224168711, name = testschip-7484
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 21.33578651800457, name = testschip-5000
# inode = 2, speed = 21.07407337073666, name = testschip-6457
# inode = 1, speed = 16.894940991265635, name = testschip-9317
# inode = 1, speed = 21.33578651800457, name = testschip-5000
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 16.39893627606805, name = testschip-8397
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 21.015621104916608, name = testschip-7363
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 13.820175959371664, name = testschip-10010
# inode = 1, speed = 16.39893627606805, name = testschip-8397
# inode = 1, speed = 21.015621104916608, name = testschip-7363
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 16.932982841032413, name = testschip-9088
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 18.412461162952987, name = testschip-7363
# inode = 1, speed = 13.820175959371664, name = testschip-10010
# origin = 8868083.0, destination = 8863475.0
# inode = 1, speed = 7.575478317588764, name = testschip-9735
# inode = 0, speed = 9.368778780182174, name = testschip-8385
# origin = B5729_A, destination = B5729_B
# inode = 1, speed = 13.276328347242208, name = testschip-6735
# origin = B5729_B, destination = 8867449.0
# inode = 2, speed = 14.441965238022163, name = testschip-6735
# inode = 0, speed = 12.586684705000286, name = testschip-12115
# origin = 8863475.0, destination = 8865217.0
# inode = 1, speed = 8.130663526902593, name = testschip-9890
# inode = 1, speed = 16.932982841032413, name = testschip-9088
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 15.895866888494757, name = testschip-11372
# inode = 1, speed = 18.412461162952987, name = testschip-7363
# origin = 8863475.0, destination = 8865217.0
# inode = 1, speed = 7.787329519608238, name = testschip-5953
# origin = 8866305.0, destination = 8864266.0
# inode = 2, speed = 20.262790396551004, name = testschip-8110
# inode = 1, speed = 15.895866888494757, name = testschip-11372
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 15.522492101007293, name = testschip-12011
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 17.227825149390696, name = testschip-9735
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 15.638895626922189, name = testschip-12927
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 16.947142226774695, name = testschip-11583
# inode = 1, speed = 15.522492101007293, name = testschip-12011
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 13.649383908887186, name = testschip-9465
# inode = 1, speed = 17.227825149390696, name = testschip-9735
# origin = 8868177.0, destination = 8862214.0
# inode = 3, speed = 18.478615934637865, name = testschip-10756
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 15.312662431582705, name = testschip-12440
# inode = 1, speed = 16.947142226774695, name = testschip-11583
# inode = 1, speed = 15.638895626922189, name = testschip-12927
# inode = 0, speed = 10.934059050040297, name = testschip-4951
# inode = 0, speed = 10.8253744568139, name = testschip-9317
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 12.332368548344762, name = testschip-6043
# inode = 1, speed = 13.649383908887186, name = testschip-9465
# inode = 1, speed = 15.312662431582705, name = testschip-12440
# inode = 0, speed = 8.271659427543254, name = testschip-6120
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 13.890473875140865, name = testschip-9265
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 14.58446741812788, name = testschip-10445
# origin = 8861732.0, destination = 8868083.0
# inode = 1, speed = 10.65606694946942, name = testschip-6043
# inode = 0, speed = 10.221945684081144, name = testschip-9265
# inode = 1, speed = 12.332368548344762, name = testschip-6043
# inode = 1, speed = 13.890473875140865, name = testschip-9265
# inode = 1, speed = 14.58446741812788, name = testschip-10445
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 10.709080921901805, name = testschip-12115
# inode = 0, speed = 7.584679128014443, name = testschip-10010
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 13.181707046213566, name = testschip-4951
# origin = 8861732.0, destination = 8868083.0
# inode = 1, speed = 6.0105151915236235, name = testschip-9086
# inode = 1, speed = 10.709080921901805, name = testschip-12115
# origin = 8860614.0, destination = B5729_A
# inode = 1, speed = 8.771800775328975, name = testschip-6735
# origin = 8867980.0, destination = 8867547.0
# inode = 1, speed = 12.599318113162456, name = testschip-12115
# inode = 2, speed = 21.07407337073666, name = testschip-6457
# origin = 8862214.0, destination = 8866780.0
# inode = 4, speed = 19.949395117852728, name = testschip-10756
# inode = 0, speed = 12.6913682245053, name = testschip-6735
# inode = 1, speed = 13.181707046213566, name = testschip-4951
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 12.117920595549108, name = testschip-9890
# origin = 8863475.0, destination = 8865217.0
# inode = 1, speed = 8.41947640901091, name = testschip-7363
# origin = 8866999.0, destination = 8867980.0
# inode = 1, speed = 15.115825087336404, name = testschip-6735
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 13.113205437305414, name = testschip-9086
# inode = 1, speed = 12.117920595549108, name = testschip-9890
# origin = 8863475.0, destination = 8865217.0
# inode = 1, speed = 7.904854047345543, name = testschip-12440
# inode = 1, speed = 13.113205437305414, name = testschip-9086
# origin = 8867547.0, destination = 8861158.0
# inode = 2, speed = 18.055228399978983, name = testschip-12115
# origin = 8864266.0, destination = 8862925.0
# inode = 1, speed = 12.03759506457212, name = testschip-8946
# inode = 0, speed = 4.9633746885987735, name = testschip-6735
# origin = 8867980.0, destination = 8867547.0
# inode = 1, speed = 10.010035790065679, name = testschip-4951
# origin = 8867980.0, destination = 8867547.0
# inode = 1, speed = 11.308392731921264, name = testschip-9317
# inode = 1, speed = 12.03759506457212, name = testschip-8946
# inode = 1, speed = 8.771800775328975, name = testschip-6735
# origin = 8868083.0, destination = 8863475.0
# inode = 2, speed = 11.34444926680744, name = testschip-6043
# origin = 8865217.0, destination = 8860596.0
# inode = 2, speed = 9.17962713148273, name = testschip-5637
# origin = 8867980.0, destination = 8867547.0
# inode = 1, speed = 10.443024525231774, name = testschip-9265
# inode = 4, speed = 19.949395117852728, name = testschip-10756
# inode = 2, speed = 14.441965238022163, name = testschip-6735
# origin = 8867547.0, destination = 8861158.0
# inode = 2, speed = 13.064300497141225, name = testschip-9317
# origin = 8867547.0, destination = 8861158.0
# inode = 2, speed = 11.874425863929234, name = testschip-4951
# inode = 0, speed = 9.848134545748662, name = testschip-6735
# origin = 8866780.0, destination = 8864748.0
# inode = 5, speed = 12.409662139782142, name = testschip-10756
# inode = 2, speed = 21.07407337073666, name = testschip-6457
# inode = 0, speed = 9.441931266093992, name = testschip-9088
# origin = 8866999.0, destination = 8867980.0
# inode = 1, speed = 12.629315404453287, name = testschip-6735
# origin = 8867547.0, destination = 8861158.0
# inode = 2, speed = 16.367347578173348, name = testschip-9265
# origin = B5729_A, destination = B5729_B
# inode = 1, speed = 10.484369571697076, name = testschip-6735
# origin = B5729_B, destination = 8867449.0
# inode = 2, speed = 13.071937174821501, name = testschip-6735
# origin = 8866999.0, destination = 8867980.0
# inode = 1, speed = 12.602276888581814, name = testschip-9317
# inode = 0, speed = 9.235068006296736, name = testschip-6735
# inode = 1, speed = 25.830788299596506, name = testschip-8961
# origin = 8865217.0, destination = 8860596.0
# inode = 1, speed = 9.549396850185488, name = testschip-6120
# origin = 8861732.0, destination = 8868083.0
# inode = 1, speed = 6.811161884456849, name = testschip-5000
# origin = 8865217.0, destination = 8860596.0
# inode = 2, speed = 8.155006017512735, name = testschip-9890
# origin = 8866999.0, destination = 8867980.0
# inode = 1, speed = 8.88176079109228, name = testschip-9088
# origin = 8864266.0, destination = 8862925.0
# inode = 3, speed = 22.387012122883657, name = testschip-8110
# origin = 8865217.0, destination = 8860596.0
# inode = 2, speed = 7.240755767759047, name = testschip-5953
# origin = 8866999.0, destination = 8867980.0
# inode = 1, speed = 9.886595245294057, name = testschip-6735
# origin = 8861158.0, destination = 8861674.0
# inode = 3, speed = 20.93761037583957, name = testschip-12115
# inode = 1, speed = 24.379477314498573, name = testschip-9317
# inode = 3, speed = 22.387012122883657, name = testschip-8110
# origin = 8868083.0, destination = 8863475.0
# inode = 2, speed = 6.562763672392209, name = testschip-9086
# origin = 8863475.0, destination = 8865217.0
# inode = 2, speed = 7.43477062879004, name = testschip-9735
# origin = 8865217.0, destination = 8860596.0
# inode = 1, speed = 10.142559353348233, name = testschip-10010
# inode = 1, speed = 22.31264617248797, name = testschip-5316
# origin = 8860596.0, destination = 8867980.0
# inode = 1, speed = 8.449406837862611, name = testschip-11583
# inode = 3, speed = 20.93761037583957, name = testschip-12115
# inode = 1, speed = 22.6989224168711, name = testschip-7484
# origin = 8860596.0, destination = 8867980.0
# inode = 1, speed = 6.591289826325836, name = testschip-8332
# inode = 0, speed = 8.01958311487492, name = testschip-8397
# origin = 8864002.0, destination = 8861067.0
# inode = 1, speed = 9.4305168244907, name = testschip-8385
# inode = 1, speed = 8.771800775328975, name = testschip-6735
# inode = 1, speed = 21.33578651800457, name = testschip-5000
# inode = 2, speed = 21.07407337073666, name = testschip-6457
# origin = 8866999.0, destination = 8867980.0
# inode = 1, speed = 12.080114404517374, name = testschip-8397
# inode = 1, speed = 15.115825087336404, name = testschip-6735
# origin = 8865217.0, destination = 8860596.0
# inode = 2, speed = 9.049931890658526, name = testschip-7363
# inode = 2, speed = 14.441965238022163, name = testschip-6735
# inode = 1, speed = 21.015621104916608, name = testschip-7363
# origin = 8863475.0, destination = 8865217.0
# inode = 3, speed = 9.712031082549727, name = testschip-6043
# origin = 8861158.0, destination = 8861674.0
# inode = 3, speed = 19.052248025849387, name = testschip-9265
# origin = 8865217.0, destination = 8860596.0
# inode = 2, speed = 8.205581973476537, name = testschip-12440
# origin = B5729_A, destination = B5729_B
# inode = 2, speed = 11.621553566193436, name = testschip-6735
# origin = 8861158.0, destination = 8861674.0
# inode = 3, speed = 15.667590734022784, name = testschip-9317
# origin = B5729_B, destination = 8867449.0
# inode = 3, speed = 14.838673159060075, name = testschip-6735
# origin = 8861067.0, destination = 8865127.0
# inode = 2, speed = 12.323293135891086, name = testschip-8385
# origin = 8866999.0, destination = 8867980.0
# inode = 1, speed = 9.99506336467835, name = testschip-7363
# origin = 8865127.0, destination = 8868177.0
# inode = 3, speed = 13.73204839529375, name = testschip-8385
# origin = 8860596.0, destination = 8867980.0
# inode = 1, speed = 5.4181836390327165, name = testschip-11372
# origin = 8861158.0, destination = 8861674.0
# inode = 3, speed = 15.7605346134957, name = testschip-4951
# inode = 3, speed = 19.052248025849387, name = testschip-9265
# origin = 8868083.0, destination = 8863475.0
# inode = 2, speed = 6.860648514022476, name = testschip-5000
# inode = 1, speed = 16.894940991265635, name = testschip-9317
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 16.418767930694752, name = testschip-6735
# inode = 1, speed = 18.412461162952987, name = testschip-7363
# inode = 3, speed = 15.667590734022784, name = testschip-9317
# inode = 2, speed = 14.441965238022163, name = testschip-6735
# inode = 3, speed = 20.93761037583957, name = testschip-12115
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 24.817012415710433, name = testschip-8961
# inode = 3, speed = 15.7605346134957, name = testschip-4951
# inode = 2, speed = 13.071937174821501, name = testschip-6735
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 19.018657625005886, name = testschip-6735
# origin = 8860596.0, destination = 8867980.0
# inode = 1, speed = 6.046311114344642, name = testschip-6394
# inode = 1, speed = 16.39893627606805, name = testschip-8397
# inode = 1, speed = 16.932982841032413, name = testschip-9088
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 24.183479641015552, name = testschip-8961
# inode = 2, speed = 21.07407337073666, name = testschip-6457
# inode = 3, speed = 24.183479641015552, name = testschip-8961
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 23.538411030266147, name = testschip-9317
# inode = 1, speed = 17.227825149390696, name = testschip-9735
# inode = 1, speed = 16.947142226774695, name = testschip-11583
# inode = 1, speed = 15.895866888494757, name = testschip-11372
# inode = 1, speed = 12.629315404453287, name = testschip-6735
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 22.45235274490734, name = testschip-9317
# inode = 0, speed = 5.7422761347386055, name = testschip-5316
# origin = 8868083.0, destination = 8863475.0
# inode = 1, speed = 9.165162475440592, name = testschip-2923
# inode = 1, speed = 12.602276888581814, name = testschip-9317
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 6.765001563420722, name = testschip-11583
# inode = 3, speed = 22.45235274490734, name = testschip-9317
# inode = 1, speed = 15.522492101007293, name = testschip-12011
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 22.693634527307967, name = testschip-5316
# inode = 1, speed = 15.638895626922189, name = testschip-12927
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 22.034266277087713, name = testschip-7484
# inode = 3, speed = 20.93761037583957, name = testschip-12115
# inode = 1, speed = 13.820175959371664, name = testschip-10010
# inode = 2, speed = 14.441965238022163, name = testschip-6735
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 24.139163250739472, name = testschip-5316
# inode = 1, speed = 15.312662431582705, name = testschip-12440
# origin = 8865217.0, destination = 8860596.0
# inode = 3, speed = 7.674490066835483, name = testschip-9735
# inode = 3, speed = 19.052248025849387, name = testschip-9265
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 21.572743396411912, name = testschip-7484
# inode = 3, speed = 14.838673159060075, name = testschip-6735
# inode = 3, speed = 24.139163250739472, name = testschip-5316
# origin = 8865217.0, destination = 8860596.0
# inode = 4, speed = 9.70728315305904, name = testschip-6043
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 25.658053157814923, name = testschip-6735
# inode = 3, speed = 21.572743396411912, name = testschip-7484
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 21.246072167015328, name = testschip-5000
# origin = 8866999.0, destination = 8867980.0
# inode = 1, speed = 6.681213181473527, name = testschip-12927
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 13.74489693793765, name = testschip-11583
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 15.410496263157912, name = testschip-6735
# inode = 1, speed = 14.58446741812788, name = testschip-10445
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 6.560919832621412, name = testschip-8332
# origin = 8866999.0, destination = 8867980.0
# inode = 1, speed = 10.366439985602382, name = testschip-8961
# inode = 3, speed = 15.667590734022784, name = testschip-9317
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 14.340464487944047, name = testschip-9317
# inode = 2, speed = 21.07407337073666, name = testschip-6457
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 21.39230471113606, name = testschip-5000
# inode = 4, speed = 25.658053157814923, name = testschip-6735
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 21.544942649652114, name = testschip-7363
# inode = 3, speed = 22.387012122883657, name = testschip-8110
# inode = 1, speed = 9.886595245294057, name = testschip-6735
# inode = 1, speed = 13.649383908887186, name = testschip-9465
# origin = 8863475.0, destination = 8865217.0
# inode = 3, speed = 6.463829816753122, name = testschip-9086
# inode = 3, speed = 15.7605346134957, name = testschip-4951
# inode = 1, speed = 13.890473875140865, name = testschip-9265
# inode = 2, speed = 13.071937174821501, name = testschip-6735
# inode = 3, speed = 21.39230471113606, name = testschip-5000
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 19.339933100156397, name = testschip-6735
# inode = 1, speed = 12.080114404517374, name = testschip-8397
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 19.963564554574308, name = testschip-7363
# origin = 8860596.0, destination = 8867980.0
# inode = 3, speed = 7.618317873215994, name = testschip-5637
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 19.1591615266083, name = testschip-9317
# inode = 1, speed = 8.88176079109228, name = testschip-9088
# inode = 3, speed = 19.963564554574308, name = testschip-7363
# inode = 2, speed = 14.441965238022163, name = testschip-6735
# origin = 8868083.0, destination = 8863475.0
# inode = 1, speed = 8.790418579101214, name = testschip-8946
# inode = 3, speed = 24.183479641015552, name = testschip-8961
# origin = 8868083.0, destination = 8863475.0
# inode = 1, speed = 7.734576719166907, name = testschip-10445
# inode = 3, speed = 20.93761037583957, name = testschip-12115
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 13.785654529167696, name = testschip-8332
# inode = 1, speed = 13.181707046213566, name = testschip-4951
# origin = 8860596.0, destination = 8867980.0
# inode = 2, speed = 9.167159478885278, name = testschip-6120
# inode = 3, speed = 19.052248025849387, name = testschip-9265
# inode = 1, speed = 12.332368548344762, name = testschip-6043
# inode = 2, speed = 13.071937174821501, name = testschip-6735
# origin = 8860596.0, destination = 8867980.0
# inode = 2, speed = 8.25155871422304, name = testschip-10010
# origin = 8868177.0, destination = 8862214.0
# inode = 4, speed = 17.013295967917006, name = testschip-8385
# inode = 4, speed = 25.658053157814923, name = testschip-6735
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 19.96517119884188, name = testschip-7363
# inode = 3, speed = 22.45235274490734, name = testschip-9317
# inode = 1, speed = 13.113205437305414, name = testschip-9086
# inode = 3, speed = 14.838673159060075, name = testschip-6735
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 11.48338216767658, name = testschip-8397
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 10.507215873207516, name = testschip-6735
# inode = 1, speed = 9.99506336467835, name = testschip-7363
# origin = 8861732.0, destination = 8868083.0
# inode = 1, speed = 6.614133250759744, name = testschip-5316
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 20.88332863259327, name = testschip-9317
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 20.146367356408675, name = testschip-7363
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 5.498710579278246, name = testschip-11372
# origin = 8863475.0, destination = 8865217.0
# inode = 3, speed = 6.907336222397929, name = testschip-5000
# origin = 8868083.0, destination = 8863475.0
# inode = 1, speed = 8.532965352393726, name = testschip-8110
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 23.46695704781559, name = testschip-6735
# inode = 3, speed = 24.139163250739472, name = testschip-5316
# inode = 1, speed = 12.117920595549108, name = testschip-9890
# origin = 8863475.0, destination = 8865217.0
# inode = 2, speed = 7.915342778088401, name = testschip-2923
# inode = 2, speed = 14.441965238022163, name = testschip-6735
# inode = 3, speed = 20.146367356408675, name = testschip-7363
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 21.20190035959906, name = testschip-9317
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 26.074042396077072, name = testschip-9317
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 18.363285696240386, name = testschip-11583
# inode = 3, speed = 15.667590734022784, name = testschip-9317
# origin = 8860596.0, destination = 8867980.0
# inode = 3, speed = 7.370631157785241, name = testschip-9890
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 6.117090774995243, name = testschip-6394
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 8.782512699543014, name = testschip-9088
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 15.765330274192248, name = testschip-8397
# origin = 8862214.0, destination = 8866780.0
# inode = 5, speed = 19.17284213604882, name = testschip-8385
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 13.19360694518694, name = testschip-9088
# inode = 3, speed = 21.572743396411912, name = testschip-7484
# inode = 3, speed = 21.20190035959906, name = testschip-9317
# inode = 3, speed = 15.7605346134957, name = testschip-4951
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 18.95636232594389, name = testschip-6735
# inode = 4, speed = 23.46695704781559, name = testschip-6735
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 16.44872038696332, name = testschip-8397
# inode = 4, speed = 26.074042396077072, name = testschip-9317
# inode = 5, speed = 12.409662139782142, name = testschip-10756
# inode = 3, speed = 14.838673159060075, name = testschip-6735
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 17.46142769462671, name = testschip-9735
# inode = 1, speed = 12.03759506457212, name = testschip-8946
# inode = 4, speed = 18.363285696240386, name = testschip-11583
# inode = 3, speed = 20.93761037583957, name = testschip-12115
# inode = 1, speed = 10.709080921901805, name = testschip-12115
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 17.317255084029206, name = testschip-11583
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 13.392873303849273, name = testschip-9088
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 17.4745848827113, name = testschip-8397
# inode = 4, speed = 25.658053157814923, name = testschip-6735
# origin = 8860596.0, destination = 8867980.0
# inode = 3, speed = 8.081781205958238, name = testschip-7363
# inode = 3, speed = 19.052248025849387, name = testschip-9265
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 19.51705466899788, name = testschip-9735
# origin = 8867449.0, destination = 8862332.0
# inode = 3, speed = 17.285495587628063, name = testschip-6735
# inode = 3, speed = 21.39230471113606, name = testschip-5000
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 16.329612335649855, name = testschip-9088
# inode = 3, speed = 17.4745848827113, name = testschip-8397
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 11.257534134988614, name = testschip-11372
# inode = 2, speed = 21.07407337073666, name = testschip-6457
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 19.1902457759287, name = testschip-11372
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 15.257083942048023, name = testschip-11583
# inode = 3, speed = 13.392873303849273, name = testschip-9088
# origin = 8860596.0, destination = 8867980.0
# inode = 3, speed = 7.305715344631071, name = testschip-5953
# inode = 3, speed = 19.51705466899788, name = testschip-9735
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 17.125156285382776, name = testschip-8332
# inode = 2, speed = 13.071937174821501, name = testschip-6735
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 10.788737437673992, name = testschip-7363
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 13.703008430670266, name = testschip-6394
# origin = 8862925.0, destination = 8864465.0
# inode = 4, speed = 21.997898860863813, name = testschip-8110
# inode = 3, speed = 17.285495587628063, name = testschip-6735
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 21.67923750567213, name = testschip-11372
# inode = 3, speed = 15.257083942048023, name = testschip-11583
# inode = 3, speed = 19.963564554574308, name = testschip-7363
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 15.138747124381672, name = testschip-12011
# origin = 8864465.0, destination = S14716_B
# inode = 5, speed = 24.849849869184926, name = testschip-8110
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 15.021340050881332, name = testschip-12927
# inode = 5, speed = 19.17284213604882, name = testschip-8385
# origin = 8867980.0, destination = 8867547.0
# inode = 4, speed = 8.787447659275497, name = testschip-5637
# inode = 3, speed = 21.67923750567213, name = testschip-11372
# origin = 8860596.0, destination = 8867980.0
# inode = 3, speed = 7.213536216252901, name = testschip-12440
# inode = 0, speed = 1.497435684083568, name = testschip-8385
# inode = 5, speed = 24.849849869184926, name = testschip-8110
# origin = 8867980.0, destination = 8867547.0
# inode = 3, speed = 9.368762778122418, name = testschip-6120
# inode = 4, speed = 17.125156285382776, name = testschip-8332
# origin = 8866780.0, destination = 8864748.0
# inode = 6, speed = 19.17746068119813, name = testschip-8385
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 16.761619127296928, name = testschip-7363
# inode = 4, speed = 26.074042396077072, name = testschip-9317
# inode = 4, speed = 23.46695704781559, name = testschip-6735
# origin = 8868083.0, destination = 8863475.0
# inode = 1, speed = 6.457890142458117, name = testschip-12011
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 14.975997689308384, name = testschip-12011
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 25.266107721508398, name = testschip-6735
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 16.29017309982947, name = testschip-12440
# origin = 8863475.0, destination = 8865217.0
# inode = 2, speed = 8.37279379288886, name = testschip-8946
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 15.54296061053414, name = testschip-12927
# inode = 4, speed = 25.658053157814923, name = testschip-6735
# origin = 8868083.0, destination = 8863475.0
# inode = 2, speed = 7.857482885267018, name = testschip-5316
# inode = 3, speed = 14.838673159060075, name = testschip-6735
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 19.98792397206618, name = testschip-8397
# origin = 8865217.0, destination = 8860596.0
# inode = 4, speed = 6.1347579671807075, name = testschip-9086
# inode = 3, speed = 15.667590734022784, name = testschip-9317
# inode = 3, speed = 14.975997689308384, name = testschip-12011
# inode = 3, speed = 15.54296061053414, name = testschip-12927
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 16.8540800740804, name = testschip-12440
# origin = 8867980.0, destination = 8867547.0
# inode = 3, speed = 8.574170384193932, name = testschip-10010
# inode = 4, speed = 25.266107721508398, name = testschip-6735
# inode = 1, speed = 10.366439985602382, name = testschip-8961
# origin = 8867547.0, destination = 8861158.0
# inode = 5, speed = 17.133056049601667, name = testschip-5637
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 17.97756193789495, name = testschip-10010
# inode = 3, speed = 15.7605346134957, name = testschip-4951
# inode = 3, speed = 20.93761037583957, name = testschip-12115
# origin = 8867547.0, destination = 8861158.0
# inode = 4, speed = 18.221723748098306, name = testschip-6120
# inode = 4, speed = 18.363285696240386, name = testschip-11583
# origin = 8863475.0, destination = 8865217.0
# inode = 2, speed = 8.069844467759834, name = testschip-10445
# inode = 2, speed = 13.071937174821501, name = testschip-6735
# inode = 3, speed = 16.8540800740804, name = testschip-12440
# inode = 4, speed = 19.98792397206618, name = testschip-8397
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 15.18119268591501, name = testschip-10445
# inode = 3, speed = 19.052248025849387, name = testschip-9265
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 17.306937942647302, name = testschip-10010
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 21.83580102707292, name = testschip-9088
# inode = 3, speed = 20.146367356408675, name = testschip-7363
# inode = 3, speed = 21.20190035959906, name = testschip-9317
# inode = 3, speed = 17.306937942647302, name = testschip-10010
# origin = 8861674.0, destination = 8860845.0
# inode = 3, speed = 20.79202643089169, name = testschip-6457
# inode = 4, speed = 26.074042396077072, name = testschip-9317
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 15.460892033672016, name = testschip-10445
# origin = 8867547.0, destination = 8861158.0
# inode = 4, speed = 16.088659327691882, name = testschip-10010
# origin = 8864748.0, destination = 8865822.0
# inode = 6, speed = 7.821171881342129, name = testschip-10756
# inode = 3, speed = 24.183479641015552, name = testschip-8961
# origin = 8865217.0, destination = 8860596.0
# inode = 3, speed = 6.6254729501349985, name = testschip-2923
# origin = 8860596.0, destination = 8867980.0
# inode = 5, speed = 8.862135248321481, name = testschip-6043
# inode = 4, speed = 23.46695704781559, name = testschip-6735
# origin = 8863475.0, destination = 8865217.0
# inode = 2, speed = 8.365146683744651, name = testschip-8110
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 15.527631450570908, name = testschip-9265
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 15.35472334235116, name = testschip-9465
# inode = 4, speed = 21.83580102707292, name = testschip-9088
# inode = 3, speed = 14.838673159060075, name = testschip-6735
# origin = 8867980.0, destination = 8867547.0
# inode = 4, speed = 5.464455509873177, name = testschip-9890
# inode = 4, speed = 25.658053157814923, name = testschip-6735
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 19.23495777659265, name = testschip-6394
# inode = 3, speed = 15.460892033672016, name = testschip-10445
# origin = 8865217.0, destination = 8860596.0
# inode = 4, speed = 7.21599749940891, name = testschip-5000
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 22.406820375250835, name = testschip-7363
# inode = 3, speed = 20.79202643089169, name = testschip-6457
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 15.401809194936483, name = testschip-9265
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 15.853004199556443, name = testschip-9465
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 18.256515387942354, name = testschip-11372
# inode = 4, speed = 25.266107721508398, name = testschip-6735
# origin = 8867980.0, destination = 8867547.0
# inode = 4, speed = 7.8199565373234226, name = testschip-7363
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 9.903409773713694, name = testschip-8961
# inode = 4, speed = 17.125156285382776, name = testschip-8332
# origin = 8862332.0, destination = 8862930.0
# inode = 4, speed = 16.49416085783862, name = testschip-6735
# inode = 4, speed = 19.23495777659265, name = testschip-6394
# inode = 5, speed = 24.849849869184926, name = testschip-8110
# inode = 3, speed = 15.853004199556443, name = testschip-9465
# inode = 3, speed = 15.401809194936483, name = testschip-9265
# inode = 3, speed = 19.51705466899788, name = testschip-9735
# inode = 4, speed = 22.406820375250835, name = testschip-7363
# inode = 2, speed = 13.071937174821501, name = testschip-6735
# origin = 8861158.0, destination = 8861674.0
# inode = 5, speed = 24.325831470924964, name = testschip-6120
# origin = 8861158.0, destination = 8861674.0
# inode = 6, speed = 22.932425636804442, name = testschip-5637
# inode = 3, speed = 21.67923750567213, name = testschip-11372
# inode = 3, speed = 17.4745848827113, name = testschip-8397
# inode = 3, speed = 22.45235274490734, name = testschip-9317
# inode = 4, speed = 18.256515387942354, name = testschip-11372
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 13.44968047666955, name = testschip-4951
# inode = 4, speed = 18.363285696240386, name = testschip-11583
# inode = 4, speed = 26.074042396077072, name = testschip-9317
# inode = 3, speed = 24.139163250739472, name = testschip-5316
# inode = 4, speed = 19.98792397206618, name = testschip-8397
# origin = 8867980.0, destination = 8867547.0
# inode = 4, speed = 9.225688792681163, name = testschip-5953
# origin = 8867547.0, destination = 8861158.0
# inode = 3, speed = 15.62014434205218, name = testschip-8961
# inode = 3, speed = 15.667590734022784, name = testschip-9317
# origin = 8860596.0, destination = 8867980.0
# inode = 4, speed = 5.9456456459253895, name = testschip-9735
# inode = 5, speed = 24.325831470924964, name = testschip-6120
# inode = 3, speed = 20.79202643089169, name = testschip-6457
# inode = 6, speed = 22.932425636804442, name = testschip-5637
# inode = 1, speed = 6.681213181473527, name = testschip-12927
# origin = 8867547.0, destination = 8861158.0
# inode = 5, speed = 16.01686739300987, name = testschip-7363
# origin = 8867547.0, destination = 8861158.0
# inode = 5, speed = 12.071829010428633, name = testschip-9890
# inode = 3, speed = 14.838673159060075, name = testschip-6735
# inode = 4, speed = 23.46695704781559, name = testschip-6735
# inode = 3, speed = 15.7605346134957, name = testschip-4951
# inode = 3, speed = 19.052248025849387, name = testschip-9265
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 14.29657226278517, name = testschip-4951
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 12.553222880536099, name = testschip-9086
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 13.336180505783513, name = testschip-6043
# inode = 4, speed = 25.658053157814923, name = testschip-6735
# origin = S14716_B, destination = S14716_A
# inode = 4, speed = 23.54994686632067, name = testschip-8961
# origin = S14716_A, destination = 8860845.0
# inode = 5, speed = 21.18715408941499, name = testschip-8961
# inode = 4, speed = 21.83580102707292, name = testschip-9088
# origin = 8861158.0, destination = 8861674.0
# inode = 5, speed = 21.80027759717559, name = testschip-10010
# inode = 5, speed = 21.18715408941499, name = testschip-8961
# origin = 8860845.0, destination = 8861674.0
# inode = 6, speed = 11.802234385423866, name = testschip-8961
# inode = 4, speed = 25.266107721508398, name = testschip-6735
# origin = 8865217.0, destination = 8860596.0
# inode = 3, speed = 8.491368428351524, name = testschip-8946
# origin = 8867449.0, destination = 8862332.0
# inode = 3, speed = 13.93975476878799, name = testschip-6735
# origin = 8867980.0, destination = 8867547.0
# inode = 4, speed = 6.166044106009139, name = testschip-12440
# inode = 3, speed = 15.257083942048023, name = testschip-11583
# inode = 3, speed = 20.79202643089169, name = testschip-6457
# inode = 3, speed = 14.29657226278517, name = testschip-4951
# origin = 8867547.0, destination = 8861158.0
# inode = 5, speed = 13.353434279948535, name = testschip-5953
# inode = 3, speed = 21.572743396411912, name = testschip-7484
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 17.437390403748275, name = testschip-6043
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 13.058235502002233, name = testschip-9086
# inode = 3, speed = 13.392873303849273, name = testschip-9088
# inode = 5, speed = 21.80027759717559, name = testschip-10010
# inode = 3, speed = 20.93761037583957, name = testschip-12115
# origin = 8867449.0, destination = 8862332.0
# inode = 4, speed = 14.220733314146845, name = testschip-6735
# inode = 3, speed = 20.79202643089169, name = testschip-6457
# inode = 3, speed = 17.437390403748275, name = testschip-6043
# inode = 3, speed = 13.93975476878799, name = testschip-6735
# inode = 4, speed = 22.406820375250835, name = testschip-7363
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 11.981150024135422, name = testschip-9890
# inode = 3, speed = 13.058235502002233, name = testschip-9086
# origin = 8863475.0, destination = 8865217.0
# inode = 3, speed = 8.702327288220602, name = testschip-5316
# inode = 4, speed = 26.074042396077072, name = testschip-9317
# inode = 4, speed = 17.125156285382776, name = testschip-8332
# origin = 8865217.0, destination = 8860596.0
# inode = 3, speed = 7.810311338353058, name = testschip-10445
# inode = 4, speed = 19.23495777659265, name = testschip-6394
# inode = 3, speed = 15.54296061053414, name = testschip-12927
# inode = 3, speed = 21.39230471113606, name = testschip-5000
# inode = 3, speed = 16.8540800740804, name = testschip-12440
# origin = 8867980.0, destination = 8867547.0
# inode = 6, speed = 8.857835751121753, name = testschip-6043
# inode = 3, speed = 14.975997689308384, name = testschip-12011
# inode = 5, speed = 24.325831470924964, name = testschip-6120
# inode = 4, speed = 14.220733314146845, name = testschip-6735
# inode = 4, speed = 16.49416085783862, name = testschip-6735
# inode = 4, speed = 19.98792397206618, name = testschip-8397
# origin = S14716_B, destination = S14716_A
# inode = 4, speed = 25.584691974170973, name = testschip-5316
# origin = S14716_B, destination = S14716_A
# inode = 4, speed = 21.366294459548534, name = testschip-9317
# origin = S14716_A, destination = 8860845.0
# inode = 5, speed = 23.342567070931693, name = testschip-5316
# origin = S14716_A, destination = 8860845.0
# inode = 5, speed = 23.148893005772386, name = testschip-9317
# inode = 6, speed = 22.932425636804442, name = testschip-5637
# origin = 8867547.0, destination = 8867980.0
# inode = 5, speed = 6.404531124899903, name = testschip-12440
# inode = 4, speed = 18.363285696240386, name = testschip-11583
# inode = 5, speed = 23.342567070931693, name = testschip-5316
# origin = 8864465.0, destination = S14716_B
# inode = 3, speed = 11.428455966526613, name = testschip-9890
# origin = 8860845.0, destination = 8861674.0
# inode = 6, speed = 17.127009248019313, name = testschip-5316
# inode = 5, speed = 23.148893005772386, name = testschip-9317
# inode = 4, speed = 23.46695704781559, name = testschip-6735
# origin = 8860845.0, destination = 8861674.0
# inode = 6, speed = 16.82563560426518, name = testschip-9317
# inode = 4, speed = 18.256515387942354, name = testschip-11372
# inode = 3, speed = 17.306937942647302, name = testschip-10010
# origin = 8862925.0, destination = 8864465.0
# inode = 2, speed = 10.968755601825046, name = testschip-8946
# inode = 4, speed = 25.266107721508398, name = testschip-6735
# origin = 8865217.0, destination = 8860596.0
# inode = 3, speed = 6.860070390158527, name = testschip-8110
# origin = 8863475.0, destination = 8865217.0
# inode = 2, speed = 7.477430771555167, name = testschip-12011
# origin = 8861158.0, destination = 8861674.0
# inode = 4, speed = 19.465091158300453, name = testschip-8961
# inode = 4, speed = 21.83580102707292, name = testschip-9088
# origin = 8861158.0, destination = 8861674.0
# inode = 6, speed = 22.08539204591146, name = testschip-7363
# inode = 3, speed = 11.428455966526613, name = testschip-9890
# inode = 6, speed = 19.17746068119813, name = testschip-8385
# origin = 8867547.0, destination = 8861158.0
# inode = 7, speed = 16.750843652090634, name = testschip-6043
# origin = 8867980.0, destination = 8867547.0
# inode = 2, speed = 7.238356838644707, name = testschip-12927
# ...
# origin = 8867980.0, destination = 8860596.0
# inode = 10, speed = 5.8854568629428625, name = testschip-8946
# inode = 25, speed = 8.911838115350195, name = testschip-6735
# origin = 8865217.0, destination = 8863475.0
# inode = 12, speed = 4.7312208784486565, name = testschip-10445
# origin = 8867547.0, destination = 8867980.0
# inode = 18, speed = 3.6870211057258215, name = testschip-8385
# inode = 7, speed = 2.671364297457504, name = testschip-12011
# origin = 8860596.0, destination = 8864988.0
# inode = 3, speed = 0.8407842895050613, name = testschip-8385
# origin = 8867980.0, destination = 8860596.0
# inode = 19, speed = 1.1117900666064309, name = testschip-8385
# origin = 8867547.0, destination = 8867980.0
# inode = 17, speed = 3.918986713685463, name = testschip-10756
# origin = 8868083.0, destination = 8861732.0
# inode = 16, speed = 2.0998929333915637, name = testschip-6043
# origin = 8860596.0, destination = 8865217.0
# inode = 11, speed = 3.5559827806500555, name = testschip-8946
# inode = 25, speed = 2.9112668475750767, name = testschip-6735
# inode = 25, speed = 8.911838115350195, name = testschip-6735
# origin = 8867980.0, destination = 8860596.0
# inode = 18, speed = 1.3841397633046046, name = testschip-10756
# origin = 8863475.0, destination = 8868083.0
# inode = 13, speed = 2.897917032727076, name = testschip-10445
# inode = 25, speed = 8.911838115350195, name = testschip-6735
# origin = 8865217.0, destination = 8863475.0
# inode = 12, speed = 3.3260043291273624, name = testschip-9890
# inode = 25, speed = 8.911838115350195, name = testschip-6735
# origin = 8861158.0, destination = 8867547.0
# inode = 26, speed = 9.00727918119084, name = testschip-6735
# inode = 7, speed = 2.671364297457504, name = testschip-12011
# origin = 8867547.0, destination = 8867980.0
# inode = 27, speed = 8.890022522859722, name = testschip-6735
# origin = 8863475.0, destination = 8868083.0
# inode = 13, speed = 1.658814949849706, name = testschip-9890
# origin = 8867980.0, destination = 8866999.0
# inode = 28, speed = 3.7433142744190073, name = testschip-6735
# inode = 3, speed = 0.8407842895050613, name = testschip-8385
# inode = 28, speed = 3.7433142744190073, name = testschip-6735
# origin = 8860596.0, destination = 8864988.0
# inode = 20, speed = 0.9264530453427692, name = testschip-8385
# inode = 7, speed = 2.671364297457504, name = testschip-12011
# inode = 3, speed = 0.8407842895050613, name = testschip-8385
# inode = 20, speed = 0.9264530453427692, name = testschip-8385
# inode = 7, speed = 2.671364297457504, name = testschip-12011
# origin = 8861158.0, destination = 8867547.0
# inode = 8, speed = 2.6743877987083797, name = testschip-12011
# inode = 20, speed = 0.9264530453427692, name = testschip-8385
# origin = 8867547.0, destination = 8867980.0
# inode = 9, speed = 3.3691693286701137, name = testschip-12011
# origin = 8867980.0, destination = 8860596.0
# inode = 10, speed = 4.977964707110749, name = testschip-12011
# origin = 8864988.0, destination = 8860596.0
# inode = 4, speed = 3.6672726342103648, name = testschip-8385
# origin = 8860596.0, destination = 8865217.0
# inode = 11, speed = 5.2162648874148285, name = testschip-12011
# inode = 4, speed = 3.6672726342103648, name = testschip-8385
# inode = 4, speed = 3.6672726342103648, name = testschip-8385
# origin = 8860596.0, destination = 8864988.0
# inode = 5, speed = 0.9563833504656194, name = testschip-8385
# origin = 8865217.0, destination = 8863475.0
# inode = 12, speed = 3.516890822293496, name = testschip-12011
# origin = 8864988.0, destination = 8860596.0
# inode = 21, speed = 0.8770547644926949, name = testschip-8385
# origin = 8863475.0, destination = 8868083.0
# inode = 13, speed = 1.516989643709333, name = testschip-12011
# inode = 5, speed = 0.9563833504656194, name = testschip-8385
# inode = 5, speed = 0.9563833504656194, name = testschip-8385
# inode = 21, speed = 0.8770547644926949, name = testschip-8385
# inode = 21, speed = 0.8770547644926949, name = testschip-8385
# origin = 8864988.0, destination = 8860596.0
# inode = 6, speed = 3.3615905071628345, name = testschip-8385
# inode = 6, speed = 3.3615905071628345, name = testschip-8385
# origin = 8860596.0, destination = 8864988.0
# inode = 22, speed = 1.1174485695872758, name = testschip-8385
# inode = 6, speed = 3.3615905071628345, name = testschip-8385
# origin = 8860596.0, destination = 8864988.0
# inode = 7, speed = 1.4638868551779645, name = testschip-8385
# inode = 22, speed = 1.1174485695872758, name = testschip-8385
# inode = 7, speed = 1.4638868551779645, name = testschip-8385
# inode = 7, speed = 1.4638868551779645, name = testschip-8385
# inode = 22, speed = 1.1174485695872758, name = testschip-8385
# origin = 8864988.0, destination = 8860596.0
# inode = 8, speed = 4.196495251433444, name = testschip-8385
# origin = 8864988.0, destination = 8860596.0
# inode = 23, speed = 0.7896889084976798, name = testschip-8385
# inode = 8, speed = 4.196495251433444, name = testschip-8385
# inode = 8, speed = 4.196495251433444, name = testschip-8385
# origin = 8860596.0, destination = 8867980.0
# inode = 9, speed = 4.513125755279523, name = testschip-8385
# origin = 8867980.0, destination = 8867547.0
# inode = 10, speed = 4.829756259125602, name = testschip-8385
# origin = 8867547.0, destination = 8861158.0
# inode = 11, speed = 12.111217426738492, name = testschip-8385
# origin = 8861158.0, destination = 8861674.0
# inode = 12, speed = 11.56933630442042, name = testschip-8385
# inode = 12, speed = 11.56933630442042, name = testschip-8385
# inode = 12, speed = 11.56933630442042, name = testschip-8385
# inode = 12, speed = 11.56933630442042, name = testschip-8385
# inode = 12, speed = 11.56933630442042, name = testschip-8385
# inode = 12, speed = 11.56933630442042, name = testschip-8385
# inode = 23, speed = 0.7896889084976798, name = testschip-8385
# inode = 12, speed = 11.56933630442042, name = testschip-8385
# inode = 12, speed = 11.56933630442042, name = testschip-8385
# origin = 8861674.0, destination = 8860845.0
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 23, speed = 0.7896889084976798, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# origin = 8860596.0, destination = 8864988.0
# inode = 24, speed = 1.1534552692261897, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 24, speed = 1.1534552692261897, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# inode = 24, speed = 1.1534552692261897, name = testschip-8385
# inode = 13, speed = 7.7483820012313185, name = testschip-8385
# origin = 8860845.0, destination = S14716_A
# inode = 14, speed = 9.649557500573364, name = testschip-8385
# inode = 14, speed = 9.649557500573364, name = testschip-8385
# origin = S14716_A, destination = S14716_B
# inode = 15, speed = 10.08910456284078, name = testschip-8385
# origin = S14716_B, destination = 8864465.0
# inode = 16, speed = 10.280091038994325, name = testschip-8385
# inode = 16, speed = 10.280091038994325, name = testschip-8385
# origin = 8864988.0, destination = 8860596.0
# inode = 25, speed = 0.6204700667945714, name = testschip-8385
# inode = 16, speed = 10.280091038994325, name = testschip-8385
# inode = 16, speed = 10.280091038994325, name = testschip-8385
# origin = 8864465.0, destination = 8862925.0
# inode = 17, speed = 9.840996518375247, name = testschip-8385
# origin = 8862925.0, destination = 8864266.0
# inode = 18, speed = 9.459344597710224, name = testschip-8385
# inode = 18, speed = 9.459344597710224, name = testschip-8385
# inode = 18, speed = 9.459344597710224, name = testschip-8385
# origin = 8864266.0, destination = 8866305.0
# inode = 19, speed = 8.840765521513251, name = testschip-8385
# inode = 25, speed = 0.6204700667945714, name = testschip-8385
# origin = 8866305.0, destination = 8865822.0
# inode = 20, speed = 13.238372408859739, name = testschip-8385
# inode = 20, speed = 13.238372408859739, name = testschip-8385
# origin = 8865822.0, destination = 8864748.0
# inode = 21, speed = 2.532604072522625, name = testschip-8385
# inode = 25, speed = 0.6204700667945714, name = testschip-8385
# origin = 8860596.0, destination = 8864988.0
# inode = 26, speed = 0.15599639848734168, name = testschip-8385
# origin = 8864748.0, destination = 8866780.0
# inode = 22, speed = 10.498401906721577, name = testschip-8385
# inode = 22, speed = 10.498401906721577, name = testschip-8385
# origin = 8866780.0, destination = 8862214.0
# inode = 23, speed = 11.706869600336766, name = testschip-8385
# inode = 23, speed = 11.706869600336766, name = testschip-8385
# origin = 8862214.0, destination = 8868177.0
# inode = 24, speed = 10.465756307836822, name = testschip-8385
# origin = 8868177.0, destination = 8865127.0
# inode = 25, speed = 7.334462169604437, name = testschip-8385
# origin = 8865127.0, destination = 8861067.0
# inode = 26, speed = 11.369044102178831, name = testschip-8385
# origin = 8861067.0, destination = 8864002.0
# inode = 27, speed = 5.1341994878900925, name = testschip-8385
# inode = 26, speed = 0.15599639848734168, name = testschip-8385
# inode = 26, speed = 0.15599639848734168, name = testschip-8385
# origin = 8864988.0, destination = 8860596.0
# inode = 27, speed = 0.2645911967627976, name = testschip-8385
# inode = 27, speed = 0.2645911967627976, name = testschip-8385
# inode = 27, speed = 0.2645911967627976, name = testschip-8385
# origin = 8860596.0, destination = 8864988.0
# inode = 28, speed = 0.6796168117780255, name = testschip-8385
# inode = 28, speed = 0.6796168117780255, name = testschip-8385
# inode = 28, speed = 0.6796168117780255, name = testschip-8385
# origin = 8864988.0, destination = 8860596.0
# inode = 29, speed = 0.4727392585998863, name = testschip-8385
# inode = 29, speed = 0.4727392585998863, name = testschip-8385
# inode = 29, speed = 0.4727392585998863, name = testschip-8385
# origin = 8860596.0, destination = 8864988.0
# inode = 30, speed = 0.7898092832481303, name = testschip-8385
# inode = 30, speed = 0.7898092832481303, name = testschip-8385
# inode = 30, speed = 0.7898092832481303, name = testschip-8385
# origin = 8864988.0, destination = 8860596.0
# inode = 31, speed = 0.4779942475085423, name = testschip-8385
# inode = 31, speed = 0.4779942475085423, name = testschip-8385
# inode = 31, speed = 0.4779942475085423, name = testschip-8385
# origin = 8860596.0, destination = 8864988.0
# inode = 32, speed = 0.8744791233804051, name = testschip-8385
# inode = 32, speed = 0.8744791233804051, name = testschip-8385
# inode = 32, speed = 0.8744791233804051, name = testschip-8385
# origin = 8864988.0, destination = 8860596.0
# inode = 33, speed = 0.8832770300755739, name = testschip-8385
# inode = 33, speed = 0.8832770300755739, name = testschip-8385
# inode = 33, speed = 0.8832770300755739, name = testschip-8385
# origin = 8860596.0, destination = 8864988.0
# inode = 34, speed = 0.7986040381437014, name = testschip-8385
# inode = 34, speed = 0.7986040381437014, name = testschip-8385
# origin = 8864185.0, destination = 8866260.0
# inode = 0, speed = 9.677133344147908, name = testschip-3799
# inode = 0, speed = 9.677133344147908, name = testschip-3799
# inode = 34, speed = 0.7986040381437014, name = testschip-8385
# origin = 8866260.0, destination = 8864288.0
# inode = 1, speed = 8.37286310540504, name = testschip-3799
# origin = 8864288.0, destination = 8861022.0
# inode = 2, speed = 9.999801663280463, name = testschip-3799
# origin = 8861022.0, destination = 8860701.0
# inode = 3, speed = 11.913194479887572, name = testschip-3799
# origin = 8860701.0, destination = 8864748.0
# inode = 4, speed = 11.85613170449574, name = testschip-3799
# origin = 8864748.0, destination = 8865822.0
# inode = 5, speed = 6.982264984343468, name = testschip-3799
# origin = 8865822.0, destination = 8866305.0
# inode = 6, speed = 9.585292384481876, name = testschip-3799
# inode = 6, speed = 9.585292384481876, name = testschip-3799
# origin = 8864988.0, destination = 8860596.0
# inode = 35, speed = 0.3477174925245895, name = testschip-8385
# origin = 8866305.0, destination = 8864266.0
# inode = 7, speed = 13.107211384265765, name = testschip-3799
# origin = 8864266.0, destination = 8862925.0
# inode = 8, speed = 13.344068721586218, name = testschip-3799
# inode = 8, speed = 13.344068721586218, name = testschip-3799
# inode = 8, speed = 13.344068721586218, name = testschip-3799
# origin = 8862925.0, destination = 8864465.0
# inode = 9, speed = 13.03508565760066, name = testschip-3799
# origin = 8864465.0, destination = S14716_B
# inode = 10, speed = 14.202378868027516, name = testschip-3799
# inode = 10, speed = 14.202378868027516, name = testschip-3799
# inode = 10, speed = 14.202378868027516, name = testschip-3799
# inode = 10, speed = 14.202378868027516, name = testschip-3799
# origin = S14716_B, destination = S14716_A
# inode = 11, speed = 11.638348761966894, name = testschip-3799
# origin = S14716_A, destination = 8860845.0
# inode = 12, speed = 13.310228813742722, name = testschip-3799
# inode = 12, speed = 13.310228813742722, name = testschip-3799
# origin = 8860845.0, destination = 8861674.0
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 35, speed = 0.3477174925245895, name = testschip-8385
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# inode = 13, speed = 11.847273196087055, name = testschip-3799
# origin = 8861674.0, destination = 8861158.0
# inode = 14, speed = 9.818459691044795, name = testschip-3799
# inode = 14, speed = 9.818459691044795, name = testschip-3799
# inode = 14, speed = 9.818459691044795, name = testschip-3799
# inode = 14, speed = 9.818459691044795, name = testschip-3799
# inode = 14, speed = 9.818459691044795, name = testschip-3799
# inode = 14, speed = 9.818459691044795, name = testschip-3799
# inode = 14, speed = 9.818459691044795, name = testschip-3799
# inode = 35, speed = 0.3477174925245895, name = testschip-8385
# inode = 14, speed = 9.818459691044795, name = testschip-3799
# origin = 8861158.0, destination = 8867547.0
# inode = 15, speed = 7.7896461860025346, name = testschip-3799
# origin = 8867547.0, destination = 8867980.0
# inode = 16, speed = 4.925987033146458, name = testschip-3799
# origin = 8867980.0, destination = 8860596.0
# inode = 17, speed = 3.7343265928353264, name = testschip-3799
# origin = 8860596.0, destination = 8865217.0
# inode = 18, speed = 0.7191354985807414, name = testschip-3799
# origin = 8860596.0, destination = 8864988.0
# inode = 36, speed = 0.21732228285448651, name = testschip-8385
# inode = 36, speed = 0.21732228285448651, name = testschip-8385
# inode = 36, speed = 0.21732228285448651, name = testschip-8385
# origin = 8864988.0, destination = 8860596.0
# inode = 37, speed = 0.22459621327980567, name = testschip-8385
# inode = 37, speed = 0.22459621327980567, name = testschip-8385
# inode = 37, speed = 0.22459621327980567, name = testschip-8385

# %% [markdown]
# # 5. Evaluate output

# %%
# basic inspection of the first vessel of the dataset
df_log = pd.DataFrame.from_dict(vessel.log)

# %%
df_log
# Out:
#                                               Message  \
# 0                                       Start sailing
# 1   Sailing from node 8863090.0 to node 8863475.0 ...
# 2   Sailing from node 8863090.0 to node 8863475.0 ...
# 3   Sailing from node 8863475.0 to node 8865217.0 ...
# 4   Sailing from node 8863475.0 to node 8865217.0 ...
# ..                                                ...
# 83  Sailing from node 8862925.0 to node 8864266.0 ...
# 84  Sailing from node 8862925.0 to node 8864266.0 ...
# 85  Sailing from node 8862925.0 to node 8864266.0 ...
# 86  Sailing from node 8862925.0 to node 8864266.0 ...
# 87                                       Stop sailing
#
#                     Timestamp            Value  \
# 0  2019-01-01 00:00:00.000000
# 1  2019-01-01 00:00:00.000000  testschip-12440
# 2  2019-01-01 00:01:28.460093  testschip-12440
# 3  2019-01-01 00:01:28.460093  testschip-12440
# 4  2019-01-01 00:02:23.645046  testschip-12440
# ..                        ...              ...
# 83 2019-01-01 00:20:41.010849  testschip-12440
# 84 2019-01-01 00:22:09.182713  testschip-12440
# 85 2019-01-01 00:22:09.182713  testschip-12440
# 86 2019-01-01 00:22:11.346430  testschip-12440
# 87 2019-01-01 00:22:11.346430
#
#                                      Geometry
# 0   POINT (4.28248423401617 51.8883798397893)
# 1   POINT (4.28248423401617 51.8883798397893)
# 2   POINT (4.28442105542451 51.8846316430902)
# 3   POINT (4.28441264524576 51.8846350350828)
# 4   POINT (4.29044058645646 51.8858419622723)
# ..                                        ...
# 83  POINT (4.10714114771394 51.9781909994644)
# 84   POINT (4.0841372668255 51.9838622952073)
# 85   POINT (4.0841372668255 51.9838622952073)
# 86  POINT (4.08355198540297 51.9839636810505)
# 87  POINT (4.08355198540297 51.9839636810505)
#
# [88 rows x 4 columns]

# %%
# create new dataframe 

df_newlog = pd.DataFrame(columns=['From edge', 'To edge', 'Sub edge', 'Timestamp', 'From geometry', 'To geometry', 'Duration', 'Distance', 'Speed'])

for i in range(1,len(df_log.index)): 
    #print(df_log['Message'].loc[i])
    #if i<len(df_log)-1:
        
    # message 
    message = df_log['Message'].iloc[i].split()
    if message[-1] == 'start':

        # determine duration and distance
        duration = (df_log['Timestamp'].loc[i+1] - df_log['Timestamp'].loc[i]).total_seconds()
        distance = geod.inv(df_log['Geometry'].loc[i].x, df_log['Geometry'].loc[i].y, 
            df_log['Geometry'].loc[i+1].x, df_log['Geometry'].loc[i+1].y)[2]
        speed = distance / duration
            
        df_newlog = df_newlog.append({'From edge': message[3], 'To edge': message[6], 'Sub edge': message[9],
                                      'Timestamp': df_log['Timestamp'].loc[i], 
                                      'From geometry': df_log['Geometry'].loc[i], 'To geometry': df_log['Geometry'].loc[i+1],
                                      'Duration': duration, 'Distance': distance, 'Speed': speed}, ignore_index=True)

# %%
df_newlog
# Out:
#     From edge    To edge Sub edge                  Timestamp  \
# 0   8863090.0  8863475.0        0 2019-01-01 00:00:00.000000
# 1   8863475.0  8865217.0        0 2019-01-01 00:01:28.460093
# 2   8865217.0  8860596.0        0 2019-01-01 00:02:23.645046
# 3   8860596.0  8867980.0        0 2019-01-01 00:04:17.138400
# 4   8867980.0  8867547.0        0 2019-01-01 00:05:14.411636
# 5   8867547.0  8867980.0        0 2019-01-01 00:05:33.182101
# 6   8867980.0  8867547.0        0 2019-01-01 00:05:51.253606
# 7   8867547.0  8861158.0        0 2019-01-01 00:06:08.676336
# 8   8861158.0  8861674.0        0 2019-01-01 00:06:43.363487
# 9   8861158.0  8861674.0        1 2019-01-01 00:06:52.537691
# 10  8861158.0  8861674.0        2 2019-01-01 00:07:24.716907
# 11  8861158.0  8861674.0        3 2019-01-01 00:07:53.823039
# 12  8861158.0  8861674.0        4 2019-01-01 00:08:23.691108
# 13  8861158.0  8861674.0        5 2019-01-01 00:08:55.741630
# 14  8861158.0  8861674.0        6 2019-01-01 00:09:29.661315
# 15  8861158.0  8861674.0        7 2019-01-01 00:10:26.778850
# 16  8861674.0  8860845.0        0 2019-01-01 00:11:05.077492
# 17  8861674.0  8860845.0        1 2019-01-01 00:11:14.113449
# 18  8861674.0  8860845.0        2 2019-01-01 00:11:29.485850
# 19  8861674.0  8860845.0        3 2019-01-01 00:11:38.660798
# 20  8861674.0  8860845.0        4 2019-01-01 00:11:45.829265
# 21  8861674.0  8860845.0        5 2019-01-01 00:12:15.309026
# 22  8861674.0  8860845.0        6 2019-01-01 00:12:28.612639
# 23  8861674.0  8860845.0        7 2019-01-01 00:12:39.146586
# 24  8861674.0  8860845.0        8 2019-01-01 00:12:47.585986
# 25  8861674.0  8860845.0        9 2019-01-01 00:12:57.593840
# 26  8861674.0  8860845.0       10 2019-01-01 00:13:10.022125
# 27  8861674.0  8860845.0       11 2019-01-01 00:13:19.015682
# 28  8861674.0  8860845.0       12 2019-01-01 00:13:32.847737
# 29  8861674.0  8860845.0       13 2019-01-01 00:13:52.438198
# 30  8861674.0  8860845.0       14 2019-01-01 00:14:36.318793
# 31  8861674.0  8860845.0       15 2019-01-01 00:15:28.697369
# 32  8860845.0   S14716_A        0 2019-01-01 00:16:38.471346
# 33  8860845.0   S14716_A        1 2019-01-01 00:16:38.662908
# 34   S14716_A   S14716_B        0 2019-01-01 00:16:39.685195
# 35   S14716_B  8864465.0        0 2019-01-01 00:16:40.069894
# 36   S14716_B  8864465.0        1 2019-01-01 00:17:14.644943
# 37   S14716_B  8864465.0        2 2019-01-01 00:18:43.523979
# 38   S14716_B  8864465.0        3 2019-01-01 00:19:30.000968
# 39  8864465.0  8862925.0        0 2019-01-01 00:19:34.351999
# 40  8862925.0  8864266.0        0 2019-01-01 00:19:39.661157
# 41  8862925.0  8864266.0        1 2019-01-01 00:20:41.010849
# 42  8862925.0  8864266.0        2 2019-01-01 00:22:09.182713
#
#                                   From geometry  \
# 0     POINT (4.28248423401617 51.8883798397893)
# 1     POINT (4.28441264524576 51.8846350350828)
# 2     POINT (4.29044058645646 51.8858419622723)
# 3     POINT (4.30330688740968 51.8884241525286)
# 4     POINT (4.30901781752353 51.8895642784668)
# 5     POINT (4.30918191152922 51.8905995237284)
# 6     POINT (4.30901781752353 51.8895642784668)
# 7     POINT (4.30918191152922 51.8905995237284)
# 8     POINT (4.30992837177677 51.8951847057235)
# 9     POINT (4.30742197256351 51.8954034825434)
# 10    POINT (4.29874400442962 51.8965645780719)
# 11    POINT (4.29106390692435 51.8980170167297)
# 12    POINT (4.28324451837622 51.8996276606504)
# 13    POINT (4.27523979772084 51.9019539223577)
# 14    POINT (4.26726870316835 51.9049892057308)
# 15      POINT (4.253925662175 51.9101805934693)
# 16     POINT (4.24483099921656 51.913512645023)
# 17    POINT (4.24242511914092 51.9143994898893)
# 18    POINT (4.23857645911312 51.9161369478001)
# 19     POINT (4.2365271222464 51.9173564618325)
# 20    POINT (4.23503512933374 51.9183748107927)
# 21     POINT (4.2297818565033 51.9229989423392)
# 22    POINT (4.22765252238981 51.9251830112109)
# 23    POINT (4.22578216469943 51.9268383762104)
# 24    POINT (4.22405266129897 51.9280523956845)
# 25    POINT (4.22191609157606 51.9294436554609)
# 26    POINT (4.21900429047722 51.9310042596332)
# 27    POINT (4.21683453208728 51.9320873138068)
# 28    POINT (4.21328244944327 51.9335735524287)
# 29    POINT (4.20834868514895 51.9357647463447)
# 30    POINT (4.19702205242875 51.9404274271939)
# 31    POINT (4.18272230241019 51.9451926463951)
# 32    POINT (4.16572686327362 51.9534749182027)
# 33    POINT (4.16567508324712 51.9535001430592)
# 34  POINT (4.165412076403014 51.95364458847217)
# 35  POINT (4.165324425507925 51.95369272702833)
# 36    POINT (4.15759560914481 51.9579374533398)
# 37    POINT (4.13683816050786 51.9681998965407)
# 38    POINT (4.12542158771241 51.9731028973176)
# 39    POINT (4.12423582717078 51.9734347697144)
# 40    POINT (4.12285425403692 51.9738214268566)
# 41    POINT (4.10714114771394 51.9781909994644)
# 42     POINT (4.0841372668255 51.9838622952073)
#
#                                     To geometry    Duration     Distance  \
# 0     POINT (4.28442105542451 51.8846316430902)   88.460093   437.845445
# 1     POINT (4.29044058645646 51.8858419622723)   55.184953   436.228995
# 2     POINT (4.30330688740968 51.8884241525286)  113.493354   931.279021
# 3     POINT (4.30901781752353 51.8895642784668)   57.273236   413.142566
# 4     POINT (4.30918191152922 51.8905995237284)   18.770465   115.739513
# 5     POINT (4.30901781752353 51.8895642784668)   18.071505   115.739513
# 6     POINT (4.30918191152922 51.8905995237284)   17.422730   115.739513
# 7     POINT (4.30992074255024 51.8951877409715)   34.687151   513.036924
# 8     POINT (4.30742197256351 51.8954034825434)    9.174204   174.244548
# 9     POINT (4.29874400442962 51.8965645780719)   32.179216   611.175984
# 10    POINT (4.29106390692435 51.8980170167297)   29.106132   552.809269
# 11    POINT (4.28324451837622 51.8996276606504)   29.868069   567.280645
# 12    POINT (4.27523979772084 51.9019539223577)   32.050522   608.731711
# 13    POINT (4.26726870316835 51.9049892057308)   33.919685   644.232514
# 14      POINT (4.253925662175 51.9101805934693)   57.117535  1084.826469
# 15     POINT (4.24483099921656 51.913512645023)   38.298642   727.401519
# 16    POINT (4.24242511914092 51.9143994898893)    9.035957   192.724862
# 17    POINT (4.23857645911312 51.9161369478001)   15.372401   327.872738
# 18     POINT (4.2365271222464 51.9173564618325)    9.174948   195.689359
# 19    POINT (4.23503512933374 51.9183748107927)    7.168467   152.893824
# 20     POINT (4.2297818565033 51.9229989423392)   29.479761   628.763842
# 21    POINT (4.22765252238981 51.9251830112109)   13.303613   283.748272
# 22    POINT (4.22578216469943 51.9268383762104)   10.533947   224.674983
# 23    POINT (4.22405266129897 51.9280523956845)    8.439400   180.001117
# 24    POINT (4.22191609157606 51.9294436554609)   10.007854   213.454139
# 25    POINT (4.21900429047722 51.9310042596332)   12.428285   265.078670
# 26    POINT (4.21683453208728 51.9320873138068)    8.993557   191.820535
# 27    POINT (4.21328244944327 51.9335735524287)   13.832055   295.019227
# 28    POINT (4.20834868514895 51.9357647463447)   19.590461   417.838328
# 29    POINT (4.19702205242875 51.9404274271939)   43.880595   935.914377
# 30    POINT (4.18272230241019 51.9451926463951)   52.378576  1117.164932
# 31    POINT (4.16572686327362 51.9534749182027)   69.773977  1488.185562
# 32    POINT (4.16567508324712 51.9535001430592)    0.191562     4.533197
# 33  POINT (4.165412076403014 51.95364458847217)    1.022287    24.191868
# 34  POINT (4.165324425507925 51.95369272702833)    0.384699     8.062286
# 35    POINT (4.15759560914481 51.9579374533398)   34.575049   710.891485
# 36    POINT (4.13683816050786 51.9681998965407)   88.879036  1827.426205
# 37    POINT (4.12542158771241 51.9731028973176)   46.476989   955.605194
# 38    POINT (4.12423582717078 51.9734347697144)    4.351031    89.460773
# 39    POINT (4.12285425403692 51.9738214268566)    5.309158   104.232441
# 40    POINT (4.10714114771394 51.9781909994644)   61.349692  1184.136286
# 41     POINT (4.0841372668255 51.9838622952073)   88.171864  1701.842355
# 42    POINT (4.08355198540297 51.9839636810505)    2.163717    41.762818
#
#         Speed
# 0    4.949638
# 1    7.904854
# 2    8.205582
# 3    7.213536
# 4    6.166044
# 5    6.404531
# 6    6.643018
# 7   14.790402
# 8   18.992879
# 9   18.992880
# 10  18.992880
# 11  18.992880
# 12  18.992880
# 13  18.992880
# 14  18.992880
# 15  18.992880
# 16  21.328661
# 17  21.328662
# 18  21.328661
# 19  21.328664
# 20  21.328661
# 21  21.328663
# 22  21.328661
# 23  21.328663
# 24  21.328662
# 25  21.328660
# 26  21.328662
# 27  21.328662
# 28  21.328662
# 29  21.328662
# 30  21.328662
# 31  21.328662
# 32  23.664385
# 33  23.664458
# 34  20.957387
# 35  20.560824
# 36  20.560824
# 37  20.560824
# 38  20.560822
# 39  19.632575
# 40  19.301422
# 41  19.301422
# 42  19.301423
