# %%
import networkx as nx
import warnings
import datetime
import seaborn as sn
sn.set()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
from ast import literal_eval

# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
passengers = pd.read_csv("Results/passengers.csv")
passengers = passengers[['route', 'origin', 'destination', 'transfers', 'transferstations']]
passengers['route'] = passengers['route'].apply(lambda x: literal_eval(x))

# %%
# singletrip = passengers[passengers['transfers'] == 0]

# ordest = []

# for index, row in singletrip.iterrows():
#     ordest.append((row['route'][0], row['route'][-1]))

# %%
transfertrips = passengers[passengers['transfers'] > 0]
transfertrips['transferstations'] = transfertrips['transferstations'].apply(lambda x: literal_eval(x))
split_lists = []

for index, row in transfertrips.iterrows():
    route = row['route']
    indexes = []
    
    for transfer in row['transferstations']:
        split = route.index((transfer)) + 1
        indexes.append(split)

    start = 0
    
    for index in indexes:
        split_lists.append(route[start:index])
        start = index - 1
    split_lists.append(route[start:])

# %%
for i in range(len(split_lists)):
    ordest.append((split_lists[i][0], split_lists[i][-1]))

# %%
Counter(ordest)
# Out:
# Counter({('Nieuwmarkt', 'Amstelstation'): 2,
#          ('Centraal Station', 'Station Holendrecht'): 59,
#          ('Amstelstation', 'Station Duivendrecht'): 11,
#          ('Noord', 'Centraal Station'): 517,
#          ('Amstelveenseweg', 'Station Zuid'): 44,
#          ('Station Bijlmer ArenA', 'Amstelstation'): 27,
#          ('Noorderpark', 'De Pijp'): 5,
#          ('Wibautstraat', 'Weesperplein'): 10,
#          ('Station Holendrecht', 'Station Bijlmer ArenA'): 10,
#          ('Noord', 'Vijzelgracht'): 11,
#          ('Station Holendrecht', 'Centraal Station'): 61,
#          ('Noord', 'Station Zuid'): 300,
#          ('Nieuwmarkt', 'Station Bijlmer ArenA'): 5,
#          ('Strandvliet', 'Station Holendrecht'): 6,
#          ('Centraal Station', 'Station Bijlmer ArenA'): 155,
#          ('Reigersbos', 'Amstelstation'): 22,
#          ('Bullewijk', 'Waterlooplein'): 7,
#          ('Weesperplein', 'Centraal Station'): 32,
#          ('Centraal Station', 'Amstelstation'): 103,
#          ('Station Duivendrecht', 'Centraal Station'): 61,
#          ('Gein', 'Station Bijlmer ArenA'): 11,
#          ('Centraal Station', 'Wibautstraat'): 34,
#          ('Centraal Station', 'Station Zuid'): 297,
#          ('Centraal Station', 'Bullewijk'): 46,
#          ('Henk Sneevlietweg', 'Station Sloterdijk'): 2,
#          ('Strandvliet', 'Weesperplein'): 9,
#          ('Weesperplein', 'Station Duivendrecht'): 5,
#          ('Gein', 'Spaklerweg'): 116,
#          ('Centraal Station', 'Strandvliet'): 11,
#          ('Strandvliet', 'Van der Madeweg'): 8,
#          ('Wibautstraat', 'Amstelstation'): 7,
#          ('De Pijp', 'Rokin'): 5,
#          ('Station Duivendrecht', 'Reigersbos'): 1,
#          ('Centraal Station', 'Weesperplein'): 97,
#          ('Spaklerweg', 'Station Holendrecht'): 53,
#          ('Van der Madeweg', 'Station Bijlmer ArenA'): 83,
#          ('Centraal Station', 'Waterlooplein'): 88,
#          ('Station Bijlmer ArenA', 'Centraal Station'): 44,
#          ('Centraal Station', 'De Pijp'): 7,
#          ('Jan v.Galenstraat', 'Amstelveenseweg'): 9,
#          ('Station Holendrecht', 'Waterlooplein'): 8,
#          ('Reigersbos', 'Station Duivendrecht'): 3,
#          ('Reigersbos', 'Centraal Station'): 53,
#          ('Station RAI', 'Jan v.Galenstraat'): 2,
#          ('De Pijp', 'Station Zuid'): 87,
#          ('Station Duivendrecht', 'Waterlooplein'): 8,
#          ('Strandvliet', 'Centraal Station'): 28,
#          ('Amstelstation', 'Centraal Station'): 89,
#          ('Gein', 'Centraal Station'): 70,
#          ('Heemstedestraat', 'Amstelveenseweg'): 4,
#          ('Postjesweg', 'Heemstedestraat'): 1,
#          ('Postjesweg', 'Henk Sneevlietweg'): 1,
#          ('Gein', 'Amstelstation'): 21,
#          ('Station Sloterdijk', 'Isolatorweg'): 2,
#          ('Noorderpark', 'Rokin'): 9,
#          ('Station Zuid', 'Vijzelgracht'): 23,
#          ('Wibautstraat', 'Station Bijlmer ArenA'): 9,
#          ('Gein', 'Waterlooplein'): 3,
#          ('Bullewijk', 'Weesperplein'): 8,
#          ('Venserpolder', 'Van der Madeweg'): 118,
#          ('Station Zuid', 'Centraal Station'): 297,
#          ('Amstelveenseweg', 'Station RAI'): 3,
#          ('Gein', 'Nieuwmarkt'): 3,
#          ('Burg.de Vlugtlaan', 'Jan v.Galenstraat'): 2,
#          ('Waterlooplein', 'Amstelstation'): 2,
#          ('Centraal Station', 'Nieuwmarkt'): 25,
#          ('Vijzelgracht', 'Station Zuid'): 42,
#          ('Wibautstraat', 'Centraal Station'): 49,
#          ('Burg.de Vlugtlaan', 'Station Zuid'): 76,
#          ('Reigersbos', 'Weesperplein'): 5,
#          ('Weesperplein', 'Waterlooplein'): 5,
#          ('Rokin', 'Centraal Station'): 36,
#          ('Amstelstation', 'Station Bijlmer ArenA'): 64,
#          ('Kraaienneststation', 'Van der Madeweg'): 359,
#          ('Postjesweg', 'Station Zuid'): 43,
#          ('Spaklerweg', 'Station Bijlmer ArenA'): 163,
#          ('Bullewijk', 'Station Duivendrecht'): 2,
#          ('Station Diemen-Zuid', 'Van der Madeweg'): 122,
#          ('Station Zuid', 'Europaplein'): 46,
#          ('Bullewijk', 'Centraal Station'): 45,
#          ('Jan v.Galenstraat', 'Heemstedestraat'): 2,
#          ('Postjesweg', 'Amstelveenseweg'): 8,
#          ('Station Bijlmer ArenA', 'Station Duivendrecht'): 6,
#          ('Wibautstraat', 'Waterlooplein'): 8,
#          ('Amstelstation', 'De Pijp'): 79,
#          ('Heemstedestraat', 'Station Zuid'): 19,
#          ('Station Zuid', 'Amstelveenseweg'): 171,
#          ('Noord', 'Noorderpark'): 4,
#          ('Henk Sneevlietweg', 'Amstelveenseweg'): 5,
#          ('Postjesweg', 'Spaklerweg'): 54,
#          ('Noorderpark', 'Station Zuid'): 83,
#          ('Rokin', 'Europaplein'): 1,
#          ('Reigersbos', 'Wibautstraat'): 7,
#          ('Spaklerweg', 'Station Sloterdijk'): 157,
#          ('Reigersbos', 'Station Bijlmer ArenA'): 16,
#          ('Amstelstation', 'Weesperplein'): 17,
#          ('Gein', 'Weesperplein'): 10,
#          ('Waterlooplein', 'Nieuwmarkt'): 1,
#          ('Centraal Station', 'Rokin'): 171,
#          ('Strandvliet', 'Gein'): 1,
#          ('Station Holendrecht', 'Station Duivendrecht'): 5,
#          ('Station Holendrecht', 'Weesperplein'): 13,
#          ('Centraal Station', 'Spaklerweg'): 60,
#          ('Station Bijlmer ArenA', 'Waterlooplein'): 9,
#          ('Station Duivendrecht', 'Bullewijk'): 2,
#          ('Station Duivendrecht', 'Amstelstation'): 21,
#          ('Henk Sneevlietweg', 'Heemstedestraat'): 2,
#          ('Gein', 'Bullewijk'): 9,
#          ('Henk Sneevlietweg', 'Station RAI'): 1,
#          ('Amstelstation', 'Reigersbos'): 4,
#          ('Station Sloterdijk', 'Amstelveenseweg'): 16,
#          ('Centraal Station', 'Gein'): 13,
#          ('Amstelstation', 'Wibautstraat'): 9,
#          ('De Pijp', 'Amstelstation'): 77,
#          ('Europaplein', 'Centraal Station'): 10,
#          ('Station Bijlmer ArenA', 'Bullewijk'): 4,
#          ('Station RAI', 'Station Sloterdijk'): 1,
#          ('De Pijp', 'Vijzelgracht'): 18,
#          ('Station Lelylaan', 'Station Zuid'): 45,
#          ('Reigersbos', 'Spaklerweg'): 145,
#          ('Station Duivendrecht', 'Weesperplein'): 4,
#          ('Centraal Station', 'Rijksmuseum'): 1,
#          ('Centraal Station', 'Vijzelgracht'): 61,
#          ('Bullewijk', 'Spaklerweg'): 81,
#          ('Centraal Station', 'Van der Madeweg'): 79,
#          ('Station Sloterdijk', 'Station Zuid'): 174,
#          ('Burg.de Vlugtlaan', 'Spaklerweg'): 66,
#          ('Station Sloterdijk', 'Overamstel'): 31,
#          ('Amstelveenseweg', 'Station Lelylaan'): 1,
#          ('Centraal Station', 'Station Duivendrecht'): 33,
#          ('Station Bijlmer ArenA', 'Nieuwmarkt'): 3,
#          ('Waterlooplein', 'Station Holendrecht'): 5,
#          ('Amstelstation', 'Van Baerlestraat'): 7,
#          ('Amstelstation', 'Nieuwmarkt'): 2,
#          ('Reigersbos', 'Waterlooplein'): 9,
#          ('Wibautstraat', 'Station Duivendrecht'): 2,
#          ('Noorderpark', 'Centraal Station'): 99,
#          ('Station Zuid', 'Station Lelylaan'): 43,
#          ('De Pijp', 'Centraal Station'): 36,
#          ('Wibautstraat', 'Nieuwmarkt'): 2,
#          ('Station Sloterdijk', 'Station Lelylaan'): 2,
#          ('Amstelstation', 'Spaklerweg'): 194,
#          ('Nieuwmarkt', 'Wibautstraat'): 1,
#          ('Reigersbos', 'Station Holendrecht'): 9,
#          ('Centraal Station', 'Noorderpark'): 31,
#          ('Van der Madeweg', 'Centraal Station'): 165,
#          ('Amstelstation', 'Van der Madeweg'): 38,
#          ('Waterlooplein', 'Centraal Station'): 34,
#          ('Vijzelgracht', 'Centraal Station'): 34,
#          ('Spaklerweg', 'Wibautstraat'): 46,
#          ('Wibautstraat', 'Spaklerweg'): 99,
#          ('Station Bijlmer ArenA', 'Weesperplein'): 8,
#          ('Rokin', 'Station Zuid'): 14,
#          ('Station Duivendrecht', 'Spaklerweg'): 122,
#          ('Station Zuid', 'Spaklerweg'): 180,
#          ('Waterlooplein', 'Spaklerweg'): 35,
#          ('Noorderpark', 'Europaplein'): 2,
#          ('Reigersbos', 'Van der Madeweg'): 24,
#          ('Verrijn Stuartweg', 'Van der Madeweg'): 25,
#          ('Station Zuid', 'Station RAI'): 47,
#          ('Overamstel', 'Station Sloterdijk'): 57,
#          ('Kraaienneststation', 'Venserpolder'): 1,
#          ('Europaplein', 'Station Zuid'): 40,
#          ('Centraal Station', 'Dam'): 34,
#          ('Amstelstation', 'Waterlooplein'): 10,
#          ('Gein', 'Station Duivendrecht'): 6,
#          ('Burg.de Vlugtlaan', 'Station Sloterdijk'): 5,
#          ('Station Sloterdijk', 'Station RAI'): 3,
#          ('Jan v.Galenstraat', 'Station Zuid'): 44,
#          ('Station Duivendrecht', 'Van der Madeweg'): 30,
#          ('Nieuwmarkt', 'Bullewijk'): 3,
#          ('Station Zuid', 'Overamstel'): 35,
#          ('Gein', 'Station Holendrecht'): 3,
#          ('Burg.de Vlugtlaan', 'Station RAI'): 2,
#          ('Weesperplein', 'Gein'): 1,
#          ('Noord', 'De Pijp'): 10,
#          ('Station Zuid', 'Jan v.Galenstraat'): 80,
#          ('Centraal Station', 'Spui'): 5,
#          ('Heemstedestraat', 'Jan v.Galenstraat'): 2,
#          ('Station Holendrecht', 'Reigersbos'): 1,
#          ('Bullewijk', 'Station Holendrecht'): 3,
#          ('Bullewijk', 'Amstelstation'): 10,
#          ('Wibautstraat', 'Reigersbos'): 2,
#          ('Henk Sneevlietweg', 'Spaklerweg'): 33,
#          ('Gaasperplas', 'Station Diemen-Zuid'): 1,
#          ('Amstelstation', 'Bullewijk'): 6,
#          ('Van der Madeweg', 'Weesperplein'): 44,
#          ('Centraal Station', 'Noord'): 67,
#          ('Station Holendrecht', 'Strandvliet'): 1,
#          ('Station Duivendrecht', 'Wibautstraat'): 2,
#          ('Noord', 'Europaplein'): 2,
#          ('Station Lelylaan', 'Jan v.Galenstraat'): 3,
#          ('Station Zuid', 'Henk Sneevlietweg'): 85,
#          ('Station Zuid', 'Rokin'): 87,
#          ('Centraal Station', 'Europaplein'): 7,
#          ('Station Holendrecht', 'Spaklerweg'): 97,
#          ('Wibautstraat', 'Van der Madeweg'): 7,
#          ('Waterlooplein', 'Weesperplein'): 6,
#          ('Reigersbos', 'Nieuwmarkt'): 7,
#          ('Amstelveenseweg', 'Station Sloterdijk'): 3,
#          ('Spaklerweg', 'Weesperplein'): 83,
#          ('Station Duivendrecht', 'Station Bijlmer ArenA'): 13,
#          ('Station Sloterdijk', 'Henk Sneevlietweg'): 4,
#          ('Wibautstraat', 'Bullewijk'): 6,
#          ('Station Duivendrecht', 'Strandvliet'): 1,
#          ('Spaklerweg', 'Amstelstation'): 143,
#          ('Amstelstation', 'Museumplein'): 3,
#          ('Station Bijlmer ArenA', 'Station Holendrecht'): 3,
#          ('Station Holendrecht', 'Bullewijk'): 5,
#          ('Station Holendrecht', 'Amstelstation'): 17,
#          ('Station Sloterdijk', 'Spaklerweg'): 186,
#          ('Strandvliet', 'Amstelstation'): 12,
#          ('Spaklerweg', 'Station Lelylaan'): 54,
#          ('Noord', 'Rokin'): 13,
#          ('Gein', 'Reigersbos'): 3,
#          ('Amstelstation', 'Station Holendrecht'): 22,
#          ('Henk Sneevlietweg', 'Station Zuid'): 39,
#          ('Bullewijk', 'Station Bijlmer ArenA'): 5,
#          ('Overamstel', 'Spaklerweg'): 22,
#          ('Strandvliet', 'Station Bijlmer ArenA'): 3,
#          ('Station Zuid', 'Station Sloterdijk'): 164,
#          ('Nieuwmarkt', 'Station Holendrecht'): 1,
#          ('Station Sloterdijk', 'Postjesweg'): 1,
#          ('Station Holendrecht', 'Wibautstraat'): 2,
#          ('Postjesweg', 'Station Sloterdijk'): 3,
#          ('Weesperplein', 'Spaklerweg'): 57,
#          ('Station Zuid', 'De Pijp'): 33,
#          ('Station Holendrecht', 'Van der Madeweg'): 18,
#          ('Jan v.Galenstraat', 'Henk Sneevlietweg'): 2,
#          ('Weesperplein', 'Station Holendrecht'): 2,
#          ('Station Duivendrecht', 'Station Holendrecht'): 5,
#          ('Noorderpark', 'Noord'): 1,
#          ('Station Zuid', 'Isolatorweg'): 21,
#          ('Strandvliet', 'Nieuwmarkt'): 1,
#          ('Centraal Station', 'Reigersbos'): 13,
#          ('Vijzelgracht', 'De Pijp'): 7,
#          ('Burg.de Vlugtlaan', 'Overamstel'): 10,
#          ('Station Bijlmer ArenA', 'Spaklerweg'): 120,
#          ('Jan v.Galenstraat', 'Station Lelylaan'): 2,
#          ('Burg.de Vlugtlaan', 'Heemstedestraat'): 1,
#          ('Amstelveenseweg', 'Spaklerweg'): 35,
#          ('Nieuwmarkt', 'Centraal Station'): 13,
#          ('Heemstedestraat', 'Henk Sneevlietweg'): 1,
#          ('Waterlooplein', 'Station Bijlmer ArenA'): 2,
#          ('Weesperplein', 'Wibautstraat'): 3,
#          ('Van der Madeweg', 'Station Diemen-Zuid'): 65,
#          ('Nieuwmarkt', 'Waterlooplein'): 1,
#          ('Centraal Station', 'Van Baerlestraat'): 3,
#          ('Weesperplein', 'Station Bijlmer ArenA'): 6,
#          ('Station Sloterdijk', 'Jan v.Galenstraat'): 1,
#          ('Spaklerweg', 'Centraal Station'): 26,
#          ('Station Bijlmer ArenA', 'Reigersbos'): 2,
#          ('Station RAI', 'Station Zuid'): 28,
#          ('Amstelveenseweg', 'Jan v.Galenstraat'): 3,
#          ('Gein', 'Strandvliet'): 1,
#          ('Station RAI', 'Overamstel'): 5,
#          ('Station Lelylaan', 'Amstelveenseweg'): 3,
#          ('Strandvliet', 'Bullewijk'): 1,
#          ('Bullewijk', 'Nieuwmarkt'): 1,
#          ('Bullewijk', 'Wibautstraat'): 1,
#          ('Gein', 'Wibautstraat'): 5,
#          ('Rokin', 'Noorderpark'): 1,
#          ('Postjesweg', 'Station Lelylaan'): 1,
#          ('Amstelstation', 'Leidseplein'): 7,
#          ('Spaklerweg', 'Strandvliet'): 7,
#          ('Station Zuid', 'Burg.de Vlugtlaan'): 15,
#          ('Heemstedestraat', 'Station Sloterdijk'): 2,
#          ('Station Lelylaan', 'Station Sloterdijk'): 2,
#          ('Kraaienneststation', 'Station Diemen-Zuid'): 1,
#          ('Station Sloterdijk', 'Heemstedestraat'): 2,
#          ('Station Holendrecht', 'Nieuwmarkt'): 5,
#          ('Strandvliet', 'Waterlooplein'): 2,
#          ('Station Lelylaan', 'Henk Sneevlietweg'): 2,
#          ('Weesperplein', 'Amstelstation'): 4,
#          ('Overamstel', 'Station Zuid'): 116,
#          ('Isolatorweg', 'Station Zuid'): 3,
#          ('Amstelveenseweg', 'Heemstedestraat'): 1,
#          ('Spaklerweg', 'Isolatorweg'): 32,
#          ('Postjesweg', 'Jan v.Galenstraat'): 1,
#          ('Overamstel', 'Postjesweg'): 1,
#          ('Van der Madeweg', 'Station Duivendrecht'): 7,
#          ('Station Zuid', 'Heemstedestraat'): 26,
#          ('Centraal Station', 'Koningsplein'): 18,
#          ('Leidseplein', 'Centraal Station'): 5,
#          ('Reigersbos', 'Strandvliet'): 1,
#          ('Victorieplein', 'Amstelstation'): 13,
#          ('Weesperplein', 'Nieuwmarkt'): 1,
#          ('Burg.de Vlugtlaan', 'Henk Sneevlietweg'): 1,
#          ('Postjesweg', 'Overamstel'): 9,
#          ('Station Zuid', 'Noord'): 28,
#          ('Spaklerweg', 'Bullewijk'): 43,
#          ('Spaklerweg', 'Station Zuid'): 441,
#          ('De Pijp', 'Noorderpark'): 1,
#          ('Strandvliet', 'Wibautstraat'): 2,
#          ('Strandvliet', 'Spaklerweg'): 79,
#          ('Strandvliet', 'Reigersbos'): 2,
#          ('Overamstel', 'Station RAI'): 21,
#          ('Bullewijk', 'Reigersbos'): 1,
#          ('Station Holendrecht', 'Gein'): 1,
#          ('Jan v.Galenstraat', 'Station RAI'): 4,
#          ('Station Duivendrecht', 'Nieuwmarkt'): 2,
#          ('De Pijp', 'Koningsplein'): 7,
#          ('Kraaienneststation', 'Verrijn Stuartweg'): 1,
#          ('Wibautstraat', 'Station Holendrecht'): 3,
#          ('Henk Sneevlietweg', 'Jan v.Galenstraat'): 1,
#          ('Burg.de Vlugtlaan', 'Station Lelylaan'): 1,
#          ('Bullewijk', 'Van der Madeweg'): 7,
#          ('Jan v.Galenstraat', 'Spaklerweg'): 40,
#          ('Heemstedestraat', 'Station RAI'): 1,
#          ('Isolatorweg', 'Station Sloterdijk'): 1,
#          ('Van der Madeweg', 'Nieuwmarkt'): 19,
#          ('Waterlooplein', 'Wibautstraat'): 1,
#          ('Venserpolder', 'Verrijn Stuartweg'): 1,
#          ('Weesperplein', 'Van der Madeweg'): 5,
#          ('Gein', 'Van der Madeweg'): 19,
#          ('Nieuwmarkt', 'Weesperplein'): 1,
#          ('Amstelveenseweg', 'Isolatorweg'): 1,
#          ('Van der Madeweg', 'Overamstel'): 351,
#          ('Station Lelylaan', 'Station RAI'): 1,
#          ('De Pijp', 'Europaplein'): 7,
#          ('Spaklerweg', 'Waterlooplein'): 81,
#          ('Nieuwmarkt', 'Spaklerweg'): 31,
#          ('Station Sloterdijk', 'Burg.de Vlugtlaan'): 1,
#          ('Station RAI', 'Amstelveenseweg'): 1,
#          ('Amstelveenseweg', 'Henk Sneevlietweg'): 1,
#          ('Reigersbos', 'Bullewijk'): 1,
#          ('Waterlooplein', 'Van der Madeweg'): 2,
#          ('Van der Madeweg', 'Spaklerweg'): 14,
#          ('Van der Madeweg', 'Verrijn Stuartweg'): 86,
#          ('Spaklerweg', 'Amstelveenseweg'): 176,
#          ('Amstelveenseweg', 'De Boelelaan/VU'): 138,
#          ('Station Zuid', 'Postjesweg'): 8,
#          ('Van der Madeweg', 'Waterlooplein'): 20,
#          ('Gaasperplas', 'Van der Madeweg'): 86,
#          ('Overamstel', 'Amstelveenseweg'): 44,
#          ('Station Bijlmer ArenA', 'Van der Madeweg'): 8,
#          ('Spaklerweg', 'Henk Sneevlietweg'): 86,
#          ('Spaklerweg', 'Nieuwmarkt'): 36,
#          ('Station Lelylaan', 'Spaklerweg'): 62,
#          ('Station RAI', 'Spaklerweg'): 22,
#          ('Spaklerweg', 'Station RAI'): 80,
#          ('Van der Madeweg', 'Wibautstraat'): 16,
#          ('Van der Madeweg', 'Gein'): 2,
#          ('Overamstel', 'Van der Madeweg'): 102,
#          ('Leidseplein', 'Amstelstation'): 14,
#          ('Spaklerweg', 'Jan v.Galenstraat'): 54,
#          ('Van der Madeweg', 'Station Holendrecht'): 20,
#          ('Amstelstation', 'Roelof Hartplein'): 4,
#          ('Roelof Hartplein', 'Gerrit v.d. Veenstraat'): 4,
#          ('Rokin', 'Muntplein'): 4,
#          ('Overamstel', 'Jan v.Galenstraat'): 18,
#          ('Overamstel', 'Heemstedestraat'): 4,
#          ('Henk Sneevlietweg', 'Overamstel'): 12,
#          ('Amstelveenseweg', 'VU medisch centrum'): 38,
#          ('Spaklerweg', 'Overamstel'): 46,
#          ('Van der Madeweg', 'Venserpolder'): 30,
#          ('Spaklerweg', 'Station Duivendrecht'): 36,
#          ('Van der Madeweg', 'Strandvliet'): 6,
#          ('Van der Madeweg', 'Amstelstation'): 48,
#          ('Spaklerweg', 'Burg.de Vlugtlaan'): 14,
#          ('Rokin', 'Dam'): 16,
#          ('Leidseplein', 'Roelof Hartplein'): 2,
#          ('Roelof Hartplein', 'De Boelelaan/VU'): 2,
#          ('De Boelelaan/VU', 'Amstelveenseweg'): 2,
#          ('Station Lelylaan', 'Overamstel'): 12,
#          ('Overamstel', 'Henk Sneevlietweg'): 18,
#          ('Olympiaweg', 'Amstelveenseweg'): 2,
#          ('Van der Madeweg', 'Kraaienneststation'): 18,
#          ('Spaklerweg', 'Reigersbos'): 14,
#          ('Centraal Station', 'Muntplein'): 8,
#          ('Heemstedestraat', 'Overamstel'): 4,
#          ('Jan v.Galenstraat', 'Overamstel'): 8,
#          ('Station Zuid', 'Noorderpark'): 12,
#          ('Leidseplein', 'De Pijp'): 4,
#          ('Heemstedestraat', 'Spaklerweg'): 38,
#          ('Spaklerweg', 'Heemstedestraat'): 24,
#          ('Overamstel', 'Isolatorweg'): 4,
#          ('Burg.de Vlugtlaan', 'Amstelveenseweg'): 4,
#          ('Centraal Station', 'Nieuwezijds Kolk'): 12,
#          ('Amstelveenseweg', 'Roelof Hartplein'): 10,
#          ('Roelof Hartplein', 'Leidseplein'): 4,
#          ('Amstelstation', 'Gein'): 2,
#          ('Amsteldijk', 'Amstelstation'): 2,
#          ('Victorieplein', 'De Pijp'): 4,
#          ('Overamstel', 'Burg.de Vlugtlaan'): 6,
#          ('Prinsengracht', 'Dam'): 2,
#          ('Dam', 'Vijzelgracht'): 2,
#          ('Overamstel', 'Station Lelylaan'): 10,
#          ('Amstelveenseweg', 'Overamstel'): 4,
#          ('Spaklerweg', 'Gein'): 14,
#          ('Van der Madeweg', 'Bullewijk'): 14,
#          ('Centraal Station', 'Leidseplein'): 2,
#          ('De Pijp', 'Rijksmuseum'): 2,
#          ('Centraal Station', 'Prinsengracht'): 2,
#          ('Amstelstation', 'Strandvliet'): 2,
#          ('Europaplein', 'De Pijp'): 2,
#          ('Roelof Hartplein', 'Van Baerlestraat'): 2,
#          ('Spaklerweg', 'Postjesweg'): 4,
#          ('Roelof Hartplein', 'Museumplein'): 2,
#          ('Museumplein', 'Amstelstation'): 2,
#          ('Prinsengracht', 'Centraal Station'): 2,
#          ('Roelof Hartplein', 'Amstelstation'): 2,
#          ('Keizersgracht', 'Centraal Station'): 2,
#          ('De Pijp', 'Roelof Hartplein'): 2})

# %%
herbest = pd.read_csv('../../Data/20190403/Datalab_Rit_Herkomst_Bestemming_Uur_20190403.csv', sep=';')

# %%
# List of all stations in the sub-network
stations = ['Amsteldijk','Amstelstation','Amstelveenseweg','Beethovenstraat','Bullewijk','Burg.de Vlugtlaan', 
    'Centraal Station','Cornelis Troostplein','Dam','De Boelelaan/VU','De Pijp','Europaplein',
    'Gaasperplas','Gein','Gerrit v.d. Veenstraat','Heemstedestraat','Henk Sneevlietweg','IJsbaanpad', 
    'Isolatorweg','Jan v.Galenstraat','Keizersgracht','Koningsplein','Kraaienneststation','Leidseplein',
    'Maasstraat','Marie Heinekenplein','Minervaplein','Muntplein','Museumplein','Nieuwezijds Kolk',
    'Nieuwmarkt','Noord','Noorderpark','Olympiaplein','Olympiaweg','Olympisch stadion','Overamstel', 
    'Postjesweg','Prinsengracht','Reigersbos','Rijksmuseum','Roelof Hartplein','Rokin','Scheldestraat',
    'Spaklerweg','Spui','Station Bijlmer ArenA','Station Diemen-Zuid','Station Duivendrecht', 'Stadionweg'
    'Station Ganzenhoef','Station Holendrecht','Station Lelylaan','Station RAI','Station Sloterdijk', 
    'Strandvliet','Van Baerlestraat','Van der Madeweg','Venserpolder','Verrijn Stuartweg','Victorieplein', 
    'Vijzelgracht','VU medisch centrum','Waalstraat','Waterlooplein','Weesperplein','Wibautstraat','Station Zuid']

# %%
herbest['Datum'] = herbest['Datum'].apply(lambda x: datetime.datetime.strptime(x[:-3], '%m/%d/%Y %H:%M:%S'))
herbest['Weekdag'] = herbest['Datum'].apply(lambda x: x.isoweekday())

# %%
herbest = herbest[herbest['Datum'] >= datetime.datetime(2018, 8, 1)]

# %%
herbest = herbest[(herbest['VertrekHalteNaam'].isin(stations)) & (herbest['Weekdag'] == 1)]
herbest = herbest[(herbest['AankomstHalteNaam'].isin(stations))]

# %%
herbest = herbest[herbest['UurgroepOmschrijving (van vertrek)'] == '06:00 - 06:59']
herbest.head()
# Out:
#                       Datum UurgroepOmschrijving (van vertrek)  \
# 4625282 2018-08-06 12:00:00                      06:00 - 06:59
# 4625339 2018-08-06 12:00:00                      06:00 - 06:59
# 4625343 2018-08-06 12:00:00                      06:00 - 06:59
# 4625344 2018-08-06 12:00:00                      06:00 - 06:59
# 4625345 2018-08-06 12:00:00                      06:00 - 06:59
#
#         VertrekHalteCode   VertrekHalteNaam  VertrekLat  VertrekLon  \
# 4625282            02221  Jan v.Galenstraat    4.858423   52.375326
# 4625339            05011   Centraal Station    4.899218   52.378108
# 4625343            05011   Centraal Station    4.899218   52.378108
# 4625344            05011   Centraal Station    4.899218   52.378108
# 4625345            05011   Centraal Station    4.899218   52.378108
#
#         AankomstHalteCode   AankomstHalteNaam  AankomstLat  AankomstLon  \
# 4625282             02361  Station Sloterdijk     4.839319    52.388335
# 4625339             05065                 Dam     4.890794    52.373678
# 4625343             06072       Prinsengracht     4.884284    52.364959
# 4625344             06076        Koningsplein     4.888579    52.366892
# 4625345             06089         Leidseplein     4.880855    52.363093
#
#          AantalRitten  Weekdag
# 4625282            14        1
# 4625339            28        1
# 4625343            18        1
# 4625344            15        1
# 4625345            32        1

# %%
stopdict = {'ITW': 1, 'GN': 1, 'RAI': 1, 'VSW': 1, 'ND': 1, 'RKN': 1, 
            'WPP': 1, 'RGB': 1, 'HVW': 1, 'OAS': 1, 'CLL': 1, 'PJW': 1, 
            'BLW': 1, 'WBS': 1, 'HLD': 1, 'MDW': 1, 'SVT': 1, 'DMZ': 1, 
            'BMR': 1, 'EPP': 1, 'WTC': 1, 'DPP': 1, 'JLS': 1, 'DVD': 1, 
            'GZH': 1, 'NDP': 1, 'NMT': 1, 'VLN': 1, 'ASA': 1, 'KEN': 1, 
            'VPD': 1, 'SLW': 1, 'WLP': 1, 'HDS': 1, 'GPP': 1, 'VZG': 1, 
            'CS': 1, 'VU': 1, 'ASW': 1, 'STD': 1, '08070': 1, '09122': 1, 
            '09121': 1, '07094': 1, '07091': 1, '08071': 1, '09013': 1, 
            '07004': 1, '08076': 1, '08078': 1, '07307': 1, '07308': 1, 
            '07120': 2, '07108': 2, '09083': 2, '09082': 2, '07202': 2, 
            '07121': 2, '09078': 2, '09079': 2, '07084': 2, '07083': 2, 
            '07207': 2, '07205': 2, '07017': 2, '07303': 2, '07350': 2, 
            '09074': 2, '09075': 2, '07098': 2, '07097': 2, '07493': 2, 
            '07490': 2, '09119': 2, '09120': 2, '05036': 3, '05035': 3, 
            '06072': 3, '06071': 3, '06075': 3, '06076': 3, '06073': 3, 
            '06074': 3, '07015': 3, '09049': 3, '09051': 3, '05062': 3, 
            '05061': 3, '07006': 3, '07007': 3, '07322': 3, '07321': 3, 
            '07323': 3, '07324': 3, '06067': 3, '05063': 3, '05032': 3, 
            '05031': 3, '07016': 0.6666666666666666, '09114': 0.6666666666666666, 
            '09111': 0.6666666666666666, '09139': 4, '09140': 4, '05022': 4, 
            '05011': 5, '06089': 5, '05065': 5, '05070': 5, '05069': 5}

# %%
herbest = herbest[herbest['VertrekHalteCode'].isin(stopdict.keys())]
herbest = herbest[herbest['AankomstHalteCode'].isin(stopdict.keys())]
herbest = herbest[herbest['AankomstHalteNaam'] != herbest['VertrekHalteNaam']]

# %%
herbest['AantalLijnenVertrek'] = herbest['VertrekHalteCode'].map(stopdict)
herbest['AantalLijnenAankomst'] = herbest['AankomstHalteCode'].map(stopdict)
herbest['AantalLijnen'] = np.where(herbest.AantalLijnenVertrek > herbest.AantalLijnenAankomst, 
         herbest.AantalLijnenAankomst, herbest.AantalLijnenVertrek)

# %%
herbest['AantalRittenNorm'] = herbest['AantalRitten']/herbest['AantalLijnen']

# %%
herbest
# Out:
#                       Datum UurgroepOmschrijving (van vertrek)  \
# 4625339 2018-08-06 12:00:00                      06:00 - 06:59
# 4625343 2018-08-06 12:00:00                      06:00 - 06:59
# 4625344 2018-08-06 12:00:00                      06:00 - 06:59
# 4625345 2018-08-06 12:00:00                      06:00 - 06:59
# 4625346 2018-08-06 12:00:00                      06:00 - 06:59
# 4625347 2018-08-06 12:00:00                      06:00 - 06:59
# 4625349 2018-08-06 12:00:00                      06:00 - 06:59
# 4625350 2018-08-06 12:00:00                      06:00 - 06:59
# 4625385 2018-08-06 12:00:00                      06:00 - 06:59
# 4625394 2018-08-06 12:00:00                      06:00 - 06:59
# 4625432 2018-08-06 12:00:00                      06:00 - 06:59
# 4625435 2018-08-06 12:00:00                      06:00 - 06:59
# 4625436 2018-08-06 12:00:00                      06:00 - 06:59
# 4625437 2018-08-06 12:00:00                      06:00 - 06:59
# 4625438 2018-08-06 12:00:00                      06:00 - 06:59
# 4625439 2018-08-06 12:00:00                      06:00 - 06:59
# 4625440 2018-08-06 12:00:00                      06:00 - 06:59
# 4625441 2018-08-06 12:00:00                      06:00 - 06:59
# 4625442 2018-08-06 12:00:00                      06:00 - 06:59
# 4625443 2018-08-06 12:00:00                      06:00 - 06:59
# 4625444 2018-08-06 12:00:00                      06:00 - 06:59
# 4625445 2018-08-06 12:00:00                      06:00 - 06:59
# 4625447 2018-08-06 12:00:00                      06:00 - 06:59
# 4625450 2018-08-06 12:00:00                      06:00 - 06:59
# 4625451 2018-08-06 12:00:00                      06:00 - 06:59
# 4625452 2018-08-06 12:00:00                      06:00 - 06:59
# 4625454 2018-08-06 12:00:00                      06:00 - 06:59
# 4625455 2018-08-06 12:00:00                      06:00 - 06:59
# 4625457 2018-08-06 12:00:00                      06:00 - 06:59
# 4625458 2018-08-06 12:00:00                      06:00 - 06:59
# ...                     ...                                ...
# 9283600 2019-03-11 12:00:00                      06:00 - 06:59
# 9283602 2019-03-11 12:00:00                      06:00 - 06:59
# 9283603 2019-03-11 12:00:00                      06:00 - 06:59
# 9283604 2019-03-11 12:00:00                      06:00 - 06:59
# 9283606 2019-03-11 12:00:00                      06:00 - 06:59
# 9283608 2019-03-11 12:00:00                      06:00 - 06:59
# 9283609 2019-03-11 12:00:00                      06:00 - 06:59
# 9283611 2019-03-11 12:00:00                      06:00 - 06:59
# 9283612 2019-03-11 12:00:00                      06:00 - 06:59
# 9283613 2019-03-11 12:00:00                      06:00 - 06:59
# 9283614 2019-03-11 12:00:00                      06:00 - 06:59
# 9283616 2019-03-11 12:00:00                      06:00 - 06:59
# 9283618 2019-03-11 12:00:00                      06:00 - 06:59
# 9283619 2019-03-11 12:00:00                      06:00 - 06:59
# 9283620 2019-03-11 12:00:00                      06:00 - 06:59
# 9283621 2019-03-11 12:00:00                      06:00 - 06:59
# 9283622 2019-03-11 12:00:00                      06:00 - 06:59
# 9283623 2019-03-11 12:00:00                      06:00 - 06:59
# 9283624 2019-03-11 12:00:00                      06:00 - 06:59
# 9283625 2019-03-11 12:00:00                      06:00 - 06:59
# 9283626 2019-03-11 12:00:00                      06:00 - 06:59
# 9283627 2019-03-11 12:00:00                      06:00 - 06:59
# 9283628 2019-03-11 12:00:00                      06:00 - 06:59
# 9283629 2019-03-11 12:00:00                      06:00 - 06:59
# 9283630 2019-03-11 12:00:00                      06:00 - 06:59
# 9283631 2019-03-11 12:00:00                      06:00 - 06:59
# 9283632 2019-03-11 12:00:00                      06:00 - 06:59
# 9283633 2019-03-11 12:00:00                      06:00 - 06:59
# 9283634 2019-03-11 12:00:00                      06:00 - 06:59
# 9451707 2019-03-18 12:00:00                      06:00 - 06:59
#
#         VertrekHalteCode       VertrekHalteNaam  VertrekLat  VertrekLon  \
# 4625339            05011       Centraal Station    4.899218   52.378108
# 4625343            05011       Centraal Station    4.899218   52.378108
# 4625344            05011       Centraal Station    4.899218   52.378108
# 4625345            05011       Centraal Station    4.899218   52.378108
# 4625346            05011       Centraal Station    4.899218   52.378108
# 4625347            05011       Centraal Station    4.899218   52.378108
# 4625349            05022       Centraal Station    4.901043   52.377720
# 4625350            05022       Centraal Station    4.901043   52.377720
# 4625385            06067            Leidseplein    4.883014   52.364316
# 4625394            07493        Amstelveenseweg    4.857250   52.338345
# 4625432            09121    Marie Heinekenplein    4.890772   52.357221
# 4625435              ASA          Amstelstation    4.917514   52.346473
# 4625436              ASA          Amstelstation    4.917514   52.346473
# 4625437              ASA          Amstelstation    4.917514   52.346473
# 4625438              ASA          Amstelstation    4.917514   52.346473
# 4625439              ASA          Amstelstation    4.917514   52.346473
# 4625440              ASA          Amstelstation    4.917514   52.346473
# 4625441              ASA          Amstelstation    4.917514   52.346473
# 4625442              ASA          Amstelstation    4.917514   52.346473
# 4625443              ASA          Amstelstation    4.917514   52.346473
# 4625444              ASA          Amstelstation    4.917514   52.346473
# 4625445              ASA          Amstelstation    4.917514   52.346473
# 4625447              ASW        Amstelveenseweg    4.857983   52.338367
# 4625450              BLW              Bullewijk    4.952336   52.306422
# 4625451              BLW              Bullewijk    4.952336   52.306422
# 4625452              BLW              Bullewijk    4.952336   52.306422
# 4625454              BMR  Station Bijlmer ArenA    4.947135   52.311930
# 4625455              BMR  Station Bijlmer ArenA    4.947135   52.311930
# 4625457              BMR  Station Bijlmer ArenA    4.947135   52.311930
# 4625458              BMR  Station Bijlmer ArenA    4.947135   52.311930
# ...                  ...                    ...         ...         ...
# 9283600              VZG           Vijzelgracht    4.890729   52.359801
# 9283602              WBS           Wibautstraat    4.912030   52.354289
# 9283603              WBS           Wibautstraat    4.912030   52.354289
# 9283604              WBS           Wibautstraat    4.912030   52.354289
# 9283606              WBS           Wibautstraat    4.912030   52.354289
# 9283608              WLP          Waterlooplein    4.902982   52.366979
# 9283609              WLP          Waterlooplein    4.902982   52.366979
# 9283611              WPP           Weesperplein    4.907875   52.361201
# 9283612              WPP           Weesperplein    4.907875   52.361201
# 9283613              WPP           Weesperplein    4.907875   52.361201
# 9283614              WPP           Weesperplein    4.907875   52.361201
# 9283616              WPP           Weesperplein    4.907875   52.361201
# 9283618              WTC           Station Zuid    4.875099   52.339080
# 9283619              WTC           Station Zuid    4.875099   52.339080
# 9283620              WTC           Station Zuid    4.875099   52.339080
# 9283621              WTC           Station Zuid    4.875099   52.339080
# 9283622              WTC           Station Zuid    4.875099   52.339080
# 9283623              WTC           Station Zuid    4.875099   52.339080
# 9283624              WTC           Station Zuid    4.875099   52.339080
# 9283625              WTC           Station Zuid    4.875099   52.339080
# 9283626              WTC           Station Zuid    4.875099   52.339080
# 9283627              WTC           Station Zuid    4.875099   52.339080
# 9283628              WTC           Station Zuid    4.875099   52.339080
# 9283629              WTC           Station Zuid    4.875099   52.339080
# 9283630              WTC           Station Zuid    4.875099   52.339080
# 9283631              WTC           Station Zuid    4.875099   52.339080
# 9283632              WTC           Station Zuid    4.875099   52.339080
# 9283633              WTC           Station Zuid    4.875099   52.339080
# 9283634              WTC           Station Zuid    4.875099   52.339080
# 9451707               ND                  Noord    4.931232   52.401172
#
#         AankomstHalteCode      AankomstHalteNaam  AankomstLat  AankomstLon  \
# 4625339             05065                    Dam     4.890794    52.373678
# 4625343             06072          Prinsengracht     4.884284    52.364959
# 4625344             06076           Koningsplein     4.888579    52.366892
# 4625345             06089            Leidseplein     4.880855    52.363093
# 4625346             07321       Van Baerlestraat     4.878958    52.358277
# 4625347             07323            Rijksmuseum     4.883550    52.359770
# 4625349             05031                    Dam     4.893484    52.373411
# 4625350             05035                  Rokin     4.892104    52.369396
# 4625385             05011       Centraal Station     4.899218    52.378108
# 4625394             07303     VU medisch centrum     4.860971    52.335153
# 4625432             05022       Centraal Station     4.901043    52.377720
# 4625435               BMR  Station Bijlmer ArenA     4.947135    52.311930
# 4625436                CS       Centraal Station     4.900781    52.377494
# 4625437               DVD   Station Duivendrecht     4.936784    52.323252
# 4625438               HLD    Station Holendrecht     4.960219    52.297805
# 4625439               RAI            Station RAI     4.889820    52.337399
# 4625440               SLW             Spaklerweg     4.920856    52.339863
# 4625441               VSW      Verrijn Stuartweg     4.966937    52.328441
# 4625442               WBS           Wibautstraat     4.912030    52.354289
# 4625443               WLP          Waterlooplein     4.902982    52.366979
# 4625444               WPP           Weesperplein     4.907875    52.361201
# 4625445               WTC           Station Zuid     4.875099    52.339080
# 4625447               STD     Station Sloterdijk     4.838784    52.388808
# 4625450               BMR  Station Bijlmer ArenA     4.947135    52.311930
# 4625451                CS       Centraal Station     4.900781    52.377494
# 4625452               WPP           Weesperplein     4.907875    52.361201
# 4625454               ASA          Amstelstation     4.917514    52.346473
# 4625455               ASW        Amstelveenseweg     4.857983    52.338367
# 4625457                CS       Centraal Station     4.900781    52.377494
# 4625458               DVD   Station Duivendrecht     4.936784    52.323252
# ...                   ...                    ...          ...          ...
# 9283600               WTC           Station Zuid     4.875099    52.339080
# 9283602               ASA          Amstelstation     4.917514    52.346473
# 9283603               BMR  Station Bijlmer ArenA     4.947135    52.311930
# 9283604                CS       Centraal Station     4.900781    52.377494
# 9283606               WTC           Station Zuid     4.875099    52.339080
# 9283608               ASA          Amstelstation     4.917514    52.346473
# 9283609                CS       Centraal Station     4.900781    52.377494
# 9283611               ASA          Amstelstation     4.917514    52.346473
# 9283612               BMR  Station Bijlmer ArenA     4.947135    52.311930
# 9283613                CS       Centraal Station     4.900781    52.377494
# 9283614               HLD    Station Holendrecht     4.960219    52.297805
# 9283616               WTC           Station Zuid     4.875099    52.339080
# 9283618               ASA          Amstelstation     4.917514    52.346473
# 9283619               ASW        Amstelveenseweg     4.857983    52.338367
# 9283620               CLL       Station Lelylaan     4.834266    52.357663
# 9283621                CS       Centraal Station     4.900781    52.377494
# 9283622               DPP                De Pijp     4.891011    52.352962
# 9283623               HDS        Heemstedestraat     4.834212    52.352558
# 9283624               HLD    Station Holendrecht     4.960219    52.297805
# 9283625               HVW      Henk Sneevlietweg     4.834393    52.346267
# 9283626               JLS      Jan v.Galenstraat     4.834925    52.371966
# 9283627               OAS             Overamstel     4.918154    52.331799
# 9283628               RKN                  Rokin     4.892297    52.369280
# 9283629               SLW             Spaklerweg     4.920856    52.339863
# 9283630               STD     Station Sloterdijk     4.838784    52.388808
# 9283631               VZG           Vijzelgracht     4.890729    52.359801
# 9283632               WBS           Wibautstraat     4.912030    52.354289
# 9283633               WLP          Waterlooplein     4.902982    52.366979
# 9283634               WPP           Weesperplein     4.907875    52.361201
# 9451707                CS       Centraal Station     4.900781    52.377494
#
#          AantalRitten  Weekdag  AantalLijnenVertrek  AantalLijnenAankomst  \
# 4625339            28        1                  5.0                   5.0
# 4625343            18        1                  5.0                   3.0
# 4625344            15        1                  5.0                   3.0
# 4625345            32        1                  5.0                   5.0
# 4625346            13        1                  5.0                   3.0
# 4625347            10        1                  5.0                   3.0
# 4625349            21        1                  4.0                   3.0
# 4625350            15        1                  4.0                   3.0
# 4625385            21        1                  3.0                   5.0
# 4625394            15        1                  2.0                   2.0
# 4625432            25        1                  1.0                   4.0
# 4625435            27        1                  1.0                   1.0
# 4625436            49        1                  1.0                   1.0
# 4625437            12        1                  1.0                   1.0
# 4625438            14        1                  1.0                   1.0
# 4625439            10        1                  1.0                   1.0
# 4625440            20        1                  1.0                   1.0
# 4625441            11        1                  1.0                   1.0
# 4625442            12        1                  1.0                   1.0
# 4625443            23        1                  1.0                   1.0
# 4625444            36        1                  1.0                   1.0
# 4625445            20        1                  1.0                   1.0
# 4625447            11        1                  1.0                   1.0
# 4625450            16        1                  1.0                   1.0
# 4625451            37        1                  1.0                   1.0
# 4625452            11        1                  1.0                   1.0
# 4625454            13        1                  1.0                   1.0
# 4625455            10        1                  1.0                   1.0
# 4625457            37        1                  1.0                   1.0
# 4625458            11        1                  1.0                   1.0
# ...               ...      ...                  ...                   ...
# 9283600            56        1                  1.0                   1.0
# 9283602            23        1                  1.0                   1.0
# 9283603            15        1                  1.0                   1.0
# 9283604            50        1                  1.0                   1.0
# 9283606            26        1                  1.0                   1.0
# 9283608            16        1                  1.0                   1.0
# 9283609            32        1                  1.0                   1.0
# 9283611            34        1                  1.0                   1.0
# 9283612            24        1                  1.0                   1.0
# 9283613            29        1                  1.0                   1.0
# 9283614            17        1                  1.0                   1.0
# 9283616            14        1                  1.0                   1.0
# 9283618            15        1                  1.0                   1.0
# 9283619            13        1                  1.0                   1.0
# 9283620            10        1                  1.0                   1.0
# 9283621            31        1                  1.0                   1.0
# 9283622            13        1                  1.0                   1.0
# 9283623            10        1                  1.0                   1.0
# 9283624            10        1                  1.0                   1.0
# 9283625            31        1                  1.0                   1.0
# 9283626            21        1                  1.0                   1.0
# 9283627            17        1                  1.0                   1.0
# 9283628            21        1                  1.0                   1.0
# 9283629            11        1                  1.0                   1.0
# 9283630            30        1                  1.0                   1.0
# 9283631            23        1                  1.0                   1.0
# 9283632            11        1                  1.0                   1.0
# 9283633            10        1                  1.0                   1.0
# 9283634            14        1                  1.0                   1.0
# 9451707            10        1                  1.0                   1.0
#
#          AantalLijnen  AantalRittenNorm
# 4625339           5.0          5.600000
# 4625343           3.0          6.000000
# 4625344           3.0          5.000000
# 4625345           5.0          6.400000
# 4625346           3.0          4.333333
# 4625347           3.0          3.333333
# 4625349           3.0          7.000000
# 4625350           3.0          5.000000
# 4625385           3.0          7.000000
# 4625394           2.0          7.500000
# 4625432           1.0         25.000000
# 4625435           1.0         27.000000
# 4625436           1.0         49.000000
# 4625437           1.0         12.000000
# 4625438           1.0         14.000000
# 4625439           1.0         10.000000
# 4625440           1.0         20.000000
# 4625441           1.0         11.000000
# 4625442           1.0         12.000000
# 4625443           1.0         23.000000
# 4625444           1.0         36.000000
# 4625445           1.0         20.000000
# 4625447           1.0         11.000000
# 4625450           1.0         16.000000
# 4625451           1.0         37.000000
# 4625452           1.0         11.000000
# 4625454           1.0         13.000000
# 4625455           1.0         10.000000
# 4625457           1.0         37.000000
# 4625458           1.0         11.000000
# ...               ...               ...
# 9283600           1.0         56.000000
# 9283602           1.0         23.000000
# 9283603           1.0         15.000000
# 9283604           1.0         50.000000
# 9283606           1.0         26.000000
# 9283608           1.0         16.000000
# 9283609           1.0         32.000000
# 9283611           1.0         34.000000
# 9283612           1.0         24.000000
# 9283613           1.0         29.000000
# 9283614           1.0         17.000000
# 9283616           1.0         14.000000
# 9283618           1.0         15.000000
# 9283619           1.0         13.000000
# 9283620           1.0         10.000000
# 9283621           1.0         31.000000
# 9283622           1.0         13.000000
# 9283623           1.0         10.000000
# 9283624           1.0         10.000000
# 9283625           1.0         31.000000
# 9283626           1.0         21.000000
# 9283627           1.0         17.000000
# 9283628           1.0         21.000000
# 9283629           1.0         11.000000
# 9283630           1.0         30.000000
# 9283631           1.0         23.000000
# 9283632           1.0         11.000000
# 9283633           1.0         10.000000
# 9283634           1.0         14.000000
# 9451707           1.0         10.000000
#
# [4914 rows x 16 columns]

# %%
simulationdict = dict(Counter(ordest))

# %%
datadict = {}
for index, row in herbest.iterrows():
    datadict[(row['VertrekHalteNaam'], row['AankomstHalteNaam'])] = row['AantalRittenNorm']

# %%
simulation = pd.DataFrame.from_dict(simulationdict, orient='index')
simulation = simulation.reset_index()

# %%
data = pd.DataFrame.from_dict(datadict, orient='index')
data = data.reset_index()
# data.columns = [['Stations', 'DataTrips']]

# %%
combined = pd.merge(simulation, data, on=['index'])

# %%
combined.columns = [['stations', 'simulation', 'data']]

# %%
combined = combined.fillna(value=0)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt
mean_absolute_error(combined['data'], combined['simulation'])
# Out:
# 33.250374531835206

# %%
def rmse(predictions, targets):

    differences = predictions - targets                       #the DIFFERENCEs.

    differences_squared = differences ** 2                    #the SQUAREs of ^

    mean_of_differences_squared = differences_squared.mean()  #the MEAN of ^

    rmse_val = np.sqrt(mean_of_differences_squared)           #ROOT of ^

    return rmse_val
