# %% [markdown]
# ### Ship sailing strategies with various combinations of payloads and velocities for passing a bottleneck waterway section

# %% [markdown]
# ### Steps before sailing:
# - Giving a sailing route, in which there is an section with limited water depth (h_min)
# - Listing a group of possible actual draughts depending on the limited water depth and minimum operating draughts
# - Using the T2v function to find out the corresponding velocities the ship can sail with to safely pass the bottlenek without grounding
# - Displaying the possible actual draughts with its maximum sailing velocities and suggesting several sailing strategies.
#
# ### Steps while sailing:
# - c

# %% [markdown]
# ### Test the reality of sailing with v_computed
# We test it by comparing the total required power (P_tot) of the ship while sailing at v_computed with its installed power (P_installed). If P_tot <= P_installed, the v_computed is realistic.
#
# So the steps to do:
# - set the above results [Strategies: 'T_strategy','v_computed'] as input data for a vessel sailing and consuming energy simulation
# - run the simulation to get results: 'P_tot', 'P_installed', 'total fuel use', 'total emissions_CO2', 'total emissions_PM10', 'total emissions_NOx', 'duration', 'payload'. (Note that you need the "T2payload" function based on "Van Dorsser's method" to get the corresponding 'payload'for each 'T_strategy'.)
# - put the results into dataframe for later easy selecting, processing and plotting
# - select the Strategies of which P_tot <= P_installed
# - analysis the selected Strategies
# - visualize some typical selected Strategies via a series Bar Chart. In each bar chart, y_axis is amount, x_axis is evaluation items.
# - visualize some typical selected Strategies together with ambient waterway sections of different water depths.(Note that the input [Vs, P_tot_given] are different for bottle neck section and ambient sections)

# %%
import functools
import itertools
import warnings
warnings.filterwarnings('ignore')
import sys
sys.tracebacklimit=0
# package(s) related to time, space and id
import logging
import datetime, time
import platform

# you need these dependencies (you can get these from anaconda)
# package(s) related to the simulation
import simpy
import pandas as pd

# spatial libraries 
import pyproj
import shapely.geometry
from simplekml import Kml, Style

# package(s) for data handling
import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import tqdm

# OpenTNSim
import opentnsim

# Used for mathematical functions
import math             

# Used for making the graph to visualize our problem
import networkx as nx   

import plotly.express as px
from plotly.subplots import make_subplots

#logging.basicConfig(level=logging.DEBUG) #turn on all the debug messages
#logging.basicConfig(level=logging.INFO)# turn off all the debug messages

logger = logging.getLogger('notebook')

# %% [markdown]
# ### Create graph
# We first need to create a 1D network (a graph) along which the vessel will move. A graph contains edges (blue dots in plot below) and vertices (black lines in plot below). For this example, we will construct a network consisting of 4 nodes in a straight line. Since we would like to have two-way traffic, we add two edges between each pair of nodes: one from left to right, and another the other way around (however, we could easily apply one-way traffic as well by remove one of the two edges). Consequently, we arrive at a total of 4 nodes, and 6 edges.
#
# Due to the nature of discrete modelling in which the time step is dependent on the activities (in this example: forcing a ship to move from node to node from its origin to its destination), it is important to add OpenTNSim mix-ins to the nodes in such a way we could identify the node (mix-in Identifiable, which imports a name and imports/creates an ID), and to locate the node (mix-in Locatable, which gives the node a geometry).

# %%
FG = nx.DiGraph()
nodes = []
path = []

Node = type('Site', (opentnsim.core.Identifiable, opentnsim.core.Locatable), {})

data_node_1 = {"name": "Node 1",
               "geometry": shapely.geometry.Point(0, 0)}
data_node_2 = {"name": "Node 2",
               "geometry": shapely.geometry.Point(0.8983, 0)}  # 0.8983 degree =100km
data_node_3 = {"name": "Node 3",
               "geometry": shapely.geometry.Point(1.7966, 0)}   # 1.7966 degree =200km
data_node_4 = {"name": "Node 4",
               "geometry": shapely.geometry.Point(2.6949, 0)}    # 2.6949 degree =300km

node_1 = Node(**data_node_1)
node_2 = Node(**data_node_2)
node_3 = Node(**data_node_3)
node_4 = Node(**data_node_4)

nodes = [node_1, node_2, node_3, node_4]

positions = {}
for node in nodes:
    positions[node.name] = (node.geometry.x, node.geometry.y)
    FG.add_node(node.name, geometry = node.geometry)

path = [[node_1, node_2], # From node 1 to node 2
        [node_2, node_3], # From node 2 to node 3
        [node_3, node_4], # From node 3 to node 4
        [node_4, node_3], # From node 4 to node 3
        [node_3, node_2], # From node 3 to node 2
        [node_2, node_1]] # From node 2 to node 1


for edge in path:
    # For the energy consumption calculation we add info to the graph. We need depth info for resistance.
    # NB: the CalculateEnergy routine expects the graph to have "Info" that contains "GeneralDepth" 
    #     this may not be very generic!
    FG.add_edge(edge[0].name, edge[1].name, weight = 1, Info = {"GeneralDepth": 6})
    
middle_edges = [
    (node_2.name, node_3.name),
    (node_3.name, node_2.name)
]
for e in middle_edges:
    edge = FG.edges[e]
    edge['Info']['GeneralDepth'] = 2.5

# env.FG = FG
nx.draw(FG, positions)
plt.show()

# %%
# This cell just shows that now a depth of 10 m is added to the edges. 
# You can use this to vary depths, e.g. make the middle edge shallower. Note that edges are bi-directional 
for edge in FG.edges:
    print('General depth for edge {} is {}'.format(edge, FG.get_edge_data(edge[0], edge[1])["Info"]["GeneralDepth"]))
# Out:
# General depth for edge ('Node 1', 'Node 2') is 6
# General depth for edge ('Node 2', 'Node 3') is 2.5
# General depth for edge ('Node 2', 'Node 1') is 6
# General depth for edge ('Node 3', 'Node 4') is 6
# General depth for edge ('Node 3', 'Node 2') is 2.5
# General depth for edge ('Node 4', 'Node 3') is 6

# %% [markdown]
# ### Create vessel - add VesselProperties and ConsumesEnergy mixins
# The following mix-ins are required for each vessel in our problem: Identifiable (gives the vessel a name and a random ID), Movable (gives that the object (*vessel*) can move with a fixed speed and logs this activity, it requires input for the following mix-ins: Locatable, Routeable, and Log), and Routable (gives the object a route). We now modify our original vessel from the basic example and include vessel properties (like width, length, etc.) and a mixin that is needed to calculate resistance and energy consumption.

# %%
# Make your preferred class out of available mix-ins.
TransportResource = type(
    "Vessel",
    (
        opentnsim.core.Identifiable,
        opentnsim.core.Movable,
        opentnsim.core.Routeable,
        opentnsim.core.VesselProperties,  # needed to add vessel properties
        opentnsim.core.HasContainer,  # needed to calculate filling degree for draught
        opentnsim.core.ConsumesEnergy,
        opentnsim.core.ExtraMetadata,
        
    ),
    {},
)  # needed to calculate resistances

# %%
# Create a dict with all important settings
data_vessel = {"env": None,
               "name": None,
               "route": None,
               "geometry": None,
               "v": 1,  # m/s
               "type": 'Dortmund-Eems (L <= 74 m)', # <-- note that inputs from hereon are due to the added mixins!
               "B": 11.4,
               "L": 110,
               "capacity": 2500,   # maximum designed payload
               "level":2500,     # actual payload
               "H_e": None, 
               "H_f": None, 
               "T": None,
               "safety_margin": 0.3, # for tanker vessel with rocky bed the safety margin is recommended as 0.3 m
               "P_installed": 1750.0,   
               "P_tot_given": None, # kW
               "L_w": 3.0 ,
               "C_B":0.85, 
               "C_year":1990,
               "current_year":None
              }

# %% [markdown]
# ### Define paths
# We are going to create a simulation in which a vessel moves from *Node 1* to *Node 4*. Therefore, we need to create a vessel to which we will need to append this paths. Therefore, first let's create the path.

# %%
path = nx.dijkstra_path(FG, node_1.name, node_4.name)
path_bottleneck = nx.dijkstra_path(FG, node_2.name, node_3.name)

# %% [markdown]
# ### Define T2v function

# %%
def T2v(vessel, h_min, bounds=(0, 10)):
    """Compute vessel velocity given the minimum water depth and possible actual draught 
    
    bounds is the limits where to look for a solution for the velocity [m/s]
    returns velocity [m/s]
    """
    
    def seek_v_given_T(v, vessel, h_min):
        """function to optimize"""
        
        # compute the maximum draught a vessel can have to pass the minimum water depth section, 
        # considering the maximum squat while sailing in limited water depth.
        h_min = vessel.h_min
        #z = (vessel.C_B * (1.94 * v)**2) * (6 * vessel.B * vessel.T / (150 * vessel.h_min) + 0.4) / 100 # vessel.T is the computed T
        # Here we use the standard width 150 m as the waterway width
        z = (vessel.C_B * ((vessel.B * vessel.T) / (150 * vessel.h_min)) ** 0.81) * (v ** 2.08) / 20
        # print('z: {:.2f} m'.format(z))
        # compute difference between given draught (T_strategy) and computed draught (T_computed)
        T_strategy = vessel._T  # the user provided T
        T_computed = vessel.h_min - z - vessel.safety_margin
        # T_computed = vessel.h_min - z 
        diff = T_strategy - T_computed
        
        # print('T_strategy: {:.2f} m'.format(T_strategy))
        # print('T_computed: {:.2f} m'.format(T_computed))
        # print('T_strategy - T_computed: {:.2f} m'.format(diff))

#        logger.debug(f'optimizing for v: {v}, T_strategy: {T_strategy}, T: {vessel.T}'T_computed: {:.2f} m'.format(T_computed), T: {vessel.T}')
        
        return diff ** 2        
        
#    print('')
#    print('I am in T2v')    

    # fill in some of the parameters that we already know
    fun = functools.partial(seek_v_given_T, vessel=vessel, h_min = vessel.h_min)       

    # lookup a minimum
    fit = scipy.optimize.minimize_scalar(fun, bounds=bounds, method='bounded')

    # check if we found a minimum
    if not fit.success:
        raise ValueError(fit)    

    v_T2v =  fit.x


    return v_T2v

# %% [markdown]
# ### Define P2v function

# %%
def P2v(vessel, h_min, bounds=(0, 10)):
    """Compute vessel velocity given an edge and power (P_tot_given)
    
    bounds is the limits where to look for a solution for the velocity [m/s]
    returns velocity [m/s]
    """

    def seek_v_given_P_installed(v, vessel, h_min):
        """function to optimize"""
        # water depth from the edge
        h_min = vessel.h_min
        # TODO: consider precomputing a range v/h combinations for the ship before the simulation starts
        vessel.calculate_total_resistance(v, h_min)
        # compute total power given
        vessel.calculate_total_power_required(v=v)
        if isinstance(vessel.P_tot, complex):
            raise ValueError(f"P tot is complex: {vessel.P_tot}")

        # compute difference between power setting by captain and power needed for velocity
        diff = vessel.P_installed - vessel.P_tot
        #logger.debug(f'optimizing for v: {v}, P_tot_given: {vessel.P_tot_given}, P_tot {vessel.P_tot}, P_given {P_given}')
        return diff ** 2

    # fill in some of the parameters that we already know
    fun = functools.partial(seek_v_given_P_installed, vessel=vessel, h_min = vessel.h_min)
    # lookup a minimum
    fit = scipy.optimize.minimize_scalar(fun, bounds=bounds, method='bounded')
    v_P2v = fit.x

    # check if we found a minimum
    if not fit.success:
        raise ValueError(fit)
    logger.debug(f"fit: {fit}")
    # return fit.x
    return v_P2v

# %% [markdown]
# ### Define formulate_sailing_strategies (T2v, P2v) simulation to get maximum possible veolicities
# Now we can define the run. First, we make an environment and add the graph to the environment. Then we add one vessel, to which we will append the environment and the above route. Lastly, we give the vessel the process of moving from the origin to the destination of the defined path and subsequently run the model.

# %%
# To get maximum velocity (v_computed) for each T_strategy considering maximum sinkage and safety margin
# here we need Graph (FG) and path (overall) to know the minimum waterdepth h_min along the route for planning strategies
def formulate_sailing_strategies(FG, path, T_strategy):
    
    # Start simpy environment
    simulation_start = datetime.datetime.now()
    env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
    env.epoch = time.mktime(simulation_start.timetuple())

    # Add graph to environment
    env.FG = FG
            
    # create a fresh instance of vessel
#    print('start the vessel')
    vessel = TransportResource(**data_vessel)
    vessel.name = 'Vessel No.1'                     
    # add environment and path to the vessel
    vessel.env = env                                        #the created environment
    vessel.route = path                                     #the route (the sequence of nodes, as stored as the second column in the path)

    # position vessel at the start of the path
    vessel.geometry = env.FG.nodes[path[0]]['geometry']     #a shapely.geometry.Point(lon,lat) (here taken as the starting node of the vessel)

    # new properties added
    vessel._T =  T_strategy # start with the minimum operational draft (and fill up)
    
    # get T2v
    v_T2v  = T2v(vessel, h_min = vessel.h_min)
    # get P2v
    v_P2v = P2v(vessel, h_min = vessel.h_min)
    #print('v_computed: {:.2f} m/s'.format(v_computed))
   
    #print('z: {:.2f} m'.format(z))
    # Start the simulation
    env.process(vessel.move())
    env.run()

    
    return v_T2v, v_P2v

# %% [markdown]
# ### Define T2Payload function to know the corresponding Payload for each T_strategy

# %%
# To know the corresponding Payload for each T_strategy
def T2Payload(self, T_strategy, vesl_type):

    """ Calculate payload based on Van Dorsser et al
    (https://www.researchgate.net/publication/344340126_The_effect_of_low_water_on_loading_capacity_of_inland_ships)

    Given a route we get several possible draught (T_strategy) with veolicity (v_computed) combinations for the moving vessel, this step is done via T2v simulation.
    At this step, we calculate the payload for the possible draughts (T_strategy).

    Input:
    - T_strategy
    - vessel types: "Container","Dry_SH","Dry_DH","Barge","Tanker"

    Output:
    - corresponding payload for the T_strategy for different vessel types     

    """
    #Design draft T_design, refer to Table 5

    Tdesign_coefs = dict({"intercept":0,
                     "c1": 1.7244153371,
                     "c2": 2.2767179246,
                     "c3": 1.3365379898,
                     "c4": -5.9459308905,
                     "c5": 6.2902305560*10**-2,
                     "c6": 7.7398861528*10**-5,
                     "c7": 9.0052384439*10**-3,
                     "c8": 2.8438560877
                     })

    assert vesl_type in ["Container","Dry_SH","Dry_DH","Barge","Tanker"],'Invalid value vesl_type, should be "Container","Dry_SH","Dry_DH","Barge" or "Tanker"'
    if vesl_type == "Container":
        [dum_container, dum_dry,
        dum_barge, dum_tanker] = [1,0,0,0]
    elif vesl_type == "Dry_SH":
        [dum_container, dum_dry,
        dum_barge, dum_tanker] = [0,1,0,0]
    elif vesl_type == "Dry_DH":
        [dum_container, dum_dry,
        dum_barge, dum_tanker] = [0,1,0,0]
    elif vesl_type == "Barge":
        [dum_container, dum_dry,
        dum_barge, dum_tanker] = [0,0,1,0]
    elif vesl_type == "Tanker":
        [dum_container, dum_dry,
        dum_barge, dum_tanker] = [0,0,0,1]

    T_design = Tdesign_coefs['intercept'] + (dum_container * Tdesign_coefs['c1']) + \
                                            (dum_dry * Tdesign_coefs['c2']) + \
                                            (dum_barge * Tdesign_coefs['c3']) +\
                                            (dum_tanker * Tdesign_coefs['c4']) +\
                                            (Tdesign_coefs['c5'] * dum_container * self.L**0.4 * self.B**0.6) +\
                                            (Tdesign_coefs['c6'] * dum_dry * self.L**0.7 * self.B**2.6)+\
                                            (Tdesign_coefs['c7'] * dum_barge * self.L**0.3 * self.B**1.8) +\
                                            (Tdesign_coefs['c8'] * dum_tanker * self.L**0.1 * self.B**0.3)

    #Empty draft T_empty, refer to Table 4
    
    Tempty_coefs = dict({"intercept": 7.5740820927*10**-2,
                "c1": 1.1615080992*10**-1,
                "c2": 1.6865973494*10**-2,
                "c3": -2.7490565381*10**-2,
                "c4": -5.1501240744*10**-5,
                "c5": 1.0257551153*10**-1,
                "c6": 2.4299435211*10**-1,
                "c7": -2.1354295627*10**-1,
                })


    if vesl_type == "Container":
        [dum_container, dum_dry,
        dum_barge, dum_tanker] = [1,0,0,0]
    elif vesl_type == "Dry_SH":
        [dum_container, dum_dry,
        dum_barge, dum_tanker] = [0,0,0,0]
    elif vesl_type == "Dry_DH":
        [dum_container, dum_dry,
        dum_barge, dum_tanker] = [0,1,0,0]
    elif vesl_type == "Barge":
        [dum_container, dum_dry,
        dum_barge, dum_tanker] = [0,0,1,0]

    elif vesl_type == "Tanker":
        [dum_container, dum_dry,
        dum_barge, dum_tanker] = [0,0,0,1]

    # dum_container and dum_dry use the same "c5"
    T_empty = Tempty_coefs['intercept']  + (Tempty_coefs['c1'] * self.B) + \
                                           (Tempty_coefs['c2'] * ((self.L * T_design) / self.B)) + \
                                           (Tempty_coefs['c3'] * (np.sqrt(self.L * self.B)))  + \
                                           (Tempty_coefs['c4'] * (self.L * self.B * T_design)) +  \
                                           (Tempty_coefs['c5'] * dum_container) + \
                                           (Tempty_coefs['c5'] * dum_dry)   + \
                                           (Tempty_coefs['c6'] * dum_tanker) + \
                                           (Tempty_coefs['c7'] * dum_barge)



    #Capacity indexes, refer to Table 3 and eq 2
    CI_coefs = dict({"intercept": 2.0323139721 * 10**1,

            "c1": -7.8577991460 * 10**1,
            "c2": -7.0671612519 * 10**0,
            "c3": 2.7744056480 * 10**1,
            "c4": 7.5588609922 * 10**-1,
            "c5": 3.6591813315 * 10**1
            })
    # Capindex_1 related to actual draft (especially used for shallow water)
    Capindex_1 = CI_coefs["intercept"] + (CI_coefs["c1"] * T_empty) + (CI_coefs["c2"] * T_empty**2)  +  (
    CI_coefs["c3"] * T_strategy) + (CI_coefs["c4"] * T_strategy**2)   + ( CI_coefs["c5"] * (T_empty * T_strategy))
    # Capindex_2 related to design draft
    Capindex_2 = CI_coefs["intercept"] + (CI_coefs["c1"] * T_empty) + (CI_coefs["c2"] * T_empty**2)   + (
    CI_coefs["c3"] * T_design) + (CI_coefs["c4"] * T_design**2)  + (CI_coefs["c5"] * (T_empty * T_design))

    #DWT design capacity, refer to Table 6 and eq 3
    capacity_coefs = dict({"intercept": -1.6687441313*10**1,
         "c1": 9.7404521380*10**-1,
         "c2": -1.1068568208,
         })

    DWT_design = capacity_coefs['intercept'] + (capacity_coefs['c1'] * self.L * self.B * T_design) + (
     capacity_coefs['c2'] * self.L * self.B * T_empty) # designed DWT
    DWT_actual = (Capindex_1/Capindex_2)*DWT_design # actual DWT of shallow water


    if T_strategy < T_design:
        consumables=0.04 #consumables represents the persentage of fuel weight,which is 4-6% of designed DWT
                          # 4% for shallow water (Van Dosser  et al. Chapter 8,pp.68).

    else:
        consumables=0.06 #consumables represents the persentage of fuel weight,which is 4-6% of designed DWT
                          # 6% for deep water (Van Dosser et al. Chapter 8, pp.68).

    fuel_weight=DWT_design*consumables #(Van Dosser et al. Chapter 8, pp.68).
    Payload_strategy = DWT_actual-fuel_weight # payload=DWT-fuel_weight


    return  Payload_strategy

# %% [markdown]
# ### Define max_sinkage_at_v_strategy function to know the maximum sinkage for a possible velocity

# %%
# with this function we can get differet max_sinkages for different velocities for one T_strategy or a list of T_strategy 
def max_sinkage_at_v_strategy (self, T_strategy, v_strategy):
        # Start simpy environment
        
    # Start simpy environment
    simulation_start = datetime.datetime.now()
    env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
    env.epoch = time.mktime(simulation_start.timetuple())

    # Add graph to environment
    env.FG = FG
            
    # create a fresh instance of vessel
#    print('start the vessel')
    vessel = TransportResource(**data_vessel)
    vessel.name = 'Vessel No.1'                     
    # add environment and path to the vessel
    vessel.env = env                                        #the created environment
    vessel.route = path  
    # position vessel at the start of the path
    vessel.geometry = env.FG.nodes[path[0]]['geometry']     #a shapely.geometry.Point(lon,lat) (here taken as the starting node of the vessel)

    
    max_sinkage = (vessel.C_B * ((vessel.B * T_strategy) / (150 * vessel.h_min)) ** 0.81) * (v_strategy ** 2.08) / 20
    
    # Start the simulation
    env.process(vessel.move())
    env.run()
    
    return v_strategy, max_sinkage

# %% [markdown]
# ### Prepare input matrix for 'formulate_sailing_strategies simulation (T2v, P2v)'

# %%
# give some possible draught for h_min = 2.5 m
# TODO: give T_strategy for passing limited water depth by collectting values between min-operational draught and (h_min-ukc)

T_strategy = [ 2.2, 2.19, 2.18, 2.17, 2.16, 2.15, 2.14, 2.13, 2.12, 2.11, 2.10, 2.05, 2.00,
              1.95, 1.90, 1.85, 1.80, 1.75, 1.70, 1.65, 1.60, 1.55, 1.50, 1.45, 1.4] 
h_min = [2.5]
safety_margin =[0.3]

# %%
# prepare the work to be done
# create a list of all combinations
work = list(itertools.product(T_strategy, h_min, safety_margin))

# prepare a list of dictionaries for pandas
rows = []
for item in work:
    row = {"T_strategy": item[0],"h_min":item[1], "safety_margin":item[2]}
    rows.append(row)

    # these are all the simulations that we want to run
# convert them to dataframe, so that we can apply a function and monitor progress
work_df = pd.DataFrame(rows)
work_df.tail()
# Out:
#     T_strategy  h_min  safety_margin
# 20        1.60    2.5            0.3
# 21        1.55    2.5            0.3
# 22        1.50    2.5            0.3
# 23        1.45    2.5            0.3
# 24        1.40    2.5            0.3

# %% [markdown]
# ### Run 'formulate_sailing_strategies simulation' to get maximum possible sailing veolicites for the T_strategy for h_min with a safety margin

# %%
Strategies = []

for i, row in tqdm.tqdm(work_df.iterrows()):
    T_strategy = row['T_strategy']
    h_min = row['h_min']
    safety_margin = row['safety_margin']
    
   
    vessel = TransportResource(**data_vessel)

    v_computed, v_p2v  = formulate_sailing_strategies(FG, path, T_strategy)
    v_max_final = min (v_computed, v_p2v)
    
    Payload_strategy = T2Payload(vessel, T_strategy, vesl_type = "Tanker") 
    
    v_strategy, max_sinkage = max_sinkage_at_v_strategy (vessel,T_strategy, v_max_final)
    remained_distance_to_margin = h_min - T_strategy - max_sinkage - safety_margin
    
    
    Strategy ={}
    Strategy.update(row)
    Strategy['max_sinkage_at_v_max_final'] = max_sinkage    
    Strategy['h_min'] = h_min
    Strategy['safety_margin'] = safety_margin
    Strategy['remained_distance_to_margin'] = remained_distance_to_margin
    Strategy['v_max_(sinkage_allowed)'] = v_computed
    Strategy['v_max_(power_allowed)'] = v_p2v    
    Strategy['v_max_final'] = v_max_final
    Strategy['Payload_strategy_tanker'] = Payload_strategy
    Strategies.append(Strategy)
# Out:
# 25it [00:00, 173.99it/s]

# %% [markdown]
# ### The DataFrame Table (Strategies_df) showing below is the overall strategy for an M8 tanker vessel to pass the bottleneck section (h_min = 2.5 m, safety margin = 0.3 m), including:
# - possible draughts, corresponding payloads,
# - maximum ship velocities considering maximum allowed sinkage without touching safety margin,
# - maximum ship velocities within installed power,
# - the final realistic maximum ship velocities (v_max_final) considering both maximum allowed sinkage and installed power (which is the lower value between v_max(sinkage_allowed) and v_max_(power_allowed) )
# - remained_distance between ship bottom to safety margin while sailing at v_max_final with its maximum sinkage

# %%
Strategies_df = pd.DataFrame(Strategies)
with pd.option_context('display.float_format', '{:.4f}'.format):
    display(Strategies_df)
# Out:
#     T_strategy  h_min  safety_margin  max_sinkage_at_v_max_final  \
# 0       2.2000 2.5000         0.3000                      0.0000
# 1       2.1900 2.5000         0.3000                      0.0100
# 2       2.1800 2.5000         0.3000                      0.0200
# 3       2.1700 2.5000         0.3000                      0.0300
# 4       2.1600 2.5000         0.3000                      0.0400
# 5       2.1500 2.5000         0.3000                      0.0500
# 6       2.1400 2.5000         0.3000                      0.0600
# 7       2.1300 2.5000         0.3000                      0.0700
# 8       2.1200 2.5000         0.3000                      0.0788
# 9       2.1100 2.5000         0.3000                      0.0785
# 10      2.1000 2.5000         0.3000                      0.0782
# 11      2.0500 2.5000         0.3000                      0.0767
# 12      2.0000 2.5000         0.3000                      0.0751
# 13      1.9500 2.5000         0.3000                      0.0734
# 14      1.9000 2.5000         0.3000                      0.0718
# 15      1.8500 2.5000         0.3000                      0.0701
# 16      1.8000 2.5000         0.3000                      0.0684
# 17      1.7500 2.5000         0.3000                      0.0667
# 18      1.7000 2.5000         0.3000                      0.0649
# 19      1.6500 2.5000         0.3000                      0.0631
# 20      1.6000 2.5000         0.3000                      0.0613
# 21      1.5500 2.5000         0.3000                      0.0593
# 22      1.5000 2.5000         0.3000                      0.0571
# 23      1.4500 2.5000         0.3000                      0.0545
# 24      1.4000 2.5000         0.3000                      0.0603
#
#     remained_distance_to_margin  v_max_(sinkage_allowed)  \
# 0                       -0.0000                   0.0000
# 1                       -0.0000                   1.4326
# 2                        0.0000                   2.0027
# 3                       -0.0000                   2.4381
# 4                        0.0000                   2.8048
# 5                        0.0000                   3.1281
# 6                       -0.0000                   3.4209
# 7                        0.0000                   3.6907
# 8                        0.0012                   3.9427
# 9                        0.0115                   4.1800
# 10                       0.0218                   4.4054
# 11                       0.0733                   5.4040
# 12                       0.1249                   6.2656
# 13                       0.1766                   7.0442
# 14                       0.2282                   7.7678
# 15                       0.2799                   8.4526
# 16                       0.3316                   9.1097
# 17                       0.3833                   9.7468
# 18                       0.4351                  10.0000
# 19                       0.4869                  10.0000
# 20                       0.5387                  10.0000
# 21                       0.5907                  10.0000
# 22                       0.6429                  10.0000
# 23                       0.6955                  10.0000
# 24                       0.7397                  10.0000
#
#     v_max_(power_allowed)  v_max_final  Payload_strategy_tanker
# 0                  3.9152       0.0000                1227.2542
# 1                  3.9153       1.4326                1215.7939
# 2                  3.9153       2.0027                1204.3362
# 3                  3.9154       2.4381                1192.8810
# 4                  3.9154       2.8048                1181.4284
# 5                  3.9153       3.1281                1169.9783
# 6                  3.9152       3.4209                1158.5308
# 7                  3.9151       3.6907                1147.0858
# 8                  3.9150       3.9150                1135.6434
# 9                  3.9148       3.9148                1124.2034
# 10                 3.9146       3.9146                1112.7661
# 11                 3.9133       3.9133                1055.6174
# 12                 3.9114       3.9114                 998.5323
# 13                 3.9089       3.9089                 941.5108
# 14                 3.9058       3.9058                 884.5529
# 15                 3.9021       3.9021                 827.6586
# 16                 3.8977       3.8977                 770.8279
# 17                 3.8926       3.8926                 714.0607
# 18                 3.8864       3.8864                 657.3571
# 19                 3.8790       3.8790                 600.7172
# 20                 3.8696       3.8696                 544.1408
# 21                 3.8569       3.8569                 487.6280
# 22                 3.8354       3.8354                 431.1787
# 23                 3.8025       3.8025                 374.7931
# 24                 4.0443       4.0443                 318.4711

# %% [markdown]
# ### Based on the overall strategies from the above table, we do a further analysis for one given T_strategy with several possible velocities

# %%
T_strategy_n10 = [2.1] 
v_strategy_n10 = [0, 1, 1.5, 2, 2.5, 3, 3.5, 3.91]
h_min = [2.5]

safety_margin =[0.3]

# %%
# prepare the work to be done
# create a list of all combinations
work4 = list(itertools.product(T_strategy_n10, v_strategy_n10, h_min, safety_margin))

# prepare a list of dictionaries for pandas
rows4 = []
for item4 in work4:
    row4 = {"T_strategy_n10 (m)": item4[0], "v_strategy_n10 (m)": item4[1], "h_min (m)":item4[2], "safety_margin (m)":item4[3]}
    rows4.append(row4)
print(row4)
# these are all the simulations that we want to run
# convert them to dataframe, so that we can apply a function and monitor progress
work4_df = pd.DataFrame(rows4)
work4_df.tail(8)
# Out:
# {'T_strategy_n10 (m)': 2.1, 'v_strategy_n10 (m)': 3.91, 'h_min (m)': 2.5, 'safety_margin (m)': 0.3}
#    T_strategy_n10 (m)  v_strategy_n10 (m)  h_min (m)  safety_margin (m)
# 0                 2.1                0.00        2.5                0.3
# 1                 2.1                1.00        2.5                0.3
# 2                 2.1                1.50        2.5                0.3
# 3                 2.1                2.00        2.5                0.3
# 4                 2.1                2.50        2.5                0.3
# 5                 2.1                3.00        2.5                0.3
# 6                 2.1                3.50        2.5                0.3
# 7                 2.1                3.91        2.5                0.3

# %%
Strategies_n10 = []

for i, row4 in tqdm.tqdm(work4_df.iterrows()):
    T_strategy_n10 = row4['T_strategy_n10 (m)']
    v_strategy_n10 = row4['v_strategy_n10 (m)']
    h_min_n10 = row4['h_min (m)']
    safety_margin_n10 = row4['safety_margin (m)']
    
   
    vessel = TransportResource(**data_vessel)

    
    Payload_strategy_n10 = T2Payload(vessel, T_strategy_n10, vesl_type = "Tanker") 
    
    v_strategy_n10, max_sinkage_n10 = max_sinkage_at_v_strategy (vessel,T_strategy_n10, v_strategy_n10)
    remained_distance_to_margin_n10 = h_min_n10 - T_strategy_n10 - max_sinkage_n10 - safety_margin_n10
    
    
    Strategy_n10 ={}
    Strategy_n10.update(row4)
        
    Strategy_n10['h_min (m)'] = h_min_n10    
    Strategy_n10['max_sinkage_at_v_strategy (m)'] = max_sinkage_n10
    Strategy_n10['remained_distance_to_margin (m)'] = remained_distance_to_margin_n10
    Strategy_n10['safety_margin (m)'] = safety_margin_n10
    Strategy_n10['Payload_strategy_tanker (ton)'] = Payload_strategy_n10
    Strategies_n10.append(Strategy_n10)
# Out:
# 8it [00:00, 775.29it/s]

# %% [markdown]
# ### The DataFrame Table (Strategies_n10_df) showing below is the strategy for an M8 tanker vessel to pass the bottleneck section (h_min = 2.5 m, safety margin = 0.3 m) with a given T_strategy = 2.1 m and a list of possible velocities, including:
# - given draught, corresponding payload,
# - maximum sinkage at each v_strategy
# - remained_distance between ship bottom to safety margin while sailing at each given v_strategy

# %%
Strategies_n10_df = pd.DataFrame(Strategies_n10)
with pd.option_context('display.float_format', '{:.4f}'.format):
    display(Strategies_n10_df)
# Out:
#    T_strategy_n10 (m)  v_strategy_n10 (m)  h_min (m)  safety_margin (m)  \
# 0              2.1000              0.0000     2.5000             0.3000
# 1              2.1000              1.0000     2.5000             0.3000
# 2              2.1000              1.5000     2.5000             0.3000
# 3              2.1000              2.0000     2.5000             0.3000
# 4              2.1000              2.5000     2.5000             0.3000
# 5              2.1000              3.0000     2.5000             0.3000
# 6              2.1000              3.5000     2.5000             0.3000
# 7              2.1000              3.9100     2.5000             0.3000
#
#    max_sinkage_at_v_strategy (m)  remained_distance_to_margin (m)  \
# 0                         0.0000                           0.1000
# 1                         0.0046                           0.0954
# 2                         0.0106                           0.0894
# 3                         0.0193                           0.0807
# 4                         0.0308                           0.0692
# 5                         0.0450                           0.0550
# 6                         0.0620                           0.0380
# 7                         0.0780                           0.0220
#
#    Payload_strategy_tanker (ton)
# 0                      1112.7661
# 1                      1112.7661
# 2                      1112.7661
# 3                      1112.7661
# 4                      1112.7661
# 5                      1112.7661
# 6                      1112.7661
# 7                      1112.7661

# %% [markdown]
# ### Based on the overall and detailed strategies analysis above, next we simulate the energy consumption and sailing duration for the selected strategies
#
# - 1st we simulate for passing the bottleneck section (h_min = 2.5 m) with overall strategies (all the T_strategies with v_max_final)
# - 2nd we simulate for passing the bottleneck section (h_min = 2.5 m) with selected strategies
# - 3rd we simulate for passing the whloe sections: (h_0: 6 m, 2.5 m, 6 m) with selected strategies
#   - the selected strategies are:
#     - T_strategy = 2.1 m
#     - v_strategy = [3, 3.5] m/s;
#     Note that for (h_0: 6 m, 4 m, 6 m) and (h_0: 6 m, 6 m, 6 m) examples, v_strategy = [3, 3.5, 4] m/s

# %% [markdown]
# ### Define "T_v_strategy_energy_simulation" for passing bottleneck section (h_min = 2.5 m)

# %%
def T_v_strategy_energy_simulation(v_strategy, T_strategy):
    
    # Start simpy environment
    simulation_start = datetime.datetime.now()
    env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
    env.epoch = time.mktime(simulation_start.timetuple())

    # Add graph to environment
    env.FG = FG

    # Add environment and path to the vessel
    # create a fresh instance of vessel
    vessel = TransportResource(**data_vessel)
    vessel.env = env                                        #the created environment
    vessel.name = 'Vessel No.1'                     
    vessel.route = path_bottleneck                #the route (the sequence of nodes, as stored as the second column in the path)
    vessel.geometry = env.FG.nodes[path[0]]['geometry']     #a shapely.geometry.Point(lon,lat) (here taken as the starting node of the vessel)
    vessel._T = T_strategy
    vessel.v = v_strategy
    
 
    # Start the simulation
    env.process(vessel.move())
    env.run()
    
    return vessel

# %% [markdown]
# ### Run "T_v_strategy_energy_simulation" for passing bottleneck section with overall strategies (all the T_strategies with v_max_final)

# %%
df_collect = {}
sinkage_max = {}


for i, row in tqdm.tqdm(T_v_Strategies_df.iterrows()):
    # create a new vessel, like the one above (so that it also has L)   
    
    v_strategy = row['v_strategy']
    T_strategy = row['T_strategy']
    
    data_vessel_i = data_vessel.copy()
    vessel = TransportResource(**data_vessel_i)
    vessel=  run_simulation(v_strategy, T_strategy)
    # z = (vessel.C_B * ((vessel.B * vessel.T) / (150 * vessel.h_min)) ** 0.81) * (v_computed ** 2.08) / 20
  

    # sinkage_max = z

    #create an EnergyCalculation object and perform energy consumption calculation
    energycalculation = opentnsim.energy.EnergyCalculation(FG, vessel)
    energycalculation.calculate_energy_consumption()
    #P_tot = vessel.calculate_total_power_required(v_computed)
    
    # create dataframe from energy calculation computation
    
    df = pd.DataFrame.from_dict(energycalculation.energy_use)
    df.update(row)
    
    # add/modify some comlums to suit our plotting needs
    # df['P_tot'] = P_tot
    df['fuel_kg_bottleneck'] = df['total_fuel_consumption']/1000   # g --> kg
    df['CO2_kg_bottleneck']   = df['total_emission_CO2']/1000
    df['PM10_kg_bottleneck']  = df['total_emission_PM10']/1000
    df['NOx_kg_bottleneck']   = df['total_emission_NOX']/1000
    df['duration_hrs_bottleneck'] = df['delta_t'] /3600  # s--> hour
    # df['sinkage_max_m_bottleneck'] = sinkage_max
    # df['Payload_strategy_ton_bottleneck'] = Payload_strategy
    
    
    label = 'T_strategy = ' + str(T_strategy) + ' v_strategy = ' + str(round(v_strategy,2))
    
    df_collect[label + ' P_tot']   = list(df.P_tot[[0]])
    df_collect[label + ' P_installed'] = list(df.P_installed[[0]])
    df_collect[label + ' duration_hrs_bottleneck']   = list(df.duration_hrs_bottleneck[[0]])
    df_collect[label + ' fuel_kg_bottleneck']   = list(df.fuel_kg_bottleneck[[0]])
    df_collect[label + ' CO2_kg_bottleneck'] = list(df.CO2_kg_bottleneck[[0]])
    df_collect[label + ' PM10_kg_bottleneck']   = list(df.PM10_kg_bottleneck[[0]])
    df_collect[label + ' NOx_kg_bottleneck']   = list(df.NOx_kg_bottleneck[[0]])
    # df_collect[label + ' sinkage_max_m_bottleneck']   = list(df.sinkage_max_m_bottleneck[[0]])

    # df_output['T_strategy']   = list(Strategies_df.T_strategy[0:17])
    # df_output['v_computed']   = list(Strategies_df.v_computed[0:17])
    # df_output['P_tot']   = list(df.P_tot[[0]])
    # df_output[' P_installed'] = list(df.P_installed[[0]])
    # df_output[' duration_hrs_bottleneck']   = list(df.duration_hrs_bottleneck[[0]])
    # df_output[' fuel_kg_bottleneck']   = list(df.fuel_kg_bottleneck[[0]])
    # df_output[' CO2_g_bottleneck'] = list(df.CO2_g_bottleneck[[0]])
    # df_output[' PM10_g_bottleneck']   = list(df.PM10_g_bottleneck[[0]])
    # df_output[' NOx_g_bottleneck']   = list(df.NOx_g_bottleneck[[0]])

# %% [markdown]
# ### Run "T_v_strategy_energy_simulation" for passing bottleneck section with selected strategies (T_strategy = 2.1 m, v_strategy = [3, 3.5] m/s)

# %%
df_collect = {}
sinkage_max = {}


for i, row in tqdm.tqdm(T_v_Strategies_df.iterrows()):
    # create a new vessel, like the one above (so that it also has L)   
    
    v_strategy = row['v_strategy']
    T_strategy = row['T_strategy']
    
    data_vessel_i = data_vessel.copy()
    vessel = TransportResource(**data_vessel_i)
    vessel=  run_simulation(v_strategy, T_strategy)
    # z = (vessel.C_B * ((vessel.B * vessel.T) / (150 * vessel.h_min)) ** 0.81) * (v_computed ** 2.08) / 20
  

    # sinkage_max = z

    #create an EnergyCalculation object and perform energy consumption calculation
    energycalculation = opentnsim.energy.EnergyCalculation(FG, vessel)
    energycalculation.calculate_energy_consumption()
    #P_tot = vessel.calculate_total_power_required(v_computed)
    
    # create dataframe from energy calculation computation
    
    df = pd.DataFrame.from_dict(energycalculation.energy_use)
    df.update(row)
    
    # add/modify some comlums to suit our plotting needs
    # df['P_tot'] = P_tot
    df['fuel_kg_bottleneck'] = df['total_fuel_consumption']/1000   # g --> kg
    df['CO2_kg_bottleneck']   = df['total_emission_CO2']/1000
    df['PM10_kg_bottleneck']  = df['total_emission_PM10']/1000
    df['NOx_kg_bottleneck']   = df['total_emission_NOX']/1000
    df['duration_hrs_bottleneck'] = df['delta_t'] /3600  # s--> hour
    # df['sinkage_max_m_bottleneck'] = sinkage_max
    # df['Payload_strategy_ton_bottleneck'] = Payload_strategy
    
    
    label = 'T_strategy = ' + str(T_strategy) + ' v_strategy = ' + str(round(v_strategy,2))
    
    df_collect[label + ' P_tot']   = list(df.P_tot[[0]])
    df_collect[label + ' P_installed'] = list(df.P_installed[[0]])
    df_collect[label + ' duration_hrs_bottleneck']   = list(df.duration_hrs_bottleneck[[0]])
    df_collect[label + ' fuel_kg_bottleneck']   = list(df.fuel_kg_bottleneck[[0]])
    df_collect[label + ' CO2_kg_bottleneck'] = list(df.CO2_kg_bottleneck[[0]])
    df_collect[label + ' PM10_kg_bottleneck']   = list(df.PM10_kg_bottleneck[[0]])
    df_collect[label + ' NOx_kg_bottleneck']   = list(df.NOx_kg_bottleneck[[0]])
    # df_collect[label + ' sinkage_max_m_bottleneck']   = list(df.sinkage_max_m_bottleneck[[0]])

    # df_output['T_strategy']   = list(Strategies_df.T_strategy[0:17])
    # df_output['v_computed']   = list(Strategies_df.v_computed[0:17])
    # df_output['P_tot']   = list(df.P_tot[[0]])
    # df_output[' P_installed'] = list(df.P_installed[[0]])
    # df_output[' duration_hrs_bottleneck']   = list(df.duration_hrs_bottleneck[[0]])
    # df_output[' fuel_kg_bottleneck']   = list(df.fuel_kg_bottleneck[[0]])
    # df_output[' CO2_g_bottleneck'] = list(df.CO2_g_bottleneck[[0]])
    # df_output[' PM10_g_bottleneck']   = list(df.PM10_g_bottleneck[[0]])
    # df_output[' NOx_g_bottleneck']   = list(df.NOx_g_bottleneck[[0]])
# Out:
# 0it [00:00, ?it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 8it [00:00, 70.33it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 16it [00:00, 70.80it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 24it [00:00, 65.96it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 31it [00:00, 66.73it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 39it [00:00, 68.87it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 47it [00:00, 70.63it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 55it [00:00, 71.17it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 63it [00:00, 71.62it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 71it [00:01, 71.49it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 79it [00:01, 71.37it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 87it [00:01, 71.60it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 95it [00:01, 71.81it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 103it [00:01, 72.44it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# ...
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 119it [00:01, 73.68it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 127it [00:01, 69.52it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 135it [00:01, 70.70it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 143it [00:02, 72.19it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 151it [00:02, 72.83it/s]Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# Exception ignored in: <function BaseGeometry.__del__ at 0x000001E6490D5C10>
# AttributeError: can't set attribute
# 153it [00:02, 71.12it/s]

# %%
df_collect
# Out:
# {'T_strategy = 2.2 v_strategy = 1.0 P_tot': [95.40518240584832],
#  'T_strategy = 2.2 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 2.2 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 2.2 v_strategy = 1.0 fuel_kg_bottleneck': [726.6702653993533],
#  'T_strategy = 2.2 v_strategy = 1.0 CO2_kg_bottleneck': [2305.526569312494],
#  'T_strategy = 2.2 v_strategy = 1.0 PM10_kg_bottleneck': [2.5089234318536646],
#  'T_strategy = 2.2 v_strategy = 1.0 NOx_kg_bottleneck': [47.796872768884924],
#  'T_strategy = 2.2 v_strategy = 1.5 P_tot': [112.66254854103443],
#  'T_strategy = 2.2 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 2.2 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 2.2 v_strategy = 1.5 fuel_kg_bottleneck': [568.4550175589939],
#  'T_strategy = 2.2 v_strategy = 1.5 CO2_kg_bottleneck': [1803.5527375280806],
#  'T_strategy = 2.2 v_strategy = 1.5 PM10_kg_bottleneck': [1.8418483544212523],
#  'T_strategy = 2.2 v_strategy = 1.5 NOx_kg_bottleneck': [35.592010165672924],
#  'T_strategy = 2.2 v_strategy = 2.0 P_tot': [145.07894564107548],
#  'T_strategy = 2.2 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 2.2 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 2.2 v_strategy = 2.0 fuel_kg_bottleneck': [542.443372747498],
#  'T_strategy = 2.2 v_strategy = 2.0 CO2_kg_bottleneck': [1721.0248826261525],
#  'T_strategy = 2.2 v_strategy = 2.0 PM10_kg_bottleneck': [1.5369913591837665],
#  'T_strategy = 2.2 v_strategy = 2.0 NOx_kg_bottleneck': [30.680319709094412],
#  'T_strategy = 2.2 v_strategy = 2.5 P_tot': [197.83079635468332],
#  'T_strategy = 2.2 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 2.2 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 2.2 v_strategy = 2.5 fuel_kg_bottleneck': [581.3442719711517],
#  'T_strategy = 2.2 v_strategy = 2.5 CO2_kg_bottleneck': [1844.4468265266541],
#  'T_strategy = 2.2 v_strategy = 2.5 PM10_kg_bottleneck': [1.3620319671343166],
#  'T_strategy = 2.2 v_strategy = 2.5 NOx_kg_bottleneck': [28.764096392095144],
#  'T_strategy = 2.2 v_strategy = 3.0 P_tot': [304.29464871917924],
#  'T_strategy = 2.2 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 2.2 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 2.2 v_strategy = 3.0 fuel_kg_bottleneck': [722.5395460532618],
#  'T_strategy = 2.2 v_strategy = 3.0 CO2_kg_bottleneck': [2292.420923387167],
#  'T_strategy = 2.2 v_strategy = 3.0 PM10_kg_bottleneck': [1.4176565774213215],
#  'T_strategy = 2.2 v_strategy = 3.0 NOx_kg_bottleneck': [32.34286941778114],
#  'T_strategy = 2.2 v_strategy = 3.5 P_tot': [645.695392539317],
#  'T_strategy = 2.2 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 2.2 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 2.2 v_strategy = 3.5 fuel_kg_bottleneck': [1220.2961062990814],
#  'T_strategy = 2.2 v_strategy = 3.5 CO2_kg_bottleneck': [3871.6667372579946],
#  'T_strategy = 2.2 v_strategy = 3.5 PM10_kg_bottleneck': [2.1367285225994275],
#  'T_strategy = 2.2 v_strategy = 3.5 NOx_kg_bottleneck': [53.11360486410822],
#  'T_strategy = 2.2 v_strategy = 4.0 P_tot': [2146.432190163064],
#  'T_strategy = 2.2 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 2.2 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 2.2 v_strategy = 4.0 fuel_kg_bottleneck': [3344.799919607704],
#  'T_strategy = 2.2 v_strategy = 4.0 CO2_kg_bottleneck': [10612.137926755351],
#  'T_strategy = 2.2 v_strategy = 4.0 PM10_kg_bottleneck': [5.783343889517777],
#  'T_strategy = 2.2 v_strategy = 4.0 NOx_kg_bottleneck': [146.02943321032384],
#  'T_strategy = 2.2 v_strategy = 4.5 P_tot': [4519.41473975914],
#  'T_strategy = 2.2 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 2.2 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 2.2 v_strategy = 4.5 fuel_kg_bottleneck': [6260.1198305101725],
#  'T_strategy = 2.2 v_strategy = 4.5 CO2_kg_bottleneck': [19861.652916800453],
#  'T_strategy = 2.2 v_strategy = 4.5 PM10_kg_bottleneck': [10.824093111577303],
#  'T_strategy = 2.2 v_strategy = 4.5 NOx_kg_bottleneck': [273.30835106732684],
#  'T_strategy = 2.2 v_strategy = 5.0 P_tot': [6437.651304937108],
#  'T_strategy = 2.2 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 2.2 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 2.2 v_strategy = 5.0 fuel_kg_bottleneck': [8025.468744234676],
#  'T_strategy = 2.2 v_strategy = 5.0 CO2_kg_bottleneck': [25462.623561253655],
#  'T_strategy = 2.2 v_strategy = 5.0 PM10_kg_bottleneck': [13.876478933881703],
#  'T_strategy = 2.2 v_strategy = 5.0 NOx_kg_bottleneck': [350.3810930805129],
#  'T_strategy = 2.15 v_strategy = 1.0 P_tot': [94.94545972088387],
#  'T_strategy = 2.15 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 2.15 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 2.15 v_strategy = 1.0 fuel_kg_bottleneck': [723.2906439490675],
#  'T_strategy = 2.15 v_strategy = 1.0 CO2_kg_bottleneck': [2294.803952165678],
#  'T_strategy = 2.15 v_strategy = 1.0 PM10_kg_bottleneck': [2.5013233393460865],
#  'T_strategy = 2.15 v_strategy = 1.0 NOx_kg_bottleneck': [47.635132722877835],
#  'T_strategy = 2.15 v_strategy = 1.5 P_tot': [111.25001122074632],
#  'T_strategy = 2.15 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 2.15 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 2.15 v_strategy = 1.5 fuel_kg_bottleneck': [561.6205250927874],
#  'T_strategy = 2.15 v_strategy = 1.5 CO2_kg_bottleneck': [1781.8687568852981],
#  'T_strategy = 2.15 v_strategy = 1.5 PM10_kg_bottleneck': [1.8295311397155127],
#  'T_strategy = 2.15 v_strategy = 1.5 NOx_kg_bottleneck': [35.31035748498728],
#  'T_strategy = 2.15 v_strategy = 2.0 P_tot': [141.94518241572464],
#  'T_strategy = 2.15 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 2.15 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 2.15 v_strategy = 2.0 fuel_kg_bottleneck': [531.3477079616575],
#  'T_strategy = 2.15 v_strategy = 2.0 CO2_kg_bottleneck': [1685.821364351077],
#  'T_strategy = 2.15 v_strategy = 2.0 PM10_kg_bottleneck': [1.5266679326219494],
#  'T_strategy = 2.15 v_strategy = 2.0 NOx_kg_bottleneck': [30.36703945162111],
#  'T_strategy = 2.15 v_strategy = 2.5 P_tot': [192.1006810988937],
#  'T_strategy = 2.15 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 2.15 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 2.15 v_strategy = 2.5 fuel_kg_bottleneck': [565.4283183303999],
#  'T_strategy = 2.15 v_strategy = 2.5 CO2_kg_bottleneck': [1793.9498463391778],
#  'T_strategy = 2.15 v_strategy = 2.5 PM10_kg_bottleneck': [1.3399133732813835],
#  'T_strategy = 2.15 v_strategy = 2.5 NOx_kg_bottleneck': [28.170948489536887],
#  'T_strategy = 2.15 v_strategy = 3.0 P_tot': [295.92315292202886],
#  'T_strategy = 2.15 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 2.15 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 2.15 v_strategy = 3.0 fuel_kg_bottleneck': [704.3918139605747],
#  'T_strategy = 2.15 v_strategy = 3.0 CO2_kg_bottleneck': [2234.8431188385507],
#  'T_strategy = 2.15 v_strategy = 3.0 PM10_kg_bottleneck': [1.3922867930267102],
#  'T_strategy = 2.15 v_strategy = 3.0 NOx_kg_bottleneck': [31.638416919189087],
#  'T_strategy = 2.15 v_strategy = 3.5 P_tot': [639.246157947504],
#  'T_strategy = 2.15 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 2.15 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 2.15 v_strategy = 3.5 fuel_kg_bottleneck': [1209.7530259777132],
#  'T_strategy = 2.15 v_strategy = 3.5 CO2_kg_bottleneck': [3838.2164187838357],
#  'T_strategy = 2.15 v_strategy = 3.5 PM10_kg_bottleneck': [2.1183782221420437],
#  'T_strategy = 2.15 v_strategy = 3.5 NOx_kg_bottleneck': [52.62087072270286],
#  'T_strategy = 2.15 v_strategy = 4.0 P_tot': [2144.4222059702456],
#  'T_strategy = 2.15 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 2.15 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 2.15 v_strategy = 4.0 fuel_kg_bottleneck': [3341.66774753287],
#  'T_strategy = 2.15 v_strategy = 4.0 CO2_kg_bottleneck': [10602.200398990652],
#  'T_strategy = 2.15 v_strategy = 4.0 PM10_kg_bottleneck': [5.7779281909213625],
#  'T_strategy = 2.15 v_strategy = 4.0 NOx_kg_bottleneck': [145.8926868207644],
#  'T_strategy = 2.15 v_strategy = 4.5 P_tot': [4496.477706203135],
#  'T_strategy = 2.15 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 2.15 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 2.15 v_strategy = 4.5 fuel_kg_bottleneck': [6228.348332011968],
#  'T_strategy = 2.15 v_strategy = 4.5 CO2_kg_bottleneck': [19760.850617019787],
#  'T_strategy = 2.15 v_strategy = 4.5 PM10_kg_bottleneck': [10.769158435029606],
#  'T_strategy = 2.15 v_strategy = 4.5 NOx_kg_bottleneck': [271.9212504844975],
#  'T_strategy = 2.15 v_strategy = 5.0 P_tot': [6386.752677993231],
#  'T_strategy = 2.15 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 2.15 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 2.15 v_strategy = 5.0 fuel_kg_bottleneck': [7962.016202257252],
#  'T_strategy = 2.15 v_strategy = 5.0 CO2_kg_bottleneck': [25261.305950798007],
#  'T_strategy = 2.15 v_strategy = 5.0 PM10_kg_bottleneck': [13.76676598251254],
#  'T_strategy = 2.15 v_strategy = 5.0 NOx_kg_bottleneck': [347.61084105844157],
#  'T_strategy = 2.1 v_strategy = 1.0 P_tot': [94.59206266873264],
#  'T_strategy = 2.1 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 2.1 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 2.1 v_strategy = 1.0 fuel_kg_bottleneck': [720.6918657270191],
#  'T_strategy = 2.1 v_strategy = 1.0 CO2_kg_bottleneck': [2286.5587376248154],
#  'T_strategy = 2.1 v_strategy = 1.0 PM10_kg_bottleneck': [2.4954514563527876],
#  'T_strategy = 2.1 v_strategy = 1.0 NOx_kg_bottleneck': [47.51034879849357],
#  'T_strategy = 2.1 v_strategy = 1.5 P_tot': [110.16154150331644],
#  'T_strategy = 2.1 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 2.1 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 2.1 v_strategy = 1.5 fuel_kg_bottleneck': [556.3489478483779],
#  'T_strategy = 2.1 v_strategy = 1.5 CO2_kg_bottleneck': [1765.1434799916717],
#  'T_strategy = 2.1 v_strategy = 1.5 PM10_kg_bottleneck': [1.8198531023075442],
#  'T_strategy = 2.1 v_strategy = 1.5 NOx_kg_bottleneck': [35.09047094078701],
#  'T_strategy = 2.1 v_strategy = 2.0 P_tot': [139.5297485744755],
#  'T_strategy = 2.1 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 2.1 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 2.1 v_strategy = 2.0 fuel_kg_bottleneck': [522.7766980765734],
#  'T_strategy = 2.1 v_strategy = 2.0 CO2_kg_bottleneck': [1658.6278875338558],
#  'T_strategy = 2.1 v_strategy = 2.0 PM10_kg_bottleneck': [1.518021546475741],
#  'T_strategy = 2.1 v_strategy = 2.0 NOx_kg_bottleneck': [30.115040925979],
#  'T_strategy = 2.1 v_strategy = 2.5 P_tot': [187.72066762466946],
#  'T_strategy = 2.1 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 2.1 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 2.1 v_strategy = 2.5 fuel_kg_bottleneck': [553.2252916621953],
#  'T_strategy = 2.1 v_strategy = 2.5 CO2_kg_bottleneck': [1755.232970819147],
#  'T_strategy = 2.1 v_strategy = 2.5 PM10_kg_bottleneck': [1.3223089927386185],
#  'T_strategy = 2.1 v_strategy = 2.5 NOx_kg_bottleneck': [27.707900373435635],
#  'T_strategy = 2.1 v_strategy = 3.0 P_tot': [289.9738557122977],
#  'T_strategy = 2.1 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 2.1 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 2.1 v_strategy = 3.0 fuel_kg_bottleneck': [691.4354221700845],
#  'T_strategy = 2.1 v_strategy = 3.0 CO2_kg_bottleneck': [2193.7360212487224],
#  'T_strategy = 2.1 v_strategy = 3.0 PM10_kg_bottleneck': [1.3737886617110722],
#  'T_strategy = 2.1 v_strategy = 3.0 NOx_kg_bottleneck': [31.131415851439268],
#  'T_strategy = 2.1 v_strategy = 3.5 P_tot': [637.2452000509468],
#  'T_strategy = 2.1 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 2.1 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 2.1 v_strategy = 3.5 fuel_kg_bottleneck': [1206.4751519024069],
#  'T_strategy = 2.1 v_strategy = 3.5 CO2_kg_bottleneck': [3827.8166183085455],
#  'T_strategy = 2.1 v_strategy = 3.5 PM10_kg_bottleneck': [2.1126725366645185],
#  'T_strategy = 2.1 v_strategy = 3.5 NOx_kg_bottleneck': [52.46783872842009],
#  'T_strategy = 2.1 v_strategy = 4.0 P_tot': [2150.2391882673764],
#  'T_strategy = 2.1 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 2.1 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 2.1 v_strategy = 4.0 fuel_kg_bottleneck': [3350.7323907156233],
#  'T_strategy = 2.1 v_strategy = 4.0 CO2_kg_bottleneck': [10630.960039634114],
#  'T_strategy = 2.1 v_strategy = 4.0 PM10_kg_bottleneck': [5.793601459882629],
#  'T_strategy = 2.1 v_strategy = 4.0 NOx_kg_bottleneck': [146.28843686203635],
#  'T_strategy = 2.1 v_strategy = 4.5 P_tot': [4484.354752996697],
#  'T_strategy = 2.1 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 2.1 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 2.1 v_strategy = 4.5 fuel_kg_bottleneck': [6211.556082541186],
#  'T_strategy = 2.1 v_strategy = 4.5 CO2_kg_bottleneck': [19707.5733891534],
#  'T_strategy = 2.1 v_strategy = 4.5 PM10_kg_bottleneck': [10.740123707780658],
#  'T_strategy = 2.1 v_strategy = 4.5 NOx_kg_bottleneck': [271.18812362146156],
#  'T_strategy = 2.1 v_strategy = 5.0 P_tot': [6349.57957964419],
#  'T_strategy = 2.1 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 2.1 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 2.1 v_strategy = 5.0 fuel_kg_bottleneck': [7915.674528128708],
#  'T_strategy = 2.1 v_strategy = 5.0 CO2_kg_bottleneck': [25114.27645742654],
#  'T_strategy = 2.1 v_strategy = 5.0 PM10_kg_bottleneck': [13.686638667174416],
#  'T_strategy = 2.1 v_strategy = 5.0 NOx_kg_bottleneck': [345.5876263461539],
#  'T_strategy = 2.05 v_strategy = 1.0 P_tot': [94.3086880582662],
#  'T_strategy = 2.05 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 2.05 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 2.05 v_strategy = 1.0 fuel_kg_bottleneck': [718.6075079024824],
#  'T_strategy = 2.05 v_strategy = 1.0 CO2_kg_bottleneck': [2279.9456387087853],
#  'T_strategy = 2.05 v_strategy = 1.0 PM10_kg_bottleneck': [2.4907244743341055],
#  'T_strategy = 2.05 v_strategy = 1.0 NOx_kg_bottleneck': [47.41000619019242],
#  'T_strategy = 2.05 v_strategy = 1.5 P_tot': [109.28652289398859],
#  'T_strategy = 2.05 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 2.05 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 2.05 v_strategy = 1.5 fuel_kg_bottleneck': [552.1079377671892],
#  'T_strategy = 2.05 v_strategy = 1.5 CO2_kg_bottleneck': [1751.6879116431733],
#  'T_strategy = 2.05 v_strategy = 1.5 PM10_kg_bottleneck': [1.811955137764721],
#  'T_strategy = 2.05 v_strategy = 1.5 NOx_kg_bottleneck': [34.91190508328756],
#  'T_strategy = 2.05 v_strategy = 2.0 P_tot': [137.58890918750393],
#  'T_strategy = 2.05 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 2.05 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 2.05 v_strategy = 2.0 fuel_kg_bottleneck': [515.877946029048],
#  'T_strategy = 2.05 v_strategy = 2.0 CO2_kg_bottleneck': [1636.7400287648884],
#  'T_strategy = 2.05 v_strategy = 2.0 PM10_kg_bottleneck': [1.5106392258642378],
#  'T_strategy = 2.05 v_strategy = 2.0 NOx_kg_bottleneck': [29.905914492260035],
#  'T_strategy = 2.05 v_strategy = 2.5 P_tot': [184.2442063952672],
#  'T_strategy = 2.05 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 2.05 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 2.05 v_strategy = 2.5 fuel_kg_bottleneck': [543.5167350389974],
#  'T_strategy = 2.05 v_strategy = 2.5 CO2_kg_bottleneck': [1724.4303684419096],
#  'T_strategy = 2.05 v_strategy = 2.5 PM10_kg_bottleneck': [1.307906157112983],
#  'T_strategy = 2.05 v_strategy = 2.5 NOx_kg_bottleneck': [27.33441943469896],
#  'T_strategy = 2.05 v_strategy = 3.0 P_tot': [285.74236896006045],
#  'T_strategy = 2.05 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 2.05 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 2.05 v_strategy = 3.0 fuel_kg_bottleneck': [682.1899945491939],
#  'T_strategy = 2.05 v_strategy = 3.0 CO2_kg_bottleneck': [2164.402800887897],
#  'T_strategy = 2.05 v_strategy = 3.0 PM10_kg_bottleneck': [1.3603946639864735],
#  'T_strategy = 2.05 v_strategy = 3.0 NOx_kg_bottleneck': [30.76758420032985],
#  'T_strategy = 2.05 v_strategy = 3.5 P_tot': [638.7145313682945],
#  'T_strategy = 2.05 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 2.05 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 2.05 v_strategy = 3.5 fuel_kg_bottleneck': [1208.8824523363162],
#  'T_strategy = 2.05 v_strategy = 3.5 CO2_kg_bottleneck': [3835.4543260488576],
#  'T_strategy = 2.05 v_strategy = 3.5 PM10_kg_bottleneck': [2.1168628679643122],
#  'T_strategy = 2.05 v_strategy = 3.5 NOx_kg_bottleneck': [52.58021941404891],
#  'T_strategy = 2.05 v_strategy = 4.0 P_tot': [2162.5450431189497],
#  'T_strategy = 2.05 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 2.05 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 2.05 v_strategy = 4.0 fuel_kg_bottleneck': [3369.9086882510787],
#  'T_strategy = 2.05 v_strategy = 4.0 CO2_kg_bottleneck': [10691.801201814787],
#  'T_strategy = 2.05 v_strategy = 4.0 PM10_kg_bottleneck': [5.826758337974236],
#  'T_strategy = 2.05 v_strategy = 4.0 NOx_kg_bottleneck': [147.12564803384942],
#  'T_strategy = 2.05 v_strategy = 4.5 P_tot': [4481.114314034606],
#  'T_strategy = 2.05 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 2.05 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 2.05 v_strategy = 4.5 fuel_kg_bottleneck': [6207.067550867451],
#  'T_strategy = 2.05 v_strategy = 4.5 CO2_kg_bottleneck': [19693.33250229764],
#  'T_strategy = 2.05 v_strategy = 4.5 PM10_kg_bottleneck': [10.732362788487393],
#  'T_strategy = 2.05 v_strategy = 4.5 NOx_kg_bottleneck': [270.9921604093066],
#  'T_strategy = 2.05 v_strategy = 5.0 P_tot': [6323.422116360288],
#  'T_strategy = 2.05 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 2.05 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 2.05 v_strategy = 5.0 fuel_kg_bottleneck': [7883.065445395006],
#  'T_strategy = 2.05 v_strategy = 5.0 CO2_kg_bottleneck': [25010.8167312987],
#  'T_strategy = 2.05 v_strategy = 5.0 PM10_kg_bottleneck': [13.630255761199923],
#  'T_strategy = 2.05 v_strategy = 5.0 NOx_kg_bottleneck': [344.16395797029793],
#  'T_strategy = 2.0 v_strategy = 1.0 P_tot': [94.0737860542605],
#  'T_strategy = 2.0 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 2.0 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 2.0 v_strategy = 1.0 fuel_kg_bottleneck': [716.8793495245142],
#  'T_strategy = 2.0 v_strategy = 1.0 CO2_kg_bottleneck': [2274.462663491413],
#  'T_strategy = 2.0 v_strategy = 1.0 PM10_kg_bottleneck': [2.4867935435494504],
#  'T_strategy = 2.0 v_strategy = 1.0 NOx_kg_bottleneck': [47.32663640302886],
#  'T_strategy = 2.0 v_strategy = 1.5 P_tot': [108.55930924554748],
#  'T_strategy = 2.0 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 2.0 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 2.0 v_strategy = 1.5 fuel_kg_bottleneck': [548.5811336774558],
#  'T_strategy = 2.0 v_strategy = 1.5 CO2_kg_bottleneck': [1740.4983241221098],
#  'T_strategy = 2.0 v_strategy = 1.5 PM10_kg_bottleneck': [1.8053113729855879],
#  'T_strategy = 2.0 v_strategy = 1.5 NOx_kg_bottleneck': [34.76228153909922],
#  'T_strategy = 2.0 v_strategy = 2.0 P_tot': [135.97854748886581],
#  'T_strategy = 2.0 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 2.0 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 2.0 v_strategy = 2.0 fuel_kg_bottleneck': [510.14589555628646],
#  'T_strategy = 2.0 v_strategy = 2.0 CO2_kg_bottleneck': [1618.5537959013088],
#  'T_strategy = 2.0 v_strategy = 2.0 PM10_kg_bottleneck': [1.5042198341899207],
#  'T_strategy = 2.0 v_strategy = 2.0 NOx_kg_bottleneck': [29.727904903564866],
#  'T_strategy = 2.0 v_strategy = 2.5 P_tot': [181.41062923555106],
#  'T_strategy = 2.0 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 2.0 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 2.0 v_strategy = 2.5 fuel_kg_bottleneck': [535.5885469166503],
#  'T_strategy = 2.0 v_strategy = 2.5 CO2_kg_bottleneck': [1699.276389762827],
#  'T_strategy = 2.0 v_strategy = 2.5 PM10_kg_bottleneck': [1.2958852297451064],
#  'T_strategy = 2.0 v_strategy = 2.5 NOx_kg_bottleneck': [27.026106065280956],
#  'T_strategy = 2.0 v_strategy = 3.0 P_tot': [282.84018789893423],
#  'T_strategy = 2.0 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 2.0 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 2.0 v_strategy = 3.0 fuel_kg_bottleneck': [675.8345242075422],
#  'T_strategy = 2.0 v_strategy = 3.0 CO2_kg_bottleneck': [2144.2386268039295],
#  'T_strategy = 2.0 v_strategy = 3.0 PM10_kg_bottleneck': [1.3510944199988182],
#  'T_strategy = 2.0 v_strategy = 3.0 NOx_kg_bottleneck': [30.516500018308033],
#  'T_strategy = 2.0 v_strategy = 3.5 P_tot': [643.177639195129],
#  'T_strategy = 2.0 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 2.0 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 2.0 v_strategy = 3.5 fuel_kg_bottleneck': [1216.1840836092208],
#  'T_strategy = 2.0 v_strategy = 3.5 CO2_kg_bottleneck': [3858.6204107238004],
#  'T_strategy = 2.0 v_strategy = 3.5 PM10_kg_bottleneck': [2.1295718269794497],
#  'T_strategy = 2.0 v_strategy = 3.5 NOx_kg_bottleneck': [52.9213342609626],
#  'T_strategy = 2.0 v_strategy = 4.0 P_tot': [2180.751897736027],
#  'T_strategy = 2.0 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 2.0 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 2.0 v_strategy = 4.0 fuel_kg_bottleneck': [3398.280553963213],
#  'T_strategy = 2.0 v_strategy = 4.0 CO2_kg_bottleneck': [10781.817393937832],
#  'T_strategy = 2.0 v_strategy = 4.0 PM10_kg_bottleneck': [5.875814861576322],
#  'T_strategy = 2.0 v_strategy = 4.0 NOx_kg_bottleneck': [148.36432525480214],
#  'T_strategy = 2.0 v_strategy = 4.5 P_tot': [4485.84478847755],
#  'T_strategy = 2.0 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 2.0 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 2.0 v_strategy = 4.5 fuel_kg_bottleneck': [6213.6200224977865],
#  'T_strategy = 2.0 v_strategy = 4.5 CO2_kg_bottleneck': [19714.12170774298],
#  'T_strategy = 2.0 v_strategy = 4.5 PM10_kg_bottleneck': [10.743692374015781],
#  'T_strategy = 2.0 v_strategy = 4.5 NOx_kg_bottleneck': [271.27823244389845],
#  'T_strategy = 2.0 v_strategy = 5.0 P_tot': [6306.914734182719],
#  'T_strategy = 2.0 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 2.0 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 2.0 v_strategy = 5.0 fuel_kg_bottleneck': [7862.486592418982],
#  'T_strategy = 2.0 v_strategy = 5.0 CO2_kg_bottleneck': [24945.525643220222],
#  'T_strategy = 2.0 v_strategy = 5.0 PM10_kg_bottleneck': [13.594673787248507],
#  'T_strategy = 2.0 v_strategy = 5.0 NOx_kg_bottleneck': [343.26551312802474],
#  'T_strategy = 1.95 v_strategy = 1.0 P_tot': [93.87377061664453],
#  'T_strategy = 1.95 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 1.95 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 1.95 v_strategy = 1.0 fuel_kg_bottleneck': [715.4076062727936],
#  'T_strategy = 1.95 v_strategy = 1.0 CO2_kg_bottleneck': [2269.7932235382264],
#  'T_strategy = 1.95 v_strategy = 1.0 PM10_kg_bottleneck': [2.4834374691330314],
#  'T_strategy = 1.95 v_strategy = 1.0 NOx_kg_bottleneck': [47.25551164466842],
#  'T_strategy = 1.95 v_strategy = 1.5 P_tot': [107.93853829103085],
#  'T_strategy = 1.95 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 1.95 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 1.95 v_strategy = 1.5 fuel_kg_bottleneck': [545.568991559473],
#  'T_strategy = 1.95 v_strategy = 1.5 CO2_kg_bottleneck': [1730.9416186750555],
#  'T_strategy = 1.95 v_strategy = 1.5 PM10_kg_bottleneck': [1.7995826811176479],
#  'T_strategy = 1.95 v_strategy = 1.5 NOx_kg_bottleneck': [34.633682037192855],
#  'T_strategy = 1.95 v_strategy = 2.0 P_tot': [134.60856260544037],
#  'T_strategy = 1.95 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 1.95 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 1.95 v_strategy = 2.0 fuel_kg_bottleneck': [505.26375839900106],
#  'T_strategy = 1.95 v_strategy = 2.0 CO2_kg_bottleneck': [1603.0641061931944],
#  'T_strategy = 1.95 v_strategy = 2.0 PM10_kg_bottleneck': [1.498548676819156],
#  'T_strategy = 1.95 v_strategy = 2.0 NOx_kg_bottleneck': [29.573259206708368],
#  'T_strategy = 1.95 v_strategy = 2.5 P_tot': [179.06119474435295],
#  'T_strategy = 1.95 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 1.95 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 1.95 v_strategy = 2.5 fuel_kg_bottleneck': [529.0047570769727],
#  'T_strategy = 1.95 v_strategy = 2.5 CO2_kg_bottleneck': [1678.3878201805771],
#  'T_strategy = 1.95 v_strategy = 2.5 PM10_kg_bottleneck': [1.285726449693432],
#  'T_strategy = 1.95 v_strategy = 2.5 NOx_kg_bottleneck': [26.76781590588051],
#  'T_strategy = 1.95 v_strategy = 3.0 P_tot': [281.05796117343664],
#  'T_strategy = 1.95 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 1.95 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 1.95 v_strategy = 3.0 fuel_kg_bottleneck': [671.925804982269],
#  'T_strategy = 1.95 v_strategy = 3.0 CO2_kg_bottleneck': [2131.837326716472],
#  'T_strategy = 1.95 v_strategy = 3.0 PM10_kg_bottleneck': [1.34533720967648],
#  'T_strategy = 1.95 v_strategy = 3.0 NOx_kg_bottleneck': [30.361684858540464],
#  'T_strategy = 1.95 v_strategy = 3.5 P_tot': [650.4534698609265],
#  'T_strategy = 1.95 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 1.95 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 1.95 v_strategy = 3.5 fuel_kg_bottleneck': [1228.0532350091573],
#  'T_strategy = 1.95 v_strategy = 3.5 CO2_kg_bottleneck': [3896.2779910745085],
#  'T_strategy = 1.95 v_strategy = 3.5 PM10_kg_bottleneck': [2.1502282029665705],
#  'T_strategy = 1.95 v_strategy = 3.5 NOx_kg_bottleneck': [53.476642776903276],
#  'T_strategy = 1.95 v_strategy = 4.0 P_tot': [2204.717786170817],
#  'T_strategy = 1.95 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 1.95 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 1.95 v_strategy = 4.0 fuel_kg_bottleneck': [3435.6267613474415],
#  'T_strategy = 1.95 v_strategy = 4.0 CO2_kg_bottleneck': [10900.3067246387],
#  'T_strategy = 1.95 v_strategy = 4.0 PM10_kg_bottleneck': [5.940388517837822],
#  'T_strategy = 1.95 v_strategy = 4.0 NOx_kg_bottleneck': [149.99481007540498],
#  'T_strategy = 1.95 v_strategy = 4.5 P_tot': [4498.2271327848],
#  'T_strategy = 1.95 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 1.95 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 1.95 v_strategy = 4.5 fuel_kg_bottleneck': [6230.771570565304],
#  'T_strategy = 1.95 v_strategy = 4.5 CO2_kg_bottleneck': [19768.538892066284],
#  'T_strategy = 1.95 v_strategy = 4.5 PM10_kg_bottleneck': [10.773348348392773],
#  'T_strategy = 1.95 v_strategy = 4.5 NOx_kg_bottleneck': [272.02704579691743],
#  'T_strategy = 1.95 v_strategy = 5.0 P_tot': [6299.458793583273],
#  'T_strategy = 1.95 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 1.95 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 1.95 v_strategy = 5.0 fuel_kg_bottleneck': [7853.1916779532285],
#  'T_strategy = 1.95 v_strategy = 5.0 CO2_kg_bottleneck': [24916.03541459706],
#  'T_strategy = 1.95 v_strategy = 5.0 PM10_kg_bottleneck': [13.578602366514495],
#  'T_strategy = 1.95 v_strategy = 5.0 NOx_kg_bottleneck': [342.85970975449095],
#  'T_strategy = 1.9 v_strategy = 1.0 P_tot': [93.6996583622082],
#  'T_strategy = 1.9 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 1.9 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 1.9 v_strategy = 1.0 fuel_kg_bottleneck': [714.1262805083603],
#  'T_strategy = 1.9 v_strategy = 1.0 CO2_kg_bottleneck': [2265.7279263401615],
#  'T_strategy = 1.9 v_strategy = 1.0 PM10_kg_bottleneck': [2.4805093261976094],
#  'T_strategy = 1.9 v_strategy = 1.0 NOx_kg_bottleneck': [47.19349562276898],
#  'T_strategy = 1.9 v_strategy = 1.5 P_tot': [107.3968965468803],
#  'T_strategy = 1.9 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 1.9 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 1.9 v_strategy = 1.5 fuel_kg_bottleneck': [542.9396323603276],
#  'T_strategy = 1.9 v_strategy = 1.5 CO2_kg_bottleneck': [1722.59937903413],
#  'T_strategy = 1.9 v_strategy = 1.5 PM10_kg_bottleneck': [1.794541048719769],
#  'T_strategy = 1.9 v_strategy = 1.5 NOx_kg_bottleneck': [34.52081556957827],
#  'T_strategy = 1.9 v_strategy = 2.0 P_tot': [133.42041387182337],
#  'T_strategy = 1.9 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 1.9 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 1.9 v_strategy = 2.0 fuel_kg_bottleneck': [501.0253748804612],
#  'T_strategy = 1.9 v_strategy = 2.0 CO2_kg_bottleneck': [1589.616871211645],
#  'T_strategy = 1.9 v_strategy = 2.0 PM10_kg_bottleneck': [1.4934739325567805],
#  'T_strategy = 1.9 v_strategy = 2.0 NOx_kg_bottleneck': [29.43675180289913],
#  'T_strategy = 1.9 v_strategy = 2.5 P_tot': [177.09819331521203],
#  'T_strategy = 1.9 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 1.9 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 1.9 v_strategy = 2.5 fuel_kg_bottleneck': [523.4967689792848],
#  'T_strategy = 1.9 v_strategy = 2.5 CO2_kg_bottleneck': [1660.9124761251853],
#  'T_strategy = 1.9 v_strategy = 2.5 PM10_kg_bottleneck': [1.2771052845734252],
#  'T_strategy = 1.9 v_strategy = 2.5 NOx_kg_bottleneck': [26.55016342384934],
#  'T_strategy = 1.9 v_strategy = 3.0 P_tot': [280.3007800765604],
#  'T_strategy = 1.9 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 1.9 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 1.9 v_strategy = 3.0 fuel_kg_bottleneck': [670.2638381947468],
#  'T_strategy = 1.9 v_strategy = 3.0 CO2_kg_bottleneck': [2126.5643593633326],
#  'T_strategy = 1.9 v_strategy = 3.0 PM10_kg_bottleneck': [1.3428806719154496],
#  'T_strategy = 1.9 v_strategy = 3.0 NOx_kg_bottleneck': [30.295767607028946],
#  'T_strategy = 1.9 v_strategy = 3.5 P_tot': [660.5615167045269],
#  'T_strategy = 1.9 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 1.9 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 1.9 v_strategy = 3.5 fuel_kg_bottleneck': [1244.4724889945385],
#  'T_strategy = 1.9 v_strategy = 3.5 CO2_kg_bottleneck': [3948.3718059917633],
#  'T_strategy = 1.9 v_strategy = 3.5 PM10_kg_bottleneck': [2.1787978523657414],
#  'T_strategy = 1.9 v_strategy = 3.5 NOx_kg_bottleneck': [54.24650297945142],
#  'T_strategy = 1.9 v_strategy = 4.0 P_tot': [2234.6058972342757],
#  'T_strategy = 1.9 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 1.9 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 1.9 v_strategy = 4.0 fuel_kg_bottleneck': [3482.201608640748],
#  'T_strategy = 1.9 v_strategy = 4.0 CO2_kg_bottleneck': [11048.076012869282],
#  'T_strategy = 1.9 v_strategy = 4.0 PM10_kg_bottleneck': [6.0209190024626125],
#  'T_strategy = 1.9 v_strategy = 4.0 NOx_kg_bottleneck': [152.02820481218095],
#  'T_strategy = 1.9 v_strategy = 4.5 P_tot': [4518.33250488183],
#  'T_strategy = 1.9 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 1.9 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 1.9 v_strategy = 4.5 fuel_kg_bottleneck': [6258.620760297139],
#  'T_strategy = 1.9 v_strategy = 4.5 CO2_kg_bottleneck': [19856.89677585183],
#  'T_strategy = 1.9 v_strategy = 4.5 PM10_kg_bottleneck': [10.821501136342645],
#  'T_strategy = 1.9 v_strategy = 4.5 NOx_kg_bottleneck': [273.2429036926518],
#  'T_strategy = 1.9 v_strategy = 5.0 P_tot': [6300.945380408758],
#  'T_strategy = 1.9 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 1.9 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 1.9 v_strategy = 5.0 fuel_kg_bottleneck': [7855.04492466362],
#  'T_strategy = 1.9 v_strategy = 5.0 CO2_kg_bottleneck': [24921.915260978214],
#  'T_strategy = 1.9 v_strategy = 5.0 PM10_kg_bottleneck': [13.581806732484335],
#  'T_strategy = 1.9 v_strategy = 5.0 NOx_kg_bottleneck': [342.9406199952293],
#  'T_strategy = 1.85 v_strategy = 1.0 P_tot': [93.54527463400773],
#  'T_strategy = 1.85 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 1.85 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 1.85 v_strategy = 1.0 fuel_kg_bottleneck': [712.9899991091996],
#  'T_strategy = 1.85 v_strategy = 1.0 CO2_kg_bottleneck': [2262.122815355551],
#  'T_strategy = 1.85 v_strategy = 1.0 PM10_kg_bottleneck': [2.4779077526430973],
#  'T_strategy = 1.85 v_strategy = 1.0 NOx_kg_bottleneck': [47.138426912170644],
#  'T_strategy = 1.85 v_strategy = 1.5 P_tot': [106.91566570868373],
#  'T_strategy = 1.85 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 1.85 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 1.85 v_strategy = 1.5 fuel_kg_bottleneck': [540.602616625757],
#  'T_strategy = 1.85 v_strategy = 1.5 CO2_kg_bottleneck': [1715.1846654762658],
#  'T_strategy = 1.85 v_strategy = 1.5 PM10_kg_bottleneck': [1.79002797161994],
#  'T_strategy = 1.85 v_strategy = 1.5 NOx_kg_bottleneck': [34.42002186818925],
#  'T_strategy = 1.85 v_strategy = 2.0 P_tot': [132.37531314381295],
#  'T_strategy = 1.85 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 1.85 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 1.85 v_strategy = 2.0 fuel_kg_bottleneck': [497.29401444390396],
#  'T_strategy = 1.85 v_strategy = 2.0 CO2_kg_bottleneck': [1577.7782821902047],
#  'T_strategy = 1.85 v_strategy = 2.0 PM10_kg_bottleneck': [1.4888901349791832],
#  'T_strategy = 1.85 v_strategy = 2.0 NOx_kg_bottleneck': [29.31484587193816],
#  'T_strategy = 1.85 v_strategy = 2.5 P_tot': [175.46405704775918],
#  'T_strategy = 1.85 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 1.85 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 1.85 v_strategy = 2.5 fuel_kg_bottleneck': [518.9066176201414],
#  'T_strategy = 1.85 v_strategy = 2.5 CO2_kg_bottleneck': [1646.349177722085],
#  'T_strategy = 1.85 v_strategy = 2.5 PM10_kg_bottleneck': [1.2698358818027102],
#  'T_strategy = 1.85 v_strategy = 2.5 NOx_kg_bottleneck': [26.36769303850633],
#  'T_strategy = 1.85 v_strategy = 3.0 P_tot': [280.55758181615215],
#  'T_strategy = 1.85 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 1.85 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 1.85 v_strategy = 3.0 fuel_kg_bottleneck': [670.8275922502542],
#  'T_strategy = 1.85 v_strategy = 3.0 CO2_kg_bottleneck': [2128.3529972303513],
#  'T_strategy = 1.85 v_strategy = 3.0 PM10_kg_bottleneck': [1.3437145259985952],
#  'T_strategy = 1.85 v_strategy = 3.0 NOx_kg_bottleneck': [30.318133384543856],
#  'T_strategy = 1.85 v_strategy = 3.5 P_tot': [673.6800731023279],
#  'T_strategy = 1.85 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 1.85 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 1.85 v_strategy = 3.5 fuel_kg_bottleneck': [1265.6603367037474],
#  'T_strategy = 1.85 v_strategy = 3.5 CO2_kg_bottleneck': [4015.5950682691614],
#  'T_strategy = 1.85 v_strategy = 3.5 PM10_kg_bottleneck': [2.2156553917486663],
#  'T_strategy = 1.85 v_strategy = 3.5 NOx_kg_bottleneck': [55.24286162420444],
#  'T_strategy = 1.85 v_strategy = 4.0 P_tot': [2270.821434264579],
#  'T_strategy = 1.85 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 1.85 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 1.85 v_strategy = 4.0 fuel_kg_bottleneck': [3538.6365269683124],
#  'T_strategy = 1.85 v_strategy = 4.0 CO2_kg_bottleneck': [11227.128617381282],
#  'T_strategy = 1.85 v_strategy = 4.0 PM10_kg_bottleneck': [6.118498094758046],
#  'T_strategy = 1.85 v_strategy = 4.0 NOx_kg_bottleneck': [154.49207689264063],
#  'T_strategy = 1.85 v_strategy = 4.5 P_tot': [4546.525209915814],
#  'T_strategy = 1.85 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 1.85 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 1.85 v_strategy = 4.5 fuel_kg_bottleneck': [6297.67221320017],
#  'T_strategy = 1.85 v_strategy = 4.5 CO2_kg_bottleneck': [19980.7963855169],
#  'T_strategy = 1.85 v_strategy = 4.5 PM10_kg_bottleneck': [10.88902325633541],
#  'T_strategy = 1.85 v_strategy = 4.5 NOx_kg_bottleneck': [274.94783722246905],
#  'T_strategy = 1.85 v_strategy = 5.0 P_tot': [6311.617541550417],
#  'T_strategy = 1.85 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 1.85 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 1.85 v_strategy = 5.0 fuel_kg_bottleneck': [7868.349325852628],
#  'T_strategy = 1.85 v_strategy = 5.0 CO2_kg_bottleneck': [24964.126497477882],
#  'T_strategy = 1.85 v_strategy = 5.0 PM10_kg_bottleneck': [13.604810777320942],
#  'T_strategy = 1.85 v_strategy = 5.0 NOx_kg_bottleneck': [343.5214721273538],
#  'T_strategy = 1.8 v_strategy = 1.0 P_tot': [93.40623651192968],
#  'T_strategy = 1.8 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 1.8 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 1.8 v_strategy = 1.0 fuel_kg_bottleneck': [711.9665491066114],
#  'T_strategy = 1.8 v_strategy = 1.0 CO2_kg_bottleneck': [2258.875687620067],
#  'T_strategy = 1.8 v_strategy = 1.0 PM10_kg_bottleneck': [2.475560577027098],
#  'T_strategy = 1.8 v_strategy = 1.0 NOx_kg_bottleneck': [47.088767887478795],
#  'T_strategy = 1.8 v_strategy = 1.5 P_tot': [106.48164622119903],
#  'T_strategy = 1.8 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 1.8 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 1.8 v_strategy = 1.5 fuel_kg_bottleneck': [538.4941349737627],
#  'T_strategy = 1.8 v_strategy = 1.5 CO2_kg_bottleneck': [1708.495028234938],
#  'T_strategy = 1.8 v_strategy = 1.5 PM10_kg_bottleneck': [1.7859304132090745],
#  'T_strategy = 1.8 v_strategy = 1.5 NOx_kg_bottleneck': [34.32870051327504],
#  'T_strategy = 1.8 v_strategy = 2.0 P_tot': [131.44780104312744],
#  'T_strategy = 1.8 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 1.8 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 1.8 v_strategy = 2.0 fuel_kg_bottleneck': [493.9799292617204],
#  'T_strategy = 1.8 v_strategy = 2.0 CO2_kg_bottleneck': [1567.263593748549],
#  'T_strategy = 1.8 v_strategy = 2.0 PM10_kg_bottleneck': [1.4847279862630145],
#  'T_strategy = 1.8 v_strategy = 2.0 NOx_kg_bottleneck': [29.205218838541057],
#  'T_strategy = 1.8 v_strategy = 2.5 P_tot': [174.13086228737697],
#  'T_strategy = 1.8 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 1.8 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 1.8 v_strategy = 2.5 fuel_kg_bottleneck': [515.2007495994641],
#  'T_strategy = 1.8 v_strategy = 2.5 CO2_kg_bottleneck': [1634.5914691837545],
#  'T_strategy = 1.8 v_strategy = 2.5 PM10_kg_bottleneck': [1.2676865010671068],
#  'T_strategy = 1.8 v_strategy = 2.5 NOx_kg_bottleneck': [26.280076078281187],
#  'T_strategy = 1.8 v_strategy = 3.0 P_tot': [281.88912134500936],
#  'T_strategy = 1.8 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 1.8 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 1.8 v_strategy = 3.0 fuel_kg_bottleneck': [673.7492293667325],
#  'T_strategy = 1.8 v_strategy = 3.0 CO2_kg_bottleneck': [2137.6225549908154],
#  'T_strategy = 1.8 v_strategy = 3.0 PM10_kg_bottleneck': [1.3480264949457348],
#  'T_strategy = 1.8 v_strategy = 3.0 NOx_kg_bottleneck': [30.433943675262732],
#  'T_strategy = 1.8 v_strategy = 3.5 P_tot': [690.1339753443723],
#  'T_strategy = 1.8 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 1.8 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 1.8 v_strategy = 3.5 fuel_kg_bottleneck': [1292.0409303005738],
#  'T_strategy = 1.8 v_strategy = 3.5 CO2_kg_bottleneck': [4099.293497044548],
#  'T_strategy = 1.8 v_strategy = 3.5 PM10_kg_bottleneck': [2.261530758516808],
#  'T_strategy = 1.8 v_strategy = 3.5 NOx_kg_bottleneck': [56.48808337171094],
#  'T_strategy = 1.8 v_strategy = 4.0 P_tot': [2313.9905466949895],
#  'T_strategy = 1.8 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 1.8 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 1.8 v_strategy = 4.0 fuel_kg_bottleneck': [3605.9072492620385],
#  'T_strategy = 1.8 v_strategy = 4.0 CO2_kg_bottleneck': [11440.56027265865],
#  'T_strategy = 1.8 v_strategy = 4.0 PM10_kg_bottleneck': [6.234812890880887],
#  'T_strategy = 1.8 v_strategy = 4.0 NOx_kg_bottleneck': [157.42902549474235],
#  'T_strategy = 1.8 v_strategy = 4.5 P_tot': [4583.420848666481],
#  'T_strategy = 1.8 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 1.8 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 1.8 v_strategy = 4.5 fuel_kg_bottleneck': [6348.778635846103],
#  'T_strategy = 1.8 v_strategy = 4.5 CO2_kg_bottleneck': [20142.94312645718],
#  'T_strategy = 1.8 v_strategy = 4.5 PM10_kg_bottleneck': [10.977389085152797],
#  'T_strategy = 1.8 v_strategy = 4.5 NOx_kg_bottleneck': [277.17907440010805],
#  'T_strategy = 1.8 v_strategy = 5.0 P_tot': [6332.004309298523],
#  'T_strategy = 1.8 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 1.8 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 1.8 v_strategy = 5.0 fuel_kg_bottleneck': [7893.764397220801],
#  'T_strategy = 1.8 v_strategy = 5.0 CO2_kg_bottleneck': [25044.761587545996],
#  'T_strategy = 1.8 v_strategy = 5.0 PM10_kg_bottleneck': [13.648754840114398],
#  'T_strategy = 1.8 v_strategy = 5.0 NOx_kg_bottleneck': [344.6310597128885],
#  'T_strategy = 1.75 v_strategy = 1.0 P_tot': [93.27934704209423],
#  'T_strategy = 1.75 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 1.75 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 1.75 v_strategy = 1.0 fuel_kg_bottleneck': [711.0324302274383],
#  'T_strategy = 1.75 v_strategy = 1.0 CO2_kg_bottleneck': [2255.9119831761454],
#  'T_strategy = 1.75 v_strategy = 1.0 PM10_kg_bottleneck': [2.473415018503019],
#  'T_strategy = 1.75 v_strategy = 1.0 NOx_kg_bottleneck': [47.04339487644325],
#  'T_strategy = 1.75 v_strategy = 1.5 P_tot': [106.08535095846108],
#  'T_strategy = 1.75 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 1.75 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 1.75 v_strategy = 1.5 fuel_kg_bottleneck': [536.5683060847126],
#  'T_strategy = 1.75 v_strategy = 1.5 CO2_kg_bottleneck': [1702.3848983960431],
#  'T_strategy = 1.75 v_strategy = 1.5 PM10_kg_bottleneck': [1.7821664444719085],
#  'T_strategy = 1.75 v_strategy = 1.5 NOx_kg_bottleneck': [34.24497200957568],
#  'T_strategy = 1.75 v_strategy = 2.0 P_tot': [130.62234168468686],
#  'T_strategy = 1.75 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 1.75 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 1.75 v_strategy = 2.0 fuel_kg_bottleneck': [491.02846663777717],
#  'T_strategy = 1.75 v_strategy = 2.0 CO2_kg_bottleneck': [1557.8994077871293],
#  'T_strategy = 1.75 v_strategy = 2.0 PM10_kg_bottleneck': [1.4809493762029173],
#  'T_strategy = 1.75 v_strategy = 2.0 NOx_kg_bottleneck': [29.106517215669566],
#  'T_strategy = 1.75 v_strategy = 2.5 P_tot': [173.09605133315614],
#  'T_strategy = 1.75 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 1.75 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 1.75 v_strategy = 2.5 fuel_kg_bottleneck': [512.3392137868295],
#  'T_strategy = 1.75 v_strategy = 2.5 CO2_kg_bottleneck': [1625.5125964691229],
#  'T_strategy = 1.75 v_strategy = 2.5 PM10_kg_bottleneck': [1.2675224478880236],
#  'T_strategy = 1.75 v_strategy = 2.5 NOx_kg_bottleneck': [26.23646706086706],
#  'T_strategy = 1.75 v_strategy = 3.0 P_tot': [284.42811785014794],
#  'T_strategy = 1.75 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 1.75 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 1.75 v_strategy = 3.0 fuel_kg_bottleneck': [679.313380792625],
#  'T_strategy = 1.75 v_strategy = 3.0 CO2_kg_bottleneck': [2155.276089969328],
#  'T_strategy = 1.75 v_strategy = 3.0 PM10_kg_bottleneck': [1.3561945370599517],
#  'T_strategy = 1.75 v_strategy = 3.0 NOx_kg_bottleneck': [30.65403699678505],
#  'T_strategy = 1.75 v_strategy = 3.5 P_tot': [710.4021555215608],
#  'T_strategy = 1.75 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 1.75 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 1.75 v_strategy = 3.5 fuel_kg_bottleneck': [1324.2399320293937],
#  'T_strategy = 1.75 v_strategy = 3.5 CO2_kg_bottleneck': [4201.452147984168],
#  'T_strategy = 1.75 v_strategy = 3.5 PM10_kg_bottleneck': [2.317500704648513],
#  'T_strategy = 1.75 v_strategy = 3.5 NOx_kg_bottleneck': [58.01514913289939],
#  'T_strategy = 1.75 v_strategy = 4.0 P_tot': [2364.9661457791767],
#  'T_strategy = 1.75 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 1.75 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 1.75 v_strategy = 4.0 fuel_kg_bottleneck': [3685.3428729449793],
#  'T_strategy = 1.75 v_strategy = 4.0 CO2_kg_bottleneck': [11692.587842343617],
#  'T_strategy = 1.75 v_strategy = 4.0 PM10_kg_bottleneck': [6.372161473719483],
#  'T_strategy = 1.75 v_strategy = 4.0 NOx_kg_bottleneck': [160.8970772114169],
#  'T_strategy = 1.75 v_strategy = 4.5 P_tot': [4629.877446308054],
#  'T_strategy = 1.75 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 1.75 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 1.75 v_strategy = 4.5 fuel_kg_bottleneck': [6413.128531773011],
#  'T_strategy = 1.75 v_strategy = 4.5 CO2_kg_bottleneck': [20347.107796261647],
#  'T_strategy = 1.75 v_strategy = 4.5 PM10_kg_bottleneck': [11.088653611087025],
#  'T_strategy = 1.75 v_strategy = 4.5 NOx_kg_bottleneck': [279.98850367994737],
#  'T_strategy = 1.75 v_strategy = 5.0 P_tot': [6362.896034376148],
#  'T_strategy = 1.75 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 1.75 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 1.75 v_strategy = 5.0 fuel_kg_bottleneck': [7932.2754259054145],
#  'T_strategy = 1.75 v_strategy = 5.0 CO2_kg_bottleneck': [25166.946578554453],
#  'T_strategy = 1.75 v_strategy = 5.0 PM10_kg_bottleneck': [13.715342536770503],
#  'T_strategy = 1.75 v_strategy = 5.0 NOx_kg_bottleneck': [346.3123990534552],
#  'T_strategy = 1.7 v_strategy = 1.0 P_tot': [93.16221924442482],
#  'T_strategy = 1.7 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 1.7 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 1.7 v_strategy = 1.0 fuel_kg_bottleneck': [710.170093749453],
#  'T_strategy = 1.7 v_strategy = 1.0 CO2_kg_bottleneck': [2253.176024714174],
#  'T_strategy = 1.7 v_strategy = 1.0 PM10_kg_bottleneck': [2.4714315791684474],
#  'T_strategy = 1.7 v_strategy = 1.0 NOx_kg_bottleneck': [47.00146753099432],
#  'T_strategy = 1.7 v_strategy = 1.5 P_tot': [105.71993027878251],
#  'T_strategy = 1.7 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 1.7 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 1.7 v_strategy = 1.5 fuel_kg_bottleneck': [534.7919963361475],
# ...
#  'T_strategy = 1.6 v_strategy = 3.0 fuel_kg_bottleneck': [717.5611554164734],
#  'T_strategy = 1.6 v_strategy = 3.0 CO2_kg_bottleneck': [2276.6258476395383],
#  'T_strategy = 1.6 v_strategy = 3.0 PM10_kg_bottleneck': [1.4107602151393743],
#  'T_strategy = 1.6 v_strategy = 3.0 NOx_kg_bottleneck': [32.15028627371321],
#  'T_strategy = 1.6 v_strategy = 3.5 P_tot': [801.8333555438468],
#  'T_strategy = 1.6 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 1.6 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 1.6 v_strategy = 3.5 fuel_kg_bottleneck': [1467.7094658612966],
#  'T_strategy = 1.6 v_strategy = 3.5 CO2_kg_bottleneck': [4656.641850778114],
#  'T_strategy = 1.6 v_strategy = 3.5 PM10_kg_bottleneck': [2.5709140003445365],
#  'T_strategy = 1.6 v_strategy = 3.5 NOx_kg_bottleneck': [64.81029329601498],
#  'T_strategy = 1.6 v_strategy = 4.0 P_tot': [2577.3710428292347],
#  'T_strategy = 1.6 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 1.6 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 1.6 v_strategy = 4.0 fuel_kg_bottleneck': [4016.334872521422],
#  'T_strategy = 1.6 v_strategy = 4.0 CO2_kg_bottleneck': [12742.735186454329],
#  'T_strategy = 1.6 v_strategy = 4.0 PM10_kg_bottleneck': [6.944464931097647],
#  'T_strategy = 1.6 v_strategy = 4.0 NOx_kg_bottleneck': [175.34773951021552],
#  'T_strategy = 1.6 v_strategy = 4.5 P_tot': [4839.269480932491],
#  'T_strategy = 1.6 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 1.6 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 1.6 v_strategy = 4.5 fuel_kg_bottleneck': [6703.1703411187],
#  'T_strategy = 1.6 v_strategy = 4.5 CO2_kg_bottleneck': [21267.331355003877],
#  'T_strategy = 1.6 v_strategy = 4.5 PM10_kg_bottleneck': [11.590151926711478],
#  'T_strategy = 1.6 v_strategy = 4.5 NOx_kg_bottleneck': [292.6513361494648],
#  'T_strategy = 1.6 v_strategy = 5.0 P_tot': [6530.625763100177],
#  'T_strategy = 1.6 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 1.6 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 1.6 v_strategy = 5.0 fuel_kg_bottleneck': [8141.37492999339],
#  'T_strategy = 1.6 v_strategy = 5.0 CO2_kg_bottleneck': [25830.362277888118],
#  'T_strategy = 1.6 v_strategy = 5.0 PM10_kg_bottleneck': [14.076887133856664],
#  'T_strategy = 1.6 v_strategy = 5.0 NOx_kg_bottleneck': [355.4414001298807],
#  'T_strategy = 1.55 v_strategy = 1.0 P_tot': [92.85316112775293],
#  'T_strategy = 1.55 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 1.55 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 1.55 v_strategy = 1.0 fuel_kg_bottleneck': [707.8943300810004],
#  'T_strategy = 1.55 v_strategy = 1.0 CO2_kg_bottleneck': [2245.9556472569925],
#  'T_strategy = 1.55 v_strategy = 1.0 PM10_kg_bottleneck': [2.466184448662457],
#  'T_strategy = 1.55 v_strategy = 1.0 NOx_kg_bottleneck': [46.89062941409295],
#  'T_strategy = 1.55 v_strategy = 1.5 P_tot': [104.76983472561832],
#  'T_strategy = 1.55 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 1.55 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 1.55 v_strategy = 1.5 fuel_kg_bottleneck': [530.1712545547475],
#  'T_strategy = 1.55 v_strategy = 1.5 CO2_kg_bottleneck': [1682.0887985418808],
#  'T_strategy = 1.55 v_strategy = 1.5 PM10_kg_bottleneck': [1.7695174017940758],
#  'T_strategy = 1.55 v_strategy = 1.5 NOx_kg_bottleneck': [33.96467362762626],
#  'T_strategy = 1.55 v_strategy = 2.0 P_tot': [128.3444413727897],
#  'T_strategy = 1.55 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 1.55 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 1.55 v_strategy = 2.0 fuel_kg_bottleneck': [482.8738696768931],
#  'T_strategy = 1.55 v_strategy = 2.0 CO2_kg_bottleneck': [1532.0270956112336],
#  'T_strategy = 1.55 v_strategy = 2.0 PM10_kg_bottleneck': [1.4701585449895178],
#  'T_strategy = 1.55 v_strategy = 2.0 NOx_kg_bottleneck': [28.82859157041581],
#  'T_strategy = 1.55 v_strategy = 2.5 P_tot': [172.9295741073444],
#  'T_strategy = 1.55 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 1.55 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 1.55 v_strategy = 2.5 fuel_kg_bottleneck': [511.87863517107814],
#  'T_strategy = 1.55 v_strategy = 2.5 CO2_kg_bottleneck': [1624.0513061336933],
#  'T_strategy = 1.55 v_strategy = 2.5 PM10_kg_bottleneck': [1.2674878276119574],
#  'T_strategy = 1.55 v_strategy = 2.5 NOx_kg_bottleneck': [26.229325696677012],
#  'T_strategy = 1.55 v_strategy = 3.0 P_tot': [312.7468640171275],
#  'T_strategy = 1.55 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 1.55 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 1.55 v_strategy = 3.0 fuel_kg_bottleneck': [740.7629509740079],
#  'T_strategy = 1.55 v_strategy = 3.0 CO2_kg_bottleneck': [2350.238817181171],
#  'T_strategy = 1.55 v_strategy = 3.0 PM10_kg_bottleneck': [1.4424885321121594],
#  'T_strategy = 1.55 v_strategy = 3.0 NOx_kg_bottleneck': [33.04347606859091],
#  'T_strategy = 1.55 v_strategy = 3.5 P_tot': [846.4895970499585],
#  'T_strategy = 1.55 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 1.55 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 1.55 v_strategy = 3.5 fuel_kg_bottleneck': [1541.9071895987784],
#  'T_strategy = 1.55 v_strategy = 3.5 CO2_kg_bottleneck': [4892.050992454306],
#  'T_strategy = 1.55 v_strategy = 3.5 PM10_kg_bottleneck': [2.7140950687012655],
#  'T_strategy = 1.55 v_strategy = 3.5 NOx_kg_bottleneck': [68.07346227196992],
#  'T_strategy = 1.55 v_strategy = 4.0 P_tot': [2674.025377900537],
#  'T_strategy = 1.55 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 1.55 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 1.55 v_strategy = 4.0 fuel_kg_bottleneck': [4166.951982000976],
#  'T_strategy = 1.55 v_strategy = 4.0 CO2_kg_bottleneck': [13220.602197439463],
#  'T_strategy = 1.55 v_strategy = 4.0 PM10_kg_bottleneck': [7.204890236258372],
#  'T_strategy = 1.55 v_strategy = 4.0 NOx_kg_bottleneck': [181.92347846552386],
#  'T_strategy = 1.55 v_strategy = 4.5 P_tot': [4938.321036458681],
#  'T_strategy = 1.55 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 1.55 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 1.55 v_strategy = 4.5 fuel_kg_bottleneck': [6840.372753974801],
#  'T_strategy = 1.55 v_strategy = 4.5 CO2_kg_bottleneck': [21702.637192156417],
#  'T_strategy = 1.55 v_strategy = 4.5 PM10_kg_bottleneck': [11.827382480134682],
#  'T_strategy = 1.55 v_strategy = 4.5 NOx_kg_bottleneck': [298.64140762340065],
#  'T_strategy = 1.55 v_strategy = 5.0 P_tot': [6617.196873909049],
#  'T_strategy = 1.55 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 1.55 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 1.55 v_strategy = 5.0 fuel_kg_bottleneck': [8249.298411872169],
#  'T_strategy = 1.55 v_strategy = 5.0 CO2_kg_bottleneck': [26172.77405221261],
#  'T_strategy = 1.55 v_strategy = 5.0 PM10_kg_bottleneck': [14.263492797711237],
#  'T_strategy = 1.55 v_strategy = 5.0 NOx_kg_bottleneck': [360.1531931422087],
#  'T_strategy = 1.5 v_strategy = 1.0 P_tot': [92.76049479897216],
#  'T_strategy = 1.5 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 1.5 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 1.5 v_strategy = 1.0 fuel_kg_bottleneck': [707.2118733078782],
#  'T_strategy = 1.5 v_strategy = 1.0 CO2_kg_bottleneck': [2243.790398040451],
#  'T_strategy = 1.5 v_strategy = 1.0 PM10_kg_bottleneck': [2.4646073482537054],
#  'T_strategy = 1.5 v_strategy = 1.0 NOx_kg_bottleneck': [46.8573378216416],
#  'T_strategy = 1.5 v_strategy = 1.5 P_tot': [104.49897909137464],
#  'T_strategy = 1.5 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 1.5 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 1.5 v_strategy = 1.5 fuel_kg_bottleneck': [528.8533459456544],
#  'T_strategy = 1.5 v_strategy = 1.5 CO2_kg_bottleneck': [1677.907433954849],
#  'T_strategy = 1.5 v_strategy = 1.5 PM10_kg_bottleneck': [1.7668835888478873],
#  'T_strategy = 1.5 v_strategy = 1.5 NOx_kg_bottleneck': [33.90651210209872],
#  'T_strategy = 1.5 v_strategy = 2.0 P_tot': [128.14396623997374],
#  'T_strategy = 1.5 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 1.5 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 1.5 v_strategy = 2.0 fuel_kg_bottleneck': [482.15549988102777],
#  'T_strategy = 1.5 v_strategy = 2.0 CO2_kg_bottleneck': [1529.747904167988],
#  'T_strategy = 1.5 v_strategy = 2.0 PM10_kg_bottleneck': [1.4691833055602945],
#  'T_strategy = 1.5 v_strategy = 2.0 NOx_kg_bottleneck': [28.803741386271923],
#  'T_strategy = 1.5 v_strategy = 2.5 P_tot': [174.55169229292005],
#  'T_strategy = 1.5 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 1.5 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 1.5 v_strategy = 2.5 fuel_kg_bottleneck': [516.3637753472424],
#  'T_strategy = 1.5 v_strategy = 2.5 CO2_kg_bottleneck': [1638.2814326926143],
#  'T_strategy = 1.5 v_strategy = 2.5 PM10_kg_bottleneck': [1.2677280143626133],
#  'T_strategy = 1.5 v_strategy = 2.5 NOx_kg_bottleneck': [26.29742573783241],
#  'T_strategy = 1.5 v_strategy = 3.0 P_tot': [327.28767288936024],
#  'T_strategy = 1.5 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 1.5 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 1.5 v_strategy = 3.0 fuel_kg_bottleneck': [771.880171132571],
#  'T_strategy = 1.5 v_strategy = 3.0 CO2_kg_bottleneck': [2448.965270229703],
#  'T_strategy = 1.5 v_strategy = 3.0 PM10_kg_bottleneck': [1.4833685960946594],
#  'T_strategy = 1.5 v_strategy = 3.0 NOx_kg_bottleneck': [34.223755111632585],
#  'T_strategy = 1.5 v_strategy = 3.5 P_tot': [901.2590170686499],
#  'T_strategy = 1.5 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 1.5 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 1.5 v_strategy = 3.5 fuel_kg_bottleneck': [1631.8216625472985],
#  'T_strategy = 1.5 v_strategy = 3.5 CO2_kg_bottleneck': [5177.325092990975],
#  'T_strategy = 1.5 v_strategy = 3.5 PM10_kg_bottleneck': [2.8811157456583474],
#  'T_strategy = 1.5 v_strategy = 3.5 NOx_kg_bottleneck': [72.24254918115098],
#  'T_strategy = 1.5 v_strategy = 4.0 P_tot': [2787.8840592760203],
#  'T_strategy = 1.5 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 1.5 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 1.5 v_strategy = 4.0 fuel_kg_bottleneck': [4344.378741652034],
#  'T_strategy = 1.5 v_strategy = 4.0 CO2_kg_bottleneck': [13783.528916695996],
#  'T_strategy = 1.5 v_strategy = 4.0 PM10_kg_bottleneck': [7.511670908025797],
#  'T_strategy = 1.5 v_strategy = 4.0 NOx_kg_bottleneck': [189.66969042765135],
#  'T_strategy = 1.5 v_strategy = 4.5 P_tot': [5056.081803695884],
#  'T_strategy = 1.5 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 1.5 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 1.5 v_strategy = 4.5 fuel_kg_bottleneck': [7003.490448784328],
#  'T_strategy = 1.5 v_strategy = 4.5 CO2_kg_bottleneck': [22220.165151143006],
#  'T_strategy = 1.5 v_strategy = 4.5 PM10_kg_bottleneck': [12.109421988094114],
#  'T_strategy = 1.5 v_strategy = 4.5 NOx_kg_bottleneck': [305.76290519937635],
#  'T_strategy = 1.5 v_strategy = 5.0 P_tot': [6722.969966410894],
#  'T_strategy = 1.5 v_strategy = 5.0 P_installed': [1750.0],
#  'T_strategy = 1.5 v_strategy = 5.0 duration_hrs_bottleneck': [5.5554610322222215],
#  'T_strategy = 1.5 v_strategy = 5.0 fuel_kg_bottleneck': [8381.159956967596],
#  'T_strategy = 1.5 v_strategy = 5.0 CO2_kg_bottleneck': [26591.13477256083],
#  'T_strategy = 1.5 v_strategy = 5.0 PM10_kg_bottleneck': [14.491488695648071],
#  'T_strategy = 1.5 v_strategy = 5.0 NOx_kg_bottleneck': [365.91008956511376],
#  'T_strategy = 1.45 v_strategy = 1.0 P_tot': [92.67171584431854],
#  'T_strategy = 1.45 v_strategy = 1.0 P_installed': [1750.0],
#  'T_strategy = 1.45 v_strategy = 1.0 duration_hrs_bottleneck': [27.777305160833333],
#  'T_strategy = 1.45 v_strategy = 1.0 fuel_kg_bottleneck': [706.5580007549004],
#  'T_strategy = 1.45 v_strategy = 1.0 CO2_kg_bottleneck': [2241.7158387587297],
#  'T_strategy = 1.45 v_strategy = 1.0 PM10_kg_bottleneck': [2.4630947507268854],
#  'T_strategy = 1.45 v_strategy = 1.0 NOx_kg_bottleneck': [46.82541751141794],
#  'T_strategy = 1.45 v_strategy = 1.5 P_tot': [104.2578262009091],
#  'T_strategy = 1.45 v_strategy = 1.5 P_installed': [1750.0],
#  'T_strategy = 1.45 v_strategy = 1.5 duration_hrs_bottleneck': [18.518203440833332],
#  'T_strategy = 1.45 v_strategy = 1.5 fuel_kg_bottleneck': [527.679732718125],
#  'T_strategy = 1.45 v_strategy = 1.5 CO2_kg_bottleneck': [1674.183879260233],
#  'T_strategy = 1.45 v_strategy = 1.5 PM10_kg_bottleneck': [1.764530140250969],
#  'T_strategy = 1.45 v_strategy = 1.5 NOx_kg_bottleneck': [33.85459939934001],
#  'T_strategy = 1.45 v_strategy = 2.0 P_tot': [128.2248296942404],
#  'T_strategy = 1.45 v_strategy = 2.0 P_installed': [1750.0],
#  'T_strategy = 1.45 v_strategy = 2.0 duration_hrs_bottleneck': [13.888652580555556],
#  'T_strategy = 1.45 v_strategy = 2.0 fuel_kg_bottleneck': [482.4452743322048],
#  'T_strategy = 1.45 v_strategy = 2.0 CO2_kg_bottleneck': [1530.667279472177],
#  'T_strategy = 1.45 v_strategy = 2.0 PM10_kg_bottleneck': [1.469577174606032],
#  'T_strategy = 1.45 v_strategy = 2.0 NOx_kg_bottleneck': [28.813772530270544],
#  'T_strategy = 1.45 v_strategy = 2.5 P_tot': [177.43412564402917],
#  'T_strategy = 1.45 v_strategy = 2.5 P_installed': [1750.0],
#  'T_strategy = 1.45 v_strategy = 2.5 duration_hrs_bottleneck': [11.110922064444443],
#  'T_strategy = 1.45 v_strategy = 2.5 fuel_kg_bottleneck': [524.4398199919034],
#  'T_strategy = 1.45 v_strategy = 2.5 CO2_kg_bottleneck': [1663.9045197924936],
#  'T_strategy = 1.45 v_strategy = 2.5 PM10_kg_bottleneck': [1.2785892480633734],
#  'T_strategy = 1.45 v_strategy = 2.5 NOx_kg_bottleneck': [26.587529895762124],
#  'T_strategy = 1.45 v_strategy = 3.0 P_tot': [346.97306728122754],
#  'T_strategy = 1.45 v_strategy = 3.0 P_installed': [1750.0],
#  'T_strategy = 1.45 v_strategy = 3.0 duration_hrs_bottleneck': [9.259101720277778],
#  'T_strategy = 1.45 v_strategy = 3.0 fuel_kg_bottleneck': [813.5362131356528],
#  'T_strategy = 1.45 v_strategy = 3.0 CO2_kg_bottleneck': [2581.128530766753],
#  'T_strategy = 1.45 v_strategy = 3.0 PM10_kg_bottleneck': [1.5350047807590037],
#  'T_strategy = 1.45 v_strategy = 3.0 NOx_kg_bottleneck': [35.77121462683444],
#  'T_strategy = 1.45 v_strategy = 3.5 P_tot': [968.9197658729058],
#  'T_strategy = 1.45 v_strategy = 3.5 P_installed': [1750.0],
#  'T_strategy = 1.45 v_strategy = 3.5 duration_hrs_bottleneck': [7.936372903055555],
#  'T_strategy = 1.45 v_strategy = 3.5 fuel_kg_bottleneck': [1741.2467575984483],
#  'T_strategy = 1.45 v_strategy = 3.5 CO2_kg_bottleneck': [5524.501076380531],
#  'T_strategy = 1.45 v_strategy = 3.5 PM10_kg_bottleneck': [3.075883430043465],
#  'T_strategy = 1.45 v_strategy = 3.5 NOx_kg_bottleneck': [77.60907399148901],
#  'T_strategy = 1.45 v_strategy = 4.0 P_tot': [2922.607113631186],
#  'T_strategy = 1.45 v_strategy = 4.0 P_installed': [1750.0],
#  'T_strategy = 1.45 v_strategy = 4.0 duration_hrs_bottleneck': [6.944326290277778],
#  'T_strategy = 1.45 v_strategy = 4.0 fuel_kg_bottleneck': [4554.318596002722],
#  'T_strategy = 1.45 v_strategy = 4.0 CO2_kg_bottleneck': [14449.61081822682],
#  'T_strategy = 1.45 v_strategy = 4.0 PM10_kg_bottleneck': [7.874668517152657],
#  'T_strategy = 1.45 v_strategy = 4.0 NOx_kg_bottleneck': [198.8353800581046],
#  'T_strategy = 1.45 v_strategy = 4.5 P_tot': [5195.932607510467],
#  'T_strategy = 1.45 v_strategy = 4.5 P_installed': [1750.0],
#  'T_strategy = 1.45 v_strategy = 4.5 duration_hrs_bottleneck': [6.172734480277778],
#  'T_strategy = 1.45 v_strategy = 4.5 fuel_kg_bottleneck': [7197.206414387237],
#  'T_strategy = 1.45 v_strategy = 4.5 CO2_kg_bottleneck': [22834.77307837405],
#  'T_strategy = 1.45 v_strategy = 4.5 PM10_kg_bottleneck': [12.44436759706884],
#  ...}

# %% [markdown]
# ### Visulization of Stratigies for passing bottleneck section

# %% [markdown]
# #### Organizing data for visulization

# %%
df_plot = pd.DataFrame( df_collect )
df_plot
# Out:
#    T_strategy = 2.2 v_strategy = 1.0 P_tot  \
# 0                                95.405182
#
#    T_strategy = 2.2 v_strategy = 1.0 P_installed  \
# 0                                         1750.0
#
#    T_strategy = 2.2 v_strategy = 1.0 duration_hrs_bottleneck  \
# 0                                          27.777305
#
#    T_strategy = 2.2 v_strategy = 1.0 fuel_kg_bottleneck  \
# 0                                         726.670265
#
#    T_strategy = 2.2 v_strategy = 1.0 CO2_kg_bottleneck  \
# 0                                        2305.526569
#
#    T_strategy = 2.2 v_strategy = 1.0 PM10_kg_bottleneck  \
# 0                                           2.508923
#
#    T_strategy = 2.2 v_strategy = 1.0 NOx_kg_bottleneck  \
# 0                                          47.796873
#
#    T_strategy = 2.2 v_strategy = 1.5 P_tot  \
# 0                               112.662549
#
#    T_strategy = 2.2 v_strategy = 1.5 P_installed  \
# 0                                         1750.0
#
#    T_strategy = 2.2 v_strategy = 1.5 duration_hrs_bottleneck  ...  \
# 0                                          18.518203          ...
#
#    T_strategy = 1.4 v_strategy = 4.5 CO2_kg_bottleneck  \
# 0                                       15424.416076
#
#    T_strategy = 1.4 v_strategy = 4.5 PM10_kg_bottleneck  \
# 0                                           8.405912
#
#    T_strategy = 1.4 v_strategy = 4.5 NOx_kg_bottleneck  \
# 0                                          212.24929
#
#    T_strategy = 1.4 v_strategy = 5.0 P_tot  \
# 0                              5911.549497
#
#    T_strategy = 1.4 v_strategy = 5.0 P_installed  \
# 0                                         1750.0
#
#    T_strategy = 1.4 v_strategy = 5.0 duration_hrs_bottleneck  \
# 0                                           5.555461
#
#    T_strategy = 1.4 v_strategy = 5.0 fuel_kg_bottleneck  \
# 0                                        7369.606317
#
#    T_strategy = 1.4 v_strategy = 5.0 CO2_kg_bottleneck  \
# 0                                        23381.75095
#
#    T_strategy = 1.4 v_strategy = 5.0 PM10_kg_bottleneck  \
# 0                                          12.742457
#
#    T_strategy = 1.4 v_strategy = 5.0 NOx_kg_bottleneck
# 0                                         321.747028
#
# [1 rows x 1071 columns]

# %%
fuel=df_plot[['T_strategy = 2.15 v_computed = 1.4 fuel_kg_bottleneck',
              'T_strategy = 2.1 v_computed = 2.0 fuel_kg_bottleneck',
              'T_strategy = 2.05 v_computed = 2.46 fuel_kg_bottleneck', 
              'T_strategy = 2.0 v_computed = 2.86 fuel_kg_bottleneck',
              'T_strategy = 1.95 v_computed = 3.22 fuel_kg_bottleneck',
              'T_strategy = 1.9 v_computed = 3.54 fuel_kg_bottleneck',
              'T_strategy = 1.85 v_computed = 3.85 fuel_kg_bottleneck']].T

fuel.index=['strategy 1 \n T$_s$=2.15 m \n V$_s$=1.4 m/s', 
            'strategy 2 \n T$_s$=2.10 m \n V$_s$=2.0 m/s',
            'strategy 3 \n T$_s$=2.05 m \n V$_s$=2.5 m/s',
            'strategy 4 \n T$_s$=2.00 m \n V$_s$=2.9 m/s',
            'strategy 5 \n T$_s$=1.95 m \n V$_s$=3.2 m/s',
            'strategy 6 \n T$_s$=1.90 m \n V$_s$=3.5 m/s',
            'strategy 7 \n T$_s$=1.85 m \n V$_s$=3.8 m/s',]

fuel.columns =['section 2 (bottleneck)']
fuel.head(7)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <module>
# ----> 1 fuel=df_plot[['T_strategy = 2.15 v_computed = 1.4 fuel_kg_bottleneck',
#       2               'T_strategy = 2.1 v_computed = 2.0 fuel_kg_bottleneck',
#       3               'T_strategy = 2.05 v_computed = 2.46 fuel_kg_bottleneck',
#       4               'T_strategy = 2.0 v_computed = 2.86 fuel_kg_bottleneck',
#       5               'T_strategy = 1.95 v_computed = 3.22 fuel_kg_bottleneck',
#       6               'T_strategy = 1.9 v_computed = 3.54 fuel_kg_bottleneck',
#       7               'T_strategy = 1.85 v_computed = 3.85 fuel_kg_bottleneck']].T
#       9 fuel.index=['strategy 1 \n T$_s$=2.15 m \n V$_s$=1.4 m/s',
#      10             'strategy 2 \n T$_s$=2.10 m \n V$_s$=2.0 m/s',
#      11             'strategy 3 \n T$_s$=2.05 m \n V$_s$=2.5 m/s',
#    (...)
#      14             'strategy 6 \n T$_s$=1.90 m \n V$_s$=3.5 m/s',
#      15             'strategy 7 \n T$_s$=1.85 m \n V$_s$=3.8 m/s',]
#      17 fuel.columns =['section 2 (bottleneck)']
#
# File C:\ANACONDA2021\envs\sim\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File C:\ANACONDA2021\envs\sim\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File C:\ANACONDA2021\envs\sim\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['T_strategy = 2.15 v_computed = 1.4 fuel_kg_bottleneck',\n       'T_strategy = 2.1 v_computed = 2.0 fuel_kg_bottleneck',\n       'T_strategy = 2.05 v_computed = 2.46 fuel_kg_bottleneck',\n       'T_strategy = 2.0 v_computed = 2.86 fuel_kg_bottleneck',\n       'T_strategy = 1.95 v_computed = 3.22 fuel_kg_bottleneck',\n       'T_strategy = 1.9 v_computed = 3.54 fuel_kg_bottleneck',\n       'T_strategy = 1.85 v_computed = 3.85 fuel_kg_bottleneck'],\n      dtype='object')] are in the [columns]"

# %%
fuel_colors=['#bf9005']
fuel.plot(kind='bar',stacked=True,color=fuel_colors,rot=0, figsize=(10, 3))

# %%
CO2=df_plot[[ 'T_strategy = 2.15 v_computed = 1.4 CO2_kg_bottleneck',
              'T_strategy = 2.1 v_computed = 2.0 CO2_kg_bottleneck',
              'T_strategy = 2.05 v_computed = 2.46 CO2_kg_bottleneck', 
              'T_strategy = 2.0 v_computed = 2.86 CO2_kg_bottleneck',
              'T_strategy = 1.95 v_computed = 3.22 CO2_kg_bottleneck',
              'T_strategy = 1.9 v_computed = 3.54 CO2_kg_bottleneck',
              'T_strategy = 1.85 v_computed = 3.85 CO2_kg_bottleneck']].T

CO2.index=[ 'strategy 1 \n T$_s$=2.15 m \n V$_s$=1.4 m/s', 
            'strategy 2 \n T$_s$=2.10 m \n V$_s$=2.0 m/s',
            'strategy 3 \n T$_s$=2.05 m \n V$_s$=2.5 m/s',
            'strategy 4 \n T$_s$=2.00 m \n V$_s$=2.9 m/s',
            'strategy 5 \n T$_s$=1.95 m \n V$_s$=3.2 m/s',
            'strategy 6 \n T$_s$=1.90 m \n V$_s$=3.5 m/s',
            'strategy 7 \n T$_s$=1.85 m \n V$_s$=3.8 m/s',]

CO2.columns =['section 2 (bottleneck)']
CO2.head(7)

# %%
CO2_colors=['orange']
CO2.plot(kind='bar', stacked=True,color=CO2_colors,rot=0, figsize=(10, 3))

# %%
PM10=df_plot[['T_strategy = 2.15 v_computed = 1.4 PM10_kg_bottleneck',
              'T_strategy = 2.1 v_computed = 2.0 PM10_kg_bottleneck',
              'T_strategy = 2.05 v_computed = 2.46 PM10_kg_bottleneck', 
              'T_strategy = 2.0 v_computed = 2.86 PM10_kg_bottleneck',
              'T_strategy = 1.95 v_computed = 3.22 PM10_kg_bottleneck',
              'T_strategy = 1.9 v_computed = 3.54 PM10_kg_bottleneck',
              'T_strategy = 1.85 v_computed = 3.85 PM10_kg_bottleneck']].T

PM10.index=['strategy 1 \n T$_s$=2.15 m \n V$_s$=1.4 m/s', 
            'strategy 2 \n T$_s$=2.10 m \n V$_s$=2.0 m/s',
            'strategy 3 \n T$_s$=2.05 m \n V$_s$=2.5 m/s',
            'strategy 4 \n T$_s$=2.00 m \n V$_s$=2.9 m/s',
            'strategy 5 \n T$_s$=1.95 m \n V$_s$=3.2 m/s',
            'strategy 6 \n T$_s$=1.90 m \n V$_s$=3.5 m/s',
            'strategy 7 \n T$_s$=1.85 m \n V$_s$=3.8 m/s',]

PM10.columns =['section 2 (bottleneck)']
PM10.head(7)

# %%
PM10_colors=['mediumseagreen']
PM10.plot(kind='bar', stacked=True,color=PM10_colors,rot=0, figsize=(10, 3))

# %%
NOx=df_plot[['T_strategy = 2.15 v_computed = 1.4 NOx_kg_bottleneck',
              'T_strategy = 2.1 v_computed = 2.0 NOx_kg_bottleneck',
              'T_strategy = 2.05 v_computed = 2.46 NOx_kg_bottleneck', 
              'T_strategy = 2.0 v_computed = 2.86 NOx_kg_bottleneck',
              'T_strategy = 1.95 v_computed = 3.22 NOx_kg_bottleneck',
              'T_strategy = 1.9 v_computed = 3.54 NOx_kg_bottleneck',
              'T_strategy = 1.85 v_computed = 3.85 NOx_kg_bottleneck']].T

NOx.index=['strategy 1 \n T$_s$=2.15 m \n V$_s$=1.4 m/s', 
            'strategy 2 \n T$_s$=2.10 m \n V$_s$=2.0 m/s',
            'strategy 3 \n T$_s$=2.05 m \n V$_s$=2.5 m/s',
            'strategy 4 \n T$_s$=2.00 m \n V$_s$=2.9 m/s',
            'strategy 5 \n T$_s$=1.95 m \n V$_s$=3.2 m/s',
            'strategy 6 \n T$_s$=1.90 m \n V$_s$=3.5 m/s',
            'strategy 7 \n T$_s$=1.85 m \n V$_s$=3.8 m/s',]

NOx.columns =['section 2 (bottleneck)']
NOx.head(7)

# %%
NOx_colors=['deeppink']
NOx.plot(kind='bar', stacked=True,color=NOx_colors,rot=0, figsize=(10, 3))

# %%
Payload = Strategies_df['Payload_strategy'][0:7]
Payload = pd.DataFrame(Payload)

Payload.index=['strategy 1 \n T$_s$=2.15 m \n V$_s$=1.4 m/s', 
            'strategy 2 \n T$_s$=2.10 m \n V$_s$=2.0 m/s',
            'strategy 3 \n T$_s$=2.05 m \n V$_s$=2.5 m/s',
            'strategy 4 \n T$_s$=2.00 m \n V$_s$=2.9 m/s',
            'strategy 5 \n T$_s$=1.95 m \n V$_s$=3.2 m/s',
            'strategy 6 \n T$_s$=1.90 m \n V$_s$=3.5 m/s',
            'strategy 7 \n T$_s$=1.85 m \n V$_s$=3.8 m/s',]

Payload.columns =['section 2 (bottleneck)']
Payload.head(7)

# %%
Payload_colors=['yellowgreen']
Payload.plot(kind='bar', stacked=True,color=Payload_colors,rot=0, figsize=(10, 3))

# %%
duration=df_plot[['T_strategy = 2.15 v_computed = 1.4 duration_hrs_bottleneck',
              'T_strategy = 2.1 v_computed = 2.0 duration_hrs_bottleneck',
              'T_strategy = 2.05 v_computed = 2.46 duration_hrs_bottleneck', 
              'T_strategy = 2.0 v_computed = 2.86 duration_hrs_bottleneck',
              'T_strategy = 1.95 v_computed = 3.22 duration_hrs_bottleneck',
              'T_strategy = 1.9 v_computed = 3.54 duration_hrs_bottleneck',
              'T_strategy = 1.85 v_computed = 3.85 duration_hrs_bottleneck']].T

duration.index=['strategy 1 \n T$_s$=2.15 m \n V$_s$=1.4 m/s', 
            'strategy 2 \n T$_s$=2.10 m \n V$_s$=2.0 m/s',
            'strategy 3 \n T$_s$=2.05 m \n V$_s$=2.5 m/s',
            'strategy 4 \n T$_s$=2.00 m \n V$_s$=2.9 m/s',
            'strategy 5 \n T$_s$=1.95 m \n V$_s$=3.2 m/s',
            'strategy 6 \n T$_s$=1.90 m \n V$_s$=3.5 m/s',
            'strategy 7 \n T$_s$=1.85 m \n V$_s$=3.8 m/s',]

duration.columns =['section 2 (bottleneck)']
duration.head(7)

# %%
duration_colors=['mediumpurple']
duration.plot(kind='bar', stacked=True,color=duration_colors,rot=0, figsize=(10, 3))

# %%
sinkage_max=df_plot[['T_strategy = 2.15 v_computed = 1.4 sinkage_max_m_bottleneck',
              'T_strategy = 2.1 v_computed = 2.0 sinkage_max_m_bottleneck',
              'T_strategy = 2.05 v_computed = 2.46 sinkage_max_m_bottleneck', 
              'T_strategy = 2.0 v_computed = 2.86 sinkage_max_m_bottleneck',
              'T_strategy = 1.95 v_computed = 3.22 sinkage_max_m_bottleneck',
              'T_strategy = 1.9 v_computed = 3.54 sinkage_max_m_bottleneck',
              'T_strategy = 1.85 v_computed = 3.85 sinkage_max_m_bottleneck']].T

sinkage_max.index=['strategy 1 \n T$_s$=2.15 m \n V$_s$=1.4 m/s', 
            'strategy 2 \n T$_s$=2.10 m \n V$_s$=2.0 m/s',
            'strategy 3 \n T$_s$=2.05 m \n V$_s$=2.5 m/s',
            'strategy 4 \n T$_s$=2.00 m \n V$_s$=2.9 m/s',
            'strategy 5 \n T$_s$=1.95 m \n V$_s$=3.2 m/s',
            'strategy 6 \n T$_s$=1.90 m \n V$_s$=3.5 m/s',
            'strategy 7 \n T$_s$=1.85 m \n V$_s$=3.8 m/s',]

sinkage_max.columns =['section 2 (bottleneck)']
sinkage_max.head(7)

# %%
sinkage_max_colors=['tomato']
sinkage_max.plot(kind='bar', stacked=True,color=sinkage_max_colors,rot=0, figsize=(10, 3))

# %%
dynamic_ukc=df_plot[['T_strategy = 2.15 v_computed = 1.4 dynamic_ukc_m_bottleneck',
              'T_strategy = 2.1 v_computed = 2.0 dynamic_ukc_m_bottleneck',
              'T_strategy = 2.05 v_computed = 2.46 dynamic_ukc_m_bottleneck', 
              'T_strategy = 2.0 v_computed = 2.86 dynamic_ukc_m_bottleneck',
              'T_strategy = 1.95 v_computed = 3.22 dynamic_ukc_m_bottleneck',
              'T_strategy = 1.9 v_computed = 3.54 dynamic_ukc_m_bottleneck',
              'T_strategy = 1.85 v_computed = 3.85 dynamic_ukc_m_bottleneck']].T

dynamic_ukc.index=['strategy 1 \n T$_s$=2.15 m \n V$_s$=1.4 m/s', 
            'strategy 2 \n T$_s$=2.10 m \n V$_s$=2.0 m/s',
            'strategy 3 \n T$_s$=2.05 m \n V$_s$=2.5 m/s',
            'strategy 4 \n T$_s$=2.00 m \n V$_s$=2.9 m/s',
            'strategy 5 \n T$_s$=1.95 m \n V$_s$=3.2 m/s',
            'strategy 6 \n T$_s$=1.90 m \n V$_s$=3.5 m/s',
            'strategy 7 \n T$_s$=1.85 m \n V$_s$=3.8 m/s',]

dynamic_ukc.columns =['section 2 (bottleneck)']
dynamic_ukc.head(7)

# %%
dynamic_ukc_colors=['deepskyblue']
dynamic_ukc.plot(kind='bar', stacked=True,color=dynamic_ukc_colors,rot=0, figsize=(10, 3))

# %%
fig, axes = plt.subplots(nrows=8, ncols=1,figsize=(10, 24),sharex=True)


fuel.plot(ax=axes[0],kind='bar', stacked=True,color=fuel_colors,rot=0)
plt.yticks(weight = 'bold', fontsize=12)

plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.2f}'))
axes[0].set_ylim(0, 3000)
axes[0].set_ylabel('Total fuel use \n (kg)',fontsize=12,fontweight='bold',labelpad=12)
axes[0].annotate('(a)', xy=(6, 3000*7/8), fontsize=12,weight = 'bold')
axes[0].set_yticklabels(axes[0].get_yticks(), size=12,weight = 'bold')  
axes[0].legend(loc='upper left')
axes[0].set_title('M8 vessel: L$_s$ = 110 m, B$_s$ = 11.40 m, h$_0$ = 2.5 m')

CO2.plot(ax=axes[1],kind='bar', stacked=True,color=CO2_colors,rot=0)
axes[1].set_ylim(0, 9000)
axes[1].set_ylabel('Total CO2 emission \n (kg)',fontsize=12,fontweight='bold',labelpad=3)
axes[1].set_yticklabels(axes[1].get_yticks(), size=12,weight = 'bold')  
axes[1].annotate('(b)', xy=(6, 9000*7/8), fontsize=12,weight = 'bold')
axes[1].legend(loc='upper left')
plt.yticks(weight = 'bold', fontsize=12)
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

PM10.plot(ax=axes[2],kind='bar', stacked=True,color=PM10_colors,rot=0)
axes[2].set_ylim(0, 5)
axes[2].set_ylabel('Total PM10 emission \n (kg)',fontsize=12,fontweight='bold',labelpad=27)
axes[2].annotate('(c)', xy=(6, 5*7/8), fontsize=12,weight = 'bold')
axes[2].set_yticklabels(axes[2].get_yticks(), size=12,weight = 'bold')  
axes[2].legend(loc='upper left')
plt.yticks(weight = 'bold', fontsize=12)
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

NOx.plot(ax=axes[3],kind='bar', stacked=True,color=NOx_colors,rot=0)
axes[3].set_ylim(0, 120)
axes[3].set_ylabel('Total NOx emission \n (kg)',fontsize=12,fontweight='bold',labelpad=20)  
axes[3].set_yticklabels(axes[3].get_yticks(), size=12,weight = 'bold')  
axes[3].annotate('(d)', xy=(6, 120*7/8), fontsize=12,weight = 'bold')
axes[3].legend(loc='upper left')
plt.yticks(weight = 'bold', fontsize=12)
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

Payload.plot(ax=axes[4],kind='bar', stacked=True,color=Payload_colors,rot=0)
axes[4].set_ylim(0, 2000)
axes[4].set_ylabel('payload \n (ton)',fontsize=12,fontweight='bold',labelpad=20)  
axes[4].set_yticklabels(axes[4].get_yticks(), size=12,weight = 'bold')  
axes[4].annotate('(e)', xy=(6, 2000*7/8), fontsize=12,weight = 'bold')
axes[4].legend(loc='upper left')
plt.yticks(weight = 'bold', fontsize=12)
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

duration.plot(ax=axes[5],kind='bar', stacked=True,color=duration_colors,rot=0)
axes[5].set_ylim(0, 25)
axes[5].set_ylabel('duration \n (hours)',fontsize=12,fontweight='bold',labelpad=20)  
axes[5].set_yticklabels(axes[5].get_yticks(), size=12,weight = 'bold')  
axes[5].annotate('(f)', xy=(6, 25*7/8), fontsize=12,weight = 'bold')
axes[5].legend(loc='upper left')
plt.yticks(weight = 'bold', fontsize=12)
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

sinkage_max.plot(ax=axes[6],kind='bar', stacked=True,color=sinkage_max_colors,rot=0)
axes[6].set_ylim(0, 0.6)
axes[6].set_ylabel('maximum sinkage \n (m)',fontsize=12,fontweight='bold',labelpad=0)  
axes[6].set_yticklabels(axes[6].get_yticks(), size=12,weight = 'bold')  
axes[6].annotate('(g)', xy=(6, 0.6*7/8), fontsize=12,weight = 'bold')
axes[6].legend(loc='upper left')
plt.yticks(weight = 'bold', fontsize=12)
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.2f}'))

dynamic_ukc.plot(ax=axes[7],kind='bar', stacked=True,color=dynamic_ukc_colors,rot=0)
axes[7].set_ylim(0, 0.6)
axes[7].set_ylabel('dynamic ukc \n (m)',fontsize=12,fontweight='bold',labelpad=20)  
axes[7].set_yticklabels(axes[6].get_yticks(), size=12,weight = 'bold')  
axes[7].annotate('(h)', xy=(6, 0.6*7/8), fontsize=12,weight = 'bold')
axes[7].legend(loc='upper left')
plt.yticks(weight = 'bold', fontsize=12)
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.2f}'))


plt.xticks( weight = 'bold', fontsize=12)

plt.savefig('Strategies for passing bottleneck.pdf',bbox_inches = 'tight', dpi=600, format='pdf')  
plt.show()

# %% [markdown]
# ### Define "T_v_strategy_energy_simulation" for passing 3 whole sections (h_0: 6 m, 2.5 m, 6 m)

# %%
def T_v_strategy_energy_simulation(v_strategy, T_strategy):
    
    # Start simpy environment
    simulation_start = datetime.datetime.now()
    env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
    env.epoch = time.mktime(simulation_start.timetuple())

    # Add graph to environment
    env.FG = FG

    # Add environment and path to the vessel
    # create a fresh instance of vessel
    vessel = TransportResource(**data_vessel)
    vessel.env = env                                        #the created environment
    vessel.name = 'Vessel No.1'                     
    vessel.route = path                #the route (the sequence of nodes, as stored as the second column in the path)
    vessel.geometry = env.FG.nodes[path[0]]['geometry']     #a shapely.geometry.Point(lon,lat) (here taken as the starting node of the vessel)
    vessel._T = T_strategy
    vessel.v = v_strategy
    
 
    # Start the simulation
    env.process(vessel.move())
    env.run()
    
    return vessel

# %% [markdown]
# ### Run "T_v_strategy_energy_simulation" for passing 3 whole sections (h_0: 6 m, 2.5 m, 6 m)

# %% [markdown]
# ### Visulization of Stratigies for passing  3 whole sections (h_0: 6 m, 2.5 m, 6 m)

# %%
use dataframe as input run simulation and plot multi-figure sets with strategies, refer to figure 3 5 7 8 9 notebook

# %%
do the same to fig 10, 11,13,14,15

# %%
will also influence 3 5 7 8 9, due to v, h_0 variation
