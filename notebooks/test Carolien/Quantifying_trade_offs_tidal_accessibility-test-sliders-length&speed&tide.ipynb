# %%
# package(s) used for creating and geo-locating the graph
import networkx as nx
from pyproj import Geod
from shapely.geometry import Point, LineString
from opentnsim import graph

# package(s) related to the hydrodynamics and tidal windows
import xarray as xr

# load OpenTNSim modules
from opentnsim.core import Identifiable, Movable 
from opentnsim.core.vessel_properties import VesselProperties
from opentnsim.graph import HasMultiDiGraph
from opentnsim.vessel_traffic_service import VesselTrafficService
from opentnsim.port.mixins.port import IsPort, HasPortAccess
from opentnsim.port.mixins.terminal import IsTerminal, HasTerminal
from opentnsim.port.mixins.berth import IsJetty, IsQuay
from opentnsim.port.mixins.anchorage_area import IsAnchorage, PassesAnchorage
from opentnsim.port.mixins import tidal_accessibility
from opentnsim.port.mixins.tidal_accessibility import HasDraughtRestrictions
from opentnsim.port.rule_constructor import vessel_characteristics, vessel_direction, vessel_type
from opentnsim.port.tidal_window_constructor import vessel_specifications, \
                                                    vertical_tidal_window_specifications, \
                                                    vertical_tidal_window_input, \
                                                    horizontal_tidal_window_specifications, \
                                                    horizontal_tidal_window_method, \
                                                    horizontal_tidal_window_input, \
                                                    tidal_period, \
                                                    accessibility, \
                                                    NetworkProperties

# package(s) related to the simulation (creating the vessel, running the simulation)
import datetime
import simpy
import opentnsim

# package(s) needed for inspecting the output
import pandas as pd
import numpy as np
import scipy

# package(s) for plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.colors as mcolors

print("This notebook is executed with OpenTNSim version {}".format(opentnsim.__version__))
# Out:
# This notebook is executed with OpenTNSim version 1.3.7

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### 1. Constants

# %%
# Environment  
simulation_start = datetime.datetime(2024, 1, 1, 0, 0, 0)
simulation_stop = datetime.datetime(2024, 1, 3, 0, 0, 0)
timestep = pd.Timedelta(minutes=5)
time_series = pd.date_range(simulation_start,simulation_stop,freq=timestep)

# %%
# initialize geodetic calculator with WGS84 ellipsoid
geod = Geod(ellps="WGS84")

# %%
# make your preferred Vessel class out of available mix-ins.
Vessel = type(
    "Vessel", 
    (HasPortAccess,
     HasTerminal,
     PassesAnchorage,
     HasDraughtRestrictions,
     HasMultiDiGraph,
     Identifiable, # allows to give the object a name and a random ID,
     Movable,      # allows the object to move, with a fixed speed, while logging this activity
     VesselProperties,
    ), 
    {}
)

# %%
def mission(env, vessel):
    """
    Method that defines the mission of the vessel. 
    
    In this case: 
        keep moving along the path until its end point is reached
    """
    yield from vessel.move()

# %% [markdown]
# #### 2. Create simulation
# We define a function

# %%
def create_and_run_env_with_tidal_window(
    original_waterway_depth,
    added_depth,
    waterway_length, 
    ukc_percentage,
    tidal_range_sea,
    tidal_period,
    tidal_amplication,
    tidal_propagation_speed,
    interarrival_time,
    vessel_beam,
    vessel_draught,
    vessel_speed,
    vessel_loading_factor,
):
    env = simpy.Environment(initial_time=simulation_start.timestamp())
    env.simulation_start = simulation_start
    env.simulation_stop = simulation_stop
    env.epoch = simulation_start

    # Graph
    coordinates_sea = (0,0)
    coordinates_port = geod.fwd(coordinates_sea[0], coordinates_sea[1], 90 ,waterway_length) # East from Point 0
    coordinates_waterway = {"Sea": (coordinates_sea[0], coordinates_sea[1]),
                            "Port basin": (coordinates_port[0], coordinates_port[1]),}
    FG = nx.DiGraph()
    for name, coordinate in coordinates_waterway.items():
        FG.add_node(name, geometry=Point(coordinate[0], coordinate[1]))
    edges = [("Sea", "Port basin"), ("Port basin", "Sea")]
    for edge in edges:
        FG.add_edge(edge[0], edge[1], geometry=LineString([Point(coordinates_sea),Point(coordinates_port[:-1])]), weight=1, length_m=waterway_length)
    env.graph = FG

    # Hydrodynamic data
    waterway_depth = original_waterway_depth + added_depth
    hydrodynamic_data = xr.Dataset()
    tidal_phase_shift = pd.Timedelta(seconds=waterway_length/tidal_propagation_speed)
    tidal_water_level_sea = (tidal_range_sea/2)*np.sin(2*np.pi*((time_series-simulation_start)/(tidal_period*pd.Timedelta(hours=1))))
    amplification_factor = ((tidal_amplication-(1/10000))*waterway_length+1)
    tidal_water_level_port = amplification_factor*(tidal_range_sea/2)*np.sin(2*np.pi*((time_series-simulation_start-tidal_phase_shift)/(tidal_period*pd.Timedelta(hours=1))))
    water_level_data = xr.DataArray(data=[tidal_water_level_sea,tidal_water_level_port],coords={'STATION':FG.nodes,'TIME':time_series})
    MBLs = waterway_depth*np.ones(len(time_series))
    MBL_data = xr.DataArray(data=[MBLs,MBLs],coords={'STATION':FG.nodes,'TIME':time_series})
    hydrodynamic_data['Water level'] = water_level_data
    hydrodynamic_data['MBL'] = MBL_data
    vessel_traffic_service = VesselTrafficService(hydrodynamic_data = hydrodynamic_data)
    env.vessel_traffic_service = vessel_traffic_service
    
    network_properties = NetworkProperties()
    for index, node in enumerate(FG.nodes):
        FG.nodes[node]['Vertical tidal restriction'] = {}
        vertical_tidal_window_inputs = []
    
        vessel_specification = vessel_specifications({vessel_characteristics.min_ge_Draught: 0.0},'x',vessel_direction.inbound)
        window_specification = vertical_tidal_window_specifications(ukc_s = 0.,
                                                                    ukc_p = ukc_percentage/100,
                                                                    fwa = 0.,)
        
        vertical_tidal_window_inputs.append(vertical_tidal_window_input(vessel_specifications = vessel_specification,
                                                                        window_specifications = window_specification))

        vessel_specification = vessel_specifications({vessel_characteristics.min_ge_Draught: 0.0},'x',vessel_direction.outbound)
        window_specification = vertical_tidal_window_specifications(ukc_s = 0.,
                                                                    ukc_p = ukc_percentage/100,
                                                                    fwa = 0.,)
        
        vertical_tidal_window_inputs.append(vertical_tidal_window_input(vessel_specifications = vessel_specification,
                                                                        window_specifications = window_specification))
    
        network_properties.append_vertical_tidal_restriction_to_network(env.graph,node,vertical_tidal_window_inputs)
        
    # Infrastructure
    max_draught = np.max([vessel_draught,vessel_draught+vessel_draught*vessel_loading_factor/100])
    always_sufficient_depth = max_draught + tidal_range_sea + (ukc_percentage/100)*max_draught + 0.5 # m (not important, should be 100% accessible) 

    port = IsPort(env=env, name = "Port", port_entry_nodes=['Sea'])
    anchorage = IsAnchorage(env=env, capacity=20, name = 'Anchorage', node = 'Sea', depth = always_sufficient_depth, geometry=env.graph.nodes['Sea']['geometry'], port = port)
    jetty = IsJetty(env=env,length=300, depth=always_sufficient_depth, name='Jetty',node='Port basin')
    terminal = IsTerminal(env=env, name = 'Terminal', berths=[jetty], port = port)

    # Vessel
    path = nx.dijkstra_path(env.graph, "Sea", "Port basin")
    data_vessel = {
        "env": env,                                       # needed for simpy simulation
        "name": "Vessel 1",                               # required by Identifiable
        "geometry": env.graph.nodes[path[0]]['geometry'], # required by Locatable
        "route": path,                                    # required by Routeable
        "v": vessel_speed,                                # required by Movable, 1 m/s to check if the distance is covered in the expected time
        "bound": 'inbound',
        "terminal": terminal,
        "berthing_time":15, #minutes
        "loading_time": 12, #hours
        "deberthing_time":5, #minutes,
        "next_destination":"Sea",
        "type":"tanker",
        "loading_factor":vessel_loading_factor,
        "L":vessel_beam*8,
        "B":vessel_beam,
        "T":vessel_draught,
    } 
    vessel = Vessel(**data_vessel)
    vessel.mission = env.process(mission(env, vessel))
    env.run()
    try:
        inbound_window_lengths = [(window[1]-window[0]).total_seconds() for window in vessel.tidal_window_calculations[0]['vertical_tidal_windows']]
        inbound_window_length = scipy.stats.mode(inbound_window_lengths)[0]
        inbound_window_length = np.min([inbound_window_length,pd.Timedelta(hours=tidal_period).total_seconds()])
        if pd.isna(inbound_window_length):
            inbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    except:
        inbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    try:
        outbound_window_lengths = [(window[1]-window[0]).total_seconds() for window in vessel.tidal_window_calculations[1]['vertical_tidal_windows']]
        outbound_window_length = scipy.stats.mode(outbound_window_lengths)[0]
        outbound_window_length = np.min([outbound_window_length,pd.Timedelta(hours=tidal_period).total_seconds()])
        if pd.isna(outbound_window_length):
            outbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    except:
        outbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    inbound_vessel_capacity = np.floor(inbound_window_length/interarrival_time.total_seconds())
    outbound_vessel_capacity = np.floor(outbound_window_length/interarrival_time.total_seconds())
    dredging = added_depth*waterway_length*(3*vessel.B)
    return inbound_vessel_capacity, outbound_vessel_capacity, dredging, vessel

# %% [markdown]
# #### 3. Run simulation

# %%
original_waterway_depth = 11.0

waterway_lengths = [10000, 25000, 50000]
vessel_speeds = [2, 4, 6, 8]
tidal_ranges = [2, 4, 6, 8]

inbound_water_transport_capacity_performances = {}
outbound_water_transport_capacity_performances = {}
dredging_performances = {}

for waterway_length in waterway_lengths:
    inbound_water_transport_capacity_performances[waterway_length] = {}
    outbound_water_transport_capacity_performances[waterway_length] = {}
    dredging_performances[waterway_length] = {}

    for vessel_speed in vessel_speeds:
        inbound_water_transport_capacity_performances[waterway_length][vessel_speed] = {}
        outbound_water_transport_capacity_performances[waterway_length][vessel_speed] = {}
        dredging_performances[waterway_length][vessel_speed] = {}

        for tidal_range in tidal_ranges:
            inbound_water_transport_capacity_performance = {}
            outbound_water_transport_capacity_performance = {}
            dredging_performance = {}

            for added_depth in np.arange(-3, 3, 0.1):
                inbound_waterway_capacity_for_design_vessel, \
                outbound_waterway_capacity_for_design_vessel, \
                dredging, vessel = create_and_run_env_with_tidal_window(
                    original_waterway_depth=original_waterway_depth,
                    added_depth=added_depth,
                    waterway_length=waterway_length,
                    ukc_percentage=10.0,
                    tidal_range_sea=tidal_range,   
                    tidal_period=12.5,
                    tidal_amplication=1.0 / 10000,
                    tidal_propagation_speed=15.0,
                    interarrival_time=pd.Timedelta(minutes=20),
                    vessel_draught=10.0,
                    vessel_beam=30,
                    vessel_speed=vessel_speed,
                    vessel_loading_factor=-40.0,
                )

                inbound_water_transport_capacity_performance[added_depth] = int(inbound_waterway_capacity_for_design_vessel)
                outbound_water_transport_capacity_performance[added_depth] = int(outbound_waterway_capacity_for_design_vessel)
                dredging_performance[added_depth] = dredging

            inbound_water_transport_capacity_performances[waterway_length][vessel_speed][tidal_range] = inbound_water_transport_capacity_performance
            outbound_water_transport_capacity_performances[waterway_length][vessel_speed][tidal_range] = outbound_water_transport_capacity_performance
            dredging_performances[waterway_length][vessel_speed][tidal_range] = dredging_performance
# Out:
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d6598934-4e8c-433a-8eff-e3f966fa2f90
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 73a42f11-c830-46c5-a852-b1aa6541a603
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 41b0543c-9948-46fc-8f55-43dd6e6c9ba6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e3fe0b1f-979b-4508-8ed9-2c69171c47d2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 516cbd62-2a9e-4abe-8401-1b561c471ea6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 071c7a93-da04-4f2b-8d54-454303c8f0a4
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: abf7c141-b6f6-4f76-b01f-9478cb218bdb
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 821a66de-6936-4640-b7f1-25fa90345365
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a6c5a05c-6632-4b66-ab67-6bcbe851d1c0
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 49f5a366-a000-4ada-8544-0b38dc45e011
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 088645c0-c2f7-4c99-89af-b390f0e6142b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 9528442d-1f41-4559-afe2-ddcfd2353fa2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 888d30f8-6ef0-45df-9099-ffc48e8fb0bc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b86b52f9-1ec8-4984-bc55-691c2a8ef22a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1b26d3a1-a979-4bcd-b140-99d0f8fd33ef
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# ...
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: dba45d03-6773-4a40-9cc3-f0fbf2aacc63
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1bb72df5-7bc1-4c7d-b7e4-ea57ef8c33f8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 50bf6e66-5029-401d-aad5-8701cf81170d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 564fe92d-2554-4df0-8ed9-10602f67f6e6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 7f6ef17f-caae-4ad5-97fe-d8d5f6c678ee
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a1f08983-59ba-4718-8fe5-af5c598fcf30
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 090b2068-7303-4ca6-b56a-fe83bf623aeb
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 7704c259-5708-40cd-8214-6b0802e14a57
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: dd079833-0f2c-4029-89a2-3b3859e4e1a2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 03b52d23-4619-4d85-a669-6b58eb875271
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ef42a639-24ac-48a2-a0f4-7f69c14e2541
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8499d728-c787-43fd-9a6e-e7c05da4b641
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 516a3cef-df1c-4fc0-a848-3fa21d8f07f9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ccb69f92-c6ee-4809-abe5-9cba581a7aad
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 86b1c2e5-cb4a-4dc5-8037-950b9f4d750a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4a967d7b-4fe3-4238-ac59-c058a3f961fa
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8c08b837-0d85-4ec3-b268-9af29b3998d3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 96b78449-b4fb-463f-8952-bd3e8f6e1a5b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5b764149-1cde-453e-98ba-28d020faebc8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 36539264-c27b-4951-bed4-05f6e8ce3a42
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5e75e3fd-a8ff-4e97-8123-c9f33292fdd1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2e19a3c6-d72b-4979-8075-c9b28c892575
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d2aa15c0-889f-46fe-ad60-0a2c749f4fec
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 19c0ae8f-0627-4d55-8266-3e85a5d7157c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0b8c5fa8-328b-4ab7-b6d8-023524d49388
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: fe1f2947-0ca9-43ce-b56e-a9e5d44f5897
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1a112194-f3f7-49bd-83fb-487fa89b551f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1cd2db11-5f97-4f7a-a549-91c50e06bd3b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f2756693-16f1-4b46-9b9d-2c3ef0168596
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 95e4d54b-9c60-46ad-b180-5a0b8aa034ed
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 63d62017-3d4e-4450-9f6e-e07d0aa2458a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 43154c46-e990-4409-ace0-b56b2f6107ea
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1f4d948b-0825-4afe-b8ba-213b127227d1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1ee5fd78-5f93-4612-8c57-25deb2c4f2cc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: bb4d81ea-a50f-4379-866e-fd21360d3eae
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: eb10d1c8-358f-45d5-ae24-69928050ef70
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d78e5fbe-3b5b-4dcd-8ec9-752f3f4972dd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 450e9418-75a4-45f0-8ba5-496b2a879231
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3f39153a-a885-4d8b-a644-ac6c95706f05
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b9d14e70-3563-4343-aa39-b2fa7fc9d07b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_25264\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors as mcolors
import numpy as np
import ipywidgets as widgets
from ipywidgets import interactive
from matplotlib.ticker import MultipleLocator

def plot_capacity_vs_dredging(waterway_length, vessel_speed, tidal_range):
    waterway_length = int(waterway_length)
    vessel_speed = int(vessel_speed)
    tidal_range = int(tidal_range)
    
    fig, ax = plt.subplots()

    bound = 'inbound'
    water_transport_capacity_performances = inbound_water_transport_capacity_performances
    if bound == 'outbound':
        water_transport_capacity_performances = outbound_water_transport_capacity_performances

    filtered_water_transport_capacity_performance = {
        k: v for k, v in water_transport_capacity_performances[waterway_length][vessel_speed][tidal_range].items() if v > -1
    }

    filtered_dredging_performance = {
        k: -dredging_performances[waterway_length][vessel_speed][tidal_range][k]
        for k in filtered_water_transport_capacity_performance
    }

    if len(filtered_water_transport_capacity_performance) == 0:
        print("No data available for this waterway length.")
        return

    min_depth = min(filtered_water_transport_capacity_performance.keys())
    max_depth = max(filtered_water_transport_capacity_performance.keys())

    cmap = plt.get_cmap('bwr')
    norm = mpl.colors.Normalize(min_depth, max_depth)

    if min_depth >= 0.0:
        cmap = mcolors.LinearSegmentedColormap.from_list(
            'bwr_truncated',
            cmap(np.linspace(0.5, 1, 256))
        )
        norm = mpl.colors.Normalize(min_depth - 1.0, max_depth)

    x_vals = list(filtered_water_transport_capacity_performance.values())
    y_vals = np.array(list(filtered_dredging_performance.values())) / 1e6
    c_vals = list(filtered_water_transport_capacity_performance.keys())

    line, = ax.plot(
        x_vals,
        y_vals,
        label=f'L = {waterway_length/1000:.0f} km, v = {vessel_speed} m/s, tidal range = {tidal_range} ({bound})',
        zorder=-1, color = 'black', 
    )

    cbar = ax.scatter(
        x_vals,
        y_vals,
        c=c_vals,
        cmap=cmap,
        norm=norm,
        edgecolor=line.get_color(),
    )

    ax.set_xlabel('Waterway capacity\n[nr. of vessels]')
    #ax.set_ylabel('Dredging volume [m3] / dredging activities')
    # Dredging (pijl naar beneden)

    fig.subplots_adjust(left=0.20)
    fig.text(
    0.01, 0.5,  # x, y positie (links van figuur)
    'Dredging volume [10⁶ m³]',  # jouw titel
    va='center',
    rotation='vertical',
    fontsize=12
    )
        
    
    ax.annotate(
        'Dredging',
        xy=(-0.2, 0.10),       # punt waar pijl naartoe wijst
        xytext=(-0.2, 0.35),   # waar tekst staat
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    # Sedimentation (pijl naar boven)
    ax.annotate(
        'Sedimentation',
        xy=(-0.2, 0.90),
        xytext=(-0.2, 0.65),
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    ax.set_xlim(0, 40)
    ax.xaxis.set_major_locator(MultipleLocator(5))

    ax.set_ylim(-17, 4)
    ax.yaxis.set_major_locator(MultipleLocator(0.5))

    ax.legend()
    fig.colorbar(cbar, label='Added depth [m]')

    ax.set_title(f'Channel vessel capacity for {bound} port and various channel depths. \n For a vessel with draught {vessel.T}m and loading capacity of {vessel.loading_factor} % and natural channel depth {original_waterway_depth}')


    plt.show()

slider_waterway_length = widgets.SelectionSlider(
    options=[10000, 25000, 50000],
    value=25000,
    description='Waterway length [m]:',
    continuous_update=False
)

slider_vessel_speed = widgets.SelectionSlider(
    options=[2, 4, 6, 8],
    value=6,
    description='Vessel speed [m/s]:',
    continuous_update=False
)

slider_tidal_range = widgets.SelectionSlider(
    options=[2, 4, 6, 8],
    value=2,
    description='Tidal range [m]:',
    continuous_update=False
)



interactive_plot = interactive(
    plot_capacity_vs_dredging,
    waterway_length=slider_waterway_length, 
    vessel_speed=slider_vessel_speed,
    tidal_range = slider_tidal_range
)

output = interactive_plot.children[-1]
output.layout.height = '500px'
interactive_plot
# Out:
# interactive(children=(SelectionSlider(continuous_update=False, description='Waterway length [m]:', index=1, op…
