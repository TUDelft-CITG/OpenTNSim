# %%
# package(s) used for creating and geo-locating the graph
import networkx as nx
from pyproj import Geod
from shapely.geometry import Point, LineString
from opentnsim import graph

# package(s) related to the hydrodynamics and tidal windows
import xarray as xr

# load OpenTNSim modules
from opentnsim.core import Identifiable, Movable 
from opentnsim.core.vessel_properties import VesselProperties
from opentnsim.graph import HasMultiDiGraph
from opentnsim.vessel_traffic_service import VesselTrafficService
from opentnsim.port.mixins.port import IsPort, HasPortAccess
from opentnsim.port.mixins.terminal import IsTerminal, HasTerminal
from opentnsim.port.mixins.berth import IsJetty, IsQuay
from opentnsim.port.mixins.anchorage_area import IsAnchorage, PassesAnchorage
from opentnsim.port.mixins import tidal_accessibility
from opentnsim.port.mixins.tidal_accessibility import HasDraughtRestrictions
from opentnsim.port.rule_constructor import vessel_characteristics, vessel_direction, vessel_type
from opentnsim.port.tidal_window_constructor import vessel_specifications, \
                                                    vertical_tidal_window_specifications, \
                                                    vertical_tidal_window_input, \
                                                    horizontal_tidal_window_specifications, \
                                                    horizontal_tidal_window_method, \
                                                    horizontal_tidal_window_input, \
                                                    tidal_period, \
                                                    accessibility, \
                                                    NetworkProperties

# package(s) related to the simulation (creating the vessel, running the simulation)
import datetime
import simpy
import opentnsim

# package(s) needed for inspecting the output
import pandas as pd
import numpy as np
import scipy

# package(s) for plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.colors as mcolors

print("This notebook is executed with OpenTNSim version {}".format(opentnsim.__version__))
# Out:
# This notebook is executed with OpenTNSim version 1.3.7

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### 1. Constants

# %%
# Environment  
simulation_start = datetime.datetime(2024, 1, 1, 0, 0, 0)
simulation_stop = datetime.datetime(2024, 1, 3, 0, 0, 0)
timestep = pd.Timedelta(minutes=5)
time_series = pd.date_range(simulation_start,simulation_stop,freq=timestep)

# %%
# initialize geodetic calculator with WGS84 ellipsoid
geod = Geod(ellps="WGS84")

# %%
# make your preferred Vessel class out of available mix-ins.
Vessel = type(
    "Vessel", 
    (HasPortAccess,
     HasTerminal,
     PassesAnchorage,
     HasDraughtRestrictions,
     HasMultiDiGraph,
     Identifiable, # allows to give the object a name and a random ID,
     Movable,      # allows the object to move, with a fixed speed, while logging this activity
     VesselProperties,
    ), 
    {}
)

# %%
def mission(env, vessel):
    """
    Method that defines the mission of the vessel. 
    
    In this case: 
        keep moving along the path until its end point is reached
    """
    yield from vessel.move()

# %% [markdown]
# #### 2. Create simulation
# We define a function

# %%
def create_and_run_env_with_tidal_window(
    original_waterway_depth,
    added_depth,
    waterway_length, 
    ukc_percentage,
    tidal_range_sea,
    tidal_period,
    tidal_amplication,
    tidal_propagation_speed,
    interarrival_time,
    vessel_beam,
    vessel_draught,
    vessel_speed,
    vessel_loading_factor,
):
    env = simpy.Environment(initial_time=simulation_start.timestamp())
    env.simulation_start = simulation_start
    env.simulation_stop = simulation_stop
    env.epoch = simulation_start

    # Graph
    coordinates_sea = (0,0)
    coordinates_port = geod.fwd(coordinates_sea[0], coordinates_sea[1], 90 ,waterway_length) # East from Point 0
    coordinates_waterway = {"Sea": (coordinates_sea[0], coordinates_sea[1]),
                            "Port basin": (coordinates_port[0], coordinates_port[1]),}
    FG = nx.DiGraph()
    for name, coordinate in coordinates_waterway.items():
        FG.add_node(name, geometry=Point(coordinate[0], coordinate[1]))
    edges = [("Sea", "Port basin"), ("Port basin", "Sea")]
    for edge in edges:
        FG.add_edge(edge[0], edge[1], geometry=LineString([Point(coordinates_sea),Point(coordinates_port[:-1])]), weight=1, length_m=waterway_length)
    env.graph = FG

    # Hydrodynamic data
    waterway_depth = original_waterway_depth + added_depth
    hydrodynamic_data = xr.Dataset()
    tidal_phase_shift = pd.Timedelta(seconds=waterway_length/tidal_propagation_speed)
    tidal_water_level_sea = (tidal_range_sea/2)*np.sin(2*np.pi*((time_series-simulation_start)/(tidal_period*pd.Timedelta(hours=1))))
    amplification_factor = ((tidal_amplication-(1/10000))*waterway_length+1)
    tidal_water_level_port = amplification_factor*(tidal_range_sea/2)*np.sin(2*np.pi*((time_series-simulation_start-tidal_phase_shift)/(tidal_period*pd.Timedelta(hours=1))))
    water_level_data = xr.DataArray(data=[tidal_water_level_sea,tidal_water_level_port],coords={'STATION':FG.nodes,'TIME':time_series})
    MBLs = waterway_depth*np.ones(len(time_series))
    MBL_data = xr.DataArray(data=[MBLs,MBLs],coords={'STATION':FG.nodes,'TIME':time_series})
    hydrodynamic_data['Water level'] = water_level_data
    hydrodynamic_data['MBL'] = MBL_data
    vessel_traffic_service = VesselTrafficService(hydrodynamic_data = hydrodynamic_data)
    env.vessel_traffic_service = vessel_traffic_service
    
    network_properties = NetworkProperties()
    for index, node in enumerate(FG.nodes):
        FG.nodes[node]['Vertical tidal restriction'] = {}
        vertical_tidal_window_inputs = []
    
        vessel_specification = vessel_specifications({vessel_characteristics.min_ge_Draught: 0.0},'x',vessel_direction.inbound)
        window_specification = vertical_tidal_window_specifications(ukc_s = 0.,
                                                                    ukc_p = ukc_percentage/100,
                                                                    fwa = 0.,)
        
        vertical_tidal_window_inputs.append(vertical_tidal_window_input(vessel_specifications = vessel_specification,
                                                                        window_specifications = window_specification))

        vessel_specification = vessel_specifications({vessel_characteristics.min_ge_Draught: 0.0},'x',vessel_direction.outbound)
        window_specification = vertical_tidal_window_specifications(ukc_s = 0.,
                                                                    ukc_p = ukc_percentage/100,
                                                                    fwa = 0.,)
        
        vertical_tidal_window_inputs.append(vertical_tidal_window_input(vessel_specifications = vessel_specification,
                                                                        window_specifications = window_specification))
    
        network_properties.append_vertical_tidal_restriction_to_network(env.graph,node,vertical_tidal_window_inputs)
        
    # Infrastructure
    max_draught = np.max([vessel_draught,vessel_draught+vessel_draught*vessel_loading_factor/100])
    always_sufficient_depth = max_draught + tidal_range_sea + (ukc_percentage/100)*max_draught + 0.5 # m (not important, should be 100% accessible) 

    port = IsPort(env=env, name = "Port", port_entry_nodes=['Sea'])
    anchorage = IsAnchorage(env=env, capacity=20, name = 'Anchorage', node = 'Sea', depth = always_sufficient_depth, geometry=env.graph.nodes['Sea']['geometry'], port = port)
    jetty = IsJetty(env=env,length=300, depth=always_sufficient_depth, name='Jetty',node='Port basin')
    terminal = IsTerminal(env=env, name = 'Terminal', berths=[jetty], port = port)

    # Vessel
    path = nx.dijkstra_path(env.graph, "Sea", "Port basin")
    data_vessel = {
        "env": env,                                       # needed for simpy simulation
        "name": "Vessel 1",                               # required by Identifiable
        "geometry": env.graph.nodes[path[0]]['geometry'], # required by Locatable
        "route": path,                                    # required by Routeable
        "v": vessel_speed,                                # required by Movable, 1 m/s to check if the distance is covered in the expected time
        "bound": 'inbound',
        "terminal": terminal,
        "berthing_time":15, #minutes
        "loading_time": 12, #hours
        "deberthing_time":5, #minutes,
        "next_destination":"Sea",
        "type":"tanker",
        "loading_factor":vessel_loading_factor,
        "L":vessel_beam*8,
        "B":vessel_beam,
        "T":vessel_draught,
    } 
    vessel = Vessel(**data_vessel)
    vessel.mission = env.process(mission(env, vessel))
    env.run()
    try:
        inbound_window_lengths = [(window[1]-window[0]).total_seconds() for window in vessel.tidal_window_calculations[0]['vertical_tidal_windows']]
        inbound_window_length = scipy.stats.mode(inbound_window_lengths)[0]
        inbound_window_length = np.min([inbound_window_length,pd.Timedelta(hours=tidal_period).total_seconds()])
        if pd.isna(inbound_window_length):
            inbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    except:
        inbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    try:
        outbound_window_lengths = [(window[1]-window[0]).total_seconds() for window in vessel.tidal_window_calculations[1]['vertical_tidal_windows']]
        outbound_window_length = scipy.stats.mode(outbound_window_lengths)[0]
        outbound_window_length = np.min([outbound_window_length,pd.Timedelta(hours=tidal_period).total_seconds()])
        if pd.isna(outbound_window_length):
            outbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    except:
        outbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    inbound_vessel_capacity = np.floor(inbound_window_length/interarrival_time.total_seconds())
    outbound_vessel_capacity = np.floor(outbound_window_length/interarrival_time.total_seconds())
    dredging = added_depth*waterway_length*(3*vessel.B)
    return inbound_vessel_capacity, outbound_vessel_capacity, dredging, vessel

# %%
env = simpy.Environment(initial_time=simulation_start.timestamp())
env.simulation_start = simulation_start
env.simulation_stop = simulation_stop
env.epoch = simulation_start

waterway_length = 25000
# Graph
coordinates_sea = (0,0)
coordinates_port = geod.fwd(coordinates_sea[0], coordinates_sea[1], 90 ,waterway_length) # East from Point 0
coordinates_waterway = {"Sea": (coordinates_sea[0], coordinates_sea[1]),
                       "Port basin": (coordinates_port[0], coordinates_port[1]),}
FG = nx.DiGraph()

for name, coordinate in coordinates_waterway.items():
   FG.add_node(name, geometry=Point(coordinate[0], coordinate[1]))
    
edges = [("Sea", "Port basin"), ("Port basin", "Sea")]
for edge in edges:
    FG.add_edge(edge[0], edge[1], geometry=LineString([Point(coordinates_sea),Point(coordinates_port[:-1])]), weight=1, length_m="L")
env.graph = FG

# Extract de coördinaten van de knopen voor het tekenen
pos = {node: (FG.nodes[node]['geometry'].x, FG.nodes[node]['geometry'].y) for node in FG.nodes}

edge_labels = {}
for u, v, data in FG.edges(data=True):
    edge_labels[(u, v)] = f"{data['length_m']} m"  # Lengte toevoegen als label

# Plot de grafiek met expliciete coördinaten
plt.figure(figsize=(8, 8))  # Grootte van de figuur
nx.draw(FG, pos=pos, with_labels=True, node_size=1000, node_color='skyblue', font_size=12)
nx.draw_networkx_edge_labels(FG, pos=pos, edge_labels=edge_labels, font_size=10, font_color='Black')
plt.title("Waterway Network")  # Titel voor de grafiek

# Sla de grafiek op in de 'figures' map
plt.savefig('figures/nodes_network.png')  # Bestandsnaam in de figures map

# Toon de grafiek
plt.show()  # Toon de grafiek

# %% [markdown]
# #### 3. Run simulation

# %%
original_waterway_depth = 11.0

inbound_water_transport_capacity_performances = {}
outbound_water_transport_capacity_performances = {}
dredging_performances = {}
# Looping over waterway length
for waterway_length in [10000, 12000, 14000, 16000, 18000, 20000, 22000, 24000, 26000, 28000, 30000]:
    inbound_water_transport_capacity_performance = {}
    outbound_water_transport_capacity_performance = {}
    dredging_performance = {}

    # looping over waterway depth
    for added_depth in np.arange(-2, 2, 0.1):
        waterway_depth = original_waterway_depth + added_depth
        inbound_waterway_capacity_for_design_vessel, outbound_waterway_capacity_for_design_vessel, dredging, vessel = create_and_run_env_with_tidal_window(
            original_waterway_depth = original_waterway_depth, #in m (better known as NGD: nautical guaranteed depth or MBL: maintained bed level)
            added_depth = added_depth,
            waterway_length = waterway_length, #in m 
            ukc_percentage = 10.0, #in % of draught (10% of draught is common)
            tidal_range_sea = 2.0, #in m
            tidal_period = 12.5, # hrs (semi-diurnal tide, most common tide)
            tidal_amplication = 1.0 / 10000, #in m^-1 (amplification factor per 10 km: 1.0 = not damping / amplifying)
            tidal_propagation_speed = np.sqrt(9.81*original_waterway_depth), #15.0, # m/s (could be calculated using np.sqrt(9.81*waterway_depth))
            interarrival_time = pd.Timedelta(minutes=20),
            vessel_draught = 10.0, #in m
            vessel_beam = 30,
            vessel_speed = 6.0, # m/s (common speed in confined waterways)
            vessel_loading_factor = 0, #in % of draught (+ = loading when export terminal, - = unloading when import terminal, 30% is common)
        )
        inbound_water_transport_capacity_performance[added_depth] = int(inbound_waterway_capacity_for_design_vessel)
        outbound_water_transport_capacity_performance[added_depth] = int(outbound_waterway_capacity_for_design_vessel)
        dredging_performance[added_depth] = dredging
        
    inbound_water_transport_capacity_performances[waterway_length] = inbound_water_transport_capacity_performance
    outbound_water_transport_capacity_performances[waterway_length] = outbound_water_transport_capacity_performance
    dredging_performances[waterway_length] = dredging_performance
# Out:
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 91255dc9-2541-4687-bf39-230d9bdefa18
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 50258b31-8e9e-46be-b0c0-90d4aa3dc34e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 57c24907-0521-4868-a36b-afbdf4daf0b0
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 55d0f045-96a4-4b6c-9268-f7f99c836c14
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e34c748f-f17f-4f35-a2b5-8ba8d5561702
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 281ede0a-6329-417a-a672-3806de9f47d8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5811f010-bf91-4af0-a774-e693e37afaae
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2025ed20-3a30-4aa6-b19b-0b4c796ae81c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ae19d3c3-e8bb-4f84-b870-617ef9ba263a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0fa3a3a3-52e1-4eae-a6a2-f377c5132754
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3fabb9c6-e1ac-486b-9723-3512bd10b7b2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3b75cf1f-23ae-4cba-b471-67100f73c8fd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8b6429a8-6af4-40c1-8987-8c94ba8e51bd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3b3ef41e-35e9-43ad-81e4-0532dee74687
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2b376009-5f19-4cae-8b1d-97e9ecdfa08e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a67e62d8-618c-4b7d-bdd7-937c07986402
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b993f674-9b85-47c7-a3e7-b62c6f355569
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c06a70fa-3d95-4ace-871c-1dcfd26b85e3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4595a23c-26a6-478f-bd2a-e88fa91264f1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: edf2c851-a596-4a88-a0c6-3a0f1a0a5845
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 83113c1a-1a98-4cc5-9f58-7ab6a2ba0220
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4506cad3-d316-4a98-aa4f-4cb2fd95a976
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 7fd359f3-0377-4239-a22b-fabb77867b57
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: fca69cc8-bd34-4b1d-ab11-a32233869b64
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 6b4e7b06-062d-4be3-b992-b99e89f811de
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 78402b58-957e-4419-b70b-b7d13304099c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: de0752ef-83c5-479c-a65d-0e48fddc2033
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 322a37ba-52bd-4578-bb48-9785f046232e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1c7bddab-3d8d-4165-8cab-781357f1507a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ef17223c-91e6-41d7-90c9-c1c56d95fe5e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 93c57d39-65aa-4b66-b2f3-0eabfff480a1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1baa10ab-3756-45de-a1fc-bef9b99a2c65
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c7bed0b2-a195-4a0e-affc-d393c4165768
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: cc10e246-0add-4a45-b957-a3d09be26b93
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 19a471f6-bd66-4e07-9f39-86c48497b49d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 80bcc9c0-602e-4777-8a64-0d95e21f0b52
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a31a143e-f509-401c-9d41-d58ca4efaae8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c7ef73f3-41a2-422c-b9fa-d7f7af156002
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 651220fd-cdc8-47bc-93e8-8e5a69af14ce
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3dc03df4-8000-490d-8ef2-1daf333bb59f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: def04232-d0b8-4d42-be96-0e6b7141706f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3099d4ea-eebb-42ee-8c53-a44e0caa52aa
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 29e9ecf9-ee4b-4d45-a548-0fba33a8b1a7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8123b8ae-67d5-4a56-a4bf-947535ff2020
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: bd63d025-8d2e-4c0a-addb-ae3592b655b3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 446ec03b-96df-45ea-bac7-cac0aacf9837
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 29d79bfa-d8d6-4713-898b-377d33996029
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f7025a3f-0f31-4a16-af61-5206cfb803f9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f0f1b16a-a143-4b3f-8c6e-863d3b383008
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 75cc9fe0-9900-47d7-9f40-773617e54711
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b5c83daf-dc10-4ea7-b6c5-92316511584e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3df0d593-a207-43c9-8987-fe0bceb0dfe2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 43c5ea8d-da1e-4678-a8c5-8e28dc6b09c7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5b5ed2c7-b599-4305-9dd8-96c73aab5191
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 9044b3fe-1e2b-4a72-b096-8597f8cc2303
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f32129e5-4cb8-4d62-ad2a-620136f50605
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a50b22d6-41ff-4290-90ca-cbab2955160e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1776e91a-dc85-486a-851f-7364471f0258
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 18bfc131-5fb6-4290-a613-4e6b33aec766
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c153c539-39bf-46b6-aa1b-35777d5d8155
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: fc76db43-c07d-4e95-9726-26c4a33a6e43
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f446e363-3717-442b-8450-3c55d0f975d3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 79838fa3-6465-4c30-adb5-d8443fceed8f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8def296f-cfd8-4d44-af12-d39cac237828
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4728e753-b168-4d76-aa77-44f98fae605d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4308150f-bbda-4581-be27-3874fbc44e92
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4dd37640-35c0-47db-9fc4-7d48d44382c5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 9f11e2d8-fc92-4c42-9db3-4638c6e089ab
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 7af97cfc-d4cc-4209-84aa-cae9bcc0a22a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1a86659a-017c-4782-9ee0-ae7895198a7e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 703bf01a-6ee9-46b1-805f-22c8cbac0696
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 76974d98-675a-486f-b34d-0ad2af7cb735
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 918a0d38-0b6e-4d18-9f56-056b7ffa25e5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b350873c-3106-4bf4-b8eb-459920cea842
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b6254d39-0b66-4b43-880f-fb5c3bb2b780
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8529cdd0-72f9-4709-9ab4-13899ea14334
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0006556a-0c33-4761-acd1-2a4729734fc6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 6d0013be-cab9-4dc5-a47b-b66548fc06a3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ad2168b8-8f27-42bb-ba32-d6bc95d84304
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a37ce0cb-3c20-42b6-a199-4bd711d2642b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0d473fa4-69c6-453b-803e-b75cf99c863a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1056daa0-7217-41c9-bb70-93e3bbfb142e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ce9f10d5-4c34-418b-be5a-5a630dc31660
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 52f696c6-fdb5-4832-a096-343efbd0df74
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 9a75b2c4-0d67-4d71-b6a8-163e5aafa47d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 713a00bb-52df-4bcf-a07f-2f47f38e1f72
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1ba6115d-7377-440a-9230-7661cacd6de4
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c11eb66f-da70-408d-b3f4-8f644437e92a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 9a04e113-cb4e-40f1-9929-900b136216b0
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 95bc7a13-7dc7-43be-8978-5c4e852a3314
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c9052159-1f68-4181-be76-62cbd0fa5fb8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a8cd8d9b-a54d-47a2-a2b9-228c48c6414f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: da6b2180-5e9f-4525-8c45-a7dcbce2fb6c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 302b36ed-b6c8-4235-8f83-50511ecb010d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: bb6e782a-43e2-4fd7-94e3-b2e4a1b99b15
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8cf435f4-4e15-4dcb-98c5-7edaf0299490
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1f390f7a-c792-4190-817d-7fee4b3fdecd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 176f549c-28e2-40d8-99bb-b1c625166fe6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 30af4766-8602-4ba9-8bf4-0f7740c38e7b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a4f918d5-5a77-4f69-87d9-f6ba99e3c214
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a4f918d5-5a77-4f69-87d9-f6ba99e3c214
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 193fde31-ddb0-43e1-bb86-728dc2af3964
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 700b60bf-f93f-44c1-9ad3-8eb6b0f0e5be
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 06f4007e-3319-49a8-aa03-b13a0917005e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3d008f09-53ea-42c9-9cf7-b9103459759d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c70b4fc1-5f68-414f-a69c-ee8511dbe2f3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 6bdf2538-d2a0-44e6-8842-aef007f68586
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 37cbcd36-33bb-4781-a0af-cff908947162
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a84f4250-49ca-4fbd-9903-1c4e4ae8fd7c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 047b48b3-fe6b-43a8-b30a-ef63dc2288ef
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a4e9aac0-b768-42f7-b50e-2b6215d58252
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2440683d-5dfb-4591-bd67-30ce8ef4fc6e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f2a7fe94-23de-4542-9bca-c2b2dd8bbe0f
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f2a7fe94-23de-4542-9bca-c2b2dd8bbe0f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: fdfefe75-c5e2-44a3-b08b-d671787be478
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8b3f9680-7979-46b1-bd99-cb4913dda791
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a0c229d2-e285-4af3-96ba-32157c283ecf
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: cc24c8af-0b47-4dc5-a530-ee75fd978743
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: cc9364a4-5030-4779-95a8-ce6ad9abe257
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c9872bdb-714d-49f9-8d8d-a90315cdfb01
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1bbf579c-345a-4964-a08b-5124be2e074e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c32a8bab-f1c5-44ae-8bdb-2535f706c91c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d3080feb-ed2e-41f2-9389-384e6b89fa37
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 18478e18-c21f-4b3f-ab24-867aa2f01beb
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0ec05396-43b7-43bf-b49d-92822493f97a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e221bc62-dc42-4aba-ba8b-f7e58ea5cce2
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e221bc62-dc42-4aba-ba8b-f7e58ea5cce2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.

# %%
from matplotlib.ticker import MultipleLocator


# Lijsten met stijlen voor de lijnen en markers
line_styles = ['-', '--', '-.', ':']  # Verschillende lijnstijlen
markers = ['o', 's', '^', 'D']  # Verschillende markeringen
colors = ['blue', 'green', 'red', 'purple']  # Verschillende kleuren


fig, ax = plt.subplots()
min_depth = 0.
max_depth = 0.
bound = 'inbound'

water_transport_capacity_performances = inbound_water_transport_capacity_performances
if bound == 'outbound':
    water_transport_capacity_performances = outbound_water_transport_capacity_performances
    
for waterway_length in water_transport_capacity_performances.keys():
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[waterway_length].items() if v > -1}
    
    filtered_dredging_performance = {k: -dredging_performances[waterway_length][k] for k in filtered_water_transport_capacity_performance}
    new_min_depth = np.min(list(filtered_water_transport_capacity_performance.keys()))
    new_max_depth = np.max(list(filtered_water_transport_capacity_performance.keys())) 
    if new_min_depth < min_depth:
        min_depth = new_min_depth
    if new_max_depth > max_depth:
        max_depth = new_max_depth
    norm = mpl.colors.Normalize(min_depth,max_depth)
    cmap = plt.get_cmap('coolwarm')
    
    if min_depth >= 0.:
        cmap = mcolors.LinearSegmentedColormap.from_list(
            'bwr',
            cmap(np.linspace(0.5, 1, 256))
        )
        norm = mpl.colors.Normalize(new_min_depth-1.,max_depth)

# for waterway_length in water_transport_capacity_performances.keys():
#     filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[waterway_length].items() if v > -1}
#     filtered_dredging_performance = {k: -dredging_performances[waterway_length][k] for k in filtered_water_transport_capacity_performance}


    # Loop opnieuw over de waterway_lengths en voeg de stijlen toe
for i, waterway_length in enumerate(water_transport_capacity_performances.keys()):
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[waterway_length].items() if v > -1}
    filtered_dredging_performance = {k: -dredging_performances[waterway_length][k] for k in filtered_water_transport_capacity_performance}

    x_vals = list(filtered_water_transport_capacity_performance.values())
    #y_vals = list(filtered_dredging_performance.values())
    y_vals = np.array(list(filtered_dredging_performance.values())) / 1e6


    
    # Kies de lijnstijl, marker en kleur per waterway_length
    line_style = line_styles[i % len(line_styles)]  # Afwisselen van lijnstijlen
    marker = markers[i % len(markers)]  # Afwisselen van markers
    color = colors[i % len(colors)]  # Afwisselen van kleuren

    
    line, = ax.plot(
        x_vals,
        y_vals,
        label=f'L={waterway_length/1000} km ({bound})', 
        linestyle = line_style,
        color = 'black',
        zorder=-1
    )
    
    cbar = ax.scatter(
        x_vals,
        y_vals,
        c=filtered_dredging_performance.keys(),
        cmap=cmap,
        norm = norm,
        edgecolor=line.get_color(),
    )
    
    ax.set_xlabel('Waterway capacity\n[nr. of vessels]')
    ax.set_ylabel('Dredging volume [10⁶ m³]')
    # Dredging (pijl naar beneden)
    ax.annotate(
        'Dredging',
        xy=(-0.10, 0.10),       # punt waar pijl naartoe wijst
        xytext=(-0.10, 0.35),   # waar tekst staat
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

# Sedimentation (pijl naar boven)
    ax.annotate(
        'Sedimentation',
        xy=(-0.10, 0.90),
        xytext=(-0.10, 0.65),
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    ax.set_ylim(-4, 4)
    ax.yaxis.set_major_locator(MultipleLocator(0.5))

    ax.set_title(f'Channel vessel capacity for {bound} port and various channel depths. \n For a vessel with draught {vessel.T} and loading capacity ={vessel.loading_factor} m and natural channel depth {original_waterway_depth}')

#ax.legend()
fig.colorbar(cbar, label='Added depth [m]')

fig.savefig('figures/Capacity_changing_waterway_lengths_inbound.png', dpi=300)

plt.show()

# %% [markdown]
# Outbound

# %% [markdown]
# **run simulation**

# %%
original_waterway_depth = 11.0

inbound_water_transport_capacity_performances = {}
outbound_water_transport_capacity_performances = {}
dredging_performances = {}
# Looping over waterway length
for waterway_length in [10000, 25000, 50000]:
    inbound_water_transport_capacity_performance = {}
    outbound_water_transport_capacity_performance = {}
    dredging_performance = {}

    # looping over waterway depth
    for added_depth in np.arange(-3, 3, 0.1):
        waterway_depth = original_waterway_depth + added_depth
        inbound_waterway_capacity_for_design_vessel, outbound_waterway_capacity_for_design_vessel, dredging, vessel = create_and_run_env_with_tidal_window(
            original_waterway_depth = original_waterway_depth, #in m (better known as NGD: nautical guaranteed depth or MBL: maintained bed level)
            added_depth = added_depth,
            waterway_length = waterway_length, #in m 
            ukc_percentage = 10.0, #in % of draught (10% of draught is common)
            tidal_range_sea = 2.0, #in m
            tidal_period = 12.5, # hrs (semi-diurnal tide, most common tide)
            tidal_amplication = 1.0 / 10000, #in m^-1 (amplification factor per 10 km: 1.0 = not damping / amplifying)
            tidal_propagation_speed = 15.0, # m/s (could be calculated using np.sqrt(9.81*waterway_depth))
            interarrival_time = pd.Timedelta(minutes=20),
            vessel_draught = 10.0, #in m
            vessel_beam = 30,
            vessel_speed = 6.0, # m/s (common speed in confined waterways)
            vessel_loading_factor = 30.0, #in % of draught (+ = loading when export terminal, - = unloading when import terminal, 30% is common)
        )
        inbound_water_transport_capacity_performance[added_depth] = int(inbound_waterway_capacity_for_design_vessel)
        outbound_water_transport_capacity_performance[added_depth] = int(outbound_waterway_capacity_for_design_vessel)
        dredging_performance[added_depth] = dredging
        
    inbound_water_transport_capacity_performances[waterway_length] = inbound_water_transport_capacity_performance
    outbound_water_transport_capacity_performances[waterway_length] = outbound_water_transport_capacity_performance
    dredging_performances[waterway_length] = dredging_performance
# Out:
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c3390f11-5bbd-45ae-a095-606741750ac6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a4326a52-ae5f-4e3d-a970-9d513d828bcc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d57bc33d-454a-4efd-bfdb-b8dea53f7ced
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a3974e33-43b5-4230-8baf-2f2c280e2626
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 248b792f-b764-4963-bb03-f14a78e840eb
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c1df60d3-f146-4c04-8c3b-9a0a8812f32d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2819377d-9276-4c88-8311-4dda99f44949
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0cbdf8cd-a1f5-4dc7-a8c7-482586c0272f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 14bb36d8-bd19-42f6-a163-059bc01b3194
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4d8e064e-e874-4689-9d11-65c8b46c54e3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: dd7c184d-6ea0-4fa8-b1a7-a33403c00ebb
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b034bbfe-10b1-405e-8ae0-134f1aa80bcf
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ade7c0a7-b120-4032-a4cf-a8da761b2ba9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 17426232-cb53-4e86-88e6-f2867c7478a4
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a5a157d0-1b0f-4d2e-883c-b9854aaffe67
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: caca9ca9-3a84-450c-8de9-6b75a46a2ec6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a7cbe0ea-a652-469c-9829-45da2ba94bee
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: cc4c9724-0b5c-49cb-9f7a-8c84e66ae86d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2a7b2348-30c8-45cc-8ba9-41fbe0a44689
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 056b2555-01cb-4589-9937-53b1a58afac1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 48783642-197d-4479-9c6b-0879dec6d1de
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1c03f6ed-9ae1-420c-aa24-0fa3238267ff
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1c03f6ed-9ae1-420c-aa24-0fa3238267ff
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2d26c7d1-64a7-46fc-84b3-31fc59639f3c
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2d26c7d1-64a7-46fc-84b3-31fc59639f3c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 58ec9966-06c7-4f3b-87b4-a19b79bc688e
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 58ec9966-06c7-4f3b-87b4-a19b79bc688e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6e3aa5fc-b73c-4e34-a07b-3bdf9f3ae950
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6e3aa5fc-b73c-4e34-a07b-3bdf9f3ae950
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e27e86a3-485b-4662-b493-a39af6e6a82d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e27e86a3-485b-4662-b493-a39af6e6a82d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b9cb4378-4bbe-4a87-a5a2-4cf50fd14cc8
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b9cb4378-4bbe-4a87-a5a2-4cf50fd14cc8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 018dc01b-4edb-4aee-a3da-3b455bb33df3
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 018dc01b-4edb-4aee-a3da-3b455bb33df3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 55138642-f7a6-4871-a1c2-fa9b203a48d5
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 55138642-f7a6-4871-a1c2-fa9b203a48d5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a1f9868c-86b4-4a3f-9ebc-70398e5224cf
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a1f9868c-86b4-4a3f-9ebc-70398e5224cf
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7d3a8da8-f81a-44c5-97ac-53793c51ee36
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7d3a8da8-f81a-44c5-97ac-53793c51ee36
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c79fbd0c-9b01-4ec8-9ba8-8809895eca07
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c79fbd0c-9b01-4ec8-9ba8-8809895eca07
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 18de66e0-a578-4a53-a69d-8ec41302e2e2
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 18de66e0-a578-4a53-a69d-8ec41302e2e2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7bad85d4-943f-4cc1-b469-3b8aad791c6f
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7bad85d4-943f-4cc1-b469-3b8aad791c6f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 22b7313a-7f3e-43f9-a66a-658336590d35
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 22b7313a-7f3e-43f9-a66a-658336590d35
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 23aa1e11-c94a-4dcb-8baf-6aebb1ec8a4a
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 23aa1e11-c94a-4dcb-8baf-6aebb1ec8a4a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 285aba2f-9c2d-4d71-b5a6-c1100aa6a5dd
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 285aba2f-9c2d-4d71-b5a6-c1100aa6a5dd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7bf3d8c3-f559-41f4-883f-d2984153ce50
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7bf3d8c3-f559-41f4-883f-d2984153ce50
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 172a43ca-ed5a-4fd7-9462-645db02e4e68
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 172a43ca-ed5a-4fd7-9462-645db02e4e68
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c311ae9a-9da8-4c15-b9db-598bd5eaf6b1
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c311ae9a-9da8-4c15-b9db-598bd5eaf6b1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 89564959-2a0d-41d1-936e-e131f32aac32
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 89564959-2a0d-41d1-936e-e131f32aac32
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8b2702a3-2dc9-49de-8ddf-c517ad33c274
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8b2702a3-2dc9-49de-8ddf-c517ad33c274
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e8355e17-0981-44e5-87ff-09243709ec92
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e8355e17-0981-44e5-87ff-09243709ec92
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 61b56c77-528f-4549-95b0-6f4b8d5b9ac3
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 61b56c77-528f-4549-95b0-6f4b8d5b9ac3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 70c0a95d-6b68-4ca1-9bb7-47fd13e41cd6
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 70c0a95d-6b68-4ca1-9bb7-47fd13e41cd6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: dea62ca2-d5a7-4be4-ac80-23ef0e873bd1
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: dea62ca2-d5a7-4be4-ac80-23ef0e873bd1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a4b70fd8-767b-4531-a11b-7f29bf8f152c
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a4b70fd8-767b-4531-a11b-7f29bf8f152c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7665d36a-0cb6-4825-a956-d4429d8960b8
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7665d36a-0cb6-4825-a956-d4429d8960b8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 22b3adff-bff5-40fb-86df-3a76d18bf24d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 22b3adff-bff5-40fb-86df-3a76d18bf24d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 44556c30-ce91-488f-81fc-1ef74c0c88b1
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 44556c30-ce91-488f-81fc-1ef74c0c88b1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: dfd60943-9208-4563-8f7a-fcf766fa027c
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: dfd60943-9208-4563-8f7a-fcf766fa027c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: d26905ae-37c2-4b39-a974-9c78969746c1
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: d26905ae-37c2-4b39-a974-9c78969746c1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: df7faf1a-b8dd-4eed-b0ca-41c143eea511
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: df7faf1a-b8dd-4eed-b0ca-41c143eea511
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 3f70b21c-1545-4876-a33e-02de314a9889
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 3f70b21c-1545-4876-a33e-02de314a9889
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 61eb8113-68ac-4dda-a0b8-cbc86d85c3e0
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 39c4aaf3-d559-4ebf-87eb-cbe6fae3dab8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 69bea87f-6a4a-4bed-a8de-f2feee306937
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8887b8fd-c29c-4cf4-a0d7-01d5fdfd8c12
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e3072ad3-61cf-4c6b-b69c-d31609d680d0
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: da3b441f-f506-479f-bf80-a984069b2c94
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c274c272-149e-4644-ba86-5ddcea28c163
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d1a07b47-aca1-4adf-a472-a93dfa59b375
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 49a35ff4-69dd-49e8-9de0-c2d887f582b1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c878fefb-9e98-475c-8da7-e06663ae7691
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ee1d4eb3-1a91-4cc3-8037-6675279d52e3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d82d16da-c31d-4508-afe5-ef1db6e5bedd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 64f740ae-f563-429c-beb6-65762387b5a9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0831aefb-0554-4539-ad67-50b14d9b8ef5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8698ad4e-b605-44ce-aaa4-90651b184a9e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 066d386a-49ae-43ff-8d8d-03e84c0cbf39
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8ac7f618-23a5-49af-b8cc-c59111819809
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8486c22a-4692-40b4-85f3-ec51a12c4ae1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: cf6f28ca-5fcc-4c48-95c8-4bd6791586df
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5f8c3191-66ea-4d27-8881-7585aa3205d9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 101242ef-6d0f-4a57-bb97-c3471cd3711a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 4d940265-8c44-4a17-9d6c-efff0e1dd30c
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 4d940265-8c44-4a17-9d6c-efff0e1dd30c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: dd33178e-e6a3-4f0c-bf9d-9e20a8434596
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: dd33178e-e6a3-4f0c-bf9d-9e20a8434596
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e5b951bb-d4f9-407d-853c-fe545e313203
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e5b951bb-d4f9-407d-853c-fe545e313203
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b96cc54f-2a53-401e-93cb-96c0ba456158
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b96cc54f-2a53-401e-93cb-96c0ba456158
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 59b57874-f04d-4d16-a576-ce0878732c06
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 59b57874-f04d-4d16-a576-ce0878732c06
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7e50195b-d955-4280-a147-0987d1a9e526
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7e50195b-d955-4280-a147-0987d1a9e526
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1a52ec83-e0f7-4226-bfeb-943fc28418f7
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1a52ec83-e0f7-4226-bfeb-943fc28418f7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c92fce3b-fe20-4870-89ff-779f1944058d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c92fce3b-fe20-4870-89ff-779f1944058d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 25b20224-70a2-4d1f-9896-ab6afe62ee34
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 25b20224-70a2-4d1f-9896-ab6afe62ee34
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1ac6ab2d-f99d-4041-a1d1-09b21bd7b13b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1ac6ab2d-f99d-4041-a1d1-09b21bd7b13b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2497473c-934b-40b0-8bd6-2bdef142de2b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2497473c-934b-40b0-8bd6-2bdef142de2b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 696d16cf-7092-4592-ae47-949e5a2d9dc5
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 696d16cf-7092-4592-ae47-949e5a2d9dc5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: da67149b-e15a-4dd5-9301-9ce9e7b0d4b3
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: da67149b-e15a-4dd5-9301-9ce9e7b0d4b3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a4a3ee28-f012-43ca-8d58-f437a9c363a1
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a4a3ee28-f012-43ca-8d58-f437a9c363a1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 01767d3f-0a52-4813-8c6b-1ad1c7694751
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 01767d3f-0a52-4813-8c6b-1ad1c7694751
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 84296d40-47b1-4b9d-a4ef-5b29b101947d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 84296d40-47b1-4b9d-a4ef-5b29b101947d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 714752ed-00ed-449f-b0f1-a920945d2721
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 714752ed-00ed-449f-b0f1-a920945d2721
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b68d7e05-8c63-4580-8466-a225e1377971
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b68d7e05-8c63-4580-8466-a225e1377971
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 59c0cf94-07e1-45db-8f9c-6d871230b425
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 59c0cf94-07e1-45db-8f9c-6d871230b425
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c0b951eb-4d10-4dd5-b85d-3ad17d65e157
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c0b951eb-4d10-4dd5-b85d-3ad17d65e157
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b00d738b-4b87-4a13-8b6f-0de2ac90506b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b00d738b-4b87-4a13-8b6f-0de2ac90506b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: cd61dd1d-fcf5-4d59-bdd1-0738a2cf586d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: cd61dd1d-fcf5-4d59-bdd1-0738a2cf586d
#
# ...
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e0eea9af-8acd-4099-89af-efe67164e633
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: aaafb115-bcfa-492c-bcc4-7cb8f77d9aba
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: aaafb115-bcfa-492c-bcc4-7cb8f77d9aba
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 49eaa572-ef14-45c2-898d-4577f63d0e43
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 49eaa572-ef14-45c2-898d-4577f63d0e43
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 85b1ee91-12ee-4bd6-b0c3-0fcca3e7d7fa
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 85b1ee91-12ee-4bd6-b0c3-0fcca3e7d7fa
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b967eb55-512a-467c-be93-92cd86a56802
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b967eb55-512a-467c-be93-92cd86a56802
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 43bd2519-ac04-4191-876e-18dbf2299bdc
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 43bd2519-ac04-4191-876e-18dbf2299bdc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: eb642ac4-1b79-4482-8b69-f954790f3665
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: eb642ac4-1b79-4482-8b69-f954790f3665
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: ae699184-0621-4e73-97a0-3d4058e610a6
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: ae699184-0621-4e73-97a0-3d4058e610a6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2fd493d7-178b-47db-b231-85afdbd89715
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2fd493d7-178b-47db-b231-85afdbd89715
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c15ecb87-3dea-4016-8822-63c6bff71b16
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c15ecb87-3dea-4016-8822-63c6bff71b16
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 05f216ce-653f-4eea-8b41-4889c6d189e0
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 05f216ce-653f-4eea-8b41-4889c6d189e0
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 30b6e7e6-69ed-4664-a02d-9ad9af9640cf
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 30b6e7e6-69ed-4664-a02d-9ad9af9640cf
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: d6f75930-f59d-43da-8206-763466c0a693
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: d6f75930-f59d-43da-8206-763466c0a693
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f6cfaba1-4427-4c2a-9719-30c34e64e1a2
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f6cfaba1-4427-4c2a-9719-30c34e64e1a2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8d433b29-a642-44a0-9f33-0b025aa68f35
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8d433b29-a642-44a0-9f33-0b025aa68f35
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 685e581f-4b99-44e2-a8be-e52f6b56ee00
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 685e581f-4b99-44e2-a8be-e52f6b56ee00
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 47a6aadb-aca8-4e02-9a5f-31ff1973d58f
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 47a6aadb-aca8-4e02-9a5f-31ff1973d58f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a3b50daa-0c5a-499c-8040-3a47d09d854b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a3b50daa-0c5a-499c-8040-3a47d09d854b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1f0bb1c7-c776-49b9-b449-790caa19be44
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1f0bb1c7-c776-49b9-b449-790caa19be44
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: dce3e730-1cf4-438f-a050-67dcdc9172f4
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: dce3e730-1cf4-438f-a050-67dcdc9172f4
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 626c58c3-acee-46f1-b1c4-5d8a9056abae
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 626c58c3-acee-46f1-b1c4-5d8a9056abae
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e7f09c9a-f948-4e50-baf0-5391731bba32
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e7f09c9a-f948-4e50-baf0-5391731bba32
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: fbc39d71-125f-4eea-a4de-dbc35f6bc37a
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: fbc39d71-125f-4eea-a4de-dbc35f6bc37a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 379833f8-59dd-49d9-86b5-8ac5db42266b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 379833f8-59dd-49d9-86b5-8ac5db42266b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1f83c03e-987b-4792-bbdb-21f78bd7f47d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1f83c03e-987b-4792-bbdb-21f78bd7f47d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 699c8d89-389d-40dc-8551-8a06fa0102a7
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 699c8d89-389d-40dc-8551-8a06fa0102a7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1a6708c2-cc56-404c-a0e2-ea93123ed3a8
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1a6708c2-cc56-404c-a0e2-ea93123ed3a8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7dd0d7f6-19c0-46cb-a438-2e69b435500d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7dd0d7f6-19c0-46cb-a438-2e69b435500d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27824\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.

# %% [markdown]
# **Create plot**

# %%
from matplotlib.ticker import MultipleLocator

fig, ax = plt.subplots()
min_depth = 0.
max_depth = 0.
bound = 'outbound'

water_transport_capacity_performances = inbound_water_transport_capacity_performances
if bound == 'outbound':
    water_transport_capacity_performances = outbound_water_transport_capacity_performances
    
for waterway_length in water_transport_capacity_performances.keys():
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[waterway_length].items() if v > -1}
    
    filtered_dredging_performance = {k: -dredging_performances[waterway_length][k] for k in filtered_water_transport_capacity_performance}
    new_min_depth = np.min(list(filtered_water_transport_capacity_performance.keys()))
    new_max_depth = np.max(list(filtered_water_transport_capacity_performance.keys())) 
    if new_min_depth < min_depth:
        min_depth = new_min_depth
    if new_max_depth > max_depth:
        max_depth = new_max_depth
    norm = mpl.colors.Normalize(min_depth,max_depth)
    cmap = plt.get_cmap('bwr')
    
    if min_depth >= 0.:
        cmap = mcolors.LinearSegmentedColormap.from_list(
            'bwr_truncated',
            cmap(np.linspace(0.5, 1, 256))
        )
        norm = mpl.colors.Normalize(new_min_depth-1.,max_depth)

for waterway_length in water_transport_capacity_performances.keys():
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[waterway_length].items() if v > -1}
    filtered_dredging_performance = {k: -dredging_performances[waterway_length][k] for k in filtered_water_transport_capacity_performance}

    x_vals = list(filtered_water_transport_capacity_performance.values())
    #y_vals = list(filtered_dredging_performance.values())
    y_vals = np.array(list(filtered_dredging_performance.values())) / 1e6
    
    line, = ax.plot(
        x_vals,
        y_vals,
        label=f'L={waterway_length/1000} km ({bound})',
        zorder=-1,
    )
    cbar = ax.scatter(
        x_vals,
        y_vals,
        c=filtered_dredging_performance.keys(),
        cmap=cmap,
        norm = norm,
        edgecolor=line.get_color(),
    )
    
    ax.set_xlabel('Waterway capacity\n[nr. of vessels]')
    #ax.set_ylabel('Dredging volume [m3] / dredging activities')
    # Dredging (pijl naar beneden)
    ax.annotate(
        'Dredging',
        xy=(-0.12, 0.10),       # punt waar pijl naartoe wijst
        xytext=(-0.12, 0.35),   # waar tekst staat
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

# Sedimentation (pijl naar boven)
    ax.annotate(
        'Sedimentation',
        xy=(-0.12, 0.90),
        xytext=(-0.12, 0.65),
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    ax.set_ylim(-4, 4)
    ax.yaxis.set_major_locator(MultipleLocator(0.5))

ax.legend()
fig.colorbar(cbar, label='Added depth [m]')

fig.savefig('figures/Capacity_changing_waterway_lengths_outbound.png', dpi=300)

plt.show()
