# %%
# package(s) used for creating and geo-locating the graph
import networkx as nx
from pyproj import Geod
from shapely.geometry import Point, LineString
from opentnsim import graph

# package(s) related to the hydrodynamics and tidal windows
import xarray as xr

# load OpenTNSim modules
from opentnsim.core import Identifiable, Movable 
from opentnsim.core.vessel_properties import VesselProperties
from opentnsim.graph import HasMultiDiGraph
from opentnsim.vessel_traffic_service import VesselTrafficService
from opentnsim.port.mixins.port import IsPort, HasPortAccess
from opentnsim.port.mixins.terminal import IsTerminal, HasTerminal
from opentnsim.port.mixins.berth import IsJetty, IsQuay
from opentnsim.port.mixins.anchorage_area import IsAnchorage, PassesAnchorage
from opentnsim.port.mixins import tidal_accessibility
from opentnsim.port.mixins.tidal_accessibility import HasDraughtRestrictions
from opentnsim.port.rule_constructor import vessel_characteristics, vessel_direction, vessel_type
from opentnsim.port.tidal_window_constructor import vessel_specifications, \
                                                    vertical_tidal_window_specifications, \
                                                    vertical_tidal_window_input, \
                                                    horizontal_tidal_window_specifications, \
                                                    horizontal_tidal_window_method, \
                                                    horizontal_tidal_window_input, \
                                                    tidal_period, \
                                                    accessibility, \
                                                    NetworkProperties

# package(s) related to the simulation (creating the vessel, running the simulation)
import datetime
import simpy
import opentnsim

# package(s) needed for inspecting the output
import pandas as pd
import numpy as np
import scipy

# package(s) for plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.colors as mcolors

print("This notebook is executed with OpenTNSim version {}".format(opentnsim.__version__))
# Out:
# This notebook is executed with OpenTNSim version 1.3.7

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### 1. Constants

# %%
# Environment  
simulation_start = datetime.datetime(2024, 1, 1, 0, 0, 0)
simulation_stop = datetime.datetime(2024, 1, 3, 0, 0, 0)
timestep = pd.Timedelta(minutes=5)
time_series = pd.date_range(simulation_start,simulation_stop,freq=timestep)

# %%
# initialize geodetic calculator with WGS84 ellipsoid
geod = Geod(ellps="WGS84")

# %%
# make your preferred Vessel class out of available mix-ins.
Vessel = type(
    "Vessel", 
    (HasPortAccess,
     HasTerminal,
     PassesAnchorage,
     HasDraughtRestrictions,
     HasMultiDiGraph,
     Identifiable, # allows to give the object a name and a random ID,
     Movable,      # allows the object to move, with a fixed speed, while logging this activity
     VesselProperties,
    ), 
    {}
)

# %%
def mission(env, vessel):
    """
    Method that defines the mission of the vessel. 
    
    In this case: 
        keep moving along the path until its end point is reached
    """
    yield from vessel.move()

# %% [markdown]
# #### 2. Create simulation
# We define a function

# %%
def create_and_run_env_with_tidal_window(
    original_waterway_depth,
    added_depth,
    waterway_length, 
    ukc_percentage,
    tidal_range_sea,
    tidal_period,
    tidal_amplication,
    tidal_propagation_speed,
    interarrival_time,
    vessel_beam,
    vessel_draught,
    vessel_speed,
    vessel_loading_factor,
):
    env = simpy.Environment(initial_time=simulation_start.timestamp())
    env.simulation_start = simulation_start
    env.simulation_stop = simulation_stop
    env.epoch = simulation_start

    # Graph
    coordinates_sea = (0,0)
    coordinates_port = geod.fwd(coordinates_sea[0], coordinates_sea[1], 90 ,waterway_length) # East from Point 0
    coordinates_waterway = {"Sea": (coordinates_sea[0], coordinates_sea[1]),
                            "Port basin": (coordinates_port[0], coordinates_port[1]),}
    FG = nx.DiGraph()
    for name, coordinate in coordinates_waterway.items():
        FG.add_node(name, geometry=Point(coordinate[0], coordinate[1]))
    edges = [("Sea", "Port basin"), ("Port basin", "Sea")]
    for edge in edges:
        FG.add_edge(edge[0], edge[1], geometry=LineString([Point(coordinates_sea),Point(coordinates_port[:-1])]), weight=1, length_m=waterway_length)
    env.graph = FG

    # Hydrodynamic data
    waterway_depth = original_waterway_depth + added_depth
    hydrodynamic_data = xr.Dataset()
    tidal_phase_shift = pd.Timedelta(seconds=waterway_length/tidal_propagation_speed)
    tidal_water_level_sea = (tidal_range_sea/2)*np.sin(2*np.pi*((time_series-simulation_start)/(tidal_period*pd.Timedelta(hours=1))))
    amplification_factor = ((tidal_amplication-(1/10000))*waterway_length+1)
    tidal_water_level_port = amplification_factor*(tidal_range_sea/2)*np.sin(2*np.pi*((time_series-simulation_start-tidal_phase_shift)/(tidal_period*pd.Timedelta(hours=1))))
    water_level_data = xr.DataArray(data=[tidal_water_level_sea,tidal_water_level_port],coords={'STATION':FG.nodes,'TIME':time_series})
    MBLs = waterway_depth*np.ones(len(time_series))
    MBL_data = xr.DataArray(data=[MBLs,MBLs],coords={'STATION':FG.nodes,'TIME':time_series})
    hydrodynamic_data['Water level'] = water_level_data
    hydrodynamic_data['MBL'] = MBL_data
    vessel_traffic_service = VesselTrafficService(hydrodynamic_data = hydrodynamic_data)
    env.vessel_traffic_service = vessel_traffic_service
    
    network_properties = NetworkProperties()
    for index, node in enumerate(FG.nodes):
        FG.nodes[node]['Vertical tidal restriction'] = {}
        vertical_tidal_window_inputs = []
    
        vessel_specification = vessel_specifications({vessel_characteristics.min_ge_Draught: 0.0},'x',vessel_direction.inbound)
        window_specification = vertical_tidal_window_specifications(ukc_s = 0.,
                                                                    ukc_p = ukc_percentage/100,
                                                                    fwa = 0.,)
        
        vertical_tidal_window_inputs.append(vertical_tidal_window_input(vessel_specifications = vessel_specification,
                                                                        window_specifications = window_specification))

        vessel_specification = vessel_specifications({vessel_characteristics.min_ge_Draught: 0.0},'x',vessel_direction.outbound)
        window_specification = vertical_tidal_window_specifications(ukc_s = 0.,
                                                                    ukc_p = ukc_percentage/100,
                                                                    fwa = 0.,)
        
        vertical_tidal_window_inputs.append(vertical_tidal_window_input(vessel_specifications = vessel_specification,
                                                                        window_specifications = window_specification))
    
        network_properties.append_vertical_tidal_restriction_to_network(env.graph,node,vertical_tidal_window_inputs)
        
    # Infrastructure
    max_draught = np.max([vessel_draught,vessel_draught+vessel_draught*vessel_loading_factor/100])
    always_sufficient_depth = max_draught + tidal_range_sea + (ukc_percentage/100)*max_draught + 0.5 # m (not important, should be 100% accessible) 

    port = IsPort(env=env, name = "Port", port_entry_nodes=['Sea'])
    anchorage = IsAnchorage(env=env, capacity=20, name = 'Anchorage', node = 'Sea', depth = always_sufficient_depth, geometry=env.graph.nodes['Sea']['geometry'], port = port)
    jetty = IsJetty(env=env,length=300, depth=always_sufficient_depth, name='Jetty',node='Port basin')
    terminal = IsTerminal(env=env, name = 'Terminal', berths=[jetty], port = port)

    # Vessel
    path = nx.dijkstra_path(env.graph, "Sea", "Port basin")
    data_vessel = {
        "env": env,                                       # needed for simpy simulation
        "name": "Vessel 1",                               # required by Identifiable
        "geometry": env.graph.nodes[path[0]]['geometry'], # required by Locatable
        "route": path,                                    # required by Routeable
        "v": vessel_speed,                                # required by Movable, 1 m/s to check if the distance is covered in the expected time
        "bound": 'inbound',
        "terminal": terminal,
        "berthing_time":15, #minutes
        "loading_time": 12, #hours
        "deberthing_time":5, #minutes,
        "next_destination":"Sea",
        "type":"tanker",
        "loading_factor":vessel_loading_factor,
        "L":vessel_beam*8,
        "B":vessel_beam,
        "T":vessel_draught,
    } 
    vessel = Vessel(**data_vessel)
    vessel.mission = env.process(mission(env, vessel))
    env.run()
    try:
        inbound_window_lengths = [(window[1]-window[0]).total_seconds() for window in vessel.tidal_window_calculations[0]['vertical_tidal_windows']]
        inbound_window_length = scipy.stats.mode(inbound_window_lengths)[0]
        inbound_window_length = np.min([inbound_window_length,pd.Timedelta(hours=tidal_period).total_seconds()])
        if pd.isna(inbound_window_length):
            inbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    except:
        inbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    try:
        outbound_window_lengths = [(window[1]-window[0]).total_seconds() for window in vessel.tidal_window_calculations[1]['vertical_tidal_windows']]
        outbound_window_length = scipy.stats.mode(outbound_window_lengths)[0]
        outbound_window_length = np.min([outbound_window_length,pd.Timedelta(hours=tidal_period).total_seconds()])
        if pd.isna(outbound_window_length):
            outbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    except:
        outbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    inbound_vessel_capacity = np.floor(inbound_window_length/interarrival_time.total_seconds())
    outbound_vessel_capacity = np.floor(outbound_window_length/interarrival_time.total_seconds())
    dredging = added_depth*waterway_length*(3*vessel.B)
    return inbound_vessel_capacity, outbound_vessel_capacity, dredging, vessel

# %% [markdown]
# #### 3. Run simulation

# %%
original_waterway_depth = 11.0

inbound_water_transport_capacity_performances = {}
outbound_water_transport_capacity_performances = {}
dredging_performances = {}
# Looping over waterway length
for tidal_range in [0.5, 1, 2, 5]:
    inbound_water_transport_capacity_performance = {}
    outbound_water_transport_capacity_performance = {}
    dredging_performance = {}

    # looping over waterway depth
    for added_depth in np.arange(-2, 2, 0.1):
        waterway_depth = original_waterway_depth + added_depth
        inbound_waterway_capacity_for_design_vessel, outbound_waterway_capacity_for_design_vessel, dredging, vessel = create_and_run_env_with_tidal_window(
            original_waterway_depth = original_waterway_depth, #in m (better known as NGD: nautical guaranteed depth or MBL: maintained bed level)
            added_depth = added_depth,
            waterway_length = 25000, #in m 
            ukc_percentage = 10.0, #in % of draught (10% of draught is common)
            tidal_range_sea = tidal_range, #in m
            tidal_period = 12.5, # hrs (semi-diurnal tide, most common tide)
            tidal_amplication = 1.0 / 10000, #in m^-1 (amplification factor per 10 km: 1.0 = not damping / amplifying)
            tidal_propagation_speed = np.sqrt(9.81*original_waterway_depth), #15.0, # m/s (could be calculated using np.sqrt(9.81*waterway_depth))
            interarrival_time = pd.Timedelta(minutes=20),
            vessel_draught = 10.0, #in m
            vessel_beam = 30,
            vessel_speed = 6.0, # m/s (common speed in confined waterways)
            vessel_loading_factor = -30.0, #in % of draught (+ = loading when export terminal, - = unloading when import terminal, 30% is common)
        )
        inbound_water_transport_capacity_performance[added_depth] = int(inbound_waterway_capacity_for_design_vessel)
        outbound_water_transport_capacity_performance[added_depth] = int(outbound_waterway_capacity_for_design_vessel)
        dredging_performance[added_depth] = dredging
        
    inbound_water_transport_capacity_performances[tidal_range] = inbound_water_transport_capacity_performance
    outbound_water_transport_capacity_performances[tidal_range] = outbound_water_transport_capacity_performance
    dredging_performances[tidal_range] = dredging_performance
# Out:
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 81f66fd4-fef1-455d-a52d-772b418bb3ed
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c615f8b6-9b1a-4751-92ff-b3a417e92789
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e0566e8e-0d31-40fc-a39e-024019c90399
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: acaee74e-52df-4fc9-97d5-d6e760d372ef
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 6e319f78-d55e-4f25-bb52-50b422aebc06
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b725005e-5a20-4169-a483-a0dad957164b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f1438266-c60b-4c4f-9c70-565606887c88
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a2746683-a595-4a4f-9616-b4da9bdbd6a9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 672f3c83-a677-4979-a086-81ac6fdf03cc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ab237c5a-59da-4600-937d-295a1367706a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2c310363-d9b2-46cb-834a-e0e9b21d194c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 050763d7-d24e-4fa2-ab22-af01746d31b8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 65057e35-a07c-429d-ae5b-7d3c8fd4790f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8281c717-6d38-4bbd-aa43-51f3bad224d1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f6bdf25d-617f-4678-8052-ab3caf5a29b5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3f8906e0-4ebd-4ec6-9371-996a9094e65d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b5851dff-be17-4d98-8a44-065bf03436f5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f97c5b67-8e60-4a82-a284-4f97e3c3af39
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f949cb41-99f3-4115-9b01-98bff9b0a971
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 256778c2-4514-4886-b964-fb6d29ce69d9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: fd11ff98-0fdc-4950-a674-1f02b04d7d8e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5b06d49b-2370-42bc-8e1e-c36ea73b6f69
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a986aef7-41da-48ca-a4c2-fe1b89dcb882
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2835ad98-691d-41b3-b4db-f9fad606df44
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e5d493b8-b63f-4854-8571-09a7f3fddf2e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0b5189d4-ddd5-4dce-b5d7-b652c8d511c1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 6ec6aff8-487b-42fa-b167-02b5f0a3945e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 540c3023-320d-44aa-909d-523f65af1d6c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: aabec11d-6db0-4253-9e25-fd8f210e0c2d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 929d731a-3770-4f1d-9607-cfd1b6493838
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5ae0bb86-b689-4929-ada8-9f11a432d432
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 7fe47a1e-95c6-49b5-8e54-6f29744d9078
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4b8780b8-4349-45dc-8285-88df3a628436
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 45499cdf-37d1-49db-8e00-d6ae0d7a2a16
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 95fdcb10-062f-4022-8312-032fb4893569
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 26fd98d2-29b7-45e1-921c-5493993ef5ea
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4f6dd976-ab0f-458a-843f-6f31382a5186
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 87f3738f-97e2-42c7-a0ca-77613106cdfe
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2528b451-1908-4531-a4cf-2b77dc24e475
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c65de9fb-2fd1-4089-bf81-53ba99cc715b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 094f989e-3a47-4d6d-9aba-2b83267b392f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 77b541ad-b4db-4e28-9fa4-512e2173f524
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4fb95cfc-0ac8-4865-8031-d7d795678eff
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: aacfd222-60f2-41c0-8a6c-cb83b7dd5607
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 720740e2-54f4-4cf4-8938-f9ea6ecd8d30
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.

# %%
from matplotlib.ticker import MultipleLocator

fig, ax = plt.subplots()
min_depth = 0.
max_depth = 0.
bound = 'inbound'

water_transport_capacity_performances = inbound_water_transport_capacity_performances
if bound == 'outbound':
    water_transport_capacity_performances = outbound_water_transport_capacity_performances
    
for tidal_range in water_transport_capacity_performances.keys():
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[tidal_range].items() if v > -1}
    
    filtered_dredging_performance = {k: -dredging_performances[tidal_range][k] for k in filtered_water_transport_capacity_performance}
    new_min_depth = np.min(list(filtered_water_transport_capacity_performance.keys()))
    new_max_depth = np.max(list(filtered_water_transport_capacity_performance.keys())) 
    if new_min_depth < min_depth:
        min_depth = new_min_depth
    if new_max_depth > max_depth:
        max_depth = new_max_depth
    norm = mpl.colors.Normalize(min_depth,max_depth)
    cmap = plt.get_cmap('coolwarm')
    
    if min_depth >= 0.:
        cmap = mcolors.LinearSegmentedColormap.from_list(
            'coolwarm',
            cmap(np.linspace(0.5, 1, 256))
        )
        norm = mpl.colors.Normalize(new_min_depth-1.,max_depth)

# for tidal_range in water_transport_capacity_performances.keys():
#     filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[tidal_range].items() if v > -1}
#     filtered_dredging_performance = {k: -dredging_performances[tidal_range][k] for k in filtered_water_transport_capacity_performance}

for i, tidal_range in enumerate(water_transport_capacity_performances.keys()):
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[tidal_range].items() if v > -1}
    filtered_dredging_performance = {k: -dredging_performances[tidal_range][k] for k in filtered_water_transport_capacity_performance}

    
    x_vals = list(filtered_water_transport_capacity_performance.values())
    #y_vals = list(filtered_dredging_performance.values())
    y_vals = np.array(list(filtered_dredging_performance.values())) / 1e6

    line_styles = ['-', '--', ':', '-.'] 
    line_style = line_styles[i % len(line_styles)]  # Afwisselen van lijnstijlen
    
    line, = ax.plot(
        x_vals,
        y_vals,
        label=f'tidal range = {tidal_range} m ({bound})',
        zorder=-1,
        linestyle = line_style,
        color = 'black',
    )
    cbar = ax.scatter(
        x_vals,
        y_vals,
        c=filtered_dredging_performance.keys(),
        cmap=cmap,
        norm = norm,
        edgecolor=line.get_color(),
    )
    
    ax.set_xlabel('Waterway capacity\n[nr. of vessels]')
    #ax.set_ylabel('Dredging volume [m3] / dredging activities')
    # Dredging (pijl naar beneden)

    fig.subplots_adjust(left=0.20)
    fig.text(
    0.01, 0.5,  # x, y positie (links van figuur)
    'Dredging volume [10⁶ m³]',  # jouw titel
    va='center',
    rotation='vertical',
    fontsize=12
    )
        
    
    ax.annotate(
        'Dredging',
        xy=(-0.2, 0.10),       # punt waar pijl naartoe wijst
        xytext=(-0.2, 0.35),   # waar tekst staat
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    # Sedimentation (pijl naar boven)
    ax.annotate(
        'Sedimentation',
        xy=(-0.2, 0.90),
        xytext=(-0.2, 0.65),
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    ax.set_ylim(-5, 5)
    ax.yaxis.set_major_locator(MultipleLocator(0.5))

    ax.set_title(
        f'Channel vessel capacity for various channel depths\n'
        f'(Natural channel depth = {original_waterway_depth} m, vessel draught = {vessel.T} m)'
    )

ax.legend()
fig.colorbar(cbar, label='Added depth [m]')

fig.savefig('figures/Capacity_changing_tidal_range_inbound.png', dpi=300)

plt.show()

# %% [markdown]
# Outbound

# %% [markdown]
# **run simulation**

# %%
original_waterway_depth = 11.0

inbound_water_transport_capacity_performances = {}
outbound_water_transport_capacity_performances = {}
dredging_performances = {}
# Looping over waterway length
for tidal_range in [0.5, 1, 2, 5]:
    inbound_water_transport_capacity_performance = {}
    outbound_water_transport_capacity_performance = {}
    dredging_performance = {}

    # looping over waterway depth
    for added_depth in np.arange(-2, 2, 0.1):
        waterway_depth = original_waterway_depth + added_depth
        inbound_waterway_capacity_for_design_vessel, outbound_waterway_capacity_for_design_vessel, dredging, vessel = create_and_run_env_with_tidal_window(
            original_waterway_depth = original_waterway_depth, #in m (better known as NGD: nautical guaranteed depth or MBL: maintained bed level)
            added_depth = added_depth,
            waterway_length = 25000, #in m 
            ukc_percentage = 10.0, #in % of draught (10% of draught is common)
            tidal_range_sea = tidal_range, #in m
            tidal_period = 12.5, # hrs (semi-diurnal tide, most common tide)
            tidal_amplication = 1.0 / 10000, #in m^-1 (amplification factor per 10 km: 1.0 = not damping / amplifying)
            tidal_propagation_speed = 15.0, # m/s (could be calculated using np.sqrt(9.81*waterway_depth))
            interarrival_time = pd.Timedelta(minutes=20),
            vessel_draught = 8.0, #in m
            vessel_beam = 30,
            vessel_speed = 6.0, # m/s (common speed in confined waterways)
            vessel_loading_factor = 30.0, #in % of draught (+ = loading when export terminal, - = unloading when import terminal, 30% is common)
        )
        inbound_water_transport_capacity_performance[added_depth] = int(inbound_waterway_capacity_for_design_vessel)
        outbound_water_transport_capacity_performance[added_depth] = int(outbound_waterway_capacity_for_design_vessel)
        dredging_performance[added_depth] = dredging
        
    inbound_water_transport_capacity_performances[tidal_range] = inbound_water_transport_capacity_performance
    outbound_water_transport_capacity_performances[tidal_range] = outbound_water_transport_capacity_performance
    dredging_performances[tidal_range] = dredging_performance
# Out:
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: ce650690-932a-454c-9a1b-1a70629ecc2a
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: ce650690-932a-454c-9a1b-1a70629ecc2a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: ce38ea9a-124d-46bc-a56d-99b1169781cf
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: ce38ea9a-124d-46bc-a56d-99b1169781cf
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 78b53788-b78c-4553-a730-8c3c55c8df8f
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 78b53788-b78c-4553-a730-8c3c55c8df8f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2d2859f2-281c-4bd1-8fa1-7d938bdc1743
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2d2859f2-281c-4bd1-8fa1-7d938bdc1743
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: bde59a19-91b6-44e8-9af8-af4316920689
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: bde59a19-91b6-44e8-9af8-af4316920689
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c0ab85e7-8f5b-45dc-8ca2-18b42632fada
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c0ab85e7-8f5b-45dc-8ca2-18b42632fada
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e8bff5a2-9a3b-40dc-919b-509a6129551c
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e8bff5a2-9a3b-40dc-919b-509a6129551c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6aa85dc0-4d38-4ca3-b3ba-2ccc3eea50e1
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6aa85dc0-4d38-4ca3-b3ba-2ccc3eea50e1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: eec569fb-d4a4-4ba6-bbfb-33f191283934
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: eec569fb-d4a4-4ba6-bbfb-33f191283934
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 3573b1af-1a1e-4030-8dea-7f42f8d637b7
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 3573b1af-1a1e-4030-8dea-7f42f8d637b7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 0c510632-13c4-4f31-8dee-d57bd5280c03
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 0c510632-13c4-4f31-8dee-d57bd5280c03
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 714b8a62-795e-4b62-bc18-0e059289c661
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 714b8a62-795e-4b62-bc18-0e059289c661
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 82c87db4-7ed5-4c9f-bacf-b5af06ec65d5
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 82c87db4-7ed5-4c9f-bacf-b5af06ec65d5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8c4c331b-b668-48c2-9559-804b4309271f
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8c4c331b-b668-48c2-9559-804b4309271f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 9af32515-44bc-41a3-ba0d-64afb62cfc30
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 9af32515-44bc-41a3-ba0d-64afb62cfc30
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 5d72f015-428d-4a72-8894-9d33b84560ea
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 5d72f015-428d-4a72-8894-9d33b84560ea
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 459d3da3-29d7-4f6e-bd9b-8b6f9038851c
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 459d3da3-29d7-4f6e-bd9b-8b6f9038851c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 54bd2904-57b3-4e0f-8ce0-852065ef5936
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 54bd2904-57b3-4e0f-8ce0-852065ef5936
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 4a3c3a8f-042b-4139-86a4-f01466e290a2
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 4a3c3a8f-042b-4139-86a4-f01466e290a2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8de0932f-df55-421e-b450-35a47f798e7b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8de0932f-df55-421e-b450-35a47f798e7b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c626e895-d2c1-4a09-9dcd-8fc275995f29
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c626e895-d2c1-4a09-9dcd-8fc275995f29
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e9f390f3-513a-4a38-a7c1-4d8ed148e806
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e9f390f3-513a-4a38-a7c1-4d8ed148e806
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c71586cd-82d6-4760-ab89-8162cd1d4b65
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c71586cd-82d6-4760-ab89-8162cd1d4b65
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6b0cd3f3-681a-421d-a992-6bfe88695f2a
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6b0cd3f3-681a-421d-a992-6bfe88695f2a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 4e05984e-bde7-45f0-a44b-e8e8ed2286d5
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 4e05984e-bde7-45f0-a44b-e8e8ed2286d5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 4c71ad53-1dde-41b3-a0d8-2307c5893b9d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 4c71ad53-1dde-41b3-a0d8-2307c5893b9d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 9d54eadd-7418-40ce-bf23-5e559cc1e262
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 9d54eadd-7418-40ce-bf23-5e559cc1e262
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8712444a-5bb4-4f5a-82e7-a4c36e40c96b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8712444a-5bb4-4f5a-82e7-a4c36e40c96b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 89cd655a-6075-4a7b-9edc-29d3ae10f15e
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 89cd655a-6075-4a7b-9edc-29d3ae10f15e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c881da72-78d9-4386-9d9c-ce362a7152dd
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c881da72-78d9-4386-9d9c-ce362a7152dd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a6a08eb8-4ee7-4988-9d12-3d02e59a9e27
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a6a08eb8-4ee7-4988-9d12-3d02e59a9e27
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e958f412-4061-4f47-9d74-670b2257ead5
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e958f412-4061-4f47-9d74-670b2257ead5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b2104853-1d40-423f-8197-ade35c843e31
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b2104853-1d40-423f-8197-ade35c843e31
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 0b2460b1-4ccd-4810-b80b-3569eaddbcf0
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 0b2460b1-4ccd-4810-b80b-3569eaddbcf0
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 3d3d8d01-7777-4bc1-84bf-753528546f9e
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 3d3d8d01-7777-4bc1-84bf-753528546f9e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: bbd636a9-15bb-44f3-b453-68118c35b10b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: bbd636a9-15bb-44f3-b453-68118c35b10b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 3de30e78-a683-4b36-8ed2-abbae14361eb
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 3de30e78-a683-4b36-8ed2-abbae14361eb
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 16c866d5-6662-47ce-8b11-8efe2f33937f
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 16c866d5-6662-47ce-8b11-8efe2f33937f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c0f8c05b-6671-466a-af91-d825cf4ca5df
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c0f8c05b-6671-466a-af91-d825cf4ca5df
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: dc39f5e9-b98e-445a-8aff-239d908cb385
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: dc39f5e9-b98e-445a-8aff-239d908cb385
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2a6a4c8f-e83f-4045-82fc-1e295b204dbc
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2a6a4c8f-e83f-4045-82fc-1e295b204dbc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 3bff4937-cd87-4b9c-904b-28d9a18a311b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 3bff4937-cd87-4b9c-904b-28d9a18a311b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 4c7178a9-7a43-4309-91c4-ff7348b77ee9
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 4c7178a9-7a43-4309-91c4-ff7348b77ee9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 747a4462-4e77-4fc4-a69c-9c66a70a50d6
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 747a4462-4e77-4fc4-a69c-9c66a70a50d6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b0570c24-965b-43d2-a484-11d8e366f147
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b0570c24-965b-43d2-a484-11d8e366f147
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 38a3eb09-7e6e-406f-a1d3-177b7575dda3
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 38a3eb09-7e6e-406f-a1d3-177b7575dda3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 0b1811ad-eaa6-4fa6-9028-b72ba48d3438
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 0b1811ad-eaa6-4fa6-9028-b72ba48d3438
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 68b0c699-099d-46d1-82cd-fb1f88536452
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 68b0c699-099d-46d1-82cd-fb1f88536452
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 31a200d5-639b-4440-b8c7-0363569ac17b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 31a200d5-639b-4440-b8c7-0363569ac17b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 72955018-3fee-4c21-99e7-776e0be0fe9e
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 72955018-3fee-4c21-99e7-776e0be0fe9e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 82095db5-5cf3-4981-86d0-62079878bb31
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 82095db5-5cf3-4981-86d0-62079878bb31
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b11f28e0-2dd3-4f1b-848e-6b021ec716d3
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b11f28e0-2dd3-4f1b-848e-6b021ec716d3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 78002bd7-db29-429a-be33-a4c3935e181a
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 78002bd7-db29-429a-be33-a4c3935e181a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: af002627-e8e5-430b-b16a-05d492b0ab1c
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: af002627-e8e5-430b-b16a-05d492b0ab1c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 182d9d35-c41e-4a5b-ab08-b6b9ebab9e07
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 182d9d35-c41e-4a5b-ab08-b6b9ebab9e07
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8955dbe2-5f6c-4a1e-8c4f-374e288fa0eb
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8955dbe2-5f6c-4a1e-8c4f-374e288fa0eb
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 157c3d89-63df-44fc-82f5-10c58296a017
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 157c3d89-63df-44fc-82f5-10c58296a017
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6828fec4-a49b-4b78-ba18-f5c81006ecbd
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6828fec4-a49b-4b78-ba18-f5c81006ecbd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: eb0b677d-2164-4785-bd4b-c962a239ada3
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: eb0b677d-2164-4785-bd4b-c962a239ada3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c90f8146-c1b9-4da6-b45c-921e0dfc7c5d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c90f8146-c1b9-4da6-b45c-921e0dfc7c5d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c9fac637-7a21-4fd7-942e-00d57adbc3e4
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c9fac637-7a21-4fd7-942e-00d57adbc3e4
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_28220\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.

# %% [markdown]
# **Create plot**

# %%
from matplotlib.ticker import MultipleLocator

fig, ax = plt.subplots()
min_depth = 0.
max_depth = 0.
bound = 'outbound'

water_transport_capacity_performances = inbound_water_transport_capacity_performances
if bound == 'outbound':
    water_transport_capacity_performances = outbound_water_transport_capacity_performances
    
for tidal_range in water_transport_capacity_performances.keys():
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[tidal_range].items() if v > -1}
    
    filtered_dredging_performance = {k: -dredging_performances[tidal_range][k] for k in filtered_water_transport_capacity_performance}
    new_min_depth = np.min(list(filtered_water_transport_capacity_performance.keys()))
    new_max_depth = np.max(list(filtered_water_transport_capacity_performance.keys())) 
    if new_min_depth < min_depth:
        min_depth = new_min_depth
    if new_max_depth > max_depth:
        max_depth = new_max_depth
    norm = mpl.colors.Normalize(min_depth,max_depth)
    cmap = plt.get_cmap('coolwarm')
    
    if min_depth >= 0.:
        cmap = mcolors.LinearSegmentedColormap.from_list(
            'coolwarm',
            cmap(np.linspace(0.5, 1, 256))
        )
        norm = mpl.colors.Normalize(new_min_depth-1.,max_depth)


for i, tidal_range in enumerate(water_transport_capacity_performances.keys()):
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[tidal_range].items() if v > -1}
    filtered_dredging_performance = {k: -dredging_performances[tidal_range][k] for k in filtered_water_transport_capacity_performance}

    x_vals = list(filtered_water_transport_capacity_performance.values())
    #y_vals = list(filtered_dredging_performance.values())
    y_vals = np.array(list(filtered_dredging_performance.values())) / 1e6

    line_styles = ['-', '--', ':', '-.'] 
    line_style = line_styles[i % len(line_styles)]
    
    line, = ax.plot(
        x_vals,
        y_vals,
        label=f'tidal range = {tidal_range} m ({bound})',
        zorder=-1,
        linestyle = line_style,
        color = 'black', 
    )
    cbar = ax.scatter(
        x_vals,
        y_vals,
        c=filtered_dredging_performance.keys(),
        cmap=cmap,
        norm = norm,
        edgecolor=line.get_color(),
    )
 
    ax.set_xlabel('Waterway capacity\n[nr. of vessels]')
    #ax.set_ylabel('Dredging volume [m3] / dredging activities')
    # Dredging (pijl naar beneden)

    fig.subplots_adjust(left=0.20)
    fig.text(
    0.01, 0.5,  # x, y positie (links van figuur)
    'Dredging volume [10⁶ m³]',  # jouw titel
    va='center',
    rotation='vertical',
    fontsize=12
    )
        
    
    ax.annotate(
        'Dredging',
        xy=(-0.2, 0.10),       # punt waar pijl naartoe wijst
        xytext=(-0.2, 0.35),   # waar tekst staat
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    # Sedimentation (pijl naar boven)
    ax.annotate(
        'Sedimentation',
        xy=(-0.2, 0.90),
        xytext=(-0.2, 0.65),
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    ax.set_ylim(-5, 5)
    ax.yaxis.set_major_locator(MultipleLocator(0.5))

    # #ax.set_title(
    #     f'Channel vessel capacity for various channel depths\n'
    #     f'(Natural channel depth = {original_waterway_depth} m, vessel draught = {max_draught} m)'
    #)

ax.legend()
fig.colorbar(cbar, label='Added depth [m]')

fig.savefig('figures/Capacity_changing_tidal_range_outbound.png', dpi=300)

plt.show()
