# %%
# package(s) used for creating and geo-locating the graph
import networkx as nx
from pyproj import Geod
from shapely.geometry import Point, LineString
from opentnsim import graph

# package(s) related to the hydrodynamics and tidal windows
import xarray as xr

# load OpenTNSim modules
from opentnsim.core import Identifiable, Movable 
from opentnsim.core.vessel_properties import VesselProperties
from opentnsim.graph import HasMultiDiGraph
from opentnsim.vessel_traffic_service import VesselTrafficService
from opentnsim.port.mixins.port import IsPort, HasPortAccess
from opentnsim.port.mixins.terminal import IsTerminal, HasTerminal
from opentnsim.port.mixins.berth import IsJetty, IsQuay
from opentnsim.port.mixins.anchorage_area import IsAnchorage, PassesAnchorage
from opentnsim.port.mixins import tidal_accessibility
from opentnsim.port.mixins.tidal_accessibility import HasDraughtRestrictions
from opentnsim.port.rule_constructor import vessel_characteristics, vessel_direction, vessel_type
from opentnsim.port.tidal_window_constructor import vessel_specifications, \
                                                    vertical_tidal_window_specifications, \
                                                    vertical_tidal_window_input, \
                                                    horizontal_tidal_window_specifications, \
                                                    horizontal_tidal_window_method, \
                                                    horizontal_tidal_window_input, \
                                                    tidal_period, \
                                                    accessibility, \
                                                    NetworkProperties

# package(s) related to the simulation (creating the vessel, running the simulation)
import datetime
import simpy
import opentnsim

# package(s) needed for inspecting the output
import pandas as pd
import numpy as np
import scipy

# package(s) for plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.colors as mcolors

print("This notebook is executed with OpenTNSim version {}".format(opentnsim.__version__))
# Out:
# This notebook is executed with OpenTNSim version 1.3.7

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### 1. Constants

# %%
# Environment  
simulation_start = datetime.datetime(2024, 1, 1, 0, 0, 0)
simulation_stop = datetime.datetime(2024, 1, 3, 0, 0, 0)
timestep = pd.Timedelta(minutes=5)
time_series = pd.date_range(simulation_start,simulation_stop,freq=timestep)

# %%
# initialize geodetic calculator with WGS84 ellipsoid
geod = Geod(ellps="WGS84")

# %%
# make your preferred Vessel class out of available mix-ins.
Vessel = type(
    "Vessel", 
    (HasPortAccess,
     HasTerminal,
     PassesAnchorage,
     HasDraughtRestrictions,
     HasMultiDiGraph,
     Identifiable, # allows to give the object a name and a random ID,
     Movable,      # allows the object to move, with a fixed speed, while logging this activity
     VesselProperties,
    ), 
    {}
)

# %%
def mission(env, vessel):
    """
    Method that defines the mission of the vessel. 
    
    In this case: 
        keep moving along the path until its end point is reached
    """
    yield from vessel.move()

# %% [markdown]
# #### 2. Create simulation
# We define a function

# %%
def create_and_run_env_with_tidal_window(
    original_waterway_depth,
    added_depth,
    waterway_length, 
    ukc_percentage,
    tidal_range_sea,
    tidal_period,
    tidal_amplication,
    tidal_propagation_speed,
    interarrival_time,
    vessel_beam,
    vessel_draught,
    vessel_speed,
    vessel_loading_factor,
):
    env = simpy.Environment(initial_time=simulation_start.timestamp())
    env.simulation_start = simulation_start
    env.simulation_stop = simulation_stop
    env.epoch = simulation_start

    # Graph
    coordinates_sea = (0,0)
    coordinates_port = geod.fwd(coordinates_sea[0], coordinates_sea[1], 90 ,waterway_length) # East from Point 0
    coordinates_waterway = {"Sea": (coordinates_sea[0], coordinates_sea[1]),
                            "Port basin": (coordinates_port[0], coordinates_port[1]),}
    FG = nx.DiGraph()
    for name, coordinate in coordinates_waterway.items():
        FG.add_node(name, geometry=Point(coordinate[0], coordinate[1]))
    edges = [("Sea", "Port basin"), ("Port basin", "Sea")]
    for edge in edges:
        FG.add_edge(edge[0], edge[1], geometry=LineString([Point(coordinates_sea),Point(coordinates_port[:-1])]), weight=1, length_m=waterway_length)
    env.graph = FG

    # Hydrodynamic data
    waterway_depth = original_waterway_depth + added_depth
    hydrodynamic_data = xr.Dataset()
    tidal_phase_shift = pd.Timedelta(seconds=waterway_length/tidal_propagation_speed)
    tidal_water_level_sea = (tidal_range_sea/2)*np.sin(2*np.pi*((time_series-simulation_start)/(tidal_period*pd.Timedelta(hours=1))))
    amplification_factor = ((tidal_amplication-(1/10000))*waterway_length+1)
    tidal_water_level_port = amplification_factor*(tidal_range_sea/2)*np.sin(2*np.pi*((time_series-simulation_start-tidal_phase_shift)/(tidal_period*pd.Timedelta(hours=1))))
    water_level_data = xr.DataArray(data=[tidal_water_level_sea,tidal_water_level_port],coords={'STATION':FG.nodes,'TIME':time_series})
    MBLs = waterway_depth*np.ones(len(time_series))
    MBL_data = xr.DataArray(data=[MBLs,MBLs],coords={'STATION':FG.nodes,'TIME':time_series})
    hydrodynamic_data['Water level'] = water_level_data
    hydrodynamic_data['MBL'] = MBL_data
    vessel_traffic_service = VesselTrafficService(hydrodynamic_data = hydrodynamic_data)
    env.vessel_traffic_service = vessel_traffic_service
    
    network_properties = NetworkProperties()
    for index, node in enumerate(FG.nodes):
        FG.nodes[node]['Vertical tidal restriction'] = {}
        vertical_tidal_window_inputs = []
    
        vessel_specification = vessel_specifications({vessel_characteristics.min_ge_Draught: 0.0},'x',vessel_direction.inbound)
        window_specification = vertical_tidal_window_specifications(ukc_s = 0.,
                                                                    ukc_p = ukc_percentage/100,
                                                                    fwa = 0.,)
        
        vertical_tidal_window_inputs.append(vertical_tidal_window_input(vessel_specifications = vessel_specification,
                                                                        window_specifications = window_specification))

        vessel_specification = vessel_specifications({vessel_characteristics.min_ge_Draught: 0.0},'x',vessel_direction.outbound)
        window_specification = vertical_tidal_window_specifications(ukc_s = 0.,
                                                                    ukc_p = ukc_percentage/100,
                                                                    fwa = 0.,)
        
        vertical_tidal_window_inputs.append(vertical_tidal_window_input(vessel_specifications = vessel_specification,
                                                                        window_specifications = window_specification))
    
        network_properties.append_vertical_tidal_restriction_to_network(env.graph,node,vertical_tidal_window_inputs)
        
    # Infrastructure
    max_draught = np.max([vessel_draught,vessel_draught+vessel_draught*vessel_loading_factor/100])
    always_sufficient_depth = max_draught + tidal_range_sea + (ukc_percentage/100)*max_draught + 0.5 # m (not important, should be 100% accessible) 

    port = IsPort(env=env, name = "Port", port_entry_nodes=['Sea'])
    anchorage = IsAnchorage(env=env, capacity=20, name = 'Anchorage', node = 'Sea', depth = always_sufficient_depth, geometry=env.graph.nodes['Sea']['geometry'], port = port)
    jetty = IsJetty(env=env,length=300, depth=always_sufficient_depth, name='Jetty',node='Port basin')
    terminal = IsTerminal(env=env, name = 'Terminal', berths=[jetty], port = port)

    # Vessel
    path = nx.dijkstra_path(env.graph, "Sea", "Port basin")
    data_vessel = {
        "env": env,                                       # needed for simpy simulation
        "name": "Vessel 1",                               # required by Identifiable
        "geometry": env.graph.nodes[path[0]]['geometry'], # required by Locatable
        "route": path,                                    # required by Routeable
        "v": vessel_speed,                                # required by Movable, 1 m/s to check if the distance is covered in the expected time
        "bound": 'inbound',
        "terminal": terminal,
        "berthing_time":15, #minutes
        "loading_time": 12, #hours
        "deberthing_time":5, #minutes,
        "next_destination":"Sea",
        "type":"tanker",
        "loading_factor":vessel_loading_factor,
        "L":vessel_beam*8,
        "B":vessel_beam,
        "T":vessel_draught,
    } 
    vessel = Vessel(**data_vessel)
    vessel.mission = env.process(mission(env, vessel))
    env.run()
    try:
        inbound_window_lengths = [(window[1]-window[0]).total_seconds() for window in vessel.tidal_window_calculations[0]['vertical_tidal_windows']]
        inbound_window_length = scipy.stats.mode(inbound_window_lengths)[0]
        inbound_window_length = np.min([inbound_window_length,pd.Timedelta(hours=tidal_period).total_seconds()])
        if pd.isna(inbound_window_length):
            inbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    except:
        inbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    try:
        outbound_window_lengths = [(window[1]-window[0]).total_seconds() for window in vessel.tidal_window_calculations[1]['vertical_tidal_windows']]
        outbound_window_length = scipy.stats.mode(outbound_window_lengths)[0]
        outbound_window_length = np.min([outbound_window_length,pd.Timedelta(hours=tidal_period).total_seconds()])
        if pd.isna(outbound_window_length):
            outbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    except:
        outbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    inbound_vessel_capacity = np.floor(inbound_window_length/interarrival_time.total_seconds())
    outbound_vessel_capacity = np.floor(outbound_window_length/interarrival_time.total_seconds())
    dredging = added_depth*waterway_length*(3*vessel.B)
    return inbound_vessel_capacity, outbound_vessel_capacity, dredging, vessel

# %%
env = simpy.Environment(initial_time=simulation_start.timestamp())
env.simulation_start = simulation_start
env.simulation_stop = simulation_stop
env.epoch = simulation_start

waterway_length = 25000
# Graph
coordinates_sea = (0,0)
coordinates_port = geod.fwd(coordinates_sea[0], coordinates_sea[1], 90 ,waterway_length) # East from Point 0
coordinates_waterway = {"Sea": (coordinates_sea[0], coordinates_sea[1]),
                       "Port basin": (coordinates_port[0], coordinates_port[1]),}
FG = nx.DiGraph()

for name, coordinate in coordinates_waterway.items():
   FG.add_node(name, geometry=Point(coordinate[0], coordinate[1]))
    
edges = [("Sea", "Port basin"), ("Port basin", "Sea")]
for edge in edges:
    FG.add_edge(edge[0], edge[1], geometry=LineString([Point(coordinates_sea),Point(coordinates_port[:-1])]), weight=1, length_m="L")
env.graph = FG

# Extract de coördinaten van de knopen voor het tekenen
pos = {node: (FG.nodes[node]['geometry'].x, FG.nodes[node]['geometry'].y) for node in FG.nodes}

edge_labels = {}
for u, v, data in FG.edges(data=True):
    edge_labels[(u, v)] = f"{data['length_m']} m"  # Lengte toevoegen als label

# Plot de grafiek met expliciete coördinaten
plt.figure(figsize=(8, 8))  # Grootte van de figuur
nx.draw(FG, pos=pos, with_labels=True, node_size=1000, node_color='skyblue', font_size=12)
nx.draw_networkx_edge_labels(FG, pos=pos, edge_labels=edge_labels, font_size=10, font_color='Black')
plt.title("Waterway Network")  # Titel voor de grafiek

# Sla de grafiek op in de 'figures' map
plt.savefig('figures/nodes_network.png')  # Bestandsnaam in de figures map

# Toon de grafiek
plt.show()  # Toon de grafiek

# %% [markdown]
# #### 3. Run simulation

# %%
original_waterway_depth = 11.0

inbound_water_transport_capacity_performances = {}
outbound_water_transport_capacity_performances = {}
dredging_performances = {}
# Looping over waterway length
for waterway_length in [10000, 25000, 50000, 100000]:
    inbound_water_transport_capacity_performance = {}
    outbound_water_transport_capacity_performance = {}
    dredging_performance = {}

    # looping over waterway depth
    for added_depth in np.arange(-2, 2, 0.1):
        waterway_depth = original_waterway_depth + added_depth
        inbound_waterway_capacity_for_design_vessel, outbound_waterway_capacity_for_design_vessel, dredging, vessel = create_and_run_env_with_tidal_window(
            original_waterway_depth = original_waterway_depth, #in m (better known as NGD: nautical guaranteed depth or MBL: maintained bed level)
            added_depth = added_depth,
            waterway_length = waterway_length, #in m 
            ukc_percentage = 10.0, #in % of draught (10% of draught is common)
            tidal_range_sea = 2.0, #in m
            tidal_period = 12.5, # hrs (semi-diurnal tide, most common tide)
            tidal_amplication = 1.0 / 10000, #in m^-1 (amplification factor per 10 km: 1.0 = not damping / amplifying)
            tidal_propagation_speed = np.sqrt(9.81*original_waterway_depth), #15.0, # m/s (could be calculated using np.sqrt(9.81*waterway_depth))
            interarrival_time = pd.Timedelta(minutes=20),
            vessel_draught = 10.0, #in m
            vessel_beam = 30,
            vessel_speed = 6.0, # m/s (common speed in confined waterways)
            vessel_loading_factor = -30, #in % of draught (+ = loading when export terminal, - = unloading when import terminal, 30% is common)
        )
      
        inbound_water_transport_capacity_performance[added_depth] = int(inbound_waterway_capacity_for_design_vessel)
        outbound_water_transport_capacity_performance[added_depth] = int(outbound_waterway_capacity_for_design_vessel)
        dredging_performance[added_depth] = dredging
        
    inbound_water_transport_capacity_performances[waterway_length] = inbound_water_transport_capacity_performance
    outbound_water_transport_capacity_performances[waterway_length] = outbound_water_transport_capacity_performance
    dredging_performances[waterway_length] = dredging_performance
# Out:
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 32393757-efa2-4750-9ddd-953860d333ef
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e7373c9d-39b6-4dbf-8bd9-c5a5c3e9b839
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d7bc975b-1d8b-469e-8afa-016aecbdf0cc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 92422f67-99f6-477e-b0f6-854356ad2c0e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2f3f771c-3bfb-4e69-9fed-a2063a243222
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: baa9c807-6053-4d49-b6af-876f54f7076b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f77da9f0-80fe-4a8d-ac50-ca48789639c5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: eb1e9d21-b97f-44b4-910d-bea04ac2dcad
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 137d87da-7e27-4c7b-bbdf-3a4a8a27f048
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 513d7cd3-3d9f-4f4b-af54-be64106f374e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a5e27d19-07b8-4ed3-b654-ad0a2476ebb9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 55d6143b-76b2-477f-9558-e7d3ed898b08
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5389f9cb-c02a-46e5-a643-a69d30b947d3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: da733cfb-dddf-40d7-94fe-d877826fec50
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d948658b-d987-4036-b5cc-2f249081717b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b30b6e3c-eef5-4d29-a213-e3431266e12a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d9b9ff1f-34c4-45d8-8c89-c6fe02156dd7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: dafa03a1-4bca-45e0-a9f1-354766c4ead5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 62206996-4a40-46b1-98c4-0a5843854b5b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 9c932613-2ed8-413f-928c-8542e8751e00
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b0d55314-4024-4099-952a-1abfa94309ac
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2a758ff2-8083-442a-81a6-3d6bcdcabbb0
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: dca8fe7c-c644-4cd0-921e-b183fdb59ece
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2e02b08a-4833-464a-a94a-e2a9f1ff7821
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 80b9ad4c-f587-4635-b700-0d28dea69d75
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ca4744f8-d03f-46a4-8ef4-808d71cc35d0
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ec781a23-d3d6-45a3-8e45-8b50b85b1df6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 361f1b57-34f1-4ec0-9dc3-4a3893176fcd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 59543878-c484-46fd-92f6-7f59ef65a45c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0d7f233f-0213-4876-a6e9-52079fb3092b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 50f4b720-23f3-4841-aef9-c1458cfc933b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 582045ca-0681-45b3-aca5-f461e39f1085
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e2ea32c2-9acc-47d9-9ee6-613265b5fb21
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 88cd227e-3b42-44e8-afc9-07393b20b980
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ba947b85-bf31-4df4-895a-e41436ffb5ef
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 646f21ae-969c-434d-a578-dbba303a0648
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 59ad20b6-f176-4bef-9e1e-9648ec4d2389
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ecb5e1ec-bb5b-4bc2-a7b3-e2e18e3b958c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 85ff8428-8f3d-437b-be85-c8d0ca36793c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e3b09630-5c6b-478c-8749-8f9372ea784e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: cdf1d2fa-f520-4753-8756-63b6fa8de3f3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 7dcddaa1-9881-4517-9e8c-45c13365f449
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 19d70c75-c4b5-4954-910a-92a379c7cc2e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: edd5a92b-3b4f-47d0-9cdd-a5a2b76387ab
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ad91a429-baa4-423e-b369-5e29c8578cc8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 7ec6b97a-82c5-4a2d-b3f8-a6317ce914eb
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.

# %%
print(vessel.T)
# Out:
# 7.0

# %%
vessel._T = 10
print(np.max([vessel.T,vessel.T+vessel.T*vessel.loading_factor/100]))
print(vessel.T)
# Out:
# 10.0
# 10

# %%
from matplotlib.ticker import MultipleLocator


# Lijsten met stijlen voor de lijnen en markers
line_styles = ['-', '--', ':', '-.']  # Verschillende lijnstijlen
markers = ['o', 's', '^', 'D']  # Verschillende markeringen
colors = ['blue', 'green', 'red', 'purple']  # Verschillende kleuren


fig, ax = plt.subplots()
min_depth = 0.
max_depth = 0.
bound = 'inbound'

water_transport_capacity_performances = inbound_water_transport_capacity_performances
if bound == 'outbound':
    water_transport_capacity_performances = outbound_water_transport_capacity_performances
    
for waterway_length in water_transport_capacity_performances.keys():
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[waterway_length].items() if v > -1}
    
    filtered_dredging_performance = {k: -dredging_performances[waterway_length][k] for k in filtered_water_transport_capacity_performance}
    new_min_depth = np.min(list(filtered_water_transport_capacity_performance.keys()))
    new_max_depth = np.max(list(filtered_water_transport_capacity_performance.keys())) 
    if new_min_depth <= min_depth:
        min_depth = new_min_depth
    if new_max_depth >= max_depth:
        max_depth = new_max_depth
    norm = mpl.colors.Normalize(min_depth,max_depth)
    cmap = plt.get_cmap('coolwarm')
    
    if min_depth >= 0.:
        cmap = mcolors.LinearSegmentedColormap.from_list(
            'coolwarm',
            cmap(np.linspace(0.5, 1, 256))
        )
        norm = mpl.colors.Normalize(new_min_depth-1.,max_depth)

# for waterway_length in water_transport_capacity_performances.keys():
#     filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[waterway_length].items() if v > -1}
#     filtered_dredging_performance = {k: -dredging_performances[waterway_length][k] for k in filtered_water_transport_capacity_performance}


    # Loop opnieuw over de waterway_lengths en voeg de stijlen toe
for i, waterway_length in enumerate(water_transport_capacity_performances.keys()):
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[waterway_length].items() if v > -1}
    filtered_dredging_performance = {k: -dredging_performances[waterway_length][k] for k in filtered_water_transport_capacity_performance}

    x_vals = list(filtered_water_transport_capacity_performance.values())
    #y_vals = list(filtered_dredging_performance.values())
    y_vals = np.array(list(filtered_dredging_performance.values())) / 1e6


    
    # Kies de lijnstijl, marker en kleur per waterway_length
    line_style = line_styles[i % len(line_styles)]  # Afwisselen van lijnstijlen
    marker = markers[i % len(markers)]  # Afwisselen van markers
    color = colors[i % len(colors)]  # Afwisselen van kleuren

    
    line, = ax.plot(
        x_vals,
        y_vals,
        label=f'L={waterway_length/1000} km ({bound})', 
        linestyle = line_style,
        color = 'black',
        zorder=-1
    )
    
    cbar = ax.scatter(
        x_vals,
        y_vals,
        c=filtered_dredging_performance.keys(),
        cmap=cmap,
        norm = norm,
        edgecolor=line.get_color(),
    )
    
    ax.set_xlabel('Waterway capacity\n[nr. of vessels]')
    ax.set_ylabel('Dredging volume [10⁶ m³]', labelpad=15)
    # Dredging (pijl naar beneden)
    ax.annotate(
        'Dredging',
        xy=(-0.12, 0.10),       # punt waar pijl naartoe wijst
        xytext=(-0.12, 0.35),   # waar tekst staat
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

# Sedimentation (pijl naar boven)
    ax.annotate(
        'Sedimentation',
        xy=(-0.12, 0.90),
        xytext=(-0.12, 0.65),
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    ax.set_ylim(-15, 5)
    ax.yaxis.set_major_locator(MultipleLocator(0.5))

    #ax.set_title(f'Channel vessel capacity for {bound} port and various channel depths. \n For a vessel with draught {np.max([vessel.T,vessel.T+vessel.T*vessel.loading_factor/100])} m and loading capacity ={vessel.loading_factor}% and natural channel depth {original_waterway_depth}m')

ax.legend()
fig.colorbar(cbar, label='Added depth [m]')

fig.savefig('figures/Capacity_changing_waterway_lengths_inbound.png', dpi=300)

plt.show()

# %% [markdown]
# Outbound

# %% [markdown]
# **run simulation**

# %%
original_waterway_depth = 11.0

inbound_water_transport_capacity_performances = {}
outbound_water_transport_capacity_performances = {}
dredging_performances = {}
# Looping over waterway length
for waterway_length in [10000, 25000, 50000, 100000]:
    inbound_water_transport_capacity_performance = {}
    outbound_water_transport_capacity_performance = {}
    dredging_performance = {}

    # looping over waterway depth
    for added_depth in np.arange(-3, 3, 0.1):
        waterway_depth = original_waterway_depth + added_depth
        inbound_waterway_capacity_for_design_vessel, outbound_waterway_capacity_for_design_vessel, dredging, vessel = create_and_run_env_with_tidal_window(
            original_waterway_depth = original_waterway_depth, #in m (better known as NGD: nautical guaranteed depth or MBL: maintained bed level)
            added_depth = added_depth,
            waterway_length = waterway_length, #in m 
            ukc_percentage = 10.0, #in % of draught (10% of draught is common)
            tidal_range_sea = 2.0, #in m
            tidal_period = 12.48, # hrs (semi-diurnal tide, most common tide)
            tidal_amplication = 1.0 / 10000, #in m^-1 (amplification factor per 10 km: 1.0 = not damping / amplifying)
            tidal_propagation_speed = 15.0, # m/s (could be calculated using np.sqrt(9.81*waterway_depth))
            interarrival_time = pd.Timedelta(minutes=20),
            vessel_draught = 7, #in m
            vessel_beam = 30,
            vessel_speed = 6.0, # m/s (common speed in confined waterways)
            vessel_loading_factor = 30.0, #in % of draught (+ = loading when export terminal, - = unloading when import terminal, 30% is common)
        )
        inbound_water_transport_capacity_performance[added_depth] = int(inbound_waterway_capacity_for_design_vessel)
        outbound_water_transport_capacity_performance[added_depth] = int(outbound_waterway_capacity_for_design_vessel)
        dredging_performance[added_depth] = dredging
        
    inbound_water_transport_capacity_performances[waterway_length] = inbound_water_transport_capacity_performance
    outbound_water_transport_capacity_performances[waterway_length] = outbound_water_transport_capacity_performance
    dredging_performances[waterway_length] = dredging_performance
# Out:
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1fa234de-06f9-4419-9df9-2e7d035cea48
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1fa234de-06f9-4419-9df9-2e7d035cea48
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 33e783c5-a7e2-4250-bbe8-aa12188e1bab
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 33e783c5-a7e2-4250-bbe8-aa12188e1bab
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a9f5353c-9038-4dea-8138-575774869ce7
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a9f5353c-9038-4dea-8138-575774869ce7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 007f9496-373c-41e5-a47a-bcf6a60ed830
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 007f9496-373c-41e5-a47a-bcf6a60ed830
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 664e120e-a66e-4fb4-95ad-5f11defd7b06
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 664e120e-a66e-4fb4-95ad-5f11defd7b06
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 023127bb-b30e-4dad-907d-ba480f8fc022
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 023127bb-b30e-4dad-907d-ba480f8fc022
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 47bc7a2f-4980-4bd6-9e3e-4a7784ff756e
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 47bc7a2f-4980-4bd6-9e3e-4a7784ff756e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6ec5f5c7-d52e-4042-adce-19e786037c62
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6ec5f5c7-d52e-4042-adce-19e786037c62
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f8d5b67f-081b-41a3-9e75-1c347e6de6f6
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f8d5b67f-081b-41a3-9e75-1c347e6de6f6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8511e541-f5ff-41b1-8e33-ed910c673a30
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8511e541-f5ff-41b1-8e33-ed910c673a30
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7bfbbfe2-c898-4a21-aff7-2e66fdc2e925
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7bfbbfe2-c898-4a21-aff7-2e66fdc2e925
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 511b17c1-4bec-43ca-8c6c-e00a85ebd969
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 511b17c1-4bec-43ca-8c6c-e00a85ebd969
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 47a474eb-9bbc-4aaf-a26b-3c04bf0940ea
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 47a474eb-9bbc-4aaf-a26b-3c04bf0940ea
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 88f5c258-eb84-4d51-b3c4-6afabe50b85b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 88f5c258-eb84-4d51-b3c4-6afabe50b85b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6f8a43bc-1bf1-4540-b3ee-048c2d1a354f
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6f8a43bc-1bf1-4540-b3ee-048c2d1a354f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: ee672b63-ddca-49bc-b5d5-a6e6f50f6c46
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: ee672b63-ddca-49bc-b5d5-a6e6f50f6c46
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2601cff6-0fa4-4dcb-ab3d-5b2c8c1ca651
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 2601cff6-0fa4-4dcb-ab3d-5b2c8c1ca651
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b94468da-5beb-414f-84e9-37c266400d4b
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b94468da-5beb-414f-84e9-37c266400d4b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6d025fad-384b-436d-9380-af9e8ef084f7
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 6d025fad-384b-436d-9380-af9e8ef084f7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 30780ba7-275c-4dab-bd3b-12cf0537c85e
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 30780ba7-275c-4dab-bd3b-12cf0537c85e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 44f1ba1e-2b2b-402b-9e8a-a3787ddc309c
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 44f1ba1e-2b2b-402b-9e8a-a3787ddc309c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 33d5e361-8470-431b-a811-eb44835332df
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 33d5e361-8470-431b-a811-eb44835332df
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: ae37d778-661b-41bf-b9a3-490eb8f72a8d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: ae37d778-661b-41bf-b9a3-490eb8f72a8d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c276f20a-c3e5-43d4-bd64-ca670999713f
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c276f20a-c3e5-43d4-bd64-ca670999713f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f79038d2-26d5-4efd-9052-12442caf06c6
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f79038d2-26d5-4efd-9052-12442caf06c6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 454fbb6f-25b4-425d-bbe7-a23062e99dd3
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 454fbb6f-25b4-425d-bbe7-a23062e99dd3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a410d3bc-e323-451b-b1ef-1500d24d1783
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a410d3bc-e323-451b-b1ef-1500d24d1783
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 5a6e232b-6212-4613-9ce7-d8eaf5c646d9
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 5a6e232b-6212-4613-9ce7-d8eaf5c646d9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e6ab9795-189f-40af-b024-8360791a85e9
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e6ab9795-189f-40af-b024-8360791a85e9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: bdf5c00c-5fd2-4511-b211-a66de1b7cff7
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: bdf5c00c-5fd2-4511-b211-a66de1b7cff7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1b499577-3d1b-4599-a1cb-22200f2d0609
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1b499577-3d1b-4599-a1cb-22200f2d0609
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a3095630-a044-47d8-90bf-2dc881f0150e
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a3095630-a044-47d8-90bf-2dc881f0150e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: da70af90-774e-4008-bded-29cd3cf7b76d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: da70af90-774e-4008-bded-29cd3cf7b76d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 0b2e0944-c432-4f0d-9454-60e507df4b73
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 0b2e0944-c432-4f0d-9454-60e507df4b73
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 0ee2fc17-dd23-4c56-988e-48fdd188039e
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 0ee2fc17-dd23-4c56-988e-48fdd188039e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f169b308-c4b9-443f-bfd9-3db13f841b1e
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f169b308-c4b9-443f-bfd9-3db13f841b1e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e7596267-de1a-41e9-8835-30f4ca539498
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e7596267-de1a-41e9-8835-30f4ca539498
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 928a6502-10ad-4287-8036-f0e3c4d88a84
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 928a6502-10ad-4287-8036-f0e3c4d88a84
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: adb4806d-c019-4323-ae46-9e60c16c5d99
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: adb4806d-c019-4323-ae46-9e60c16c5d99
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7099dd84-0893-42d1-9c7f-891a5ec80085
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 7099dd84-0893-42d1-9c7f-891a5ec80085
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 00eb3e80-ec53-4ec6-aaae-446b8211cf22
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 00eb3e80-ec53-4ec6-aaae-446b8211cf22
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a4ba2a33-5c25-434e-b4f2-32b98db5f70d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a4ba2a33-5c25-434e-b4f2-32b98db5f70d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 67e5a0a2-258b-4c0c-b697-dfd0cab23f87
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 67e5a0a2-258b-4c0c-b697-dfd0cab23f87
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e7e5239e-26b2-4220-8cb2-96f1aef34826
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: e7e5239e-26b2-4220-8cb2-96f1aef34826
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f54d0fe1-18b9-4261-936e-c6dd010c097a
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: f54d0fe1-18b9-4261-936e-c6dd010c097a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 009282d0-916d-4caf-afd8-fafd0489caf9
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 009282d0-916d-4caf-afd8-fafd0489caf9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8657f67f-d254-4eb2-8fb1-8cd52e8cf467
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 8657f67f-d254-4eb2-8fb1-8cd52e8cf467
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b2c9a17b-f169-47d3-a922-fedac7a4a050
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b2c9a17b-f169-47d3-a922-fedac7a4a050
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a1f76302-ab9f-45a4-8eff-97c1fb5e8592
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: a1f76302-ab9f-45a4-8eff-97c1fb5e8592
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b6cdd165-c126-4613-b79c-3cbe9d2c1e7d
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b6cdd165-c126-4613-b79c-3cbe9d2c1e7d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1fea617e-ef17-4b3e-b72f-ad6ef02f9567
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 1fea617e-ef17-4b3e-b72f-ad6ef02f9567
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: cec2045c-1602-4e2b-9b1c-ed1c89e0bd01
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: cec2045c-1602-4e2b-9b1c-ed1c89e0bd01
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 733a6c15-aae6-4bd5-9c1a-3f1d66121e87
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 733a6c15-aae6-4bd5-9c1a-3f1d66121e87
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: bc92e9df-1699-4e80-9c63-7e5d91a06aae
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: bc92e9df-1699-4e80-9c63-7e5d91a06aae
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b087abb5-e90a-4607-88a8-b5329ac350bc
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: b087abb5-e90a-4607-88a8-b5329ac350bc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c9dd85a3-186e-4842-8979-472bd423e665
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: c9dd85a3-186e-4842-8979-472bd423e665
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 97d9efcb-fa8c-47f7-a379-ee67fe71d6a7
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:142: UserWarning:
#
# The port is not accessible for the outbound trip of vessel with id: 97d9efcb-fa8c-47f7-a379-ee67fe71d6a7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_27656\2103955229.py:114: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.

# %% [markdown]
# **Create plot**

# %%
from matplotlib.ticker import MultipleLocator

fig, ax = plt.subplots()
min_depth = 0.
max_depth = 0.
bound = 'outbound'

water_transport_capacity_performances = inbound_water_transport_capacity_performances
if bound == 'outbound':
    water_transport_capacity_performances = outbound_water_transport_capacity_performances
    
for waterway_length in water_transport_capacity_performances.keys():
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[waterway_length].items() if v > -1}
    
    filtered_dredging_performance = {k: -dredging_performances[waterway_length][k] for k in filtered_water_transport_capacity_performance}
    new_min_depth = np.min(list(filtered_water_transport_capacity_performance.keys()))
    new_max_depth = np.max(list(filtered_water_transport_capacity_performance.keys())) 
    if new_min_depth <= min_depth:
        min_depth = new_min_depth
    if new_max_depth >= max_depth:
        max_depth = new_max_depth
    norm = mpl.colors.Normalize(min_depth,max_depth)
    cmap = plt.get_cmap('coolwarm')
    
    if min_depth >= 0.:
        cmap = mcolors.LinearSegmentedColormap.from_list(
            'coolwarm',
            cmap(np.linspace(0.5, 1, 256))
        )
        norm = mpl.colors.Normalize(new_min_depth-1.,max_depth)

# for waterway_length in water_transport_capacity_performances.keys():
#     filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[waterway_length].items() if v > -1}
#     filtered_dredging_performance = {k: -dredging_performances[waterway_length][k] for k in filtered_water_transport_capacity_performance}

for i, waterway_length in enumerate(water_transport_capacity_performances.keys()):
    filtered_water_transport_capacity_performance = {k: v for k, v in water_transport_capacity_performances[waterway_length].items() if v > -1}
    filtered_dredging_performance = {k: -dredging_performances[waterway_length][k] for k in filtered_water_transport_capacity_performance}

    
    x_vals = list(filtered_water_transport_capacity_performance.values())
    #y_vals = list(filtered_dredging_performance.values())
    y_vals = np.array(list(filtered_dredging_performance.values())) / 1e6

    line_styles = ['-', '--', ':', '-.']
    line_style = line_styles[i % len(line_styles)]  # Afwisselen van lijnstijlen

    line, = ax.plot(
        x_vals,
        y_vals,
        label=f'L={waterway_length/1000} km ({bound})',
        zorder=-1,
        linestyle = line_style,
        color = 'black', 
    )
    cbar = ax.scatter(
        x_vals,
        y_vals,
        c=filtered_dredging_performance.keys(),
        cmap=cmap,
        norm = norm,
        edgecolor=line.get_color(),
    )
    
    ax.set_xlabel('Waterway capacity\n[nr. of vessels]')
    ax.set_ylabel('Dredging volume [10⁶ m³]', labelpad=15)
    # Dredging (pijl naar beneden)
    ax.annotate(
        'Dredging',
        xy=(-0.12, 0.10),       # punt waar pijl naartoe wijst
        xytext=(-0.12, 0.35),   # waar tekst staat
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

# Sedimentation (pijl naar boven)
    ax.annotate(
        'Sedimentation',
        xy=(-0.12, 0.90),
        xytext=(-0.12, 0.65),
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    ax.set_ylim(-5, 5)
    ax.yaxis.set_major_locator(MultipleLocator(0.5))

ax.legend()
fig.colorbar(cbar, label='Added depth [m]')

fig.savefig('figures/Capacity_changing_waterway_lengths_outbound.png', dpi=300)

plt.show()
