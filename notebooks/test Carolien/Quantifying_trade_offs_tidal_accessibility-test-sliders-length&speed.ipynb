# %%
# package(s) used for creating and geo-locating the graph
import networkx as nx
from pyproj import Geod
from shapely.geometry import Point, LineString
from opentnsim import graph

# package(s) related to the hydrodynamics and tidal windows
import xarray as xr

# load OpenTNSim modules
from opentnsim.core import Identifiable, Movable 
from opentnsim.core.vessel_properties import VesselProperties
from opentnsim.graph import HasMultiDiGraph
from opentnsim.vessel_traffic_service import VesselTrafficService
from opentnsim.port.mixins.port import IsPort, HasPortAccess
from opentnsim.port.mixins.terminal import IsTerminal, HasTerminal
from opentnsim.port.mixins.berth import IsJetty, IsQuay
from opentnsim.port.mixins.anchorage_area import IsAnchorage, PassesAnchorage
from opentnsim.port.mixins import tidal_accessibility
from opentnsim.port.mixins.tidal_accessibility import HasDraughtRestrictions
from opentnsim.port.rule_constructor import vessel_characteristics, vessel_direction, vessel_type
from opentnsim.port.tidal_window_constructor import vessel_specifications, \
                                                    vertical_tidal_window_specifications, \
                                                    vertical_tidal_window_input, \
                                                    horizontal_tidal_window_specifications, \
                                                    horizontal_tidal_window_method, \
                                                    horizontal_tidal_window_input, \
                                                    tidal_period, \
                                                    accessibility, \
                                                    NetworkProperties

# package(s) related to the simulation (creating the vessel, running the simulation)
import datetime
import simpy
import opentnsim

# package(s) needed for inspecting the output
import pandas as pd
import numpy as np
import scipy

# package(s) for plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.colors as mcolors

print("This notebook is executed with OpenTNSim version {}".format(opentnsim.__version__))
# Out:
# This notebook is executed with OpenTNSim version 1.3.7

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### 1. Constants

# %%
# Environment  
simulation_start = datetime.datetime(2024, 1, 1, 0, 0, 0)
simulation_stop = datetime.datetime(2024, 1, 3, 0, 0, 0)
timestep = pd.Timedelta(minutes=5)
time_series = pd.date_range(simulation_start,simulation_stop,freq=timestep)

# %%
# initialize geodetic calculator with WGS84 ellipsoid
geod = Geod(ellps="WGS84")

# %%
# make your preferred Vessel class out of available mix-ins.
Vessel = type(
    "Vessel", 
    (HasPortAccess,
     HasTerminal,
     PassesAnchorage,
     HasDraughtRestrictions,
     HasMultiDiGraph,
     Identifiable, # allows to give the object a name and a random ID,
     Movable,      # allows the object to move, with a fixed speed, while logging this activity
     VesselProperties,
    ), 
    {}
)

# %%
def mission(env, vessel):
    """
    Method that defines the mission of the vessel. 
    
    In this case: 
        keep moving along the path until its end point is reached
    """
    yield from vessel.move()

# %% [markdown]
# #### 2. Create simulation
# We define a function

# %%
def create_and_run_env_with_tidal_window(
    original_waterway_depth,
    added_depth,
    waterway_length, 
    ukc_percentage,
    tidal_range_sea,
    tidal_period,
    tidal_amplication,
    tidal_propagation_speed,
    interarrival_time,
    vessel_beam,
    vessel_draught,
    vessel_speed,
    vessel_loading_factor,
):
    env = simpy.Environment(initial_time=simulation_start.timestamp())
    env.simulation_start = simulation_start
    env.simulation_stop = simulation_stop
    env.epoch = simulation_start

    # Graph
    coordinates_sea = (0,0)
    coordinates_port = geod.fwd(coordinates_sea[0], coordinates_sea[1], 90 ,waterway_length) # East from Point 0
    coordinates_waterway = {"Sea": (coordinates_sea[0], coordinates_sea[1]),
                            "Port basin": (coordinates_port[0], coordinates_port[1]),}
    FG = nx.DiGraph()
    for name, coordinate in coordinates_waterway.items():
        FG.add_node(name, geometry=Point(coordinate[0], coordinate[1]))
    edges = [("Sea", "Port basin"), ("Port basin", "Sea")]
    for edge in edges:
        FG.add_edge(edge[0], edge[1], geometry=LineString([Point(coordinates_sea),Point(coordinates_port[:-1])]), weight=1, length_m=waterway_length)
    env.graph = FG

    # Hydrodynamic data
    waterway_depth = original_waterway_depth + added_depth
    hydrodynamic_data = xr.Dataset()
    tidal_phase_shift = pd.Timedelta(seconds=waterway_length/tidal_propagation_speed)
    tidal_water_level_sea = (tidal_range_sea/2)*np.sin(2*np.pi*((time_series-simulation_start)/(tidal_period*pd.Timedelta(hours=1))))
    amplification_factor = ((tidal_amplication-(1/10000))*waterway_length+1)
    tidal_water_level_port = amplification_factor*(tidal_range_sea/2)*np.sin(2*np.pi*((time_series-simulation_start-tidal_phase_shift)/(tidal_period*pd.Timedelta(hours=1))))
    water_level_data = xr.DataArray(data=[tidal_water_level_sea,tidal_water_level_port],coords={'STATION':FG.nodes,'TIME':time_series})
    MBLs = waterway_depth*np.ones(len(time_series))
    MBL_data = xr.DataArray(data=[MBLs,MBLs],coords={'STATION':FG.nodes,'TIME':time_series})
    hydrodynamic_data['Water level'] = water_level_data
    hydrodynamic_data['MBL'] = MBL_data
    vessel_traffic_service = VesselTrafficService(hydrodynamic_data = hydrodynamic_data)
    env.vessel_traffic_service = vessel_traffic_service
    
    network_properties = NetworkProperties()
    for index, node in enumerate(FG.nodes):
        FG.nodes[node]['Vertical tidal restriction'] = {}
        vertical_tidal_window_inputs = []
    
        vessel_specification = vessel_specifications({vessel_characteristics.min_ge_Draught: 0.0},'x',vessel_direction.inbound)
        window_specification = vertical_tidal_window_specifications(ukc_s = 0.,
                                                                    ukc_p = ukc_percentage/100,
                                                                    fwa = 0.,)
        
        vertical_tidal_window_inputs.append(vertical_tidal_window_input(vessel_specifications = vessel_specification,
                                                                        window_specifications = window_specification))

        vessel_specification = vessel_specifications({vessel_characteristics.min_ge_Draught: 0.0},'x',vessel_direction.outbound)
        window_specification = vertical_tidal_window_specifications(ukc_s = 0.,
                                                                    ukc_p = ukc_percentage/100,
                                                                    fwa = 0.,)
        
        vertical_tidal_window_inputs.append(vertical_tidal_window_input(vessel_specifications = vessel_specification,
                                                                        window_specifications = window_specification))
    
        network_properties.append_vertical_tidal_restriction_to_network(env.graph,node,vertical_tidal_window_inputs)
        
    # Infrastructure
    max_draught = np.max([vessel_draught,vessel_draught+vessel_draught*vessel_loading_factor/100])
    always_sufficient_depth = max_draught + tidal_range_sea + (ukc_percentage/100)*max_draught + 0.5 # m (not important, should be 100% accessible) 

    port = IsPort(env=env, name = "Port", port_entry_nodes=['Sea'])
    anchorage = IsAnchorage(env=env, capacity=20, name = 'Anchorage', node = 'Sea', depth = always_sufficient_depth, geometry=env.graph.nodes['Sea']['geometry'], port = port)
    jetty = IsJetty(env=env,length=300, depth=always_sufficient_depth, name='Jetty',node='Port basin')
    terminal = IsTerminal(env=env, name = 'Terminal', berths=[jetty], port = port)

    # Vessel
    path = nx.dijkstra_path(env.graph, "Sea", "Port basin")
    data_vessel = {
        "env": env,                                       # needed for simpy simulation
        "name": "Vessel 1",                               # required by Identifiable
        "geometry": env.graph.nodes[path[0]]['geometry'], # required by Locatable
        "route": path,                                    # required by Routeable
        "v": vessel_speed,                                # required by Movable, 1 m/s to check if the distance is covered in the expected time
        "bound": 'inbound',
        "terminal": terminal,
        "berthing_time":15, #minutes
        "loading_time": 12, #hours
        "deberthing_time":5, #minutes,
        "next_destination":"Sea",
        "type":"tanker",
        "loading_factor":vessel_loading_factor,
        "L":vessel_beam*8,
        "B":vessel_beam,
        "T":vessel_draught,
    } 
    vessel = Vessel(**data_vessel)
    vessel.mission = env.process(mission(env, vessel))
    env.run()
    try:
        inbound_window_lengths = [(window[1]-window[0]).total_seconds() for window in vessel.tidal_window_calculations[0]['vertical_tidal_windows']]
        inbound_window_length = scipy.stats.mode(inbound_window_lengths)[0]
        inbound_window_length = np.min([inbound_window_length,pd.Timedelta(hours=tidal_period).total_seconds()])
        if pd.isna(inbound_window_length):
            inbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    except:
        inbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    try:
        outbound_window_lengths = [(window[1]-window[0]).total_seconds() for window in vessel.tidal_window_calculations[1]['vertical_tidal_windows']]
        outbound_window_length = scipy.stats.mode(outbound_window_lengths)[0]
        outbound_window_length = np.min([outbound_window_length,pd.Timedelta(hours=tidal_period).total_seconds()])
        if pd.isna(outbound_window_length):
            outbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    except:
        outbound_window_length = pd.Timedelta(seconds=0).total_seconds()
    inbound_vessel_capacity = np.floor(inbound_window_length/interarrival_time.total_seconds())
    outbound_vessel_capacity = np.floor(outbound_window_length/interarrival_time.total_seconds())
    dredging = added_depth*waterway_length*(3*vessel.B)
    return inbound_vessel_capacity, outbound_vessel_capacity, dredging, vessel

# %% [markdown]
# #### 3. Run simulation

# %%
original_waterway_depth = 11.0

#waterway_lengths = [10000, 25000, 50000]
vessel_speeds = [2, 4, 6, 8]

inbound_water_transport_capacity_performances = {}
outbound_water_transport_capacity_performances = {}
dredging_performances = {}

# Looping over waterway length
for waterway_length in [10000, 25000, 50000]:
    inbound_water_transport_capacity_performances[waterway_length] = {}
    outbound_water_transport_capacity_performances[waterway_length]= {}
    dredging_performances[waterway_length]= {}

    for vessel_speed in vessel_speeds:
        inbound_water_transport_capacity_performance = {}
        outbound_water_transport_capacity_performance = {}
        dredging_performance = {}

        # looping over waterway depth
        for added_depth in np.arange(-3, 3, 0.1):
            waterway_depth = original_waterway_depth + added_depth
            inbound_waterway_capacity_for_design_vessel, outbound_waterway_capacity_for_design_vessel, dredging, vessel = create_and_run_env_with_tidal_window(
            original_waterway_depth = original_waterway_depth, #in m (better known as NGD: nautical guaranteed depth or MBL: maintained bed level)
                added_depth = added_depth,
                waterway_length = waterway_length, #in m 
                ukc_percentage = 10.0, #in % of draught (10% of draught is common)
                tidal_range_sea = 2.0, #in m
                tidal_period = 12.5, # hrs (semi-diurnal tide, most common tide)
                tidal_amplication = 1.0 / 10000, #in m^-1 (amplification factor per 10 km: 1.0 = not damping / amplifying)
                tidal_propagation_speed = 15.0, # m/s (could be calculated using np.sqrt(9.81*waterway_depth))
                interarrival_time = pd.Timedelta(minutes=20),
                vessel_draught = 10.0, #in m
                vessel_beam = 30,
                vessel_speed = vessel_speed, # m/s (common speed in confined waterways)
                vessel_loading_factor = -40.0, #in % of draught (+ = loading when export terminal, - = unloading when import terminal, 30% is common)
            )
     
            inbound_water_transport_capacity_performance[added_depth] = int(inbound_waterway_capacity_for_design_vessel)
            outbound_water_transport_capacity_performance[added_depth] = int(outbound_waterway_capacity_for_design_vessel)
            dredging_performance[added_depth] = dredging
        
        inbound_water_transport_capacity_performances[waterway_length][vessel_speed] = inbound_water_transport_capacity_performance
        outbound_water_transport_capacity_performances[waterway_length][vessel_speed] = outbound_water_transport_capacity_performance
        dredging_performances[waterway_length][vessel_speed]= dredging_performance
# Out:
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 34ce64cf-d5a5-4be8-a5d9-452616a97258
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 07c4a8aa-291d-42b4-b127-efd13408a790
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2f2b5f9c-a620-4244-9f5c-489cc04b5541
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a6be09b5-f142-408a-a08e-69c7367dc02d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1a70e0f0-61e6-47bd-b853-b02f0fe57199
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 271353df-662f-4eae-bc7a-ba4bcacc4aff
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 9c2a4cba-9dbf-4336-ae93-880c5adfa5bc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ed360a05-f374-4e76-83fe-4eb96a367c7d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 240f611f-9538-421e-8d07-287aa57b131e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8e101715-78b1-49ed-9851-b144763df580
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5dc877d2-7bb2-4129-b84c-c437fc2ea71e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3d627c66-4f8c-4cde-8cea-389f9b9685ab
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e66c71b7-75e7-4ee3-b465-57f1289f21e8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: df7c7399-345e-4555-8a07-4ee1e07501c7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1ba240fd-afb6-4a21-a5c4-13f8075af650
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 33029e85-9e14-4f95-9048-e54ec7ffaf41
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5fe4fb9a-9267-444f-8dd7-7352f145e742
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d08fd0f6-3724-4037-9154-8f7c4960fdd5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d7b5ec39-c6f7-4384-a189-f0b8bbe92efd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 539d1785-8a0e-4f7e-af05-1f1810700e0a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 112ce22f-8127-49db-aedd-f4be017ddde2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 6b495587-18fe-4734-a858-1ea66a947837
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c6bd2a3d-c002-4c68-8695-eb3137db7e53
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: cdea69e6-dc3d-496c-b1f2-eae13e93094a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 321919d9-9125-45d8-b8a4-2ce19eb79297
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d1f77882-dfab-4050-979b-04e6b2182886
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8be1828a-3e07-42d8-ae62-5fe18ed77d06
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ede31a76-2648-4ac2-b326-a7322d9c8fba
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 39c881d9-e926-4b41-9c7e-ff0bdd8520cc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c93e8e2e-7277-46c4-a832-34c4708c1576
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 54ece341-ee64-423d-baf8-47781640ac83
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a3237622-0202-4692-b2a9-6b7e31548892
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 90d260bc-859a-40fe-9c02-31125f47d082
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0abbd367-ad8b-4128-b7c1-ebdc742f4123
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ce6ef1fa-4013-41ed-9ec1-3a3a6854a91c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e1bb92d8-86d1-4abb-8097-6bd12e148c7e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a57e3890-7f18-42cc-b60b-ae4c8374f633
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 00c72ad0-8681-4b24-b30e-17f726e77555
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 6c322048-9204-40a0-b5af-28a77b6dd2a4
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4692af21-799c-487f-be9b-d4acc3abdf68
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 92303393-4d46-4bb2-983c-8462b4fc23af
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 7dbc4d15-f75d-413e-88e5-d19e7abbed61
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 88b4b60e-d11c-4993-9fa5-26516b0eff3f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 687f19e5-72e8-44d1-aabb-cda7d8552d75
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 67518ff8-b9ef-4e8a-9623-5b67204842b2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e2c2121c-e9fe-44e5-b61f-50265194e90a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 70f800c8-f068-40c2-8546-6306a8bf409a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5a03987e-4579-43f2-9ba2-6d8f4c09fb75
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2410edb5-1e45-49c3-9853-c8449df12932
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: fe72057f-09d4-44f4-9ae0-ead504c0794a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 104ebf42-f7c3-4632-9cfc-55f3b6cc39fc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 959194d1-5ce2-421c-9837-1bdff3cd7d55
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d990314c-66c4-4526-ad60-5594befc23f8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c8d41033-2212-40a0-b685-4e0079d4b50a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c7966457-e47d-472f-9f79-fdcc064c7cca
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b628bcd3-0721-488e-9a07-49e481b12ded
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4ac76dd8-74a8-4f1a-b831-8bd198cd8952
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f570b06f-7543-4963-9801-76c8fba0e2c2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: cbbca3a4-00cb-4204-8a4f-89a98ea40558
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: cde61ef5-15e3-428c-b0c6-f53107c79e62
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 6e3ba6a8-f7dc-4420-aa9e-69e3c34a4035
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5052d71e-1bc8-4784-86b1-6daa760e1d0d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8585e5df-fac3-4c17-8fc5-2a3597c05e54
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2f3b6448-8f0f-47ec-8f5b-45c959e375a8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d86a4d3d-cdfd-4ad3-bb64-6f8fd2b71991
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a344846e-dc50-4472-b6c1-3bfb8fbff16e
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 08fb8892-81c7-419a-8a58-c6c45f72ce8a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a8bc5557-d5a9-4fd1-b4ca-5f36108202cb
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f7d3b199-c3e1-4ac7-b008-cf16fa30593f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d320aecd-1b7b-4400-a10f-41649037f6b5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ede99a92-3d40-44ea-89df-e2666a6a35ac
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 79ccb35a-0243-476d-86e0-159f3bc3caef
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 76d93cb8-f0e8-48ae-b9ad-ff81fc948f0d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3ef79691-4ae2-4071-a798-fe9d53f76d24
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 77ec13f0-6c86-4804-91b8-d18ddef03d3c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f2d27278-b5dd-4a12-9670-d74f82e4612f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 54faaf6f-1369-4594-ae4f-a88b87895b0f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d5baf9e9-ccc4-4368-8460-61a4ba6eb988
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b6a51f2c-0925-4cd7-b582-26c43ae568af
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 79c8bf96-7ab0-401e-b1c4-4205a09daa5f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 6746ba74-ca81-48cf-befa-d1489cdcd789
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: db9745c1-63b9-4276-97a2-79ad13e77bb8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: eba79708-c1e9-4a81-9ccb-60cdae85b8c5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b3192e0f-42a1-4ba5-8c05-22faa5b05ea9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0e6106c0-c9dc-4bf1-898d-1c79bba255c6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e19c6c86-0ebd-497a-8e9a-da57f818a5f7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 116ad100-64d6-4c76-a69d-5a2e8de7ce6b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 054d13c8-00b9-4d74-952c-a59a271c8f0c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 14fb6988-2c4d-4a4e-b143-682976600291
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 33126a68-421f-473a-a13c-a05373754580
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 85608062-10e2-40c9-939d-edc55357b25a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 30bad3be-6d1f-459d-aea2-f82a5cbe6571
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 498b5825-82a6-450a-bfa1-8dba41dc26fe
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 9659278a-1eb9-48dd-9cb7-3d452583b8c5
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: ad1fdf52-7875-44f7-9054-80f62148c2fd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a6caeb49-21dd-409b-8d0a-a60c97073d96
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: be448f12-9b63-4350-ae80-4ad65c7056fc
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 209bf213-18f2-4193-912e-d29ac4c17d3c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3a5c4e85-6730-4ff8-ac88-9bfbcebcdb7d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d4872156-d78c-4f43-864a-f60d34af866b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 6a2b89a3-8ef4-489f-b5c6-917cc4196632
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b4b813dc-4469-40fb-a621-c3ce67e5a0d4
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c838ecd8-151b-4bd2-a1c1-8e4dfe9a7f18
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0b7dfaa9-a989-4eae-b0d5-f1c8989d69c1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 69df713d-0aac-4f75-b638-7970a0db0f82
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4a6bf23e-b5a4-4951-96b0-84f90ae8c3c8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e602dd23-a93c-4656-8a6e-db6d231565b3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c7fd5d38-6d4f-4ed8-8c21-b7a43412b2fd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e2775da0-1a53-4dd3-881b-0f4d78fbe84f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 068216b3-7099-4218-9baf-03b57cd45dac
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2c7839ce-aa0d-4580-85c1-bf75e764a15c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5369b90c-5cd8-460e-bd5a-61c57920f1e7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a30d0a49-fdb7-4c9a-9d91-b9a54a54b51d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0a93ca26-c11c-483b-9944-e4aec4ab69d8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b8551ae5-28cb-4c3c-befb-62af718aaaf3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1800a4e1-0798-40ad-8bf0-48f8a822aa69
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 01cd1152-0b7a-4c4f-9e1a-89b59351bf42
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 85d7399a-ced2-4cfc-8e77-a1e1bf4f535a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 31004cff-5c2b-4f2d-9827-805bd3cbfca3
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8f7283a1-d459-42e7-9ff5-cb614562819a
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 7a45d42a-9584-484b-b462-0da4a7df4b3d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 43d231df-3432-4691-a7bd-0e625ff25a8c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# ...
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4b1ef329-ad5e-42b1-9068-35029dca62bb
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 8aff8ae4-0f3c-4931-bf62-8c38d6a211ab
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 83e3590b-bce2-487c-ac4f-d9b88b08b9e7
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 9a86a7a4-8acd-4db8-aa38-49d2fc6e2aad
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 39cb70a5-81f5-43d7-8de8-e42de0395e91
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b504ff6a-0147-4320-8b94-fb31971bf3f1
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: f74d818b-89da-45c8-903f-e380eeb66bd0
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5c526c17-7394-41dd-9a0f-93f33a833875
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 245c0d56-58ba-4a40-bdfd-713c34491d2c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2e542af1-f725-4f00-b81d-c4797896ba64
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 9e31a1b4-ba96-4d0f-87f2-59d5068ce1d4
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: eae60527-2022-4ba9-976c-e28e0d977663
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 45165f6d-8747-4685-8559-d835bdbcb049
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e7772072-e3e0-414a-bd9e-61fae68a87ed
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 58c4c453-69fa-4372-a6a5-38dca4bd3527
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 75bb2e7a-a361-48a7-b92d-1f9b7b47642c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1fa8c78c-7602-4f99-ae9a-86fdac5ce291
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: c29b7d33-6d7f-4f23-bcd9-20c0f0ad1d00
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 299f6287-9076-49c7-80e9-730468acc25b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: d8e628ee-db10-41c2-b568-14964340f14f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: db97bc3f-0fe5-47da-bc02-94677b9c4fbf
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2e99cc1f-f4bd-4b5b-b004-f974ae2d11b0
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 83581957-4533-4144-a1fa-bfca57c5110b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 2028dda1-6491-4128-87bf-301a7bb80ba2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b9d177a1-143a-41dc-87d7-187400251b4c
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 0d925099-6d94-43f5-96fd-c6ab3509f59f
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a58e2685-35f9-40ce-af5f-6fa730801738
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 3449923a-012c-4ae7-b09f-58f509fbc5bd
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1c662de9-9c36-4e40-be7f-c929aa1069e6
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 4a00a445-8470-43eb-be5f-d049f27047da
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5ecda0e4-177b-42c1-854a-4ac18bb00c05
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 1183e2c1-9438-4cbc-909b-96a6ebb0961d
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b84e0bda-82a3-4981-90c1-0d01de1e99a9
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a50ad121-0835-4ed1-984e-e7690202c886
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: eeb773a8-989b-4434-b084-481608450140
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: a8221c8f-c01b-4567-9e81-66815450139b
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: 5506db7e-3003-4f13-9a38-06104eee19bb
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: cf88408a-55cf-4089-a837-6456b679a232
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: b9cc5c8f-973d-4b94-af81-cb1126ab0cf2
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#
# C:\Users\CAdeK\OpenTNSim\opentnsim\port\mixins\port.py:144: UserWarning:
#
# The port is not accessible for the inbound trip of vessel with id: e703af23-98d4-4866-b7ed-52fa7e5702d8
#
# C:\Users\CAdeK\AppData\Local\Temp\ipykernel_10864\2103955229.py:106: SmallSampleWarning:
#
# One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors as mcolors
import numpy as np
import ipywidgets as widgets
from ipywidgets import interactive
from matplotlib.ticker import MultipleLocator

def plot_capacity_vs_dredging(waterway_length, vessel_speed):
    fig, ax = plt.subplots()

    bound = 'inbound'
    water_transport_capacity_performances = inbound_water_transport_capacity_performances
    if bound == 'outbound':
        water_transport_capacity_performances = outbound_water_transport_capacity_performances

    filtered_water_transport_capacity_performance = {
        k: v for k, v in water_transport_capacity_performances[waterway_length][vessel_speed].items() if v > -1
    }

    filtered_dredging_performance = {
        k: -dredging_performances[waterway_length][vessel_speed][k]
        for k in filtered_water_transport_capacity_performance
    }

    if len(filtered_water_transport_capacity_performance) == 0:
        print("No data available for this waterway length.")
        return

    min_depth = min(filtered_water_transport_capacity_performance.keys())
    max_depth = max(filtered_water_transport_capacity_performance.keys())

    cmap = plt.get_cmap('bwr')
    norm = mpl.colors.Normalize(min_depth, max_depth)

    if min_depth >= 0.0:
        cmap = mcolors.LinearSegmentedColormap.from_list(
            'bwr_truncated',
            cmap(np.linspace(0.5, 1, 256))
        )
        norm = mpl.colors.Normalize(min_depth - 1.0, max_depth)

    x_vals = list(filtered_water_transport_capacity_performance.values())
    y_vals = np.array(list(filtered_dredging_performance.values())) / 1e6
    c_vals = list(filtered_water_transport_capacity_performance.keys())

    line, = ax.plot(
        x_vals,
        y_vals,
        label=f'L = {waterway_length/1000:.0f} km, v = {vessel_speed} m/s ({bound})',
        zorder=-1,
    )

    cbar = ax.scatter(
        x_vals,
        y_vals,
        c=c_vals,
        cmap=cmap,
        norm=norm,
        edgecolor=line.get_color(),
    )

    ax.set_xlabel('Waterway capacity\n[nr. of vessels]')
    #ax.set_ylabel('Dredging volume [m3] / dredging activities')
    # Dredging (pijl naar beneden)

    fig.subplots_adjust(left=0.20)
    fig.text(
    0.01, 0.5,  # x, y positie (links van figuur)
    'Dredging volume [10⁶ m³]',  # jouw titel
    va='center',
    rotation='vertical',
    fontsize=12
    )
        
    
    ax.annotate(
        'Dredging',
        xy=(-0.2, 0.10),       # punt waar pijl naartoe wijst
        xytext=(-0.2, 0.35),   # waar tekst staat
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    # Sedimentation (pijl naar boven)
    ax.annotate(
        'Sedimentation',
        xy=(-0.2, 0.90),
        xytext=(-0.2, 0.65),
        xycoords='axes fraction',
        textcoords='axes fraction',
        arrowprops=dict(arrowstyle='->'),
        ha='center',
        va='center',
        rotation=90
    )

    ax.set_xlim(0, 40)
    ax.xaxis.set_major_locator(MultipleLocator(5))

    ax.set_ylim(-4, 4)
    ax.yaxis.set_major_locator(MultipleLocator(0.5))

    ax.legend()
    fig.colorbar(cbar, label='Added depth [m]')

    ax.set_title(f'Channel vessel capacity for {bound} port and various channel depths. \n For a vessel with draught {vessel.T}m and loading capacity of {vessel.loading_factor} % and natural channel depth {original_waterway_depth}')

    plt.show()

slider_waterway_length = widgets.SelectionSlider(
    options=[10000, 25000, 50000],
    value=25000,
    description='Length [m]:',
    continuous_update=False
)

slider_vessel_speed = widgets.SelectionSlider(
    options=[2, 4, 6, 8],
    value=6,
    description='Vessel speed [m/s]:',
    continuous_update=False
)

interactive_plot = interactive(
    plot_capacity_vs_dredging,
    waterway_length=slider_waterway_length, 
    vessel_speed=slider_vessel_speed
)

output = interactive_plot.children[-1]
output.layout.height = '500px'
interactive_plot
# Out:
# interactive(children=(SelectionSlider(continuous_update=False, description='Length [m]:', index=1, options=(10…
