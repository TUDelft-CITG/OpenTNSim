# %% [markdown]
# ### Import packages

# %%
import folium
import functools
import geopandas as gpd
import io
import logging
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from opentnsim import core
from opentnsim import lock
from opentnsim import model
from opentnsim import output
from opentnsim import vessel as _vessel
from opentnsim import vessel_traffic_service
import os
import pandas as pd
import pickle
import pyproj
import requests
from shapely.geometry import Point,LineString,Polygon
from shapely.geometry.collection import GeometryCollection
from shapely.ops import transform, linemerge, split, snap
import simpy
import yaml

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()

# %% [markdown]
# # Basic lock simulation
# Remember the exercise on the capacity of a lock that was given by Arne van der Hout? Instead of calculating the lock capacity by hand, we can actually simulate locks using the software of OpenTNSim. How does this work?

# %% [markdown]
# First, we create an environment

# %%
env = simpy.Environment()

#Also we need to add a time
env.simulation_start = pd.Timestamp('2024-01-01')

# %% [markdown]
# We need to create a graph and add to the environment

# %%
#We need to create a network over which the vessels will sail
FG = nx.DiGraph()
FG.add_node('A',geometry=Point(0,0))
FG.add_node('B',geometry=Point(0,400))
FG.add_node('C',geometry=Point(0,800))
FG.add_edge('A','B',geometry=LineString([Point(0,0),Point(0,400)]),Info={'length':400})
FG.add_edge('B','A',geometry=LineString([Point(0,400),Point(0,0)]),Info={'length':400})
FG.add_edge('B','C',geometry=LineString([Point(0,400),Point(0,800)]),Info={'length':400})
FG.add_edge('C','B',geometry=LineString([Point(0,800),Point(0,400)]),Info={'length':400})
env.FG = FG
env.FG = nx.MultiDiGraph(env.FG)

#In order from ships to know where they are going we need to add an VTS to the environment
env.vessel_traffic_service = vessel_traffic_service.VesselTrafficService()

# %% [markdown]
# Now we need to create the lock infrastructure

# %%
#We can now add infrastructure to the network
lock_chamber_I = lock.IsLock(env=env,
                             name='Lock I',
                             node_doors1 = 'A',
                             node_doors2 = 'B',
                             lock_length = 120,
                             lock_width = 18,
                             lock_depth = 6,
                             distance_doors1_from_first_waiting_area=140,
                             distance_doors2_from_second_waiting_area=140,
                             detector_nodes=['A','B'],
                             levelling_time=1500,
                             node_open='A')

lock.IsLockLineUpArea(env=env,
                      name='Lock I',
                      start_node = 'A',
                      end_node = 'B',
                      lineup_length = 120,
                      distance_to_lock_doors=20)

lock.IsLockLineUpArea(env=env,
                      name='Lock I',
                      start_node = 'B',
                      end_node = 'A',
                      lineup_length = 120,
                      distance_to_lock_doors=20)

lock.IsLockWaitingArea(env=env,
                       name='Lock I',
                       node='A',
                       distance_from_node=0);

lock.IsLockWaitingArea(env=env,
                       name='Lock I',
                       node='B',
                       distance_from_node=0);

# %%
#We can now add infrastructure to the network
lock_chamber_II = lock.IsLock(env=env,
                              name='Lock II',
                              node_doors1 = 'B',
                              node_doors2 = 'C',
                              lock_length = 120,
                              lock_width = 18,
                              lock_depth = 6,
                              distance_doors1_from_first_waiting_area=140,
                              distance_doors2_from_second_waiting_area=140,
                              detector_nodes=['B','C'],
                              levelling_time=1500,
                              node_open='B')

lock.IsLockLineUpArea(env=env,
                      name='Lock II',
                      start_node = 'B',
                      end_node = 'C',
                      lineup_length = 120,
                      distance_to_lock_doors=20)

lock.IsLockLineUpArea(env=env,
                      name='Lock II',
                      start_node = 'C',
                      end_node = 'B',
                      lineup_length = 120,
                      distance_to_lock_doors=20)

lock.IsLockWaitingArea(env=env,
                       name='Lock II',
                       node='B',
                       distance_from_node=0)

lock.IsLockWaitingArea(env=env,
                       name='Lock II',
                       node='C',
                       distance_from_node=0);

# %% [markdown]
# Now we need to add a vessel

# %%
#We create a type element that schematisizes a vessel
Vessel = type('Vessel',(core.SimpyObject, #It should be a simpy element
                        core.Identifiable, #The vessel should be identifiable
                        lock.HasLock, #The vessel should interact with a lock chamber
                        lock.HasWaitingArea, #The vessel should interact with a waiting area
                        lock.HasLineUpArea, #The vessel should interact with a line-up area
                        _vessel.VesselProperties, #The vessel should have properties
                        _vessel.ExtraMetadata, #The vessel can have extra metadata
                        output.HasOutput),{}) #The vessel should have output

#Using the element, we need to give the following information to the vessel
vessel = Vessel(env=env,name='Vessel', 
                geometry=Point(0,0),
                origin='A',
                destination='C',
                route=nx.dijkstra_path(FG,'A','C'),
                type='inland vessel',
                L=100,
                B=15,
                T=5,
                H=4,
                v=4,
                arrival_time=pd.Timestamp('2024-01-01'),)

# %% [markdown]
# We can now create a process in the environment in which the vessel will move (from node A to node B)

# %%
env.process(vessel.move())
# Out:
# <Process(move) object at 0x197d8bf2c40>

# %% [markdown]
# Run the simulation

# %%
env.run()

# %% [markdown]
# We can now analyse the logbook of the vessel

# %%
vessel_df = pd.DataFrame(vessel.log)
vessel_df
# Out:
#                          Time       Location  \
# 0  1970-01-01 01:00:00.000000    POINT (0 0)
# 1  1970-01-01 01:00:00.000000    POINT (0 0)
# 2  1970-01-01 01:00:23.333333   POINT (0 70)
# 3  1970-01-01 01:00:23.333333   POINT (0 70)
# 4  1970-01-01 01:01:18.888889  POINT (0 120)
# 5  1970-01-01 01:01:18.888889  POINT (0 120)
# 6  1970-01-01 01:01:41.111111  POINT (0 140)
# 7  1970-01-01 01:01:41.111111  POINT (0 140)
# 8  1970-01-01 01:02:58.888889  POINT (0 210)
# 9  1970-01-01 01:02:58.888889  POINT (0 210)
# 10 1970-01-01 01:27:58.888889  POINT (0 210)
# 11 1970-01-01 01:27:58.888889  POINT (0 210)
# 12 1970-01-01 01:28:54.444444  POINT (0 260)
# 13 1970-01-01 01:28:54.444444  POINT (0 260)
# 14 1970-01-01 01:28:59.444444  POINT (0 280)
# 15 1970-01-01 01:28:59.444444  POINT (0 280)
# 16 1970-01-01 01:29:29.444444  POINT (0 400)
# 17 1970-01-01 01:29:29.444444  POINT (0 400)
# 18 1970-01-01 01:29:29.444444  POINT (0 400)
# 19 1970-01-01 01:29:29.444444  POINT (0 400)
# 20 1970-01-01 01:29:52.777778  POINT (0 470)
# 21 1970-01-01 01:29:52.777778  POINT (0 470)
# 22 1970-01-01 01:30:48.333333  POINT (0 520)
# 23 1970-01-01 01:30:48.333333  POINT (0 520)
# 24 1970-01-01 01:31:10.555556  POINT (0 540)
# 25 1970-01-01 01:31:10.555556  POINT (0 540)
# 26 1970-01-01 01:32:28.333333  POINT (0 610)
# 27 1970-01-01 01:32:28.333333  POINT (0 610)
# 28 1970-01-01 01:57:28.333333  POINT (0 610)
# 29 1970-01-01 01:57:28.333333  POINT (0 610)
# 30 1970-01-01 01:58:23.888889  POINT (0 660)
# 31 1970-01-01 01:58:23.888889  POINT (0 660)
# 32 1970-01-01 01:58:28.888889  POINT (0 680)
# 33 1970-01-01 01:58:28.888889  POINT (0 680)
# 34 1970-01-01 01:58:58.888889  POINT (0 800)
# 35 1970-01-01 01:58:58.888889  POINT (0 800)
#
#                                         Action  \
# 0          Sailing from node A to node B start
# 1    Sailing to position in line-up area start
# 2     Sailing to position in line-up area stop
# 3         Sailing to end of line-up area start
# 4          Sailing to end of line-up area stop
# 5     Sailing to first set of lock doors start
# 6      Sailing to first set of lock doors stop
# 7   Sailing to assigned location in lock start
# 8    Sailing to assigned location in lock stop
# 9                           Passing lock start
# 10                           Passing lock stop
# 11   Sailing to second set of lock doors start
# 12    Sailing to second set of lock doors stop
# 13               Sailing to line-up area start
# 14                Sailing to line-up area stop
# 15                  Passing line-up area start
# 16                   Passing line-up area stop
# 17          Sailing from node A to node B stop
# 18         Sailing from node B to node C start
# 19   Sailing to position in line-up area start
# 20    Sailing to position in line-up area stop
# 21        Sailing to end of line-up area start
# 22         Sailing to end of line-up area stop
# 23    Sailing to first set of lock doors start
# 24     Sailing to first set of lock doors stop
# 25  Sailing to assigned location in lock start
# 26   Sailing to assigned location in lock stop
# 27                          Passing lock start
# 28                           Passing lock stop
# 29   Sailing to second set of lock doors start
# 30    Sailing to second set of lock doors stop
# 31               Sailing to line-up area start
# 32                Sailing to line-up area stop
# 33                  Passing line-up area start
# 34                   Passing line-up area stop
# 35          Sailing from node B to node C stop
#
#                                                Status
# 0   {'origin': 'A', 'destination': 'C', 'route': [...
# 1   {'origin': 'A', 'destination': 'C', 'route': [...
# 2   {'origin': 'A', 'destination': 'C', 'route': [...
# 3   {'origin': 'A', 'destination': 'C', 'route': [...
# 4   {'origin': 'A', 'destination': 'C', 'route': [...
# 5   {'origin': 'A', 'destination': 'C', 'route': [...
# 6   {'origin': 'A', 'destination': 'C', 'route': [...
# 7   {'origin': 'A', 'destination': 'C', 'route': [...
# 8   {'origin': 'A', 'destination': 'C', 'route': [...
# 9   {'origin': 'A', 'destination': 'C', 'route': [...
# 10  {'origin': 'A', 'destination': 'C', 'route': [...
# 11  {'origin': 'A', 'destination': 'C', 'route': [...
# 12  {'origin': 'A', 'destination': 'C', 'route': [...
# 13  {'origin': 'A', 'destination': 'C', 'route': [...
# 14  {'origin': 'A', 'destination': 'C', 'route': [...
# 15  {'origin': 'A', 'destination': 'C', 'route': [...
# 16  {'origin': 'A', 'destination': 'C', 'route': [...
# 17  {'origin': 'A', 'destination': 'C', 'route': [...
# 18  {'origin': 'A', 'destination': 'C', 'route': [...
# 19  {'origin': 'A', 'destination': 'C', 'route': [...
# 20  {'origin': 'A', 'destination': 'C', 'route': [...
# 21  {'origin': 'A', 'destination': 'C', 'route': [...
# 22  {'origin': 'A', 'destination': 'C', 'route': [...
# 23  {'origin': 'A', 'destination': 'C', 'route': [...
# 24  {'origin': 'A', 'destination': 'C', 'route': [...
# 25  {'origin': 'A', 'destination': 'C', 'route': [...
# 26  {'origin': 'A', 'destination': 'C', 'route': [...
# 27  {'origin': 'A', 'destination': 'C', 'route': [...
# 28  {'origin': 'A', 'destination': 'C', 'route': [...
# 29  {'origin': 'A', 'destination': 'C', 'route': [...
# 30  {'origin': 'A', 'destination': 'C', 'route': [...
# 31  {'origin': 'A', 'destination': 'C', 'route': [...
# 32  {'origin': 'A', 'destination': 'C', 'route': [...
# 33  {'origin': 'A', 'destination': 'C', 'route': [...
# 34  {'origin': 'A', 'destination': 'C', 'route': [...
# 35  {'origin': 'A', 'destination': 'C', 'route': [...

# %%
fig,ax = plt.subplots()
ax.plot([point.y for point in vessel_df.Location],vessel_df.Time)
ylim_min,ylim_max = ax.get_ylim()
plt.fill([lock_chamber_I.distance_doors1_from_first_waiting_area,
          lock_chamber_I.distance_doors1_from_first_waiting_area,
          lock_chamber_I.distance_doors1_from_first_waiting_area+lock_chamber_I.lock_length,
          lock_chamber_I.distance_doors1_from_first_waiting_area+lock_chamber_I.lock_length,],
          [ylim_min,ylim_max,ylim_max,ylim_min],color='lightgrey',edgecolor='k')

length_lock_complex_I = FG.edges['A','B']['Info']['length']
plt.fill([lock_chamber_II.distance_doors1_from_first_waiting_area+length_lock_complex_I,
          lock_chamber_II.distance_doors1_from_first_waiting_area+length_lock_complex_I,
          lock_chamber_II.distance_doors1_from_first_waiting_area+lock_chamber_II.lock_length+length_lock_complex_I,
          lock_chamber_II.distance_doors1_from_first_waiting_area+lock_chamber_II.lock_length+length_lock_complex_I,],
          [ylim_min,ylim_max,ylim_max,ylim_min],color='lightgrey',edgecolor='k')


ax.set_ylim(ylim_min,ylim_max);

# %% [markdown]
# And we can analyse the logbook of the lock

# %%
lock_df = pd.DataFrame(lock_chamber_I.log)
lock_df
# Out:
#                         Time Location                         Action  \
# 0 1970-01-01 01:02:58.888889        A       Lock doors closing start
# 1 1970-01-01 01:02:58.888889        A        Lock doors closing stop
# 2 1970-01-01 01:02:58.888889        A  Lock chamber converting start
# 3 1970-01-01 01:27:58.888889        B   Lock chamber converting stop
# 4 1970-01-01 01:27:58.888889        B       Lock doors opening start
# 5 1970-01-01 01:27:58.888889        B        Lock doors opening stop
#
#                                               Status
# 0  {'visiting_vessels': [<__main__.Vessel object ...
# 1  {'visiting_vessels': [<__main__.Vessel object ...
# 2  {'visiting_vessels': [<__main__.Vessel object ...
# 3  {'visiting_vessels': [<__main__.Vessel object ...
# 4  {'visiting_vessels': [<__main__.Vessel object ...
# 5  {'visiting_vessels': [<__main__.Vessel object ...
