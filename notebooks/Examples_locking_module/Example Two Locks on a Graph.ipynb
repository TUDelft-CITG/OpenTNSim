# %% [markdown]
# ### Import packages

# %%
import folium
import functools
import geopandas as gpd
import io
import logging
import matplotlib as mpl
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
from opentnsim import core as core_module
from opentnsim import graph as graph_module
from opentnsim import lock as lock_module
from opentnsim import model as model_module
from opentnsim import output as output_module
from opentnsim import vessel as vessel_module
from opentnsim import vessel_traffic_service as vessel_traffic_service_module
import os
import pandas as pd
import pickle
import pyproj
import requests
from shapely.geometry import Point,LineString,Polygon
from shapely.geometry.collection import GeometryCollection
from shapely.ops import transform, linemerge, split, snap
import simpy
import yaml

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()
# %matplotlib inline

# %% [markdown]
# # Basic lock simulation
# Remember the exercise on the capacity of a lock that was given by Arne van der Hout? Instead of calculating the lock capacity by hand, we can actually simulate locks using the software of OpenTNSim. How does this work?

# %% [markdown]
# First, we create an environment

# %%
simulation_start = pd.Timestamp('2024-01-01')
env = simpy.Environment(initial_time=simulation_start.timestamp())

#Also we need to add a time
env.simulation_start = simulation_start

# %% [markdown]
# We need to create a graph and add to the environment

# %%
#We need to create a network over which the vessels will sail
node_A = graph_module.Node(name='A',geometry=Point(0,0))
node_B = graph_module.Node(name='B',geometry=Point(400,0))
node_C = graph_module.Node(name='C',geometry=Point(800,0))
edges = [(node_A,node_B),(node_B,node_C)]
FG = graph_module.DiGraph(edges=edges,crs='EPSG:28992').graph

#We need to add the graph to the environment:
env.FG = FG

#In order from ships to know where they are going we need to add an VTS to the environment
env.vessel_traffic_service = vessel_traffic_service_module.VesselTrafficService(env=env)

# %% [markdown]
# Now we need to create the lock infrastructure

# %%
# #We can now add infrastructure to the network
lock_I = lock_module.IsLockComplex(env=env,
                                   name='Lock I',
                                   start_node='A',
                                   end_node='B',
                                   lock_length = 120,
                                   lock_width = 18,
                                   lock_depth = 6,
                                   lineup_area_A_length=120,
                                   lineup_area_B_length=120,
                                   effective_lineup_area_B_length=120,
                                   levelling_time=1500,
                                   distance_doors_A_from_waiting_area_A=140,
                                   distance_doors_B_from_waiting_area_B=140,
                                   distance_waiting_area_A_from_start_node=0,
                                   distance_waiting_area_B_from_end_node=0,
                                   distance_lineup_area_A_to_lock_doors_A=20,
                                   distance_lineup_area_B_to_lock_doors_B=20)

lock_II = lock_module.IsLockComplex(env=env,
                                    name='Lock II',
                                    start_node='B',
                                    node_open='B',
                                    end_node='C',
                                    lock_length = 120,
                                    lock_width = 18,
                                    lock_depth = 6,
                                    lineup_area_A_length=120,
                                    lineup_area_B_length=120,
                                    levelling_time=1500,
                                    distance_doors_A_from_waiting_area_A=140,
                                    distance_doors_B_from_waiting_area_B=140,
                                    distance_waiting_area_A_from_start_node=0,
                                    distance_waiting_area_B_from_end_node=0,
                                    distance_lineup_area_A_to_lock_doors_A=20,
                                    distance_lineup_area_B_to_lock_doors_B=20)

# %% [markdown]
# Now we need to add a vessel

# %%
#We create a type element that schematisizes a vessel
Vessel = type('Vessel',(lock_module.HasLockComplex, #The vessel should interact with a lock chamber
                        vessel_module.IsVessel),{}) #The vessel should have output

#Using the element, we need to give the following information to the vessel
vessel = Vessel(env=env,
                name='Vessel', 
                origin='A',
                destination='C',
                type='inland vessel',
                L=100,
                B=15,
                T=5,
                H=4,
                v=4,
                arrival_time=pd.Timestamp('2024-01-01'),)

# %% [markdown]
# We can now create a process in the environment in which the vessel will move (from node A to node B)

# %%
env.process(vessel.move())
# Out:
# <Process(move) object at 0x233626dde20>

# %% [markdown]
# Run the simulation

# %%
env.run()

# %% [markdown]
# We can now analyse the logbook of the vessel

# %%
vessel_df = pd.DataFrame(vessel.logbook)
vessel_df
# Out:
#                                        Message                  Timestamp  \
# 0          Sailing from node A to node B start 2024-01-01 01:00:00.000000
# 1    Sailing to position in line-up area start 2024-01-01 01:00:00.000000
# 2     Sailing to position in line-up area stop 2024-01-01 01:00:23.333333
# 3                Waiting in line-up area start 2024-01-01 01:00:23.333333
# 4                 Waiting in line-up area stop 2024-01-01 01:25:00.000000
# 5         Sailing to end of line-up area start 2024-01-01 01:25:00.000000
# 6          Sailing to end of line-up area stop 2024-01-01 01:25:55.555556
# 7     Sailing to first set of lock doors start 2024-01-01 01:25:55.555556
# 8      Sailing to first set of lock doors stop 2024-01-01 01:26:17.777778
# 9   Sailing to assigned location in lock start 2024-01-01 01:26:17.777778
# 10   Sailing to assigned location in lock stop 2024-01-01 01:27:35.555556
# 11                          Passing lock start 2024-01-01 01:27:35.555556
# 12                           Passing lock stop 2024-01-01 01:52:35.555556
# 13   Sailing to second set of lock doors start 2024-01-01 01:52:35.555556
# 14    Sailing to second set of lock doors stop 2024-01-01 01:53:31.111111
# 15               Sailing to line-up area start 2024-01-01 01:53:31.111111
# 16                Sailing to line-up area stop 2024-01-01 01:53:36.111111
# 17                  Passing line-up area start 2024-01-01 01:53:36.111111
# 18                   Passing line-up area stop 2024-01-01 01:54:06.111111
# 19          Sailing from node A to node B stop 2024-01-01 01:54:06.111111
# 20         Sailing from node B to node C start 2024-01-01 01:54:06.111111
# 21   Sailing to position in line-up area start 2024-01-01 01:54:06.111111
# 22    Sailing to position in line-up area stop 2024-01-01 01:54:29.444444
# 23        Sailing to end of line-up area start 2024-01-01 01:54:29.444444
# 24         Sailing to end of line-up area stop 2024-01-01 01:55:25.000000
# 25    Sailing to first set of lock doors start 2024-01-01 01:55:25.000000
# 26     Sailing to first set of lock doors stop 2024-01-01 01:55:47.222222
# 27  Sailing to assigned location in lock start 2024-01-01 01:55:47.222222
# 28   Sailing to assigned location in lock stop 2024-01-01 01:57:05.000000
# 29                          Passing lock start 2024-01-01 01:57:05.000000
# 30                           Passing lock stop 2024-01-01 02:22:05.000000
# 31   Sailing to second set of lock doors start 2024-01-01 02:22:05.000000
# 32    Sailing to second set of lock doors stop 2024-01-01 02:23:00.555556
# 33               Sailing to line-up area start 2024-01-01 02:23:00.555556
# 34                Sailing to line-up area stop 2024-01-01 02:23:05.555556
# 35                  Passing line-up area start 2024-01-01 02:23:05.555556
# 36                   Passing line-up area stop 2024-01-01 02:23:35.555556
# 37          Sailing from node B to node C stop 2024-01-01 02:23:35.555556
#
#                                                 Value  \
# 0   {'origin': 'A', 'destination': 'C', 'route': [...
# 1   {'origin': 'A', 'destination': 'C', 'route': [...
# 2   {'origin': 'A', 'destination': 'C', 'route': [...
# 3   {'origin': 'A', 'destination': 'C', 'route': [...
# 4   {'origin': 'A', 'destination': 'C', 'route': [...
# 5   {'origin': 'A', 'destination': 'C', 'route': [...
# 6   {'origin': 'A', 'destination': 'C', 'route': [...
# 7   {'origin': 'A', 'destination': 'C', 'route': [...
# 8   {'origin': 'A', 'destination': 'C', 'route': [...
# 9   {'origin': 'A', 'destination': 'C', 'route': [...
# 10  {'origin': 'A', 'destination': 'C', 'route': [...
# 11  {'origin': 'A', 'destination': 'C', 'route': [...
# 12  {'origin': 'A', 'destination': 'C', 'route': [...
# 13  {'origin': 'A', 'destination': 'C', 'route': [...
# 14  {'origin': 'A', 'destination': 'C', 'route': [...
# 15  {'origin': 'A', 'destination': 'C', 'route': [...
# 16  {'origin': 'A', 'destination': 'C', 'route': [...
# 17  {'origin': 'A', 'destination': 'C', 'route': [...
# 18  {'origin': 'A', 'destination': 'C', 'route': [...
# 19  {'origin': 'A', 'destination': 'C', 'route': [...
# 20  {'origin': 'A', 'destination': 'C', 'route': [...
# 21  {'origin': 'A', 'destination': 'C', 'route': [...
# 22  {'origin': 'A', 'destination': 'C', 'route': [...
# 23  {'origin': 'A', 'destination': 'C', 'route': [...
# 24  {'origin': 'A', 'destination': 'C', 'route': [...
# 25  {'origin': 'A', 'destination': 'C', 'route': [...
# 26  {'origin': 'A', 'destination': 'C', 'route': [...
# 27  {'origin': 'A', 'destination': 'C', 'route': [...
# 28  {'origin': 'A', 'destination': 'C', 'route': [...
# 29  {'origin': 'A', 'destination': 'C', 'route': [...
# 30  {'origin': 'A', 'destination': 'C', 'route': [...
# 31  {'origin': 'A', 'destination': 'C', 'route': [...
# 32  {'origin': 'A', 'destination': 'C', 'route': [...
# 33  {'origin': 'A', 'destination': 'C', 'route': [...
# 34  {'origin': 'A', 'destination': 'C', 'route': [...
# 35  {'origin': 'A', 'destination': 'C', 'route': [...
# 36  {'origin': 'A', 'destination': 'C', 'route': [...
# 37  {'origin': 'A', 'destination': 'C', 'route': [...
#
#                                          Geometry
# 0    POINT (3.3135576329102165 47.97476588466147)
# 1    POINT (3.3135576329102165 47.97476588466147)
# 2     POINT (3.314494833675866 47.97478336001946)
# 3     POINT (3.314494833675866 47.97478336001946)
# 4     POINT (3.314494833675866 47.97478336001946)
# 5     POINT (3.314494833675866 47.97478336001946)
# 6    POINT (3.3151642631813405 47.97479583773631)
# 7    POINT (3.3151642631813405 47.97479583773631)
# 8    POINT (3.3154320350738398 47.97480082773064)
# 9    POINT (3.3154320350738398 47.97480082773064)
# 10     POINT (3.3163692371038613 47.974818287795)
# 11     POINT (3.3163692371038613 47.974818287795)
# 12     POINT (3.3163692371038613 47.974818287795)
# 13     POINT (3.3163692371038613 47.974818287795)
# 14    POINT (3.317031314168243 47.97483061766784)
# 15    POINT (3.317031314168243 47.97483061766784)
# 16   POINT (3.3172990864203618 47.97483560330969)
# 17   POINT (3.3172990864203618 47.97483560330969)
# 18   POINT (3.318905721015416 47.974865504052005)
# 19  POINT (3.3189057210154163 47.974865504052005)
# 20  POINT (3.3189057210154163 47.974865504052005)
# 21  POINT (3.3189057210154167 47.974865504052005)
# 22    POINT (3.319842925444663 47.97488293434359)
# 23    POINT (3.319842925444663 47.97488293434359)
# 24     POINT (3.320512357565996 47.9748953798701)
# 25     POINT (3.320512357565996 47.9748953798701)
# 26    POINT (3.3207801305046067 47.9749003569883)
# 27    POINT (3.3207801305046067 47.9749003569883)
# 28    POINT (3.321717336194973 47.97491777198614)
# 29    POINT (3.321717336194973 47.97491777198614)
# 30    POINT (3.321717336194973 47.97491777198614)
# 31    POINT (3.321717336194973 47.97491777198614)
# 32   POINT (3.3223794198976564 47.97493007009744)
# 33   POINT (3.3223794198976564 47.97493007009744)
# 34   POINT (3.3226471931949617 47.97493504286312)
# 35   POINT (3.3226471931949617 47.97493504286312)
# 36  POINT (3.3242538340583465 47.974964866348266)
# 37    POINT (3.324253834058346 47.97496486634826)

# %%
fig,axes = plt.subplots(1,2)
ylim = (vessel_df.iloc[0]['Timestamp'],vessel_df.iloc[-1]['Timestamp'])
lock_I.create_time_distance_diagram([vessel],ax=axes[0],x_offset=-200,accuracy=200,ylim=ylim)
lock_II.create_time_distance_diagram([vessel],ax=axes[1],x_offset=200,accuracy=200,ylim=ylim)
axes[0].set_xlabel('')
for ax in axes[1:]:
    ax.set_yticks([])
    ax.set_xlabel('')
    ax.set_ylabel('')
ylim = (vessel_df.iloc[0]['Timestamp'],vessel_df.iloc[-1]['Timestamp'])
plt.subplots_adjust(wspace=0)
fig.supxlabel('Distance [m]',fontsize=10);

# %% [markdown]
# And we can analyse the logbook of the lock

# %%
lock_df = pd.DataFrame(lock_I.logbook)
lock_df
# Out:
#                           Message                  Timestamp  \
# 0        Lock doors closing start 2024-01-01 01:00:00.000000
# 1         Lock doors closing stop 2024-01-01 01:00:00.000000
# 2   Lock chamber converting start 2024-01-01 01:00:00.000000
# 3    Lock chamber converting stop 2024-01-01 01:25:00.000000
# 4        Lock doors opening start 2024-01-01 01:25:00.000000
# 5         Lock doors opening stop 2024-01-01 01:25:00.000000
# 6        Lock doors closing start 2024-01-01 01:27:35.555556
# 7         Lock doors closing stop 2024-01-01 01:27:35.555556
# 8   Lock chamber converting start 2024-01-01 01:27:35.555556
# 9    Lock chamber converting stop 2024-01-01 01:52:35.555556
# 10       Lock doors opening start 2024-01-01 01:52:35.555556
# 11        Lock doors opening stop 2024-01-01 01:52:35.555556
#
#                                                 Value Geometry
# 0                                                  {}        B
# 1                                                  {}        B
# 2                                                  {}        B
# 3                                                  {}        A
# 4                                                  {}        A
# 5                                                  {}        A
# 6   {'visiting_vessels': [<__main__.Vessel object ...        A
# 7   {'visiting_vessels': [<__main__.Vessel object ...        A
# 8   {'visiting_vessels': [<__main__.Vessel object ...        A
# 9   {'visiting_vessels': [<__main__.Vessel object ...        B
# 10  {'visiting_vessels': [<__main__.Vessel object ...        B
# 11  {'visiting_vessels': [<__main__.Vessel object ...        B
