# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import shapely

# %%
path = "C:\\Users\\floorbakker\\Downloads\\"

# %%
subte = gpd.read_file(path+'export (73).geojson')

# %%
grass = gpd.read_file(path+'export (70).geojson')

# %%
water = gpd.read_file(path+'export (71).geojson')

# %%
highways = gpd.read_file(path+'export (69).geojson')
Julio9 = gpd.read_file(path+'export (68).geojson')

# %%
service_roads = gpd.read_file(path+'export (67).geojson')

# %%
primary_roads = gpd.read_file(path+'export (66).geojson')

# %%
secondary_roads = gpd.read_file(path+'export (65).geojson')

# %%
tertiary_roads = gpd.read_file(path+'export (64).geojson')

# %%
residential_roads = gpd.read_file(path+'export (63).geojson')

# %%
fig,ax = plt.subplots(figsize=[16,9])
ax.set_facecolor((0.9,0.9,0.9))
grass.plot(ax=ax,color='lightgreen',zorder=1)
water.plot(ax=ax,color='lightblue',zorder=1)
highways.plot(ax=ax,color='k',zorder=2,linewidth=1)
Julio9.plot(ax=ax,color='k',zorder=2)
primary_roads.plot(ax=ax,color='k',zorder=2,linewidth=0.5)
secondary_roads.plot(ax=ax,color='k',zorder=2,linewidth=0.5)
tertiary_roads.plot(ax=ax,color='k',zorder=2,linewidth=0.25)
residential_roads.plot(ax=ax,color='k',zorder=2,linewidth=0.1)

for loc,info in subte[subte['from'].isin(['Plaza de Mayo','Catedral','Retiro','Leandro N. Alem','Facultad de Derecho'])].iterrows():
    if isinstance(info.geometry,shapely.geometry.MultiLineString):
        for geometry in info.geometry.geoms:
            ax.plot(*geometry.coords.xy,color=info.colour,linewidth=2,zorder=3)
            
ax.set_xlim(-58.55,-58.30)
ax.set_ylim(-34.725,-34.50)
# Out:
# (-34.725, -34.5)

# %%
residential_road = gpd.read_file(path+'export (74).geojson')
pedestrian_road = gpd.read_file(path+'export (75).geojson')
square = gpd.read_file(path+'export (76).geojson')
unclassified_road = gpd.read_file(path+'export (77).geojson')
tertiary_road = gpd.read_file(path+'export (78).geojson')
secondary_road = gpd.read_file(path+'export (79).geojson')
primary_road = gpd.read_file(path+'export (80).geojson')
motorway_road = gpd.read_file(path+'export (81).geojson')
motorway_link_road = gpd.read_file(path+'export (82).geojson')
grassland = gpd.read_file(path+'export (83).geojson')
grass = gpd.read_file(path+'export (84).geojson')
meadow = gpd.read_file(path+'export (90).geojson')
water = gpd.read_file(path+'export (91).geojson')
rail = gpd.read_file(path+'export (92).geojson')
forest = gpd.read_file(path+'export (93).geojson')
allotments = gpd.read_file(path+'export (94).geojson')
scrub = gpd.read_file(path+'export (95).geojson')
land_nursery = gpd.read_file(path+'export (96).geojson')
caravan = gpd.read_file(path+'export (97).geojson')
wetland = gpd.read_file(path+'export (98).geojson')
park = gpd.read_file(path+'export (99).geojson')

# %%
buildings = gpd.read_file(path+'export (100).geojson')

# %%
fig,ax = plt.subplots(figsize=[16,9])
ax.set_facecolor((0.35,0.35,0.35)) #(0.75,0.75,0.75)
nature_color = (0.1,0.1,0.1) #(0.9,0.9,0.9) #'palegreen'
water_color = 'darkcyan' #'lightblue'
building_color = (0.45,0.45,0.45) #(0.5,0.5,0.5)
road_color = (0.25,0.25,0.25) #(0.6,0.6,0.6)
rail_color = (0.15,0.15,0.15) #(0.8,0.8,0.8)

grassland.plot(ax=ax,color=nature_color,zorder=1)
grass.plot(ax=ax,color=nature_color,zorder=1)
meadow.plot(ax=ax,color=nature_color,zorder=1)

forest.plot(ax=ax,color=nature_color,zorder=1,linewidth=2)
allotments.plot(ax=ax,color=nature_color,zorder=1,linewidth=2)
scrub.plot(ax=ax,color=nature_color,zorder=1,linewidth=2)
land_nursery.plot(ax=ax,color=nature_color,zorder=1,linewidth=2)
caravan.plot(ax=ax,color=nature_color,zorder=1,linewidth=2)
wetland.plot(ax=ax,color=nature_color,zorder=1,linewidth=2)
park.plot(ax=ax,color=nature_color,zorder=1,linewidth=2)

water.plot(ax=ax,color=water_color,zorder=1)
buildings.plot(ax=ax,facecolor=building_color,edgecolor=building_color,zorder=1)
residential_road.plot(ax=ax,color=road_color,zorder=1,linewidth=0.5)
pedestrian_road.plot(ax=ax,color=road_color,zorder=1,linewidth=0.5)
square.plot(ax=ax,color=road_color,zorder=1)
unclassified_road.plot(ax=ax,color=road_color,zorder=1,linewidth=0.5)
tertiary_road.plot(ax=ax,color=road_color,zorder=1,linewidth=1)
secondary_road.plot(ax=ax,color=road_color,zorder=1,linewidth=1)
primary_road.plot(ax=ax,color=road_color,zorder=1,linewidth=1)
rail.plot(ax=ax,color=rail_color,zorder=1,linewidth=2)
motorway_road.plot(ax=ax,color=road_color,zorder=1,linewidth=2)
motorway_link_road.plot(ax=ax,color=road_color,zorder=1,linewidth=2)

ax.set_xlim(4.644,4.775)
ax.set_ylim(51.99,52.06);
