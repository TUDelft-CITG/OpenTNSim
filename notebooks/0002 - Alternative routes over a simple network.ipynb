# %% [markdown]
# ## Alternative routes over a simple network
# In this notebook, we set up a basic simulation where two vessels move over a 1D network path. The network is setup as a square where each edge is 100 km long. All edges are bi-directional except one. We show how each each vessel follows a different route, because of the presence of a uni-directional edge.

# %% [markdown]
# #### 0. Import libraries

# %%
# package(s) used for creating and geo-locating the graph
import networkx as nx
from pyproj import Geod
from shapely.geometry import Point

# package(s) related to the simulation (creating the vessel, running the simulation)
import datetime
import simpy
import opentnsim
from opentnsim.core.logutils import logbook2eventtable
from opentnsim.core.plotutils import generate_vessel_gantt_chart
from opentnsim.graph import mixins as graph_module

# package(s) needed for inspecting the output
import pandas as pd


print("This notebook is executed with OpenTNSim version {}".format(opentnsim.__version__))
# Out:
# This notebook is executed with OpenTNSim version 1.3.7

# %% [markdown]
# #### 1. Define object classes

# %%
# make your preferred Vessel class out of available mix-ins.
Vessel = type(
    "Vessel", 
    (
        opentnsim.core.Identifiable, # allows to give the object a name and a random ID,
        opentnsim.core.Movable,      # allows the object to move, with a fixed speed, while logging this activity
    ), 
    {}
)

# %% [markdown]
# #### 2. Create graph
# Next we create a network (a graph) along which the vessel can move. For this case we create a square network with four nodes and four edges, each 100 km long, one of which is uni-directional.

# %%
# initialize geodetic calculator with WGS84 ellipsoid
geod = Geod(ellps="WGS84")

# %%
# starting point (longitude, latitude)
lon0, lat0 = 0, 0

# compute the other three points 100 km apart to form a square
lon1, lat1, _ = geod.fwd(lon0, lat0,  0, 100000) # North from point 0
lon2, lat2, _ = geod.fwd(lon1, lat1, 90, 100000) # East from point 1
lon3, lat3, _ = geod.fwd(lon0, lat0, 90, 100000) # East from point 0

# define nodes with their geographic coordinates
coords = {
    "0": (lon0, lat0),
    "1": (lon1, lat1),
    "2": (lon2, lat2),
    "3": (lon3, lat3),
}

# %%
# create list of edges
edges = [("0", "1"), ("1", "0"), # bi-directional edge
         ("1", "2"), ("2", "1"), # bi-directional edge
         ("2", "3"), ("3", "2"), # bi-directional edge
         ("0", "3")]             # uni-directional edge

# %%
# create a directed graph
FG = nx.DiGraph()

# add nodes
for name, coord in coords.items():
    FG.add_node(name, geometry=Point(coord[0], coord[1]))

# add edges
for edge in edges:
    FG.add_edge(edge[0], edge[1], weight=1)

# %%
graph_module.plot_graph(FG)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="acaa6334-6323-4aa5-9ccf-10d4c050128e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("acaa6334-6323-4aa5-9ccf-10d4c050128e")) {                    Plotly.newPlot(                        "acaa6334-6323-4aa5-9ccf-10d4c050128e",                        [{"hoverinfo":"none","line":{"color":"red","width":2},"mode":"lines","x":[0.0,0.0],"y":[0.0,0.9043687229127633],"type":"scatter"},{"hoverinfo":"none","line":{"color":"red","width":2},"mode":"lines","x":[0.0,0.8983152841195217],"y":[0.0,0.0],"type":"scatter"},{"hoverinfo":"none","line":{"color":"red","width":2},"mode":"lines","x":[0.0,0.0],"y":[0.9043687229127633,0.0],"type":"scatter"},{"hoverinfo":"none","line":{"color":"red","width":2},"mode":"lines","x":[0.0,0.8984264319755021],"y":[0.9043687229127633,0.9042568124693914],"type":"scatter"},{"hoverinfo":"none","line":{"color":"red","width":2},"mode":"lines","x":[0.8984264319755021,0.0],"y":[0.9042568124693914,0.9043687229127633],"type":"scatter"},{"hoverinfo":"none","line":{"color":"red","width":2},"mode":"lines","x":[0.8984264319755021,0.8983152841195217],"y":[0.9042568124693914,0.0],"type":"scatter"},{"hoverinfo":"none","line":{"color":"red","width":2},"mode":"lines","x":[0.8983152841195217,0.8984264319755021],"y":[0.0,0.9042568124693914],"type":"scatter"},{"hoverinfo":"text","marker":{"color":"darkblue","size":20},"mode":"markers+text","text":["0","1","2","3"],"textfont":{"color":"white","size":15},"textposition":"middle center","x":[0.0,0.0,0.8984264319755021,0.8983152841195217],"y":[0.0,0.9043687229127633,0.9042568124693914,0.0],"type":"scatter"}],                        {"annotations":[{"arrowcolor":"red","arrowhead":2,"arrowsize":2,"arrowwidth":1,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":0.0,"xref":"x","y":0.9043687229127633,"yref":"y"},{"arrowcolor":"red","arrowhead":2,"arrowsize":2,"arrowwidth":1,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":0.8983152841195217,"xref":"x","y":0.0,"yref":"y"},{"arrowcolor":"red","arrowhead":2,"arrowsize":2,"arrowwidth":1,"ax":0.0,"axref":"x","ay":0.9043687229127633,"ayref":"y","showarrow":true,"x":0.0,"xref":"x","y":0.0,"yref":"y"},{"arrowcolor":"red","arrowhead":2,"arrowsize":2,"arrowwidth":1,"ax":0.0,"axref":"x","ay":0.9043687229127633,"ayref":"y","showarrow":true,"x":0.8984264319755021,"xref":"x","y":0.9042568124693914,"yref":"y"},{"arrowcolor":"red","arrowhead":2,"arrowsize":2,"arrowwidth":1,"ax":0.8984264319755021,"axref":"x","ay":0.9042568124693914,"ayref":"y","showarrow":true,"x":0.0,"xref":"x","y":0.9043687229127633,"yref":"y"},{"arrowcolor":"red","arrowhead":2,"arrowsize":2,"arrowwidth":1,"ax":0.8984264319755021,"axref":"x","ay":0.9042568124693914,"ayref":"y","showarrow":true,"x":0.8983152841195217,"xref":"x","y":0.0,"yref":"y"},{"arrowcolor":"red","arrowhead":2,"arrowsize":2,"arrowwidth":1,"ax":0.8983152841195217,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":0.8984264319755021,"xref":"x","y":0.9042568124693914,"yref":"y"},{"font":{"color":"black","size":15},"showarrow":false,"text":"99999 m","x":0.0,"y":0.45218436145638163},{"font":{"color":"black","size":15},"showarrow":false,"text":"100000 m","x":0.44915764205976083,"y":0.0},{"font":{"color":"black","size":15},"showarrow":false,"text":"99999 m","x":0.0,"y":0.45218436145638163},{"font":{"color":"black","size":15},"showarrow":false,"text":"100000 m","x":0.44921321598775105,"y":0.9043127676910774},{"font":{"color":"black","size":15},"showarrow":false,"text":"100000 m","x":0.44921321598775105,"y":0.9043127676910774},{"font":{"color":"black","size":15},"showarrow":false,"text":"99987 m","x":0.8983708580475118,"y":0.45212 ...

# %% [markdown]
# #### 3. Run simulation

# %%
# Step 1: Create environment
simulation_start = datetime.datetime(2024, 1, 1, 0, 0, 0)
env = simpy.Environment(initial_time=simulation_start.timestamp())
env.epoch = simulation_start

# Step 2: Assign graph to environment
env.graph = FG

# Step 3: Define routes (always use env.graph after assignment)
path_1 = nx.dijkstra_path(env.graph, "0", "3")
path_2 = nx.dijkstra_path(env.graph, "3", "0")
paths = [path_1, path_2]

# Step 4: Create vessels from dict
vessels = []

for index, path in enumerate(paths):
    data_vessel = {
        "env": env,                                       # needed for simpy simulation
        "name": "Vessel_on_Path_{}".format(index),        # required by Identifiable
        "geometry": env.graph.nodes[path[0]]['geometry'], # required by Locatable
        "route": path,                                    # required by Routeable
        "v": 1,                                           # required by Movable, 1 m/s to verify distance and travel time
    }
    vessel = Vessel(**data_vessel)
    vessels.append(vessel)

# Step 5: Start processes and run simulation
for vessel in vessels:
    env.process(vessel.execute_vessel_mission())

env.run()

# %% [markdown]
# #### 4. Inspect output
# We can now inspect  the simulation output by inspecting the _vessel.logbook_. Note that the _Log_ mix-in was included when we added _Movable_. The _vessel.logbook_ keeps track of the moving activities of the vessel. For each discrete event OpenTNSim logs an event message, the start/stop time and the location. The _vessel.logbook_ is of type dict. For convenient inspection it can be loaded into a Pandas dataframe.

# %%
for vessel in vessels:
    # load the logbook data into a dataframe
    df = pd.DataFrame.from_dict(vessel.logbook)
    
    print("'{}' logbook data:".format(vessel.name))  
    display(df)

    trip_distance = graph_module.calculate_distance_along_path(FG, vessel.route)
    trip_duration = datetime.timedelta.total_seconds(vessel.logbook[-1]['Timestamp'] - vessel.logbook[0]['Timestamp'])

    print("'{}' travelled a distance of {:.1f} meters".format(vessel.name, trip_distance))
    print("'{}' took {:.1f} seconds to arrive at its destination".format(vessel.name, trip_duration))  
    print("'{}' travelled at an average speed of {:.1f} meters per second".format(vessel.name, trip_distance/trip_duration))
# Out:
# 'Vessel_on_Path_0' logbook data:
#                                Message           Timestamp     Value  \
# 0  Sailing from node 0 to node 3 start 2024-01-01 00:00:00       0.0
# 1   Sailing from node 0 to node 3 stop 2024-01-02 03:46:40  100000.0
#
#                        Geometry
# 0                   POINT (0 0)
# 1  POINT (0.8983152841195217 0)
# 'Vessel_on_Path_0' travelled a distance of 100000.0 meters
# 'Vessel_on_Path_0' took 100000.0 seconds to arrive at its destination
# 'Vessel_on_Path_0' travelled at an average speed of 1.0 meters per second
# 'Vessel_on_Path_1' logbook data:
#                                Message                  Timestamp  \
# 0  Sailing from node 3 to node 2 start 2024-01-01 00:00:00.000000
# 1   Sailing from node 3 to node 2 stop 2024-01-02 03:57:41.408671
# 2  Sailing from node 2 to node 1 start 2024-01-02 03:57:41.408671
# 3   Sailing from node 2 to node 1 stop 2024-01-03 07:44:33.782370
# 4  Sailing from node 1 to node 0 start 2024-01-03 07:44:33.782370
# 5   Sailing from node 1 to node 0 stop 2024-01-04 11:42:27.648094
#
#            Value                                       Geometry
# 0       0.000000                   POINT (0.8983152841195217 0)
# 1  100661.408671  POINT (0.8984264319755021 0.9042568124693914)
# 2  100661.408671  POINT (0.8984264319755021 0.9042568124693914)
# 3  200673.782369                   POINT (0 0.9043687229127633)
# 4  200673.782369                   POINT (0 0.9043687229127633)
# 5  301347.648093                                    POINT (0 0)
# 'Vessel_on_Path_1' travelled a distance of 299987.6 meters
# 'Vessel_on_Path_1' took 301347.6 seconds to arrive at its destination
# 'Vessel_on_Path_1' travelled at an average speed of 1.0 meters per second

# %% [markdown]
# The inspection of the logbook data shows that the first vessel moved from its origin (*Node 0*) directly to its destination (*Node 3*). The second vessel moved from its origin (*Node 3*) to its destination (*Node 0*), but while doing so was passing *Node 2* and *Node 1* in the process. This show that indeed the edge between *Node 0* and *Node 3* is uni-directional.
#
# The print statements show that the length of the route from *Node 3* to *Node 3* is not exactly 300 km. This is primarily due to the fact that Edge '0 - 1' and Edge '2 - 3' are not exactly 100 km (see also the graph plot above). This is one of the issues that can occur when using coordinate projections.

# %%
df_eventtable = logbook2eventtable(vessels)
df_eventtable
# Out:
#                               object id       object name  \
# 0  1f017924-028b-48f6-b2a6-f956ae830df3  Vessel_on_Path_0
# 1  0e4e5d59-9c5b-4ca6-98a0-057092083842  Vessel_on_Path_1
# 2  0e4e5d59-9c5b-4ca6-98a0-057092083842  Vessel_on_Path_1
# 3  0e4e5d59-9c5b-4ca6-98a0-057092083842  Vessel_on_Path_1
#
#                    activity name  \
# 0  Sailing from node 0 to node 3
# 1  Sailing from node 3 to node 2
# 2  Sailing from node 2 to node 1
# 3  Sailing from node 1 to node 0
#
#                                   start location  \
# 0                                    POINT (0 0)
# 1                   POINT (0.8983152841195217 0)
# 2  POINT (0.8984264319755021 0.9042568124693914)
# 3                   POINT (0 0.9043687229127633)
#
#                                    stop location                 start time  \
# 0                   POINT (0.8983152841195217 0) 2024-01-01 00:00:00.000000
# 1  POINT (0.8984264319755021 0.9042568124693914) 2024-01-01 00:00:00.000000
# 2                   POINT (0 0.9043687229127633) 2024-01-02 03:57:41.408671
# 3                                    POINT (0 0) 2024-01-03 07:44:33.782370
#
#                    stop time   distance (m)   duration (s)
# 0 2024-01-02 03:46:40.000000  100000.000000  100000.000000
# 1 2024-01-02 03:57:41.408671   99987.626318  100661.408671
# 2 2024-01-03 07:44:33.782370  100000.000000  100012.373699
# 3 2024-01-04 11:42:27.648094  100000.000000  100673.865724

# %%
generate_vessel_gantt_chart(df_eventtable)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="3420b761-3537-4561-b168-5395bcec1842" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3420b761-3537-4561-b168-5395bcec1842")) {                    Plotly.newPlot(                        "3420b761-3537-4561-b168-5395bcec1842",                        [{"base":["2024-01-01T00:00:00.000000000"],"hovertemplate":"object name=Vessel_on_Path_0\u003cbr\u003estart time=%{base}\u003cbr\u003estop time=%{x}\u003cbr\u003eactivity label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Vessel_on_Path_0","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Vessel_on_Path_0","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"i4","bdata":"AOH1BQ=="},"xaxis":"x","y":["Vessel_on_Path_0 - Sailing from node 0 to node 3"],"yaxis":"y","type":"bar"},{"base":["2024-01-01T00:00:00.000000000","2024-01-02T03:57:41.408671000","2024-01-03T07:44:33.782370000"],"hovertemplate":"object name=Vessel_on_Path_1\u003cbr\u003estart time=%{base}\u003cbr\u003estop time=%{x}\u003cbr\u003eactivity label=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Vessel_on_Path_1","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Vessel_on_Path_1","orientation":"h","showlegend":true,"textposition":"auto","x":{"dtype":"i4","bdata":"oPj\u002fBVUR9gVJKQAG"},"xaxis":"x","y":["Vessel_on_Path_1 - Sailing from node 3 to node 2","Vessel_on_Path_1 - Sailing from node 2 to node 1","Vessel_on_Path_1 - Sailing from node 1 to node 0"],"yaxis":"y","type":"bar"}],                        {"barmode":"overlay","legend":{"title":{"text":"Vessel"},"tracegroupgap":0},"margin":{"b":20,"l":20,"r":20,"t":40},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"] ...
