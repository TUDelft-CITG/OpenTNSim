# %% [markdown]
# # water depth 6-6-6 -fixed speed&power-fuel&emission

# %% [markdown]
# #### Unrestricted waterway: h=6m, distance=300km; max loading with actual draft= 3.5m, payload=2500ton
# #### Same vessel:  M8, L* B * T=110* 11.4* 3.5, DWT=3000ton; construction year=1990
# #### assume that the ship maintains constant speed to water Vs=3,3.5,4,4.5m/s
# #### or maintain constant partial engine load(power):0.1(175kw),0.3(525kw),0.5(875kw),0.75(1312.5kw),0.9(1575kw)
# ## figure output:
# ###### water depth
# ###### actrual draft
# ###### payload
# ###### diesel consumption (kg/km),Vs=3,3.5,4,4.5m/s,Partial=0.1,0.3,0.5,0.75,0.9
# ###### emission rate (g/km),Vs=3,3.5,4,4.5m/s,Partial=0.1,0.3,0.5,0.75,0.9

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math 
import plotly.express as px
from plotly.subplots import make_subplots

# %%
fig, axs = plt.subplots(7, 1, figsize=(12, 19), constrained_layout=True)
fontsize=20
plt.subplot(711)

dist=([0,100,100,200,200,300])
h=([6,6,6,6,6,6])
plt.plot(dist, h,'k')
plt.ylabel('water depth (m)')

plt.subplot(712)
dist=([0,100,100,200,200,300])
adft=([3.5,3.5,3.5,3.5,3.5,3.5])
plt.plot(dist, adft,'k')
plt.ylabel('actual draft (m)')

plt.subplot(713)
dist=([0,100,100,200,200,300])
payload=([2500,2500,2500,2500,2500,2500])
plt.plot(dist, payload,'k')
plt.ylabel('payload (ton)')

ax=plt.subplot(714)
dist=([0,100,100,200,200,300])
diesel_v1=([6.57,6.57,6.57,6.57,6.57,6.57,])
diesel_v2=([7.88,7.88,7.88,7.88,7.88,7.88,])
diesel_v3=([10.7,10.7,10.7,10.7,10.7,10.7,])
diesel_v4=([17.64,17.64,17.64,17.64,17.64,17.64,])
diesel_pr1=([5.54,5.54,5.54,5.54,5.54,5.54,])
diesel_pr2=([9.36,9.36,9.36,9.36,9.36,9.36,])
diesel_pr3=([13.12,13.12,13.12,13.12,13.12,13.12,])
diesel_pr4=([17.8,17.8,17.8,17.8,17.8,17.8,])
diesel_pr5=([21.05,21.05,21.05,21.05,21.05,21.05,])
plt.plot(dist, diesel_v1,':',color='#b7e1a1',linewidth='2',label='Vs=3 m/s')
plt.plot(dist, diesel_v2,':',color='#a6c875',linewidth='2',label='Vs=3.5 m/s')
plt.plot(dist, diesel_v3,':',color='#c2b709',linewidth='2',label='Vs=4 m/s')
plt.plot(dist, diesel_v4,':',color='#9bb53c',linewidth='2.5',label='Vs=4.5 m/s')
plt.plot(dist, diesel_pr1,color='#ccad60',linewidth='2',label='Partial engine load = 10%')
plt.plot(dist, diesel_pr2,color='#ad900d',linewidth='2',label='Partial engine load = 30%')
plt.plot(dist, diesel_pr3,color='#7d7103',linewidth='2',label='Partial engine load = 50%')
plt.plot(dist, diesel_pr4,color='#8e7618',linewidth='2',label='Partial engine load = 75%')
plt.plot(dist, diesel_pr5,color='#7f684e',linewidth='2',label='Partial engine load = 90%')
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylim(0, 25)
plt.ylabel('fuel consumption (kg/km)')


ax=plt.subplot(715)
dist=([0,100,100,200,200,300])
EMrCO2_v1=([20836,20836,20836,20836,20836,20836,])
EMrCO2_v2=([25011,25011,25011,25011,25011,25011,])
EMrCO2_v3=([33956,33956,33956,33956,33956,33956,])
EMrCO2_v4=([55973,55973,55973,55973,55973,55973,])
EMrCO2_pr1=([17563,17563,17563,17563,17563,17563,])
EMrCO2_pr2=([29696,29696,29696,29696,29696,29696,])
EMrCO2_pr3=([41642,41642,41642,41642,41642,41642,])
EMrCO2_pr4=([56483,56483,56483,56483,56483,56483,])
EMrCO2_pr5=([66773,66773,66773,66773,66773,66773,])
plt.plot(dist, EMrCO2_v1,':',color='#fffd37',linewidth='2',label='Vs=3 m/s')
plt.plot(dist, EMrCO2_v2,':',color='#ffab0f',linewidth='2',label='Vs=3.5 m/s')
plt.plot(dist, EMrCO2_v3,':',color='#fe4b03',linewidth='2',label='Vs=4 m/s')
plt.plot(dist, EMrCO2_v4,':',color='#ff724c',linewidth='2.5',label='Vs=4.5 m/s')
plt.plot(dist, EMrCO2_pr1,color='#ffb07c',linewidth='2',label='Partial engine load = 10%')
plt.plot(dist, EMrCO2_pr2,color='#ff796c',linewidth='2',label='Partial engine load = 30%')
plt.plot(dist, EMrCO2_pr3,color='#f4320c',linewidth='2',label='Partial engine load = 50%')
plt.plot(dist, EMrCO2_pr4,color='#e50000',linewidth='2',label='Partial engine load = 75%')
plt.plot(dist, EMrCO2_pr5,color='#ab1239',linewidth='2',label='Partial engine load = 90%')
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('CO2 emission rate (g/km)')
plt.ylim(0, 80000)

ax=plt.subplot(716)
dist=([0,100,100,200,200,300])
EMrPM10_v1=([13.23,13.23,13.23,13.23,13.23,13.23,])
EMrPM10_v2=([14.5,14.5,14.5,14.5,14.5,14.5,])
EMrPM10_v3=([18.74,18.74,18.74,18.74,18.74,18.74,])
EMrPM10_v4=([31.44,31.44,31.44,31.44,31.44,31.44,])
EMrPM10_pr1=([13.53,13.53,13.53,13.53,13.53,13.53,])
EMrPM10_pr2=([16.56,16.56,16.56,16.56,16.56,16.56,])
EMrPM10_pr3=([23.17,23.17,23.17,23.17,23.17,23.17,])
EMrPM10_pr4=([31.72,31.72,31.72,31.72,31.72,31.72,])
EMrPM10_pr5=([36.75,36.75,36.75,36.75,36.75,36.75,])
plt.plot(dist, EMrPM10_v1,':',color='#d4ffff',linewidth='2',label='Vs=3 m/s')
plt.plot(dist, EMrPM10_v2,':',color='#41fdfe',linewidth='2',label='Vs=3.5 m/s')
plt.plot(dist, EMrPM10_v3,':',color='#6dedfd',linewidth='2',label='Vs=4 m/s')
plt.plot(dist, EMrPM10_v4,':',color='#02ccfe',linewidth='2.5',label='Vs=4.5 m/s')
plt.plot(dist, EMrPM10_pr1,color='#acc2d9',linewidth='2',label='Partial engine load = 10%')
plt.plot(dist, EMrPM10_pr2,color='#8ab8fe',linewidth='2',label='Partial engine load = 30%')
plt.plot(dist, EMrPM10_pr3,color='#0d75f8',linewidth='2',label='Partial engine load = 50%')
plt.plot(dist, EMrPM10_pr4,color='#056eee',linewidth='2',label='Partial engine load = 75%')
plt.plot(dist, EMrPM10_pr5,color='#014182',linewidth='2',label='Partial engine load = 90%')
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('PM10 emission rate (g/km)')
plt.ylim(0, 50)

ax=plt.subplot(717)
dist=([0,100,100,200,200,300])
EMrNOx_v1=([297.57,297.57,297.57,297.57,297.57,297.57,])
EMrNOx_v2=([342.67,342.67,342.67,342.67,342.67,342.67,])
EMrNOx_v3=([465.91,465.91,465.91,465.91,465.91,465.91,])
EMrNOx_v4=([792.31,792.31,792.31,792.31,792.31,792.31,])
EMrNOx_pr1=([281.12,281.12,281.12,281.12,281.12,281.12,])
EMrNOx_pr2=([402.63,402.63,402.63,402.63,402.63,402.63,])
EMrNOx_pr3=([579.38,579.38,579.38,579.38,579.38,579.38,])
EMrNOx_pr4=([800.89,800.89,800.89,800.89,800.89,800.89,])
EMrNOx_pr5=([927.88,927.88,927.88,927.88,927.88,927.88,])
plt.plot(dist, EMrNOx_v1,':',color='#fe83cc',linewidth='2',label='Vs=3 m/s')
plt.plot(dist, EMrNOx_v2,':',color='#fe46a5',linewidth='2',label='Vs=3.5 m/s')
plt.plot(dist, EMrNOx_v3,':',color='#ff08e8',linewidth='2',label='Vs=4 m/s')
plt.plot(dist, EMrNOx_v4,':',color='#fe02a2',linewidth='2.5',label='Vs=4.5 m/s')
plt.plot(dist, EMrNOx_pr1,color='#f6cefc',linewidth='2',label='Partial engine load = 10%')
plt.plot(dist, EMrNOx_pr2,color='#dd85d7',linewidth='2',label='Partial engine load = 30%')
plt.plot(dist, EMrNOx_pr3,color='#c071fe',linewidth='2',label='Partial engine load = 50%')
plt.plot(dist, EMrNOx_pr4,color='#ad03de',linewidth='2',label='Partial engine load = 75%')
plt.plot(dist, EMrNOx_pr5,color='#751973',linewidth='2',label='Partial engine load = 90%')
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('NOx emission rate (g/km)')
plt.xlabel('distance (km)')
plt.ylim(0, 1200)
# Out:
# (0.0, 1200.0)

# %%
fig, axs = plt.subplots(7, 1, figsize=(12, 19), constrained_layout=True)
fontsize=20
dist=([0,100,100,200,200,300])
ax=plt.subplot(711)
# sketch = pd.DataFrame({
#     'bedlevel': [1, 1, 1, 1, 1, 1],
#     'water_bottom': [1.4, 1.4 ,1.4, 1.4,1.4, 1.4],
#     'draught':[0.02,0.02,0.02,0.02,0.02,0.02,],
#     'water_top': [3.5, 3.5,3.5,3.5 ,3.5, 3.5 ],
#     })

# sketch.plot.area()                       


dist=([0,100,100,200,200,300])
h=([6,6,6,6,6,6])
plt.plot(dist, h,'k')
plt.ylabel('water depth (m)')

plt.subplot(712)
dist=([0,100,100,200,200,300])
adft=([3.5,3.5,3.5,3.5,3.5,3.5])
plt.plot(dist, adft,'k')
plt.ylabel('actual draft (m)')

plt.subplot(713)
dist=([0,100,100,200,200,300])
payload=([2500,2500,2500,2500,2500,2500])
plt.plot(dist, payload,'k')
plt.ylabel('payload (ton)')

ax=plt.subplot(714)
dist=([0,100,100,200,200,300])
diesel_v1=([6.57,6.57,6.57,6.57,6.57,6.57,])
diesel_v2=([7.88,7.88,7.88,7.88,7.88,7.88,])
diesel_v3=([10.7,10.7,10.7,10.7,10.7,10.7,])

plt.plot(dist, diesel_v1,color='#b7e1a1',linewidth='2',label='V=3 m/s,P=274kW')
plt.plot(dist, diesel_v2,color='#a6c875',linewidth='2',label='V=3.5 m/s,P=396kW')
plt.plot(dist, diesel_v3,color='#c2b709',linewidth='2',label='V=4 m/s,P=647kW')


# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylim(0, 25)
plt.ylabel('fuel consumption (kg/km)')


ax=plt.subplot(715)
dist=([0,100,100,200,200,300])
EMrCO2_v1=([20836,20836,20836,20836,20836,20836,])
EMrCO2_v2=([25011,25011,25011,25011,25011,25011,])
EMrCO2_v3=([33956,33956,33956,33956,33956,33956,])

plt.plot(dist, EMrCO2_v1,color='#fffd37',linewidth='2',label='Vs=3 m/s,P=274kW')
plt.plot(dist, EMrCO2_v2,color='#ffab0f',linewidth='2',label='Vs=3.5 m/s,P=396kW')
plt.plot(dist, EMrCO2_v3,color='#fe4b03',linewidth='2',label='Vs=4 m/s,P=647kW')

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('CO2 emission rate (g/km)')
plt.ylim(0, 80000)

ax=plt.subplot(716)
dist=([0,100,100,200,200,300])
EMrPM10_v1=([13.23,13.23,13.23,13.23,13.23,13.23,])
EMrPM10_v2=([14.5,14.5,14.5,14.5,14.5,14.5,])
EMrPM10_v3=([18.74,18.74,18.74,18.74,18.74,18.74,])

plt.plot(dist, EMrPM10_v1,color='#d4ffff',linewidth='2',label='Vs=3 m/s,P=274kW')
plt.plot(dist, EMrPM10_v2,color='#41fdfe',linewidth='2',label='Vs=3.5 m/s,P=396kW')
plt.plot(dist, EMrPM10_v3,color='#6dedfd',linewidth='2',label='Vs=4 m/s,P=647kW')

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('PM10 emission rate (g/km)')
plt.ylim(0, 50)

ax=plt.subplot(717)
dist=([0,100,100,200,200,300])
EMrNOx_v1=([297.57,297.57,297.57,297.57,297.57,297.57,])
EMrNOx_v2=([342.67,342.67,342.67,342.67,342.67,342.67,])
EMrNOx_v3=([465.91,465.91,465.91,465.91,465.91,465.91,])

plt.plot(dist, EMrNOx_v1,color='#fe83cc',linewidth='2',label='Vs=3 m/s,P=274kW')
plt.plot(dist, EMrNOx_v2,color='#fe46a5',linewidth='2',label='Vs=3.5 m/s,P=396kW')
plt.plot(dist, EMrNOx_v3,color='#ff08e8',linewidth='2',label='Vs=4 m/s,P=647kW')

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('NOx emission rate (g/km)')
plt.xlabel('distance (km)')
plt.ylim(0, 1200)
# Out:
# (0.0, 1200.0)

# %%
fig, axs = plt.subplots(5, 1, figsize=(8, 10), sharex=True,constrained_layout=True)
fontsize=15
ax=plt.subplot(511)

dist=[0,100,100,200,200,300]
water_level=[2.5,2.5,2.5,2.5,2.5,2.5,]
bed_level=[1,1,1,1,1,1]
draft=[3.5,3.5,3.5,3.5,3.5,3.5,]

# Basic stacked area chart.
plt.stackplot(dist,bed_level,water_level,draft, labels=['bed','water','actural draught'],colors=['#7f7053','#75bbfd','#95d0fc'])
#plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.plot(dist,draft,'k')
plt.ylabel('Longitudinal section \n of the waterway',fontsize=12,fontweight='bold')
plt.xlim(0, 300)
plt.ylim(0, 13)
plt.xticks( weight = 'bold')
plt.yticks([1,3.5,7], weight = 'bold')
ax.legend(loc='upper left')

ax=plt.subplot(512)

dist=([0,100,100,200,200,300])
diesel_v1=([6.57,6.57,6.57,6.57,6.57,6.57,])
diesel_v2=([7.88,7.88,7.88,7.88,7.88,7.88,])
diesel_v3=([10.7,10.7,10.7,10.7,10.7,10.7,])

plt.plot(dist, diesel_v1,color='#b7e1a1',linewidth='2',label='V=3 m/s,P=274kW')
plt.plot(dist, diesel_v2,color='#a6c875',linewidth='2',label='V=3.5 m/s,P=396kW')
plt.plot(dist, diesel_v3,color='#c2b709',linewidth='2',label='V=4 m/s,P=647kW')

plt.ylabel('Fuel consumption \n (kg/km)',fontsize=12,fontweight='bold')
plt.ylim(0, 25)
plt.xlim(0, 300)
plt.xticks( weight = 'bold')
plt.yticks( weight = 'bold')
ax.legend(loc='upper left')


ax=plt.subplot(513)
ax.legend(loc='upper left')
dist=([0,100,100,200,200,300])
EMrCO2_v1=([20836,20836,20836,20836,20836,20836,])
EMrCO2_v2=([25011,25011,25011,25011,25011,25011,])
EMrCO2_v3=([33956,33956,33956,33956,33956,33956,])

plt.plot(dist, EMrCO2_v1,color='#fffd37',linewidth='2',label='Vs=3 m/s,P=274kW')
plt.plot(dist, EMrCO2_v2,color='#ffab0f',linewidth='2',label='Vs=3.5 m/s,P=396kW')
plt.plot(dist, EMrCO2_v3,color='#fe4b03',linewidth='2',label='Vs=4 m/s,P=647kW')


# Put a legend to the right of the current axis
ax.legend(loc='upper left')
plt.ylabel('CO2 emission rate \n (g/km)',fontsize=12,fontweight='bold')
plt.ylim(0, 80000)
plt.xlim(0, 300)
plt.xticks( weight = 'bold')
plt.yticks( weight = 'bold')


ax=plt.subplot(514)
dist=([0,100,100,200,200,300])
EMrPM10_v1=([13.23,13.23,13.23,13.23,13.23,13.23,])
EMrPM10_v2=([14.5,14.5,14.5,14.5,14.5,14.5,])
EMrPM10_v3=([18.74,18.74,18.74,18.74,18.74,18.74,])

plt.plot(dist, EMrPM10_v1,color='#d4ffff',linewidth='2',label='Vs=3 m/s,P=274kW')
plt.plot(dist, EMrPM10_v2,color='#41fdfe',linewidth='2',label='Vs=3.5 m/s,P=396kW')
plt.plot(dist, EMrPM10_v3,color='#6dedfd',linewidth='2',label='Vs=4 m/s,P=647kW')

ax.legend(loc='upper left')
# Put a legend to the right of the current axis
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('PM10 emission rate \n (g/km)',fontsize=12,fontweight='bold')
plt.ylim(0, 50)
plt.xlim(0, 300)
plt.xticks( weight = 'bold')
plt.yticks( weight = 'bold')
ax=plt.subplot(515)

dist=([0,100,100,200,200,300])
EMrNOx_v1=([297.57,297.57,297.57,297.57,297.57,297.57,])
EMrNOx_v2=([342.67,342.67,342.67,342.67,342.67,342.67,])
EMrNOx_v3=([465.91,465.91,465.91,465.91,465.91,465.91,])

plt.plot(dist, EMrNOx_v1,color='#fe83cc',linewidth='2',label='Vs=3 m/s,P=274kW')
plt.plot(dist, EMrNOx_v2,color='#fe46a5',linewidth='2',label='Vs=3.5 m/s,P=396kW')
plt.plot(dist, EMrNOx_v3,color='#ff08e8',linewidth='2',label='Vs=4 m/s,P=647kW')

ax.legend(loc='upper left')
# Put a legend to the right of the current axis
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.ylabel('NOx emission rate \n (g/km)',fontsize=12,fontweight='bold')
plt.xlabel('distance (km)',fontsize=12,fontweight='bold')
plt.ylim(0, 1200)
plt.xlim(0, 300)
plt.xticks([0,100,200,300], weight = 'bold')
plt.yticks( weight = 'bold')
plt.savefig('6-6-6-fix speed or power', dpi=600, format='png')
# Out:
# No handles with labels found to put in legend.
